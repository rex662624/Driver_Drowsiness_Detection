# %%
import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset'

files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if ".avi" in file:
            files.append(os.path.join(r, file))
        
for f in files:
    print(f)
np.array(files).shape
# Out:
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\nonsleepyCombination.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\sleepyCombination.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\slowBlinkWithNodding.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\yawning.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\nonsleepyCombination.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\sleepyCombination.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\slowBlinkWithNodding.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\yawning.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\nonsleepyCombination.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\sleepyCombination.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\slowBlinkWithNodding.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\yawning.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\nonsleepyCombination.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\sleepyCombination.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\slowBlinkWithNodding.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\yawning.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\nonsleepyCombination.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\sleepyCombination.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\slowBlinkWithNodding.avi
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\yawning.avi
# (20,)

# %%
Statelist=['nonsleepyCombination','sleepyCombination','slowBlinkWithNodding','yawning']
for i in range(4):
    print(files[i][55:58])
    print(files[i][67:-4])
    print(files[i][54:-4])
    print('----')
# Out:
# 001
# nonsleepyCombination
# \001\glasses\nonsleepyCombination
# ----
# 001
# sleepyCombination
# \001\glasses\sleepyCombination
# ----
# 001
# slowBlinkWithNodding
# \001\glasses\slowBlinkWithNodding
# ----
# 001
# yawning
# \001\glasses\yawning
# ----

# %% [markdown]
# ## MTCNN
#
# if face not detected in 60 frames, use the last detected

# %%
from mtcnn.mtcnn import MTCNN
# import the necessary packages
from imutils import face_utils
import dlib
import cv2
import numpy as np
import os
from operator import itemgetter
import time

eyes_width = 90
eyes_height = 50
mouth_width = 75
mouth_height = 50
face_width = 105
face_height = 125
num_classes = 2
channel = 1



def CreateFolder(name):
    try:
        # creating a folder named data 
        if not os.path.exists(name):
            os.makedirs(name)
        # if not created then raise error 
    except OSError: 
        print ('Error: Creating directory of data')            
#==============================================================

detector = MTCNN()

for filename in files:
    
    #==========================
    f = open('droplist.txt','a')
    f.write(filename+"\n")
    f.close()
    #==========================
    # img = cv2.imread("me.jpg")
    
    #filename = '.\\Dataset\\Training_Evaluation_Dataset\\Training Dataset\\001\\glasses\\yawning.avi'

    print(filename)
    cap = cv2.VideoCapture(filename)
    #================================================================ create new folder

    DefaultPath = '.\\Dataset\\Training_Evaluation_Dataset\\Training Image\\'+filename[54:-4]+"\\"
    CreateFolder(DefaultPath+"face")
    CreateFolder(DefaultPath+"eyes")
    CreateFolder(DefaultPath+"mouth")
    #================================================================
    Face_ImageDataList = []

    currentframe = 0
    missing_frame = 0
    DropList = []

    eyes_w = eyes_width
    eyes_h = eyes_height
    face_w = face_width
    face_h = face_height
    mouth_w = mouth_width
    mouth_h = mouth_height
    length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print(length)
    x,y,w,h = 0,0,0,0
    
    while(cap.isOpened()):
        
        currentframe += 1
        # load the input image and convert it to grayscale
        ret, image = cap.read()
        if (not ret):
          break
        
        start_time = time.time()
        

        
        #3 frame sample once
        if(currentframe%3!=0):
            continue
        
        #if(currentframe<2200):
        #    continue
        

        height,width = image.shape[:2]
        #gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        #image = cv2.resize(image,(width//2,height//2),interpolation=cv2.INTER_CUBIC)
        #print(image.shape[:2])
        faces = detector.detect_faces(image)
        #print(np.array(faces).shape[0])
        
        if(np.array(faces).shape[0] > 0):
            face = faces[0]
            x,y,w,h = face['box']
            
            face_image = image[max(0,y):max(0,y+h),max(0,x):max(0,x+w)]
            #print(face_image.shape)
            #print(face_image.shape)
            #print(image[x:x+w,y:y+h])
            #cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)
            face_image = cv2.resize(face_image,(face_w,face_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "face\\frame" + str(currentframe) + '.jpg',face_image) 


            eyes_image = image[max(0,face['keypoints']['left_eye'][1]-int(h*0.2)):max(0,face['keypoints']['right_eye'][1]+int(h*0.2))
                                ,max(0,face['keypoints']['left_eye'][0]-int(w*0.2)):max(0,face['keypoints']['right_eye'][0]+int(w*0.2))]
            
            #cv2.rectangle(image, (face['keypoints']['left_eye'][0]-int(w*0.2), face['keypoints']['left_eye'][1]-int(h*0.2)),
            #              (face['keypoints']['right_eye'][0]+int(w*0.2), face['keypoints']['right_eye'][1]+int(h*0.2)),(0, 255, 0),2)
            eyes_image = cv2.resize(eyes_image,(eyes_w,eyes_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "eyes\\frame" + str(currentframe) + '.jpg',eyes_image) 


            mouth_image = image[max(0,face['keypoints']['mouth_left'][1]-int(h*0.2)):max(0,face['keypoints']['mouth_right'][1]+int(h*0.2))
                               ,max(0,face['keypoints']['mouth_left'][0]-int(w*0.2)):max(0,face['keypoints']['mouth_right'][0]+int(w*0.2))]
            #cv2.rectangle(image, (face['keypoints']['mouth_left'][0]-int(w*0.2), face['keypoints']['mouth_left'][1]-int(h*0.2)),
            #              (face['keypoints']['mouth_right'][0]+int(w*0.2), face['keypoints']['mouth_right'][1]+int(h*0.2)),(0, 255, 0),2)
            mouth_image = cv2.resize(mouth_image,(mouth_w,mouth_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "mouth\\frame" + str(currentframe) + '.jpg',mouth_image) 



            #cv2.rectangle(image, (face['keypoints']['left_eye'][0], face['keypoints']['left_eye'][1]), 2, (0, 255, 0), -1)


            #cv2.circle(image, (face['keypoints']['left_eye'][0], face['keypoints']['left_eye'][1]), 2, (0, 255, 0), -1)
            #cv2.circle(image, (face['keypoints']['right_eye'][0], face['keypoints']['right_eye'][1]), 2, (0, 255, 0), -1)
            #cv2.circle(image, (face['keypoints']['nose'][0], face['keypoints']['nose'][1]), 2, (0, 255, 0), -1)
            #cv2.circle(image, (face['keypoints']['mouth_left'][0], face['keypoints']['mouth_left'][1]), 2, (0, 255, 0), -1)
            #cv2.circle(image, (face['keypoints']['mouth_right'][0], face['keypoints']['mouth_right'][1]), 2, (0, 255, 0), -1)
            if(currentframe%100==0):        
                name = './data/frame' + str(currentframe) + '.jpg'
                print ('Creating...' + name) 
        elif (missing_frame<60 and (not((x == 0) or (y == 0) or (w == 0) or (h == 0) ))):
            print ('missing using last frame') 
            missing_frame = missing_frame + 1        

            face_image = image[max(0,y):max(0,y+h),max(0,x):max(0,x+w)]
            print(y)
            print(y+h)
            print(x)
            print(x+w)
            #print(image[x:x+w,y:y+h])
            #cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)
            face_image = cv2.resize(face_image,(face_w,face_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "face\\frame" + str(currentframe) + '.jpg',face_image) 


            eyes_image = image[max(0,face['keypoints']['left_eye'][1]-int(h*0.2)):max(0,face['keypoints']['right_eye'][1]+int(h*0.2))
                                ,max(0,face['keypoints']['left_eye'][0]-int(w*0.2)):max(0,face['keypoints']['right_eye'][0]+int(w*0.2))]
            #cv2.rectangle(image, (face['keypoints']['left_eye'][0]-int(w*0.2), face['keypoints']['left_eye'][1]-int(h*0.2)),
            #              (face['keypoints']['right_eye'][0]+int(w*0.2), face['keypoints']['right_eye'][1]+int(h*0.2)),(0, 255, 0),2)
            eyes_image = cv2.resize(eyes_image,(eyes_w,eyes_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "eyes\\frame" + str(currentframe) + '.jpg',eyes_image) 


            mouth_image = image[max(0,face['keypoints']['mouth_left'][1]-int(h*0.2)):max(0,face['keypoints']['mouth_right'][1]+int(h*0.2))
                               ,max(0,face['keypoints']['mouth_left'][0]-int(w*0.2)):max(0,face['keypoints']['mouth_right'][0]+int(w*0.2))]
            #cv2.rectangle(image, (face['keypoints']['mouth_left'][0]-int(w*0.2), face['keypoints']['mouth_left'][1]-int(h*0.2)),
            #              (face['keypoints']['mouth_right'][0]+int(w*0.2), face['keypoints']['mouth_right'][1]+int(h*0.2)),(0, 255, 0),2)
            mouth_image = cv2.resize(mouth_image,(mouth_w,mouth_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "mouth\\frame" + str(currentframe) + '.jpg',mouth_image) 
            
            #if(currentframe%100==0):
            name = './data/frame' + str(currentframe) + '.jpg'
            print ('missing using last frame:  '+ 'Creating...' + name) 

        else:
            name = './data/frame' + str(currentframe) + '.jpg'
            f = open('droplist.txt','a')
            f.write(name+"\n")
            f.close()
            DropList.append(currentframe)
            print("drop")



        '''
        cv2.imshow('img',image)

        #print("FPS: ", 1.0 / (time.time() - start_time))

        k = cv2.waitKey(5) & 0xFF
        if k == 27:
            break
        '''
    
    print("total_frame:" +str(length)+" missing frame"+ str(np.array(DropList).shape[0])+" total frame2:"+ str(currentframe))
    print(DropList)
    cap.release()
    cv2.destroyAllWindows()
# Out:
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\nonsleepyCombination.avi
# 3330
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2700.jpg
# Creating..../data/frame3000.jpg
# Creating..../data/frame3300.jpg
# total_frame:3330 missing frame0 total frame2:3331
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\sleepyCombination.avi
# 2748
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2700.jpg
# total_frame:2748 missing frame0 total frame2:2749
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\slowBlinkWithNodding.avi
# 1920
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1800.jpg
# total_frame:1920 missing frame0 total frame2:1922
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\yawning.avi
# 1850
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1800.jpg
# total_frame:1850 missing frame0 total frame2:1851
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\nonsleepyCombination.avi
# 1521
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame900.jpg
# missing using last frame
# 182
# 389
# 172
# 347
# missing using last frame:  Creating..../data/frame1119.jpg
# missing using last frame
# 182
# 389
# 172
# 347
# missing using last frame:  Creating..../data/frame1122.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1500.jpg
# total_frame:1521 missing frame0 total frame2:1522
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\sleepyCombination.avi
# 1502
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# missing using last frame
# 201
# 439
# 202
# 402
# missing using last frame:  Creating..../data/frame618.jpg
# missing using last frame
# 201
# 439
# 202
# 402
# missing using last frame:  Creating..../data/frame621.jpg
# missing using last frame
# 253
# 494
# 196
# 427
# missing using last frame:  Creating..../data/frame660.jpg
# missing using last frame
# 253
# 494
# 196
# 427
# missing using last frame:  Creating..../data/frame663.jpg
# Creating..../data/frame900.jpg
# missing using last frame
# 214
# 446
# 155
# 359
# missing using last frame:  Creating..../data/frame1140.jpg
# missing using last frame
# 242
# 486
# 77
# 336
# missing using last frame:  Creating..../data/frame1179.jpg
# Creating..../data/frame1200.jpg
# missing using last frame
# 236
# 474
# 221
# 424
# missing using last frame:  Creating..../data/frame1476.jpg
# Creating..../data/frame1500.jpg
# total_frame:1502 missing frame0 total frame2:1503
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\slowBlinkWithNodding.avi
# 1073
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# missing using last frame
# 231
# 472
# 224
# 426
# missing using last frame:  Creating..../data/frame615.jpg
# missing using last frame
# 231
# 472
# 224
# 426
# missing using last frame:  Creating..../data/frame618.jpg
# Creating..../data/frame900.jpg
# missing using last frame
# 219
# 475
# 200
# 405
# missing using last frame:  Creating..../data/frame1023.jpg
# missing using last frame
# 219
# 475
# 200
# 405
# missing using last frame:  Creating..../data/frame1026.jpg
# missing using last frame
# 219
# 475
# 200
# 405
# missing using last frame:  Creating..../data/frame1029.jpg
# missing using last frame
# 265
# 492
# 183
# 384
# missing using last frame:  Creating..../data/frame1053.jpg
# total_frame:1073 missing frame0 total frame2:1074
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\yawning.avi
# 1038
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame900.jpg
# total_frame:1038 missing frame0 total frame2:1039
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\nonsleepyCombination.avi
# 1513
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# missing using last frame
# 176
# 390
# 203
# 376
# missing using last frame:  Creating..../data/frame765.jpg
# missing using last frame
# 176
# 390
# 203
# 376
# missing using last frame:  Creating..../data/frame768.jpg
# missing using last frame
# 176
# 390
# 203
# 376
# missing using last frame:  Creating..../data/frame771.jpg
# missing using last frame
# 176
# 390
# 203
# 376
# missing using last frame:  Creating..../data/frame774.jpg
# missing using last frame
# 176
# 390
# 203
# 376
# missing using last frame:  Creating..../data/frame777.jpg
# missing using last frame
# 176
# 390
# 203
# 376
# missing using last frame:  Creating..../data/frame780.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1500.jpg
# total_frame:1513 missing frame0 total frame2:1514
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\sleepyCombination.avi
# 1495
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# missing using last frame
# 228
# 477
# 99
# 338
# missing using last frame:  Creating..../data/frame837.jpg
# missing using last frame
# 228
# 477
# 99
# 338
# missing using last frame:  Creating..../data/frame840.jpg
# missing using last frame
# 262
# 487
# 47
# 279
# missing using last frame:  Creating..../data/frame879.jpg
# missing using last frame
# 262
# 487
# 47
# 279
# missing using last frame:  Creating..../data/frame882.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1200.jpg
# missing using last frame
# 268
# 492
# 89
# 319
# missing using last frame:  Creating..../data/frame1260.jpg
# total_frame:1495 missing frame0 total frame2:1496
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\slowBlinkWithNodding.avi
# 1098
# Creating..../data/frame300.jpg
# missing using last frame
# 233
# 467
# 284
# 516
# missing using last frame:  Creating..../data/frame558.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame900.jpg
# missing using last frame
# 249
# 470
# 194
# 423
# missing using last frame:  Creating..../data/frame1017.jpg
# total_frame:1098 missing frame0 total frame2:1099
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\yawning.avi
# 1092
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame900.jpg
# total_frame:1092 missing frame0 total frame2:1093
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\nonsleepyCombination.avi
# 2732
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame2100.jpg
# missing using last frame
# 145
# 404
# -15
# 169
# missing using last frame:  Creating..../data/frame2217.jpg
# missing using last frame
# 145
# 404
# -15
# 169
# missing using last frame:  Creating..../data/frame2220.jpg
# missing using last frame
# 145
# 404
# -15
# 169
# missing using last frame:  Creating..../data/frame2223.jpg
# missing using last frame
# 145
# 404
# -15
# 169
# missing using last frame:  Creating..../data/frame2226.jpg
# missing using last frame
# 145
# 404
# -15
# 169
# missing using last frame:  Creating..../data/frame2229.jpg
# missing using last frame
# 145
# 404
# -15
# 169
# missing using last frame:  Creating..../data/frame2232.jpg
# missing using last frame
# 145
# 404
# -15
# 169
# missing using last frame:  Creating..../data/frame2235.jpg
# missing using last frame
# 145
# 404
# -15
# 169
# missing using last frame:  Creating..../data/frame2238.jpg
# missing using last frame
# 145
# 404
# -15
# 169
# missing using last frame:  Creating..../data/frame2241.jpg
# Creating..../data/frame2400.jpg
# missing using last frame
# 156
# 267
# 73
# 159
# missing using last frame:  Creating..../data/frame2466.jpg
# missing using last frame
# 156
# 267
# 73
# 159
# missing using last frame:  Creating..../data/frame2469.jpg
# missing using last frame
# 156
# 267
# 73
# 159
# missing using last frame:  Creating..../data/frame2472.jpg
# missing using last frame
# 156
# 267
# 73
# 159
# missing using last frame:  Creating..../data/frame2475.jpg
# missing using last frame
# 156
# 267
# 73
# 159
# missing using last frame:  Creating..../data/frame2478.jpg
# missing using last frame
# 156
# 267
# 73
# 159
# missing using last frame:  Creating..../data/frame2481.jpg
# missing using last frame
# 156
# 267
# 73
# 159
# missing using last frame:  Creating..../data/frame2484.jpg
# missing using last frame
# 156
# 267
# 73
# 159
# missing using last frame:  Creating..../data/frame2487.jpg
# Creating..../data/frame2700.jpg
# total_frame:2732 missing frame0 total frame2:2733
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\sleepyCombination.avi
# 2711
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2700.jpg
# total_frame:2711 missing frame0 total frame2:2712
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\slowBlinkWithNodding.avi
# 1852
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1800.jpg
# total_frame:1852 missing frame0 total frame2:1853
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\yawning.avi
# 1872
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1800.jpg
# total_frame:1872 missing frame0 total frame2:1873
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\nonsleepyCombination.avi
# 2803
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2700.jpg
# total_frame:2803 missing frame0 total frame2:2804
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\sleepyCombination.avi
# 2805
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# missing using last frame
# 214
# 466
# 233
# 448
# missing using last frame:  Creating..../data/frame744.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2400.jpg
# missing using last frame
# 203
# 419
# 168
# 361
# missing using last frame:  Creating..../data/frame2460.jpg
# missing using last frame
# 203
# 419
# 168
# 361
# missing using last frame:  Creating..../data/frame2463.jpg
# missing using last frame
# 203
# 419
# 168
# 361
# missing using last frame:  Creating..../data/frame2466.jpg
# missing using last frame
# 203
# 419
# 168
# 361
# missing using last frame:  Creating..../data/frame2469.jpg
# Creating..../data/frame2700.jpg
# total_frame:2805 missing frame0 total frame2:2806
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\slowBlinkWithNodding.avi
# 2001
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1800.jpg
# total_frame:2001 missing frame0 total frame2:2002
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\yawning.avi
# 1965
# Creating..../data/frame300.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1800.jpg
# total_frame:1965 missing frame0 total frame2:1966
# []

# %% [markdown]
# ### TODO
# 1. 所有file 存檔案
# 2. training 進CNN model
# 3. 存沒有東西的frame

# %% [markdown]
# ### define CNN [model](https://medium.com/@mannasiladittya/building-inception-resnet-v2-in-keras-from-scratch-a3546c4d93f0)

# %%
# %run ./Model.ipynb
# Out:
# C:\Users\T-Rex\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
eyes_width = 45
eyes_height = 25
mouth_width = 35
mouth_height = 25
face_width = 50
face_height = 64
num_classes = 3
channel = 1

# %%
img_input = Input(shape=(face_height,face_width,1))

x = conv2d(img_input,32,3,2,'valid',True,name='conv1')
x = conv2d(x,32,3,1,'valid',True,name='conv2')
x = conv2d(x,64,3,1,'valid',True,name='conv3')

x_11 = MaxPooling2D(3,strides=1,padding='valid',name='stem_br_11'+'_maxpool_1')(x)
x_12 = conv2d(x,96,3,1,'valid',True,name='stem_br_12')

x = Concatenate(axis=3, name = 'stem_concat_1')([x_11,x_12])

x_21 = conv2d(x,64,1,1,'same',True,name='stem_br_211')
x_21 = conv2d(x_21,64,[1,7],1,'same',True,name='stem_br_212')
x_21 = conv2d(x_21,64,[7,1],1,'same',True,name='stem_br_213')
x_21 = conv2d(x_21,96,3,1,'valid',True,name='stem_br_214')

x_22 = conv2d(x,64,1,1,'same',True,name='stem_br_221')
x_22 = conv2d(x_22,96,3,1,'valid',True,name='stem_br_222')

x = Concatenate(axis=3, name = 'stem_concat_2')([x_21,x_22])

x_31 = conv2d(x,192,3,1,'valid',True,name='stem_br_31')
x_32 = MaxPooling2D(3,strides=1,padding='valid',name='stem_br_32'+'_maxpool_2')(x)
x = Concatenate(axis=3, name = 'stem_concat_3')([x_31,x_32])

# %%
#Inception-ResNet-A modules
x = incresA(x,0.15,name='incresA_1')
x = incresA(x,0.15,name='incresA_2')
x = incresA(x,0.15,name='incresA_3')
#x = incresA(x,0.15,name='incresA_4')

#35 × 35 to 17 × 17 reduction module.
x_red_11 = MaxPooling2D(3,strides=2,padding='valid',name='red_maxpool_1')(x)

x_red_12 = conv2d(x,384,3,2,'valid',True,name='x_red1_c1')

x_red_13 = conv2d(x,256,1,1,'same',True,name='x_red1_c2_1')
x_red_13 = conv2d(x_red_13,256,3,1,'same',True,name='x_red1_c2_2')
x_red_13 = conv2d(x_red_13,384,3,2,'valid',True,name='x_red1_c2_3')

x = Concatenate(axis=3, name='red_concat_1')([x_red_11,x_red_12,x_red_13])

#Inception-ResNet-B modules
x = incresB(x,0.1,name='incresB_1')
x = incresB(x,0.1,name='incresB_2')
x = incresB(x,0.1,name='incresB_3')
x = incresB(x,0.1,name='incresB_4')
x = incresB(x,0.1,name='incresB_5')
#x = incresB(x,0.1,name='incresB_6')
#x = incresB(x,0.1,name='incresB_7')

#17 × 17 to 8 × 8 reduction module.
x_red_21 = MaxPooling2D(3,strides=2,padding='valid',name='red_maxpool_2')(x)

x_red_22 = conv2d(x,256,1,1,'same',True,name='x_red2_c11')
x_red_22 = conv2d(x_red_22,384,3,2,'valid',True,name='x_red2_c12')

x_red_23 = conv2d(x,256,1,1,'same',True,name='x_red2_c21')
x_red_23 = conv2d(x_red_23,256,3,2,'valid',True,name='x_red2_c22')

x_red_24 = conv2d(x,256,1,1,'same',True,name='x_red2_c31')
x_red_24 = conv2d(x_red_24,256,3,1,'same',True,name='x_red2_c32')
x_red_24 = conv2d(x_red_24,256,3,2,'valid',True,name='x_red2_c33')

x = Concatenate(axis=3, name='red_concat_2')([x_red_21,x_red_22,x_red_23,x_red_24])

#Inception-ResNet-C modules
x = incresC(x,0.2,name='incresC_1')
x = incresC(x,0.2,name='incresC_2')
#x = incresC(x,0.2,name='incresC_3')

#TOP
x = GlobalAveragePooling2D(data_format='channels_last')(x)
x = Dropout(0.6)(x)
#x = Dense(num_classes, activation='softmax')(x)
flat3 = Flatten()(x)

# %%
'''
# first input model: eyes
eyes1 = Input(shape=(eyes_height,eyes_width,1))
conv11 = Conv2D(32, kernel_size=(3, 3), activation='relu')(eyes1)
pool11 = MaxPooling2D(pool_size=(2, 2))(conv11)
conv12 = Conv2D(64, kernel_size=(3, 3), activation='relu')(pool11)
#pool12 = MaxPooling2D(pool_size=(2, 2))(conv12)
#flat1 = Flatten()(pool12)
pool12 = GlobalAveragePooling2D(data_format='channels_last')(conv12)
flat1 = Flatten()(pool12)


# second input model: mouth
mouth1 = Input(shape=(mouth_height,mouth_width,1))
conv21 = Conv2D(32, kernel_size=(3, 3), activation='relu')(mouth1)
pool21 = MaxPooling2D(pool_size=(2, 2))(conv21)
conv22 = Conv2D(16, kernel_size=(3, 3), activation='relu')(pool21)
#pool22 = MaxPooling2D(pool_size=(2, 2))(conv22)
#flat2 = Flatten()(pool22)
pool22 = GlobalAveragePooling2D(data_format='channels_last')(conv22)
flat2 = Flatten()(pool22)
'''
#merge = Concatenate(axis=1, name='concat_2')([flat1, flat2,flat3])
output = Dense(num_classes, activation='softmax')(flat3)

# %%
model = Model(inputs=[ img_input], outputs=output, name='inception_resnet_v2')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 50, 1)    0
# __________________________________________________________________________________________________
# conv1conv2d (Conv2D)            (None, 31, 24, 32)   288         input_1[0][0]
# __________________________________________________________________________________________________
# conv1conv2dbn (BatchNormalizati (None, 31, 24, 32)   96          conv1conv2d[0][0]
# __________________________________________________________________________________________________
# conv1conv2dact (Activation)     (None, 31, 24, 32)   0           conv1conv2dbn[0][0]
# __________________________________________________________________________________________________
# conv2conv2d (Conv2D)            (None, 29, 22, 32)   9216        conv1conv2dact[0][0]
# __________________________________________________________________________________________________
# conv2conv2dbn (BatchNormalizati (None, 29, 22, 32)   96          conv2conv2d[0][0]
# __________________________________________________________________________________________________
# conv2conv2dact (Activation)     (None, 29, 22, 32)   0           conv2conv2dbn[0][0]
# __________________________________________________________________________________________________
# conv3conv2d (Conv2D)            (None, 27, 20, 64)   18432       conv2conv2dact[0][0]
# __________________________________________________________________________________________________
# conv3conv2dbn (BatchNormalizati (None, 27, 20, 64)   192         conv3conv2d[0][0]
# __________________________________________________________________________________________________
# conv3conv2dact (Activation)     (None, 27, 20, 64)   0           conv3conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_12conv2d (Conv2D)       (None, 25, 18, 96)   55296       conv3conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_12conv2dbn (BatchNormal (None, 25, 18, 96)   288         stem_br_12conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_11_maxpool_1 (MaxPoolin (None, 25, 18, 64)   0           conv3conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_12conv2dact (Activation (None, 25, 18, 96)   0           stem_br_12conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_concat_1 (Concatenate)     (None, 25, 18, 160)  0           stem_br_11_maxpool_1[0][0]
#                                                                  stem_br_12conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_211conv2d (Conv2D)      (None, 25, 18, 64)   10240       stem_concat_1[0][0]
# __________________________________________________________________________________________________
# stem_br_211conv2dbn (BatchNorma (None, 25, 18, 64)   192         stem_br_211conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_211conv2dact (Activatio (None, 25, 18, 64)   0           stem_br_211conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_212conv2d (Conv2D)      (None, 25, 18, 64)   28672       stem_br_211conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_212conv2dbn (BatchNorma (None, 25, 18, 64)   192         stem_br_212conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_212conv2dact (Activatio (None, 25, 18, 64)   0           stem_br_212conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_213conv2d (Conv2D)      (None, 25, 18, 64)   28672       stem_br_212conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_221conv2d (Conv2D)      (None, 25, 18, 64)   10240       stem_concat_1[0][0]
# __________________________________________________________________________________________________
# stem_br_213conv2dbn (BatchNorma (None, 25, 18, 64)   192         stem_br_213conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_221conv2dbn (BatchNorma (None, 25, 18, 64)   192         stem_br_221conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_213conv2dact (Activatio (None, 25, 18, 64)   0           stem_br_213conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_221conv2dact (Activatio (None, 25, 18, 64)   0           stem_br_221conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_214conv2d (Conv2D)      (None, 23, 16, 96)   55296       stem_br_213conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_222conv2d (Conv2D)      (None, 23, 16, 96)   55296       stem_br_221conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_214conv2dbn (BatchNorma (None, 23, 16, 96)   288         stem_br_214conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_222conv2dbn (BatchNorma (None, 23, 16, 96)   288         stem_br_222conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_214conv2dact (Activatio (None, 23, 16, 96)   0           stem_br_214conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_222conv2dact (Activatio (None, 23, 16, 96)   0           stem_br_222conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_concat_2 (Concatenate)     (None, 23, 16, 192)  0           stem_br_214conv2dact[0][0]
#                                                                  stem_br_222conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_31conv2d (Conv2D)       (None, 21, 14, 192)  331776      stem_concat_2[0][0]
# __________________________________________________________________________________________________
# stem_br_31conv2dbn (BatchNormal (None, 21, 14, 192)  576         stem_br_31conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_31conv2dact (Activation (None, 21, 14, 192)  0           stem_br_31conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_32_maxpool_2 (MaxPoolin (None, 21, 14, 192)  0           stem_concat_2[0][0]
# __________________________________________________________________________________________________
# stem_concat_3 (Concatenate)     (None, 21, 14, 384)  0           stem_br_31conv2dact[0][0]
#                                                                  stem_br_32_maxpool_2[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2d (Conv2D)    (None, 21, 14, 32)   12288       stem_concat_3[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2dbn (BatchNor (None, 21, 14, 32)   96          incresA_1b2_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2dact (Activat (None, 21, 14, 32)   0           incresA_1b2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2d (Conv2D)    (None, 21, 14, 32)   12288       stem_concat_3[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2d (Conv2D)    (None, 21, 14, 48)   13824       incresA_1b2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2dbn (BatchNor (None, 21, 14, 32)   96          incresA_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2dbn (BatchNor (None, 21, 14, 48)   144         incresA_1b2_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2dact (Activat (None, 21, 14, 32)   0           incresA_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2dact (Activat (None, 21, 14, 48)   0           incresA_1b2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2d (Conv2D)      (None, 21, 14, 32)   12288       stem_concat_3[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2d (Conv2D)    (None, 21, 14, 32)   9216        incresA_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2d (Conv2D)    (None, 21, 14, 64)   27648       incresA_1b2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2dbn (BatchNorma (None, 21, 14, 32)   96          incresA_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2dbn (BatchNor (None, 21, 14, 32)   96          incresA_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2dbn (BatchNor (None, 21, 14, 64)   192         incresA_1b2_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2dact (Activatio (None, 21, 14, 32)   0           incresA_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2dact (Activat (None, 21, 14, 32)   0           incresA_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2dact (Activat (None, 21, 14, 64)   0           incresA_1b2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1_concat (Concatenate)  (None, 21, 14, 128)  0           incresA_1b0conv2dact[0][0]
#                                                                  incresA_1b1_2conv2dact[0][0]
#                                                                  incresA_1b2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1filt_exp_1x1conv2d (Co (None, 21, 14, 384)  49152       incresA_1_concat[0][0]
# __________________________________________________________________________________________________
# incresA_1filt_exp_1x1conv2dbn ( (None, 21, 14, 384)  1152        incresA_1filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1act_scaling (Lambda)   (None, 21, 14, 384)  0           stem_concat_3[0][0]
#                                                                  incresA_1filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# incresA_2b2_1conv2d (Conv2D)    (None, 21, 14, 32)   12288       incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_1conv2dbn (BatchNor (None, 21, 14, 32)   96          incresA_2b2_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_1conv2dact (Activat (None, 21, 14, 32)   0           incresA_2b2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_1conv2d (Conv2D)    (None, 21, 14, 32)   12288       incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_2conv2d (Conv2D)    (None, 21, 14, 48)   13824       incresA_2b2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_1conv2dbn (BatchNor (None, 21, 14, 32)   96          incresA_2b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_2conv2dbn (BatchNor (None, 21, 14, 48)   144         incresA_2b2_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_1conv2dact (Activat (None, 21, 14, 32)   0           incresA_2b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_2conv2dact (Activat (None, 21, 14, 48)   0           incresA_2b2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b0conv2d (Conv2D)      (None, 21, 14, 32)   12288       incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_2conv2d (Conv2D)    (None, 21, 14, 32)   9216        incresA_2b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_3conv2d (Conv2D)    (None, 21, 14, 64)   27648       incresA_2b2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2b0conv2dbn (BatchNorma (None, 21, 14, 32)   96          incresA_2b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_2conv2dbn (BatchNor (None, 21, 14, 32)   96          incresA_2b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_3conv2dbn (BatchNor (None, 21, 14, 64)   192         incresA_2b2_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b0conv2dact (Activatio (None, 21, 14, 32)   0           incresA_2b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_2conv2dact (Activat (None, 21, 14, 32)   0           incresA_2b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_3conv2dact (Activat (None, 21, 14, 64)   0           incresA_2b2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2_concat (Concatenate)  (None, 21, 14, 128)  0           incresA_2b0conv2dact[0][0]
#                                                                  incresA_2b1_2conv2dact[0][0]
#                                                                  incresA_2b2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2filt_exp_1x1conv2d (Co (None, 21, 14, 384)  49152       incresA_2_concat[0][0]
# __________________________________________________________________________________________________
# incresA_2filt_exp_1x1conv2dbn ( (None, 21, 14, 384)  1152        incresA_2filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2act_scaling (Lambda)   (None, 21, 14, 384)  0           incresA_1act_scaling[0][0]
#                                                                  incresA_2filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# incresA_3b2_1conv2d (Conv2D)    (None, 21, 14, 32)   12288       incresA_2act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_3b2_1conv2dbn (BatchNor (None, 21, 14, 32)   96          incresA_3b2_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_3b2_1conv2dact (Activat (None, 21, 14, 32)   0           incresA_3b2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_3b1_1conv2d (Conv2D)    (None, 21, 14, 32)   12288       incresA_2act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_3b2_2conv2d (Conv2D)    (None, 21, 14, 48)   13824       incresA_3b2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_3b1_1conv2dbn (BatchNor (None, 21, 14, 32)   96          incresA_3b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_3b2_2conv2dbn (BatchNor (None, 21, 14, 48)   144         incresA_3b2_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_3b1_1conv2dact (Activat (None, 21, 14, 32)   0           incresA_3b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_3b2_2conv2dact (Activat (None, 21, 14, 48)   0           incresA_3b2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_3b0conv2d (Conv2D)      (None, 21, 14, 32)   12288       incresA_2act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_3b1_2conv2d (Conv2D)    (None, 21, 14, 32)   9216        incresA_3b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_3b2_3conv2d (Conv2D)    (None, 21, 14, 64)   27648       incresA_3b2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_3b0conv2dbn (BatchNorma (None, 21, 14, 32)   96          incresA_3b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_3b1_2conv2dbn (BatchNor (None, 21, 14, 32)   96          incresA_3b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_3b2_3conv2dbn (BatchNor (None, 21, 14, 64)   192         incresA_3b2_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_3b0conv2dact (Activatio (None, 21, 14, 32)   0           incresA_3b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_3b1_2conv2dact (Activat (None, 21, 14, 32)   0           incresA_3b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_3b2_3conv2dact (Activat (None, 21, 14, 64)   0           incresA_3b2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_3_concat (Concatenate)  (None, 21, 14, 128)  0           incresA_3b0conv2dact[0][0]
#                                                                  incresA_3b1_2conv2dact[0][0]
#                                                                  incresA_3b2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_3filt_exp_1x1conv2d (Co (None, 21, 14, 384)  49152       incresA_3_concat[0][0]
# __________________________________________________________________________________________________
# incresA_3filt_exp_1x1conv2dbn ( (None, 21, 14, 384)  1152        incresA_3filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_3act_scaling (Lambda)   (None, 21, 14, 384)  0           incresA_2act_scaling[0][0]
#                                                                  incresA_3filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# x_red1_c2_1conv2d (Conv2D)      (None, 21, 14, 256)  98304       incresA_3act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_1conv2dbn (BatchNorma (None, 21, 14, 256)  768         x_red1_c2_1conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_1conv2dact (Activatio (None, 21, 14, 256)  0           x_red1_c2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2d (Conv2D)      (None, 21, 14, 256)  589824      x_red1_c2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2dbn (BatchNorma (None, 21, 14, 256)  768         x_red1_c2_2conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2dact (Activatio (None, 21, 14, 256)  0           x_red1_c2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2d (Conv2D)        (None, 10, 6, 384)   1327104     incresA_3act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2d (Conv2D)      (None, 10, 6, 384)   884736      x_red1_c2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2dbn (BatchNormali (None, 10, 6, 384)   1152        x_red1_c1conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2dbn (BatchNorma (None, 10, 6, 384)   1152        x_red1_c2_3conv2d[0][0]
# __________________________________________________________________________________________________
# red_maxpool_1 (MaxPooling2D)    (None, 10, 6, 384)   0           incresA_3act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2dact (Activation) (None, 10, 6, 384)   0           x_red1_c1conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2dact (Activatio (None, 10, 6, 384)   0           x_red1_c2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# red_concat_1 (Concatenate)      (None, 10, 6, 1152)  0           red_maxpool_1[0][0]
#                                                                  x_red1_c1conv2dact[0][0]
#                                                                  x_red1_c2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2d (Conv2D)    (None, 10, 6, 128)   147456      red_concat_1[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2dbn (BatchNor (None, 10, 6, 128)   384         incresB_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2dact (Activat (None, 10, 6, 128)   0           incresB_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2d (Conv2D)    (None, 10, 6, 160)   143360      incresB_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2dbn (BatchNor (None, 10, 6, 160)   480         incresB_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2dact (Activat (None, 10, 6, 160)   0           incresB_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2d (Conv2D)      (None, 10, 6, 192)   221184      red_concat_1[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2d (Conv2D)    (None, 10, 6, 192)   215040      incresB_1b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2dbn (BatchNorma (None, 10, 6, 192)   576         incresB_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2dbn (BatchNor (None, 10, 6, 192)   576         incresB_1b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2dact (Activatio (None, 10, 6, 192)   0           incresB_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2dact (Activat (None, 10, 6, 192)   0           incresB_1b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1_mixed (Concatenate)   (None, 10, 6, 384)   0           incresB_1b0conv2dact[0][0]
#                                                                  incresB_1b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1filt_exp_1x1conv2d (Co (None, 10, 6, 1152)  442368      incresB_1_mixed[0][0]
# __________________________________________________________________________________________________
# incresB_1filt_exp_1x1conv2dbn ( (None, 10, 6, 1152)  3456        incresB_1filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1act_scaling (Lambda)   (None, 10, 6, 1152)  0           red_concat_1[0][0]
#                                                                  incresB_1filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# incresB_2b1_1conv2d (Conv2D)    (None, 10, 6, 128)   147456      incresB_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_1conv2dbn (BatchNor (None, 10, 6, 128)   384         incresB_2b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_1conv2dact (Activat (None, 10, 6, 128)   0           incresB_2b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_2conv2d (Conv2D)    (None, 10, 6, 160)   143360      incresB_2b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_2conv2dbn (BatchNor (None, 10, 6, 160)   480         incresB_2b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_2conv2dact (Activat (None, 10, 6, 160)   0           incresB_2b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2b0conv2d (Conv2D)      (None, 10, 6, 192)   221184      incresB_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_3conv2d (Conv2D)    (None, 10, 6, 192)   215040      incresB_2b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_2b0conv2dbn (BatchNorma (None, 10, 6, 192)   576         incresB_2b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_3conv2dbn (BatchNor (None, 10, 6, 192)   576         incresB_2b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b0conv2dact (Activatio (None, 10, 6, 192)   0           incresB_2b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_3conv2dact (Activat (None, 10, 6, 192)   0           incresB_2b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2_mixed (Concatenate)   (None, 10, 6, 384)   0           incresB_2b0conv2dact[0][0]
#                                                                  incresB_2b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_2filt_exp_1x1conv2d (Co (None, 10, 6, 1152)  442368      incresB_2_mixed[0][0]
# __________________________________________________________________________________________________
# incresB_2filt_exp_1x1conv2dbn ( (None, 10, 6, 1152)  3456        incresB_2filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2act_scaling (Lambda)   (None, 10, 6, 1152)  0           incresB_1act_scaling[0][0]
#                                                                  incresB_2filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# incresB_3b1_1conv2d (Conv2D)    (None, 10, 6, 128)   147456      incresB_2act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_3b1_1conv2dbn (BatchNor (None, 10, 6, 128)   384         incresB_3b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_3b1_1conv2dact (Activat (None, 10, 6, 128)   0           incresB_3b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_3b1_2conv2d (Conv2D)    (None, 10, 6, 160)   143360      incresB_3b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_3b1_2conv2dbn (BatchNor (None, 10, 6, 160)   480         incresB_3b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_3b1_2conv2dact (Activat (None, 10, 6, 160)   0           incresB_3b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_3b0conv2d (Conv2D)      (None, 10, 6, 192)   221184      incresB_2act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_3b1_3conv2d (Conv2D)    (None, 10, 6, 192)   215040      incresB_3b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_3b0conv2dbn (BatchNorma (None, 10, 6, 192)   576         incresB_3b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_3b1_3conv2dbn (BatchNor (None, 10, 6, 192)   576         incresB_3b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_3b0conv2dact (Activatio (None, 10, 6, 192)   0           incresB_3b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_3b1_3conv2dact (Activat (None, 10, 6, 192)   0           incresB_3b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_3_mixed (Concatenate)   (None, 10, 6, 384)   0           incresB_3b0conv2dact[0][0]
#                                                                  incresB_3b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_3filt_exp_1x1conv2d (Co (None, 10, 6, 1152)  442368      incresB_3_mixed[0][0]
# __________________________________________________________________________________________________
# incresB_3filt_exp_1x1conv2dbn ( (None, 10, 6, 1152)  3456        incresB_3filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_3act_scaling (Lambda)   (None, 10, 6, 1152)  0           incresB_2act_scaling[0][0]
#                                                                  incresB_3filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# incresB_4b1_1conv2d (Conv2D)    (None, 10, 6, 128)   147456      incresB_3act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_4b1_1conv2dbn (BatchNor (None, 10, 6, 128)   384         incresB_4b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_4b1_1conv2dact (Activat (None, 10, 6, 128)   0           incresB_4b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_4b1_2conv2d (Conv2D)    (None, 10, 6, 160)   143360      incresB_4b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_4b1_2conv2dbn (BatchNor (None, 10, 6, 160)   480         incresB_4b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_4b1_2conv2dact (Activat (None, 10, 6, 160)   0           incresB_4b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_4b0conv2d (Conv2D)      (None, 10, 6, 192)   221184      incresB_3act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_4b1_3conv2d (Conv2D)    (None, 10, 6, 192)   215040      incresB_4b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_4b0conv2dbn (BatchNorma (None, 10, 6, 192)   576         incresB_4b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_4b1_3conv2dbn (BatchNor (None, 10, 6, 192)   576         incresB_4b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_4b0conv2dact (Activatio (None, 10, 6, 192)   0           incresB_4b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_4b1_3conv2dact (Activat (None, 10, 6, 192)   0           incresB_4b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_4_mixed (Concatenate)   (None, 10, 6, 384)   0           incresB_4b0conv2dact[0][0]
#                                                                  incresB_4b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_4filt_exp_1x1conv2d (Co (None, 10, 6, 1152)  442368      incresB_4_mixed[0][0]
# __________________________________________________________________________________________________
# incresB_4filt_exp_1x1conv2dbn ( (None, 10, 6, 1152)  3456        incresB_4filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_4act_scaling (Lambda)   (None, 10, 6, 1152)  0           incresB_3act_scaling[0][0]
#                                                                  incresB_4filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# incresB_5b1_1conv2d (Conv2D)    (None, 10, 6, 128)   147456      incresB_4act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_5b1_1conv2dbn (BatchNor (None, 10, 6, 128)   384         incresB_5b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_5b1_1conv2dact (Activat (None, 10, 6, 128)   0           incresB_5b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_5b1_2conv2d (Conv2D)    (None, 10, 6, 160)   143360      incresB_5b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_5b1_2conv2dbn (BatchNor (None, 10, 6, 160)   480         incresB_5b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_5b1_2conv2dact (Activat (None, 10, 6, 160)   0           incresB_5b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_5b0conv2d (Conv2D)      (None, 10, 6, 192)   221184      incresB_4act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_5b1_3conv2d (Conv2D)    (None, 10, 6, 192)   215040      incresB_5b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_5b0conv2dbn (BatchNorma (None, 10, 6, 192)   576         incresB_5b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_5b1_3conv2dbn (BatchNor (None, 10, 6, 192)   576         incresB_5b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_5b0conv2dact (Activatio (None, 10, 6, 192)   0           incresB_5b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_5b1_3conv2dact (Activat (None, 10, 6, 192)   0           incresB_5b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_5_mixed (Concatenate)   (None, 10, 6, 384)   0           incresB_5b0conv2dact[0][0]
#                                                                  incresB_5b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_5filt_exp_1x1conv2d (Co (None, 10, 6, 1152)  442368      incresB_5_mixed[0][0]
# __________________________________________________________________________________________________
# incresB_5filt_exp_1x1conv2dbn ( (None, 10, 6, 1152)  3456        incresB_5filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_5act_scaling (Lambda)   (None, 10, 6, 1152)  0           incresB_4act_scaling[0][0]
#                                                                  incresB_5filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# x_red2_c31conv2d (Conv2D)       (None, 10, 6, 256)   294912      incresB_5act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c31conv2dbn (BatchNormal (None, 10, 6, 256)   768         x_red2_c31conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c31conv2dact (Activation (None, 10, 6, 256)   0           x_red2_c31conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c11conv2d (Conv2D)       (None, 10, 6, 256)   294912      incresB_5act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c21conv2d (Conv2D)       (None, 10, 6, 256)   294912      incresB_5act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c32conv2d (Conv2D)       (None, 10, 6, 256)   589824      x_red2_c31conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c11conv2dbn (BatchNormal (None, 10, 6, 256)   768         x_red2_c11conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c21conv2dbn (BatchNormal (None, 10, 6, 256)   768         x_red2_c21conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c32conv2dbn (BatchNormal (None, 10, 6, 256)   768         x_red2_c32conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c11conv2dact (Activation (None, 10, 6, 256)   0           x_red2_c11conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c21conv2dact (Activation (None, 10, 6, 256)   0           x_red2_c21conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c32conv2dact (Activation (None, 10, 6, 256)   0           x_red2_c32conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c12conv2d (Conv2D)       (None, 4, 2, 384)    884736      x_red2_c11conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c22conv2d (Conv2D)       (None, 4, 2, 256)    589824      x_red2_c21conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c33conv2d (Conv2D)       (None, 4, 2, 256)    589824      x_red2_c32conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c12conv2dbn (BatchNormal (None, 4, 2, 384)    1152        x_red2_c12conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c22conv2dbn (BatchNormal (None, 4, 2, 256)    768         x_red2_c22conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c33conv2dbn (BatchNormal (None, 4, 2, 256)    768         x_red2_c33conv2d[0][0]
# __________________________________________________________________________________________________
# red_maxpool_2 (MaxPooling2D)    (None, 4, 2, 1152)   0           incresB_5act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c12conv2dact (Activation (None, 4, 2, 384)    0           x_red2_c12conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c22conv2dact (Activation (None, 4, 2, 256)    0           x_red2_c22conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c33conv2dact (Activation (None, 4, 2, 256)    0           x_red2_c33conv2dbn[0][0]
# __________________________________________________________________________________________________
# red_concat_2 (Concatenate)      (None, 4, 2, 2048)   0           red_maxpool_2[0][0]
#                                                                  x_red2_c12conv2dact[0][0]
#                                                                  x_red2_c22conv2dact[0][0]
#                                                                  x_red2_c33conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_1conv2d (Conv2D)    (None, 4, 2, 192)    393216      red_concat_2[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_1conv2dbn (BatchNor (None, 4, 2, 192)    576         incresC_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_1conv2dact (Activat (None, 4, 2, 192)    0           incresC_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_2conv2d (Conv2D)    (None, 4, 2, 224)    129024      incresC_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_2conv2dbn (BatchNor (None, 4, 2, 224)    672         incresC_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_2conv2dact (Activat (None, 4, 2, 224)    0           incresC_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1b0conv2d (Conv2D)      (None, 4, 2, 192)    393216      red_concat_2[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_3conv2d (Conv2D)    (None, 4, 2, 256)    172032      incresC_1b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1b0conv2dbn (BatchNorma (None, 4, 2, 192)    576         incresC_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_3conv2dbn (BatchNor (None, 4, 2, 256)    768         incresC_1b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b0conv2dact (Activatio (None, 4, 2, 192)    0           incresC_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_3conv2dact (Activat (None, 4, 2, 256)    0           incresC_1b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1_mixed (Concatenate)   (None, 4, 2, 448)    0           incresC_1b0conv2dact[0][0]
#                                                                  incresC_1b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1fin1x1conv2d (Conv2D)  (None, 4, 2, 2048)   917504      incresC_1_mixed[0][0]
# __________________________________________________________________________________________________
# incresC_1fin1x1conv2dbn (BatchN (None, 4, 2, 2048)   6144        incresC_1fin1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1act_saling (Lambda)    (None, 4, 2, 2048)   0           red_concat_2[0][0]
#                                                                  incresC_1fin1x1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_1conv2d (Conv2D)    (None, 4, 2, 192)    393216      incresC_1act_saling[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_1conv2dbn (BatchNor (None, 4, 2, 192)    576         incresC_2b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_1conv2dact (Activat (None, 4, 2, 192)    0           incresC_2b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_2conv2d (Conv2D)    (None, 4, 2, 224)    129024      incresC_2b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_2conv2dbn (BatchNor (None, 4, 2, 224)    672         incresC_2b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_2conv2dact (Activat (None, 4, 2, 224)    0           incresC_2b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b0conv2d (Conv2D)      (None, 4, 2, 192)    393216      incresC_1act_saling[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_3conv2d (Conv2D)    (None, 4, 2, 256)    172032      incresC_2b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_2b0conv2dbn (BatchNorma (None, 4, 2, 192)    576         incresC_2b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_3conv2dbn (BatchNor (None, 4, 2, 256)    768         incresC_2b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b0conv2dact (Activatio (None, 4, 2, 192)    0           incresC_2b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_3conv2dact (Activat (None, 4, 2, 256)    0           incresC_2b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2_mixed (Concatenate)   (None, 4, 2, 448)    0           incresC_2b0conv2dact[0][0]
#                                                                  incresC_2b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_2fin1x1conv2d (Conv2D)  (None, 4, 2, 2048)   917504      incresC_2_mixed[0][0]
# __________________________________________________________________________________________________
# incresC_2fin1x1conv2dbn (BatchN (None, 4, 2, 2048)   6144        incresC_2fin1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2act_saling (Lambda)    (None, 4, 2, 2048)   0           incresC_1act_saling[0][0]
#                                                                  incresC_2fin1x1conv2dbn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           incresC_2act_saling[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           dropout[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            6147        flatten[0][0]
# ==================================================================================================
# Total params: 17,378,259
# Trainable params: 17,336,499
# Non-trainable params: 41,760
# __________________________________________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
'''
from keras.utils.vis_utils import model_to_dot
from tensorflow.keras.utils import plot_model
from IPython.display import SVG

SVG(model_to_dot(model).create(prog='dot', format='svg'))
plot_model(model, to_file='model_plot.png', 
                  show_shapes=True, show_layer_names=True)
'''
# Out:
# "\nfrom keras.utils.vis_utils import model_to_dot\nfrom tensorflow.keras.utils import plot_model\nfrom IPython.display import SVG\n\nSVG(model_to_dot(model).create(prog='dot', format='svg'))\nplot_model(model, to_file='model_plot.png', \n                  show_shapes=True, show_layer_names=True)\n"

# %% [markdown]
# ### Model2

# %%
# first input model: eyes
eyes1 = Input(shape=(eyes_height,eyes_width,1))
conv11 = Conv2D(32, kernel_size=(3, 3), activation='relu')(eyes1)
pool11 = MaxPooling2D(pool_size=(2, 2))(conv11)
conv12 = Conv2D(64, kernel_size=(3, 3), activation='relu')(pool11)
#pool12 = MaxPooling2D(pool_size=(2, 2))(conv12)
#flat1 = Flatten()(pool12)
pool12 = GlobalAveragePooling2D(data_format='channels_last')(conv12)
flat1 = Flatten()(pool12)


# second input model: mouth
mouth1 = Input(shape=(mouth_height,mouth_width,1))
conv21 = Conv2D(32, kernel_size=(3, 3), activation='relu')(mouth1)
pool21 = MaxPooling2D(pool_size=(2, 2))(conv21)
conv22 = Conv2D(64, kernel_size=(3, 3), activation='relu')(pool21)
#pool22 = MaxPooling2D(pool_size=(2, 2))(conv22)
#flat2 = Flatten()(pool22)
pool22 = GlobalAveragePooling2D(data_format='channels_last')(conv22)
flat2 = Flatten()(pool22)

# input model: face
face1 = Input(shape=(face_height,face_width,1))
conv31 = Conv2D(32, kernel_size=(3, 3), activation='relu')(face1)
pool31 = MaxPooling2D(pool_size=(2, 2))(conv31)
x = Conv2D(64, kernel_size=(3, 3), activation='relu')(pool31)
#pool22 = MaxPooling2D(pool_size=(2, 2))(conv22)
#flat2 = Flatten()(pool22)
'''
x = incresA(face1,0.15,name='incresA_1')

#35 × 35 to 17 × 17 reduction module.
x_red_11 = MaxPooling2D(3,strides=2,padding='valid',name='red_maxpool_1')(x)

x_red_12 = conv2d(x,384,3,2,'valid',True,name='x_red1_c1')

x_red_13 = conv2d(x,256,1,1,'same',True,name='x_red1_c2_1')
x_red_13 = conv2d(x_red_13,256,3,1,'same',True,name='x_red1_c2_2')
x_red_13 = conv2d(x_red_13,384,3,2,'valid',True,name='x_red1_c2_3')

x = Concatenate(axis=3, name='red_concat_1')([x_red_11,x_red_12,x_red_13])

x = incresB(x,0.1,name='incresB_1')
'''

x = GlobalAveragePooling2D(data_format='channels_last')(x)
x = Dropout(0.6)(x)
flat3 = Flatten()(x)

merge = Concatenate(axis=1, name='concat_2')([flat1, flat2,flat3])
output = Dense(num_classes, activation='softmax')(merge)

# %%
model2 = Model(inputs=[eyes1, mouth1, face1], outputs=output, name='inception_resnet_v2')
model2.summary()
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 64, 50, 1)    0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 25, 45, 1)    0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, 25, 35, 1)    0
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 62, 48, 32)   320         input_6[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 23, 43, 32)   320         input_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 23, 33, 32)   320         input_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 31, 24, 32)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 11, 21, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 11, 16, 32)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 29, 22, 64)   18496       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 9, 19, 64)    18496       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 9, 14, 64)    18496       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 64)           0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 64)           0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 64)           0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 64)           0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 64)           0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 64)           0           dropout_1[0][0]
# __________________________________________________________________________________________________
# concat_2 (Concatenate)          (None, 192)          0           flatten_3[0][0]
#                                                                  flatten_4[0][0]
#                                                                  flatten_5[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            386         concat_2[0][0]
# ==================================================================================================
# Total params: 56,834
# Trainable params: 56,834
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### model3

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras import applications
from tensorflow.keras.layers import Input


eyes_width = 45
eyes_height = 25
mouth_width = 35
mouth_height = 25
face_width = 50
face_height = 64
num_classes = 2
channel = 1

img_width, img_height = face_width, face_height

face1 = Input(shape=(face_height,face_width,1))

vgg_model = applications.VGG16(weights='imagenet', include_top=False,input_shape = (img_width, face_height, 3))
vgg_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 50, 64, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 50, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 50, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 25, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 25, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 25, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 12, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 12, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 12, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 12, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 6, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 6, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 6, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 6, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 3, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 3, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 3, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 3, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 2, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
#在VGG16的block2_pool output再加layer，VGG16的3 4 5就不要了
layer_dict = dict([(layer.name, layer) for layer in vgg_model.layers])
layer_dict
# Out:
# {'input_8': <tensorflow.python.keras.engine.input_layer.InputLayer at 0x1ec491d09e8>,
#  'block1_conv1': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec49205940>,
#  'block1_conv2': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec492055f8>,
#  'block1_pool': <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x1ec49205a58>,
#  'block2_conv1': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec49205fd0>,
#  'block2_conv2': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec49226710>,
#  'block2_pool': <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x1ec4923de80>,
#  'block3_conv1': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4923de48>,
#  'block3_conv2': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4927f9e8>,
#  'block3_conv3': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec492c7940>,
#  'block3_pool': <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x1ec492dbb00>,
#  'block4_conv1': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec492dbf98>,
#  'block4_conv2': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec493236a0>,
#  'block4_conv3': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4933ae10>,
#  'block4_pool': <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x1ec49388be0>,
#  'block5_conv1': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec49388da0>,
#  'block5_conv2': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec493c8518>,
#  'block5_conv3': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec493e1c18>,
#  'block5_pool': <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x1ec49423860>}

# %%
#Functional API

# first input model: eyes
eyes1 = Input(shape=(eyes_height,eyes_width,1))
conv11 = Conv2D(32, kernel_size=(3, 3), activation='relu')(eyes1)
pool11 = MaxPooling2D(pool_size=(2, 2))(conv11)
conv12 = Conv2D(64, kernel_size=(3, 3), activation='relu')(pool11)
#pool12 = MaxPooling2D(pool_size=(2, 2))(conv12)
#flat1 = Flatten()(pool12)
pool12 = GlobalAveragePooling2D(data_format='channels_last')(conv12)
flat1 = Flatten()(pool12)


# second input model: mouth
mouth1 = Input(shape=(mouth_height,mouth_width,1))
conv21 = Conv2D(32, kernel_size=(3, 3), activation='relu')(mouth1)
pool21 = MaxPooling2D(pool_size=(2, 2))(conv21)
conv22 = Conv2D(64, kernel_size=(3, 3), activation='relu')(pool21)
#pool22 = MaxPooling2D(pool_size=(2, 2))(conv22)
#flat2 = Flatten()(pool22)
pool22 = GlobalAveragePooling2D(data_format='channels_last')(conv22)
flat2 = Flatten()(pool22)

#===================================================



Conv2_out = layer_dict['block2_pool'].output

Conv3_out = Conv2D(filters=256, kernel_size=(1, 1), activation='relu', padding='same',kernel_initializer='random_uniform')(Conv2_out)
Conv3_out = Conv2D(filters=256, kernel_size=(1, 1), activation='relu', padding='same',kernel_initializer='random_uniform')(Conv3_out)
Conv3_out = Conv2D(filters=256, kernel_size=(1, 1), activation='relu', padding='same',kernel_initializer='random_uniform')(Conv3_out)
Conv3_Poolout = MaxPooling2D(pool_size=(2, 2))(Conv3_out)

Conv4_out = Conv2D(filters=256, kernel_size=(1, 1), activation='relu', padding='same',kernel_initializer='random_uniform')(Conv3_Poolout)
Conv4_out = Conv2D(filters=256, kernel_size=(1, 1), activation='relu', padding='same',kernel_initializer='random_uniform')(Conv4_out)
Conv4_out = Conv2D(filters=256, kernel_size=(1, 1), activation='relu', padding='same',kernel_initializer='random_uniform')(Conv4_out)
Conv4_Poolout = MaxPooling2D(pool_size=(2, 2))(Conv4_out)

Conv5_out = Conv2D(filters=256, kernel_size=(1, 1), activation='relu', padding='same',kernel_initializer='random_uniform')(Conv4_Poolout)
Conv5_out = Conv2D(filters=256, kernel_size=(1, 1), activation='relu', padding='same',kernel_initializer='random_uniform')(Conv5_out)
Conv5_out = Conv2D(filters=256, kernel_size=(1, 1), activation='relu', padding='same',kernel_initializer='random_uniform')(Conv5_out)
Conv5_Poolout = MaxPooling2D(pool_size=(2, 2))(Conv5_out)


FC6_1 = MaxPooling2D(pool_size=(12, 16))(Conv3_out)
FC6_2 = MaxPooling2D(pool_size=(6, 8))(Conv4_out)
FC6_3 = MaxPooling2D(pool_size=(3, 4))(Conv5_out)

FC6_in=Concatenate(axis=1, name='concat_2')([FC6_1,FC6_2,FC6_3])

out = Flatten()(FC6_in)

out = Dense(256, activation='relu',kernel_initializer='random_uniform')(out)
out = Dense(256, activation='relu',kernel_initializer='random_uniform')(out)
out = Dense(2, activation='softmax',kernel_initializer='random_uniform')(out)

# %%
from keras.models import Model
from keras import optimizers
custom_model = Model(input=vgg_model.input, output=out)

# Make sure that the pre-trained bottom layers are not trainable
for layer in custom_model.layers[:7]:
    layer.trainable = False
    print(layer)


sgd = optimizers.SGD(lr=0.000005, decay=0.0005, momentum=0.9, nesterov=True)
# Do not forget to compile it
custom_model.compile(loss='categorical_crossentropy',
                     optimizer='adam', 
                     metrics=['accuracy'])

custom_model.summary()
# Out:
# Using TensorFlow backend.
# C:\Users\T-Rex\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-92c5cf5e8abb> in <module>()
#       1 from keras.models import Model
#       2 from keras import optimizers
# ----> 3 custom_model = Model(input=vgg_model.input, output=out)
#       4
#       5 # Make sure that the pre-trained bottom layers are not trainable
#
# ~\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\lib\site-packages\keras\engine\network.py in __init__(self, *args, **kwargs)
#      91                 'inputs' in kwargs and 'outputs' in kwargs):
#      92             # Graph network
# ---> 93             self._init_graph_network(*args, **kwargs)
#      94         else:
#      95             # Subclassed network
#
# ~\Anaconda3\lib\site-packages\keras\engine\network.py in _init_graph_network(self, inputs, outputs, name)
#     245              input_masks=[None for _ in self.inputs],
#     246              output_masks=[None for _ in self.outputs],
# --> 247              input_shapes=[x._keras_shape for x in self.inputs],
#     248              output_shapes=[x._keras_shape for x in self.outputs])
#     249
#
# ~\Anaconda3\lib\site-packages\keras\engine\network.py in <listcomp>(.0)
#     245              input_masks=[None for _ in self.inputs],
#     246              output_masks=[None for _ in self.outputs],
# --> 247              input_shapes=[x._keras_shape for x in self.inputs],
#     248              output_shapes=[x._keras_shape for x in self.outputs])
#     249
#
# AttributeError: 'Tensor' object has no attribute '_keras_shape'

# %% [markdown]
# ### model4

# %%
from tensorflow.keras.applications.densenet import DenseNet169


img_width, img_height = face_width, face_height

face1 = Input(shape=(face_height,face_width,1))

DenseNet169Model = applications.DenseNet169(weights='imagenet', include_top=False,input_shape = (face_height,img_width, 3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-408ffedc06f8> in <module>()
#       6 face1 = Input(shape=(face_height,face_width,1))
#       7
# ----> 8 DenseNet169Model = applications.DenseNet169(weights='imagenet', include_top=False,input_shape = (face_height,img_width, 3))
#
# NameError: name 'applications' is not defined

# %%
DenseNet169Model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           (None, 64, 50, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 70, 56, 3)    0           input_12[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 32, 25, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 32, 25, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 32, 25, 64)   0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 34, 27, 64)   0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 16, 13, 64)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 16, 13, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 16, 13, 64)   0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 16, 13, 128)  8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 16, 13, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 16, 13, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 16, 13, 32)   36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 16, 13, 96)   0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 16, 13, 96)   384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 16, 13, 96)   0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 16, 13, 128)  12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 16, 13, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 16, 13, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 16, 13, 32)   36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 16, 13, 128)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 16, 13, 128)  512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 16, 13, 128)  0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 16, 13, 128)  16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 16, 13, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 16, 13, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 16, 13, 32)   36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 16, 13, 160)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 16, 13, 160)  640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 16, 13, 160)  0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 16, 13, 128)  20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 16, 13, 128)  512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 16, 13, 128)  0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 16, 13, 32)   36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 16, 13, 192)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 16, 13, 192)  768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 16, 13, 192)  0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 16, 13, 128)  24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 16, 13, 128)  512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 16, 13, 128)  0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 16, 13, 32)   36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 16, 13, 224)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 16, 13, 224)  896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 16, 13, 224)  0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 16, 13, 128)  28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 16, 13, 128)  512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 16, 13, 128)  0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 16, 13, 32)   36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 16, 13, 256)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 16, 13, 256)  1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 16, 13, 256)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 16, 13, 128)  32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 8, 6, 128)    0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 8, 6, 128)    512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 8, 6, 128)    0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 8, 6, 128)    16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 8, 6, 128)    0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 8, 6, 160)    0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 8, 6, 160)    640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 8, 6, 160)    0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 8, 6, 128)    20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 8, 6, 128)    0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 8, 6, 192)    0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 8, 6, 192)    768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 8, 6, 192)    0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 8, 6, 128)    24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 8, 6, 128)    0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 8, 6, 224)    0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 8, 6, 224)    896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 8, 6, 224)    0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 8, 6, 128)    28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 8, 6, 128)    0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 8, 6, 256)    0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 8, 6, 256)    1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 8, 6, 256)    0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 8, 6, 128)    32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 8, 6, 128)    0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 8, 6, 288)    0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 8, 6, 288)    1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 8, 6, 288)    0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 8, 6, 128)    36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 8, 6, 128)    0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 8, 6, 320)    0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 8, 6, 320)    1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 8, 6, 320)    0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 8, 6, 128)    40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 8, 6, 128)    0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 8, 6, 352)    0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 8, 6, 352)    1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 8, 6, 352)    0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 8, 6, 128)    45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 8, 6, 128)    0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 8, 6, 384)    0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 8, 6, 384)    1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 8, 6, 384)    0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 8, 6, 128)    49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 8, 6, 128)    0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 8, 6, 416)    0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 8, 6, 416)    1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 8, 6, 416)    0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 8, 6, 128)    53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 8, 6, 128)    512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 8, 6, 128)    0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 8, 6, 32)     36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 8, 6, 448)    0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 8, 6, 448)    1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 8, 6, 448)    0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 8, 6, 128)    57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 8, 6, 128)    512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 8, 6, 128)    0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 8, 6, 32)     36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 8, 6, 480)    0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 8, 6, 480)    1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 8, 6, 480)    0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 8, 6, 128)    61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 8, 6, 128)    512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 8, 6, 128)    0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 8, 6, 32)     36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 8, 6, 512)    0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 8, 6, 512)    2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 8, 6, 512)    0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 8, 6, 256)    131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 4, 3, 256)    0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 4, 3, 256)    1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 4, 3, 256)    0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 4, 3, 128)    32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 4, 3, 128)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 4, 3, 288)    0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 4, 3, 288)    1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 4, 3, 288)    0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 4, 3, 128)    36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 4, 3, 128)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 4, 3, 320)    0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 4, 3, 320)    1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 4, 3, 320)    0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 4, 3, 128)    40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 4, 3, 128)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 4, 3, 352)    0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 4, 3, 352)    1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 4, 3, 352)    0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 4, 3, 128)    45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 4, 3, 128)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 4, 3, 384)    0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 4, 3, 384)    1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 4, 3, 384)    0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 4, 3, 128)    49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 4, 3, 128)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 4, 3, 416)    0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 4, 3, 416)    1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 4, 3, 416)    0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 4, 3, 128)    53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 4, 3, 128)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 4, 3, 448)    0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 4, 3, 448)    1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 4, 3, 448)    0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 4, 3, 128)    57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 4, 3, 128)    0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 4, 3, 480)    0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 4, 3, 480)    1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 4, 3, 480)    0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 4, 3, 128)    61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 4, 3, 128)    0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 4, 3, 512)    0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 4, 3, 512)    2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 4, 3, 512)    0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 4, 3, 128)    65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 4, 3, 128)    0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 4, 3, 544)    0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 4, 3, 544)    2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 4, 3, 544)    0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 4, 3, 128)    69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 4, 3, 128)    512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 4, 3, 128)    0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 4, 3, 32)     36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 4, 3, 576)    0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 4, 3, 576)    2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 4, 3, 576)    0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 4, 3, 128)    73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 4, 3, 128)    512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 4, 3, 128)    0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 4, 3, 32)     36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 4, 3, 608)    0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 4, 3, 608)    2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 4, 3, 608)    0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 4, 3, 128)    77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 4, 3, 128)    512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 4, 3, 128)    0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 4, 3, 32)     36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, 4, 3, 640)    0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_0_bn (BatchNormal (None, 4, 3, 640)    2560        conv4_block12_concat[0][0]
# ...
# conv5_block22_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block22_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block22_concat (Concatena (None, 2, 1, 1344)   0           conv5_block21_concat[0][0]
#                                                                  conv5_block22_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_0_bn (BatchNormal (None, 2, 1, 1344)   5376        conv5_block22_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block23_0_relu (Activatio (None, 2, 1, 1344)   0           conv5_block23_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_conv (Conv2D)   (None, 2, 1, 128)    172032      conv5_block23_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_concat (Concatena (None, 2, 1, 1376)   0           conv5_block22_concat[0][0]
#                                                                  conv5_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_bn (BatchNormal (None, 2, 1, 1376)   5504        conv5_block23_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_relu (Activatio (None, 2, 1, 1376)   0           conv5_block24_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_conv (Conv2D)   (None, 2, 1, 128)    176128      conv5_block24_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block24_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block24_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block24_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_concat (Concatena (None, 2, 1, 1408)   0           conv5_block23_concat[0][0]
#                                                                  conv5_block24_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_bn (BatchNormal (None, 2, 1, 1408)   5632        conv5_block24_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_relu (Activatio (None, 2, 1, 1408)   0           conv5_block25_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_conv (Conv2D)   (None, 2, 1, 128)    180224      conv5_block25_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block25_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block25_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block25_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_concat (Concatena (None, 2, 1, 1440)   0           conv5_block24_concat[0][0]
#                                                                  conv5_block25_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_bn (BatchNormal (None, 2, 1, 1440)   5760        conv5_block25_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_relu (Activatio (None, 2, 1, 1440)   0           conv5_block26_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_conv (Conv2D)   (None, 2, 1, 128)    184320      conv5_block26_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block26_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block26_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block26_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_concat (Concatena (None, 2, 1, 1472)   0           conv5_block25_concat[0][0]
#                                                                  conv5_block26_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_bn (BatchNormal (None, 2, 1, 1472)   5888        conv5_block26_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_relu (Activatio (None, 2, 1, 1472)   0           conv5_block27_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_conv (Conv2D)   (None, 2, 1, 128)    188416      conv5_block27_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block27_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block27_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block27_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_concat (Concatena (None, 2, 1, 1504)   0           conv5_block26_concat[0][0]
#                                                                  conv5_block27_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_bn (BatchNormal (None, 2, 1, 1504)   6016        conv5_block27_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_relu (Activatio (None, 2, 1, 1504)   0           conv5_block28_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_conv (Conv2D)   (None, 2, 1, 128)    192512      conv5_block28_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block28_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block28_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block28_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_concat (Concatena (None, 2, 1, 1536)   0           conv5_block27_concat[0][0]
#                                                                  conv5_block28_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_bn (BatchNormal (None, 2, 1, 1536)   6144        conv5_block28_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_relu (Activatio (None, 2, 1, 1536)   0           conv5_block29_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_conv (Conv2D)   (None, 2, 1, 128)    196608      conv5_block29_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block29_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block29_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block29_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_concat (Concatena (None, 2, 1, 1568)   0           conv5_block28_concat[0][0]
#                                                                  conv5_block29_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_bn (BatchNormal (None, 2, 1, 1568)   6272        conv5_block29_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_relu (Activatio (None, 2, 1, 1568)   0           conv5_block30_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_conv (Conv2D)   (None, 2, 1, 128)    200704      conv5_block30_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block30_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block30_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block30_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_concat (Concatena (None, 2, 1, 1600)   0           conv5_block29_concat[0][0]
#                                                                  conv5_block30_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_bn (BatchNormal (None, 2, 1, 1600)   6400        conv5_block30_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_relu (Activatio (None, 2, 1, 1600)   0           conv5_block31_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_conv (Conv2D)   (None, 2, 1, 128)    204800      conv5_block31_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block31_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block31_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block31_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_concat (Concatena (None, 2, 1, 1632)   0           conv5_block30_concat[0][0]
#                                                                  conv5_block31_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_bn (BatchNormal (None, 2, 1, 1632)   6528        conv5_block31_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_relu (Activatio (None, 2, 1, 1632)   0           conv5_block32_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_conv (Conv2D)   (None, 2, 1, 128)    208896      conv5_block32_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block32_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block32_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block32_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_concat (Concatena (None, 2, 1, 1664)   0           conv5_block31_concat[0][0]
#                                                                  conv5_block32_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 2, 1, 1664)   6656        conv5_block32_concat[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 2, 1, 1664)   0           bn[0][0]
# ==================================================================================================
# Total params: 12,642,880
# Trainable params: 12,484,480
# Non-trainable params: 158,400
# __________________________________________________________________________________________________

# %%
layer_dict = dict([(layer.name, layer) for layer in DenseNet169Model.layers])
layer_dict
# Out:
# {'input_12': <tensorflow.python.keras.engine.input_layer.InputLayer at 0x1ec49936c18>,
#  'zero_padding2d': <tensorflow.python.keras.layers.convolutional.ZeroPadding2D at 0x1ec49936d30>,
#  'conv1/conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec49a2d3c8>,
#  'conv1/bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec49a2d358>,
#  'conv1/relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4992ceb8>,
#  'zero_padding2d_1': <tensorflow.python.keras.layers.convolutional.ZeroPadding2D at 0x1ec499360b8>,
#  'pool1': <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x1ec49a2d748>,
#  'conv2_block1_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec49a9ed30>,
#  'conv2_block1_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec49a2df28>,
#  'conv2_block1_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec49aedac8>,
#  'conv2_block1_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec49ad1eb8>,
#  'conv2_block1_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec49b2cc88>,
#  'conv2_block1_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec49bbfa20>,
#  'conv2_block1_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec49b87390>,
#  'conv2_block2_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec49b876d8>,
#  'conv2_block2_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec49be4400>,
#  'conv2_block2_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec49c41da0>,
#  'conv2_block2_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec49c880f0>,
#  'conv2_block2_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec49cca748>,
#  'conv2_block2_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec49d605f8>,
#  'conv2_block2_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec49d23f60>,
#  'conv2_block3_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec49d23668>,
#  'conv2_block3_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec49d23a20>,
#  'conv2_block3_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec49ddfd30>,
#  'conv2_block3_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec49e187b8>,
#  'conv2_block3_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec49e39b38>,
#  'conv2_block3_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec49efb978>,
#  'conv2_block3_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec49ebff98>,
#  'conv2_block4_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec49f44fd0>,
#  'conv2_block4_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec49f77d68>,
#  'conv2_block4_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec49fa0278>,
#  'conv2_block4_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec49fb4208>,
#  'conv2_block4_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec49ff5978>,
#  'conv2_block4_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4a050a58>,
#  'conv2_block4_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4a0d99e8>,
#  'conv2_block5_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4a074470>,
#  'conv2_block5_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4a074160>,
#  'conv2_block5_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4a138320>,
#  'conv2_block5_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4a149438>,
#  'conv2_block5_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4a190358>,
#  'conv2_block5_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4a1eddd8>,
#  'conv2_block5_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4a2105f8>,
#  'conv2_block6_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4a274c88>,
#  'conv2_block6_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4a245cf8>,
#  'conv2_block6_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4a2ce550>,
#  'conv2_block6_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4a309940>,
#  'conv2_block6_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4a355b70>,
#  'conv2_block6_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4a387eb8>,
#  'conv2_block6_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4a3af320>,
#  'pool2_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4a410f28>,
#  'pool2_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4a3e4588>,
#  'pool2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4a46a780>,
#  'pool2_pool': <tensorflow.python.keras.layers.pooling.AveragePooling2D at 0x1ec4a481da0>,
#  'conv3_block1_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4a4c2c18>,
#  'conv3_block1_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4a4c2438>,
#  'conv3_block1_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4a549be0>,
#  'conv3_block1_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4a558710>,
#  'conv3_block1_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4a558c88>,
#  'conv3_block1_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4a5f8dd8>,
#  'conv3_block1_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4a61a2b0>,
#  'conv3_block2_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4a683c18>,
#  'conv3_block2_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4a65bda0>,
#  'conv3_block2_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4a6da470>,
#  'conv3_block2_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4a6ef588>,
#  'conv3_block2_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4a737dd8>,
#  'conv3_block2_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4a795ba8>,
#  'conv3_block2_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4a7ba4a8>,
#  'conv3_block3_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4a7eff60>,
#  'conv3_block3_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4a81cdd8>,
#  'conv3_block3_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4a8766a0>,
#  'conv3_block3_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4a8af978>,
#  'conv3_block3_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4a8faba8>,
#  'conv3_block3_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4a9678d0>,
#  'conv3_block3_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4a956438>,
#  'conv3_block4_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4a98aa90>,
#  'conv3_block4_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4a98ae48>,
#  'conv3_block4_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4aa108d0>,
#  'conv3_block4_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4aa28f28>,
#  'conv3_block4_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4aa95a58>,
#  'conv3_block4_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4ab1fb70>,
#  'conv3_block4_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4aaed978>,
#  'conv3_block5_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4aaed2b0>,
#  'conv3_block5_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4aaed668>,
#  'conv3_block5_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4abe8240>,
#  'conv3_block5_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4abc6b38>,
#  'conv3_block5_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4ac2ae10>,
#  'conv3_block5_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4acbce10>,
#  'conv3_block5_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4ac86ef0>,
#  'conv3_block6_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4ac86710>,
#  'conv3_block6_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4ac86cf8>,
#  'conv3_block6_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4ad41d68>,
#  'conv3_block6_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4ad82668>,
#  'conv3_block6_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4ad99ef0>,
#  'conv3_block6_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4ae59b70>,
#  'conv3_block6_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4ae1e780>,
#  'conv3_block7_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4ae35f98>,
#  'conv3_block7_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4aedbf98>,
#  'conv3_block7_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4af00438>,
#  'conv3_block7_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4af15588>,
#  'conv3_block7_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4af15b70>,
#  'conv3_block7_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4afb7a58>,
#  'conv3_block7_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4b042f98>,
#  'conv3_block8_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4afd4278>,
#  'conv3_block8_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4afd4b70>,
#  'conv3_block8_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4b09b080>,
#  'conv3_block8_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4b0af940>,
#  'conv3_block8_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4b14cd68>,
#  'conv3_block8_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4b14c278>,
#  'conv3_block8_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4b172978>,
#  'conv3_block9_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4b1947f0>,
#  'conv3_block9_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4b1943c8>,
#  'conv3_block9_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4b237320>,
#  'conv3_block9_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4b246978>,
#  'conv3_block9_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4b28cd68>,
#  'conv3_block9_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4b3249b0>,
#  'conv3_block9_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4b30e080>,
#  'conv3_block10_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4b345828>,
#  'conv3_block10_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4b370da0>,
#  'conv3_block10_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4b3cb668>,
#  'conv3_block10_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4b407dd8>,
#  'conv3_block10_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4b4529e8>,
#  'conv3_block10_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4b4c06d8>,
#  'conv3_block10_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4b4ada58>,
#  'conv3_block11_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4b4ad0f0>,
#  'conv3_block11_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4b4e1e80>,
#  'conv3_block11_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4b567860>,
#  'conv3_block11_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4b57d978>,
#  'conv3_block11_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4b5e7a20>,
#  'conv3_block11_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4b677828>,
#  'conv3_block11_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4b6445f8>,
#  'conv3_block12_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4b6442e8>,
#  'conv3_block12_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4b644198>,
#  'conv3_block12_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4b6fdc88>,
#  'conv3_block12_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4b71bf60>,
#  'conv3_block12_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4b781cc0>,
#  'conv3_block12_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4b815da0>,
#  'conv3_block12_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4b7dde80>,
#  'pool3_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4b7dd6a0>,
#  'pool3_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4b7ddc88>,
#  'pool3_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4b896dd8>,
#  'pool3_pool': <tensorflow.python.keras.layers.pooling.AveragePooling2D at 0x1ec4b8dcf60>,
#  'conv4_block1_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4b8f1e80>,
#  'conv4_block1_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4b8f1cf8>,
#  'conv4_block1_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4b975748>,
#  'conv4_block1_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4b98bfd0>,
#  'conv4_block1_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4b9fcd30>,
#  'conv4_block1_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4ba63438>,
#  'conv4_block1_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4ba547f0>,
#  'conv4_block2_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4ba8a9e8>,
#  'conv4_block2_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4ba8ab38>,
#  'conv4_block2_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4bb0deb8>,
#  'conv4_block2_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4bb27b00>,
#  'conv4_block2_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4bb91c18>,
#  'conv4_block2_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4bc1fc88>,
#  'conv4_block2_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4bbe8710>,
#  'conv4_block3_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4bbe8400>,
#  'conv4_block3_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4bbe8240>,
#  'conv4_block3_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4bc9e1d0>,
#  'conv4_block3_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4bce78d0>,
#  'conv4_block3_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4bd2beb8>,
#  'conv4_block3_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4bdbeef0>,
#  'conv4_block3_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4bd86550>,
#  'conv4_block4_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4bd86898>,
#  'conv4_block4_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4bde1630>,
#  'conv4_block4_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4be3f630>,
#  'conv4_block4_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4be83a58>,
#  'conv4_block4_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4be9ddd8>,
#  'conv4_block4_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4bf5c9e8>,
#  'conv4_block4_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4bf20ba8>,
#  'conv4_block5_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4bfa4b70>,
#  'conv4_block5_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4bfda828>,
#  'conv4_block5_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4c001da0>,
#  'conv4_block5_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4c017160>,
#  'conv4_block5_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4c0668d0>,
#  'conv4_block5_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4c0b6ba8>,
#  'conv4_block5_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4c0d3828>,
#  'conv4_block6_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4c13a978>,
#  'conv4_block6_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4c113be0>,
#  'conv4_block6_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4c1982b0>,
#  'conv4_block6_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4c1aa898>,
#  'conv4_block6_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4c1efc18>,
#  'conv4_block6_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4c24cd68>,
#  'conv4_block6_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4c272e10>,
#  'conv4_block7_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4c2d5c50>,
#  'conv4_block7_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4c2a4eb8>,
#  'conv4_block7_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4c3304a8>,
#  'conv4_block7_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4c36b630>,
#  'conv4_block7_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4c38f4e0>,
#  'conv4_block7_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4c3e9c18>,
#  'conv4_block7_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4c410128>,
#  'conv4_block8_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4c46ee48>,
#  'conv4_block8_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4c46e7b8>,
#  'conv4_block8_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4c4cd710>,
#  'conv4_block8_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4c4e2e80>,
#  'conv4_block8_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4c551f98>,
#  'conv4_block8_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4c5bc908>,
#  'conv4_block8_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4c5ac470>,
#  'conv4_block9_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4c5e3b00>,
#  'conv4_block9_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4c5e3e80>,
#  'conv4_block9_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4c665908>,
#  'conv4_block9_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4c67fe80>,
#  'conv4_block9_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4c6e8ba8>,
#  'conv4_block9_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4c776d30>,
#  'conv4_block9_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4c73e9e8>,
#  'conv4_block10_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4c73e320>,
#  'conv4_block10_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4c73e6d8>,
#  'conv4_block10_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4c81a278>,
#  'conv4_block10_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4c83d198>,
#  'conv4_block10_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4c8513c8>,
#  'conv4_block10_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4c913e48>,
#  'conv4_block10_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4c8def28>,
#  'conv4_block11_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4c8de748>,
#  'conv4_block11_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4c8ded30>,
#  'conv4_block11_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4c996d68>,
#  'conv4_block11_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4c9d75f8>,
#  'conv4_block11_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4c9f0da0>,
#  'conv4_block11_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4cab17b8>,
#  'conv4_block11_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ec4ca767f0>,
#  'conv4_block12_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4cafcb38>,
#  'conv4_block12_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4cb2f7f0>,
#  'conv4_block12_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4cb564e0>,
#  'conv4_block12_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4cb6e3c8>,
#  'conv4_block12_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4cb6eb70>,
#  'conv4_block12_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ec4cc0fdd8>,
#  'conv4_block12_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee79239d30>,
#  'conv4_block13_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ec4cc2cdd8>,
#  'conv4_block13_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ec4cc2c080>,
#  'conv4_block13_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee792920b8>,
#  'conv4_block13_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee792a1320>,
#  'conv4_block13_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee792e8a90>,
#  'conv4_block13_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee79345dd8>,
#  'conv4_block13_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee793672b0>,
#  'conv4_block14_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee793d0c18>,
#  'conv4_block14_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee793a3da0>,
#  'conv4_block14_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee79428470>,
#  'conv4_block14_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7943d588>,
#  'conv4_block14_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee79485dd8>,
#  'conv4_block14_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee79527d30>,
#  'conv4_block14_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee79505f28>,
#  'conv4_block15_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7956a6d8>,
#  'conv4_block15_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7953e3c8>,
#  'conv4_block15_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee795c46d8>,
#  'conv4_block15_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee795d7a90>,
#  'conv4_block15_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7964b9e8>,
#  'conv4_block15_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee796b9dd8>,
#  'conv4_block15_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee796a6320>,
#  'conv4_block16_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee796dafd0>,
#  'conv4_block16_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee796daf98>,
#  'conv4_block16_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7975c8d0>,
#  'conv4_block16_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee79777908>,
#  'conv4_block16_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee797e0b70>,
#  'conv4_block16_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7986fbe0>,
#  'conv4_block16_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee79836668>,
#  'conv4_block17_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee79836358>,
#  'conv4_block17_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee79836198>,
#  'conv4_block17_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee79936240>,
#  'conv4_block17_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee79912b38>,
#  'conv4_block17_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7997be10>,
#  'conv4_block17_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee79a0bac8>,
#  'conv4_block17_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee799d44a8>,
#  'conv4_block18_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee799d47f0>,
#  'conv4_block18_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee79a2f588>,
#  'conv4_block18_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee79a8fd68>,
#  'conv4_block18_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee79ad25f8>,
#  'conv4_block18_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee79aeada0>,
#  'conv4_block18_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee79baa978>,
#  'conv4_block18_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee79b6ed30>,
#  'conv4_block19_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee79b6e710>,
#  'conv4_block19_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee79c287b8>,
#  'conv4_block19_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee79c4e860>,
#  'conv4_block19_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee79c648d0>,
#  'conv4_block19_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee79c64390>,
#  'conv4_block19_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee79d06dd8>,
#  'conv4_block19_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee79d23358>,
#  'conv4_block20_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee79d92d68>,
#  'conv4_block20_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee79d63c18>,
#  'conv4_block20_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee79dec0f0>,
#  'conv4_block20_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee79df9358>,
#  'conv4_block20_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee79e41278>,
#  'conv4_block20_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee79e9ee10>,
#  'conv4_block20_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee79ec2518>,
#  'conv4_block21_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee79f25c18>,
#  'conv4_block21_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee79efee80>,
#  'conv4_block21_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee79f80470>,
#  'conv4_block21_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee79fba6a0>,
#  'conv4_block21_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee79fdd4a8>,
#  'conv4_block21_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7a03a748>,
#  'conv4_block21_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7a05e128>,
#  'conv4_block22_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7a0bfe10>,
#  'conv4_block22_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7a0bf780>,
#  'conv4_block22_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7a11b6d8>,
#  'conv4_block22_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7a1307f0>,
#  'conv4_block22_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7a1a1f98>,
#  'conv4_block22_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7a20db00>,
#  'conv4_block22_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7a1fd470>,
#  'conv4_block23_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7a232b00>,
#  'conv4_block23_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7a232e80>,
#  'conv4_block23_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7a2b7908>,
#  'conv4_block23_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7a2cee80>,
#  'conv4_block23_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7a338ba8>,
#  'conv4_block23_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7a3c5d30>,
#  'conv4_block23_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7a38f9e8>,
#  'conv4_block24_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7a38f320>,
#  'conv4_block24_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7a38f6d8>,
#  'conv4_block24_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7a46c278>,
#  'conv4_block24_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7a48fda0>,
#  'conv4_block24_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7a4d0e80>,
#  'conv4_block24_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7a565a20>,
#  'conv4_block24_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7a530f98>,
#  'conv4_block25_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7a530780>,
#  'conv4_block25_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7a530e10>,
#  'conv4_block25_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7a5e4da0>,
#  'conv4_block25_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7a626eb8>,
#  'conv4_block25_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7a6919e8>,
#  'conv4_block25_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7a701dd8>,
#  'conv4_block25_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7a6ee320>,
#  'conv4_block26_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7a722fd0>,
#  'conv4_block26_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7a722f98>,
#  'conv4_block26_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7a7a68d0>,
#  'conv4_block26_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7a7bfc18>,
#  'conv4_block26_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7a7bfc50>,
#  'conv4_block26_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7a87dd68>,
#  'conv4_block26_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7a8a0208>,
#  'conv4_block27_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7a906ba8>,
#  'conv4_block27_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7a8ded30>,
#  'conv4_block27_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7a95e400>,
#  'conv4_block27_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7a973f98>,
#  'conv4_block27_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7a9e5f98>,
#  'conv4_block27_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7aa77eb8>,
#  'conv4_block27_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7aa3c630>,
#  'conv4_block28_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7aa3c978>,
#  'conv4_block28_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7aa9e710>,
#  'conv4_block28_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7ab20748>,
#  'conv4_block28_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7ab36c18>,
#  'conv4_block28_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7aba6978>,
#  'conv4_block28_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7ac2ea90>,
#  'conv4_block28_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7abfd3c8>,
#  'conv4_block29_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7abfdba8>,
#  'conv4_block29_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7abfd160>,
#  'conv4_block29_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7acb9ac8>,
#  'conv4_block29_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7acd2be0>,
#  'conv4_block29_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7ad31c88>,
#  'conv4_block29_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7ad94da0>,
#  'conv4_block29_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7adb5390>,
#  'conv4_block30_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7ae18c88>,
#  'conv4_block30_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7adebe80>,
#  'conv4_block30_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7ae75550>,
#  'conv4_block30_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7ae87f98>,
#  'conv4_block30_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7aecfdd8>,
#  'conv4_block30_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7af8d940>,
#  'conv4_block30_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7af52780>,
#  'conv4_block31_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7afd8ba8>,
#  'conv4_block31_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7b009860>,
#  'conv4_block31_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7b033208>,
#  'conv4_block31_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7b04b6a0>,
#  'conv4_block31_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7b0b3ba8>,
#  'conv4_block31_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7b141d30>,
#  'conv4_block31_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7b10c9e8>,
#  'conv4_block32_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7b10c320>,
#  'conv4_block32_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7b10c6d8>,
#  'conv4_block32_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7b220da0>,
#  'conv4_block32_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7b20b1d0>,
#  'conv4_block32_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7b245dd8>,
#  'conv4_block32_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7b2a9ba8>,
#  'conv4_block32_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7b2cc4a8>,
#  'pool4_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7b301f60>,
#  'pool4_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7b32cdd8>,
#  'pool4_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7b38a6a0>,
#  'pool4_pool': <tensorflow.python.keras.layers.pooling.AveragePooling2D at 0x1ee7b3e42e8>,
#  'conv5_block1_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7b39dba8>,
#  'conv5_block1_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7b39de80>,
#  'conv5_block1_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7b466c50>,
#  'conv5_block1_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7b47d048>,
#  'conv5_block1_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7b4e3c50>,
#  'conv5_block1_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7b5705c0>,
#  'conv5_block1_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7b538a90>,
#  'conv5_block2_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7b5383c8>,
#  'conv5_block2_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7b538780>,
#  'conv5_block2_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7b5c3d30>,
#  'conv5_block2_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7b63a4a8>,
#  'conv5_block2_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7b67e710>,
#  'conv5_block2_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7b712828>,
#  'conv5_block2_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7b6d85c0>,
#  'conv5_block3_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7b6d8908>,
#  'conv5_block3_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7b7346a0>,
#  'conv5_block3_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7b792d30>,
#  'conv5_block3_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7b7efb38>,
#  'conv5_block3_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7b7efe48>,
#  'conv5_block3_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7b889be0>,
#  'conv5_block3_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7b8aff28>,
#  'conv5_block4_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7b9307b8>,
#  'conv5_block4_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7b8d25f8>,
#  'conv5_block4_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7b953860>,
#  'conv5_block4_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7b984a90>,
#  'conv5_block4_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7b9685f8>,
#  'conv5_block4_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7ba11940>,
#  'conv5_block4_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7ba26ac8>,
#  'conv5_block5_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7ba96f98>,
#  'conv5_block5_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7ba659b0>,
#  'conv5_block5_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7baef080>,
#  'conv5_block5_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7bb012e8>,
#  'conv5_block5_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7bb43a58>,
#  'conv5_block5_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7bba0da0>,
#  'conv5_block5_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7bbc5e48>,
#  'conv5_block6_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7cbfeba8>,
#  'conv5_block6_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7cbd0ba8>,
#  'conv5_block6_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7cc53400>,
#  'conv5_block6_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7cc6b518>,
#  'conv5_block6_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7ccafd68>,
#  'conv5_block6_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7cd47668>,
#  'conv5_block6_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7cd310b8>,
#  'conv5_block7_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7cd96e48>,
#  'conv5_block7_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7cd966d8>,
#  'conv5_block7_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7cf4f630>,
#  'conv5_block7_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7cf8da20>,
#  'conv5_block7_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7cfd69b0>,
#  'conv5_block7_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7d047b38>,
#  'conv5_block7_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7d031240>,
#  'conv5_block8_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7d066e48>,
#  'conv5_block8_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7d066dd8>,
#  'conv5_block8_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7d0e9860>,
#  'conv5_block8_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7d100d68>,
#  'conv5_block8_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7d16c9e8>,
#  'conv5_block8_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7d1f8b00>,
#  'conv5_block8_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7d1c9908>,
#  'conv5_block9_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7d1c9208>,
#  'conv5_block9_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7d1c95f8>,
#  'conv5_block9_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7d283c88>,
#  'conv5_block9_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7d29ef60>,
#  'conv5_block9_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7d305cc0>,
#  'conv5_block9_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7d395da0>,
#  'conv5_block9_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7d360e80>,
#  'conv5_block10_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7d3606a0>,
#  'conv5_block10_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7d360c88>,
#  'conv5_block10_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7d418dd8>,
#  'conv5_block10_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7d45fa58>,
#  'conv5_block10_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7d4a3a58>,
#  'conv5_block10_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7d534eb8>,
#  'conv5_block10_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7d4f6630>,
#  'conv5_block11_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7d4f6978>,
#  'conv5_block11_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7d559710>,
#  'conv5_block11_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7d5d9748>,
#  'conv5_block11_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7d612400>,
#  'conv5_block11_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7d5efa20>,
#  'conv5_block11_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7d696908>,
#  'conv5_block11_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7d6eeb00>,
#  'conv5_block12_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7d71c9e8>,
#  'conv5_block12_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7d6afb00>,
#  'conv5_block12_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7d777438>,
#  'conv5_block12_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7d78bbe0>,
#  'conv5_block12_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7d78b748>,
#  'conv5_block12_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7d82acf8>,
#  'conv5_block12_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7d84a198>,
#  'conv5_block13_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7d8b6a58>,
#  'conv5_block13_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7d88acc0>,
#  'conv5_block13_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7d90f390>,
#  'conv5_block13_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7d921c88>,
#  'conv5_block13_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7d992e48>,
#  'conv5_block13_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7da24828>,
#  'conv5_block13_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7d9ec5c0>,
#  'conv5_block14_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7d9ec908>,
#  'conv5_block14_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7da486a0>,
#  'conv5_block14_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7daa5d30>,
#  'conv5_block14_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7dae1ba8>,
#  'conv5_block14_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7db52d68>,
#  'conv5_block14_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7dbbc9e8>,
#  'conv5_block14_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7dbae828>,
#  'conv5_block15_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7dbdaa20>,
#  'conv5_block15_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7dbdab70>,
#  'conv5_block15_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7dc68b38>,
#  'conv5_block15_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7dc7fef0>,
#  'conv5_block15_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7dcddc18>,
#  'conv5_block15_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7dd3ed68>,
#  'conv5_block15_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7dd61320>,
#  'conv5_block16_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7ddc5c88>,
#  'conv5_block16_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7dd98e10>,
#  'conv5_block16_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7de1e4e0>,
#  'conv5_block16_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7de36dd8>,
#  'conv5_block16_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7de7a748>,
#  'conv5_block16_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7df3b7b8>,
#  'conv5_block16_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7deff7f0>,
#  'conv5_block17_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7df85b38>,
#  'conv5_block17_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7dfb87f0>,
#  'conv5_block17_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7dfde4e0>,
#  'conv5_block17_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7dfea630>,
#  'conv5_block17_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7e063a58>,
#  'conv5_block17_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7e0edb70>,
#  'conv5_block17_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7e0bd978>,
#  'conv5_block18_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7e0bd2b0>,
#  'conv5_block18_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7e0bd668>,
#  'conv5_block18_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7e1b7ef0>,
#  'conv5_block18_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7e193ba8>,
#  'conv5_block18_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7e1f4d68>,
#  'conv5_block18_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7e2846d8>,
#  'conv5_block18_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7e2740b8>,
#  'conv5_block19_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7e2d9e48>,
#  'conv5_block19_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7e2d96d8>,
#  'conv5_block19_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7e333630>,
#  'conv5_block19_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7e349e80>,
#  'conv5_block19_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7e392588>,
#  'conv5_block19_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7e44f9b0>,
#  'conv5_block19_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7e4148d0>,
#  'conv5_block20_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7e49c9e8>,
#  'conv5_block20_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7e469940>,
#  'conv5_block20_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7e4f7438>,
#  'conv5_block20_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7e50a748>,
#  'conv5_block20_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7e574c88>,
#  'conv5_block20_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7e6059b0>,
#  'conv5_block20_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7e5ccac8>,
#  'conv5_block21_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7e5cc400>,
#  'conv5_block21_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7e5cc7b8>,
#  'conv5_block21_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7e685d68>,
#  'conv5_block21_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7e6cc978>,
#  'conv5_block21_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7e732b38>,
#  'conv5_block21_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7e765ef0>,
#  'conv5_block21_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7e78c2b0>,
#  'conv5_block22_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7e7edf98>,
#  'conv5_block22_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7e7ed828>,
#  'conv5_block22_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7e846780>,
#  'conv5_block22_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7e85cac8>,
#  'conv5_block22_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7e85c160>,
#  'conv5_block22_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7e925ba8>,
#  'conv5_block22_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7e941828>,
#  'conv5_block23_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7e9aa978>,
#  'conv5_block23_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7e981be0>,
#  'conv5_block23_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7ea042b0>,
#  'conv5_block23_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7ea19cf8>,
#  'conv5_block23_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7ea5c668>,
#  'conv5_block23_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7eb1ae80>,
#  'conv5_block23_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7eae24e0>,
#  'conv5_block24_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7eae2828>,
#  'conv5_block24_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7eb3b5c0>,
#  'conv5_block24_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7eb9dda0>,
#  'conv5_block24_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7ebdfeb8>,
#  'conv5_block24_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7ec479e8>,
#  'conv5_block24_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7ecb7dd8>,
#  'conv5_block24_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7eca2320>,
#  'conv5_block25_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7ecd7fd0>,
#  'conv5_block25_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7ecd7f98>,
#  'conv5_block25_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7ed5d8d0>,
#  'conv5_block25_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7ed72c18>,
#  'conv5_block25_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7ed72c50>,
#  'conv5_block25_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7ee33d68>,
#  'conv5_block25_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7ee55208>,
#  'conv5_block26_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7eebeba8>,
#  'conv5_block26_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7ee95d30>,
#  'conv5_block26_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7ef12400>,
#  'conv5_block26_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7ef2af98>,
#  'conv5_block26_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7ef9bf98>,
#  'conv5_block26_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7f02feb8>,
#  'conv5_block26_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7eff1630>,
#  'conv5_block27_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7eff1978>,
#  'conv5_block27_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7f052710>,
#  'conv5_block27_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7f0d3748>,
#  'conv5_block27_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7f0e6c18>,
#  'conv5_block27_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7f160978>,
#  'conv5_block27_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7f1e1a90>,
#  'conv5_block27_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7f1b23c8>,
#  'conv5_block28_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7f1b2ba8>,
#  'conv5_block28_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7f1b2160>,
#  'conv5_block28_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7f26eac8>,
#  'conv5_block28_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7f286be0>,
#  'conv5_block28_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7f2e8c88>,
#  'conv5_block28_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7f348da0>,
#  'conv5_block28_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7f369390>,
#  'conv5_block29_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7f3cec88>,
#  'conv5_block29_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7f39fe80>,
#  'conv5_block29_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7f429550>,
#  'conv5_block29_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7f440f98>,
#  'conv5_block29_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee7f486dd8>,
#  'conv5_block29_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee7f543940>,
#  'conv5_block29_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee7f506780>,
#  'conv5_block30_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee7f58fba8>,
#  'conv5_block30_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee8058d860>,
#  'conv5_block30_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee805b7828>,
#  'conv5_block30_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee805cfd30>,
#  'conv5_block30_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee8063aba8>,
#  'conv5_block30_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee806c9518>,
#  'conv5_block30_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee806902b0>,
#  'conv5_block31_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee806905f8>,
#  'conv5_block31_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee806ed320>,
#  'conv5_block31_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee8074a1d0>,
#  'conv5_block31_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee8076c2b0>,
#  'conv5_block31_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee80791860>,
#  'conv5_block31_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee8082cba8>,
#  'conv5_block31_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee808514a8>,
#  'conv5_block32_0_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee80886f60>,
#  'conv5_block32_0_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee808b3dd8>,
#  'conv5_block32_1_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee8090d6a0>,
#  'conv5_block32_1_bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee8096c160>,
#  'conv5_block32_1_relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee80920c88>,
#  'conv5_block32_2_conv': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x1ee809ec940>,
#  'conv5_block32_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x1ee80a03ac8>,
#  'bn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x1ee80a72f98>,
#  'relu': <tensorflow.python.keras.layers.core.Activation at 0x1ee80a439b0>}

# %%
from tensorflow.keras.models import Model


Conv2_out = layer_dict['conv5_block32_concat'].output
out = Flatten()(Conv2_out)
out = Dense(1024, activation='relu',kernel_initializer='random_uniform')(out)
out = Dense(512, activation='relu',kernel_initializer='random_uniform')(out)
out = Dense(2, activation='softmax',kernel_initializer='random_uniform')(out)


custom_model = Model(inputs = DenseNet169Model.input, outputs=out, name='inception_resnet_v2')

# %%
custom_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           (None, 64, 50, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 70, 56, 3)    0           input_12[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 32, 25, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 32, 25, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 32, 25, 64)   0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 34, 27, 64)   0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 16, 13, 64)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 16, 13, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 16, 13, 64)   0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 16, 13, 128)  8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 16, 13, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 16, 13, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 16, 13, 32)   36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 16, 13, 96)   0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 16, 13, 96)   384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 16, 13, 96)   0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 16, 13, 128)  12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 16, 13, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 16, 13, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 16, 13, 32)   36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 16, 13, 128)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 16, 13, 128)  512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 16, 13, 128)  0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 16, 13, 128)  16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 16, 13, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 16, 13, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 16, 13, 32)   36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 16, 13, 160)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 16, 13, 160)  640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 16, 13, 160)  0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 16, 13, 128)  20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 16, 13, 128)  512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 16, 13, 128)  0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 16, 13, 32)   36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 16, 13, 192)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 16, 13, 192)  768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 16, 13, 192)  0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 16, 13, 128)  24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 16, 13, 128)  512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 16, 13, 128)  0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 16, 13, 32)   36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 16, 13, 224)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 16, 13, 224)  896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 16, 13, 224)  0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 16, 13, 128)  28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 16, 13, 128)  512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 16, 13, 128)  0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 16, 13, 32)   36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 16, 13, 256)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 16, 13, 256)  1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 16, 13, 256)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 16, 13, 128)  32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 8, 6, 128)    0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 8, 6, 128)    512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 8, 6, 128)    0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 8, 6, 128)    16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 8, 6, 128)    0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 8, 6, 160)    0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 8, 6, 160)    640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 8, 6, 160)    0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 8, 6, 128)    20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 8, 6, 128)    0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 8, 6, 192)    0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 8, 6, 192)    768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 8, 6, 192)    0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 8, 6, 128)    24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 8, 6, 128)    0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 8, 6, 224)    0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 8, 6, 224)    896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 8, 6, 224)    0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 8, 6, 128)    28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 8, 6, 128)    0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 8, 6, 256)    0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 8, 6, 256)    1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 8, 6, 256)    0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 8, 6, 128)    32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 8, 6, 128)    0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 8, 6, 288)    0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 8, 6, 288)    1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 8, 6, 288)    0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 8, 6, 128)    36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 8, 6, 128)    0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 8, 6, 320)    0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 8, 6, 320)    1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 8, 6, 320)    0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 8, 6, 128)    40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 8, 6, 128)    0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 8, 6, 352)    0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 8, 6, 352)    1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 8, 6, 352)    0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 8, 6, 128)    45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 8, 6, 128)    0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 8, 6, 384)    0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 8, 6, 384)    1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 8, 6, 384)    0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 8, 6, 128)    49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 8, 6, 128)    512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 8, 6, 128)    0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 8, 6, 32)     36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 8, 6, 416)    0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 8, 6, 416)    1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 8, 6, 416)    0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 8, 6, 128)    53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 8, 6, 128)    512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 8, 6, 128)    0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 8, 6, 32)     36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 8, 6, 448)    0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 8, 6, 448)    1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 8, 6, 448)    0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 8, 6, 128)    57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 8, 6, 128)    512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 8, 6, 128)    0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 8, 6, 32)     36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 8, 6, 480)    0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 8, 6, 480)    1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 8, 6, 480)    0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 8, 6, 128)    61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 8, 6, 128)    512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 8, 6, 128)    0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 8, 6, 32)     36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 8, 6, 512)    0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 8, 6, 512)    2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 8, 6, 512)    0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 8, 6, 256)    131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 4, 3, 256)    0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 4, 3, 256)    1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 4, 3, 256)    0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 4, 3, 128)    32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 4, 3, 128)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 4, 3, 288)    0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 4, 3, 288)    1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 4, 3, 288)    0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 4, 3, 128)    36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 4, 3, 128)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 4, 3, 320)    0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 4, 3, 320)    1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 4, 3, 320)    0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 4, 3, 128)    40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 4, 3, 128)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 4, 3, 352)    0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 4, 3, 352)    1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 4, 3, 352)    0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 4, 3, 128)    45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 4, 3, 128)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 4, 3, 384)    0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 4, 3, 384)    1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 4, 3, 384)    0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 4, 3, 128)    49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 4, 3, 128)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 4, 3, 416)    0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 4, 3, 416)    1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 4, 3, 416)    0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 4, 3, 128)    53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 4, 3, 128)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 4, 3, 448)    0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 4, 3, 448)    1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 4, 3, 448)    0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 4, 3, 128)    57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 4, 3, 128)    0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 4, 3, 480)    0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 4, 3, 480)    1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 4, 3, 480)    0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 4, 3, 128)    61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 4, 3, 128)    0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 4, 3, 512)    0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 4, 3, 512)    2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 4, 3, 512)    0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 4, 3, 128)    65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 4, 3, 128)    512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 4, 3, 128)    0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 4, 3, 32)     36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 4, 3, 544)    0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 4, 3, 544)    2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 4, 3, 544)    0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 4, 3, 128)    69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 4, 3, 128)    512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 4, 3, 128)    0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 4, 3, 32)     36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 4, 3, 576)    0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 4, 3, 576)    2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 4, 3, 576)    0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 4, 3, 128)    73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 4, 3, 128)    512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 4, 3, 128)    0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 4, 3, 32)     36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 4, 3, 608)    0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 4, 3, 608)    2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 4, 3, 608)    0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 4, 3, 128)    77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 4, 3, 128)    512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 4, 3, 128)    0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 4, 3, 32)     36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, 4, 3, 640)    0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_0_bn (BatchNormal (None, 4, 3, 640)    2560        conv4_block12_concat[0][0]
# ...
# __________________________________________________________________________________________________
# conv5_block23_0_bn (BatchNormal (None, 2, 1, 1344)   5376        conv5_block22_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block23_0_relu (Activatio (None, 2, 1, 1344)   0           conv5_block23_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_conv (Conv2D)   (None, 2, 1, 128)    172032      conv5_block23_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_concat (Concatena (None, 2, 1, 1376)   0           conv5_block22_concat[0][0]
#                                                                  conv5_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_bn (BatchNormal (None, 2, 1, 1376)   5504        conv5_block23_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_relu (Activatio (None, 2, 1, 1376)   0           conv5_block24_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_conv (Conv2D)   (None, 2, 1, 128)    176128      conv5_block24_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block24_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block24_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block24_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_concat (Concatena (None, 2, 1, 1408)   0           conv5_block23_concat[0][0]
#                                                                  conv5_block24_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_bn (BatchNormal (None, 2, 1, 1408)   5632        conv5_block24_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_relu (Activatio (None, 2, 1, 1408)   0           conv5_block25_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_conv (Conv2D)   (None, 2, 1, 128)    180224      conv5_block25_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block25_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block25_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block25_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_concat (Concatena (None, 2, 1, 1440)   0           conv5_block24_concat[0][0]
#                                                                  conv5_block25_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_bn (BatchNormal (None, 2, 1, 1440)   5760        conv5_block25_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_relu (Activatio (None, 2, 1, 1440)   0           conv5_block26_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_conv (Conv2D)   (None, 2, 1, 128)    184320      conv5_block26_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block26_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block26_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block26_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_concat (Concatena (None, 2, 1, 1472)   0           conv5_block25_concat[0][0]
#                                                                  conv5_block26_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_bn (BatchNormal (None, 2, 1, 1472)   5888        conv5_block26_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_relu (Activatio (None, 2, 1, 1472)   0           conv5_block27_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_conv (Conv2D)   (None, 2, 1, 128)    188416      conv5_block27_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block27_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block27_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block27_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_concat (Concatena (None, 2, 1, 1504)   0           conv5_block26_concat[0][0]
#                                                                  conv5_block27_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_bn (BatchNormal (None, 2, 1, 1504)   6016        conv5_block27_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_relu (Activatio (None, 2, 1, 1504)   0           conv5_block28_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_conv (Conv2D)   (None, 2, 1, 128)    192512      conv5_block28_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block28_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block28_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block28_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_concat (Concatena (None, 2, 1, 1536)   0           conv5_block27_concat[0][0]
#                                                                  conv5_block28_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_bn (BatchNormal (None, 2, 1, 1536)   6144        conv5_block28_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_relu (Activatio (None, 2, 1, 1536)   0           conv5_block29_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_conv (Conv2D)   (None, 2, 1, 128)    196608      conv5_block29_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block29_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block29_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block29_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_concat (Concatena (None, 2, 1, 1568)   0           conv5_block28_concat[0][0]
#                                                                  conv5_block29_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_bn (BatchNormal (None, 2, 1, 1568)   6272        conv5_block29_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_relu (Activatio (None, 2, 1, 1568)   0           conv5_block30_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_conv (Conv2D)   (None, 2, 1, 128)    200704      conv5_block30_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block30_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block30_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block30_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_concat (Concatena (None, 2, 1, 1600)   0           conv5_block29_concat[0][0]
#                                                                  conv5_block30_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_bn (BatchNormal (None, 2, 1, 1600)   6400        conv5_block30_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_relu (Activatio (None, 2, 1, 1600)   0           conv5_block31_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_conv (Conv2D)   (None, 2, 1, 128)    204800      conv5_block31_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block31_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block31_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block31_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_concat (Concatena (None, 2, 1, 1632)   0           conv5_block30_concat[0][0]
#                                                                  conv5_block31_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_bn (BatchNormal (None, 2, 1, 1632)   6528        conv5_block31_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_relu (Activatio (None, 2, 1, 1632)   0           conv5_block32_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_conv (Conv2D)   (None, 2, 1, 128)    208896      conv5_block32_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_bn (BatchNormal (None, 2, 1, 128)    512         conv5_block32_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_relu (Activatio (None, 2, 1, 128)    0           conv5_block32_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_2_conv (Conv2D)   (None, 2, 1, 32)     36864       conv5_block32_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_concat (Concatena (None, 2, 1, 1664)   0           conv5_block31_concat[0][0]
#                                                                  conv5_block32_2_conv[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 3328)         0           conv5_block32_concat[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1024)         3408896     flatten_11[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 512)          524800      dense_17[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 2)            1026        dense_18[0][0]
# ==================================================================================================
# Total params: 16,570,946
# Trainable params: 16,415,874
# Non-trainable params: 155,072
# __________________________________________________________________________________________________

# %%
custom_model.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.0005), metrics=['accuracy'])

# %% [markdown]
# ### Load one file and label

# %%
# load label

import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset'

AllLabelFile = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if "head.txt" in file :
            AllLabelFile.append(os.path.join(r, file))
        
for f in AllLabelFile:
    print(f)
np.array(AllLabelFile).shape
# Out:
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\001_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\001_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\001_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\001_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\001_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\001_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\001_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\001_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\001_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\001_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\001_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\001_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\001_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\001_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\001_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\001_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\001_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\001_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\001_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\001_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\002_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\002_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\002_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\002_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\nightglasses\002_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\nightglasses\002_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\nightglasses\002_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\nightglasses\002_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\night_noglasses\002_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\night_noglasses\002_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\night_noglasses\002_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\night_noglasses\002_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\noglasses\002_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\noglasses\002_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\noglasses\002_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\noglasses\002_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\sunglasses\002_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\sunglasses\002_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\sunglasses\002_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\sunglasses\002_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\glasses\005_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\glasses\005_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\glasses\005_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\glasses\005_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\night_noglasses\005_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\night_noglasses\005_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\night_noglasses\005_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\night_noglasses\005_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\noglasses\005_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\noglasses\005_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\noglasses\005_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\noglasses\005_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\sunglasses\005_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\sunglasses\005_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\sunglasses\005_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\sunglasses\005_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\glasses\006_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\glasses\006_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\glasses\006_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\glasses\006_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\nightglasses\006_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\nightglasses\006_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\nightglasses\006_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\nightglasses\006_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\night_noglasses\006_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\night_noglasses\006_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\night_noglasses\006_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\night_noglasses\006_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\noglasses\006_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\noglasses\006_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\noglasses\006_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\noglasses\006_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\sunglasses\006_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\sunglasses\006_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\sunglasses\006_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\sunglasses\006_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\glasses\008_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\glasses\008_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\glasses\008_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\glasses\008_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\nightglasses\008_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\nightglasses\008_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\nightglasses\008_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\nightglasses\008_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\night_noglasses\008_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\night_noglasses\008_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\night_noglasses\008_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\night_noglasses\008_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\noglasses\008_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\noglasses\008_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\noglasses\008_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\noglasses\008_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\sunglasses\008_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\sunglasses\008_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\sunglasses\008_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\sunglasses\008_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\glasses\009_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\glasses\009_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\glasses\009_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\glasses\009_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\nightglasses\009_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\nightglasses\009_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\nightglasses\009_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\nightglasses\009_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\night_noglasses\009_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\night_noglasses\009_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\night_noglasses\009_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\night_noglasses\009_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\noglasses\009_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\noglasses\009_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\noglasses\009_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\noglasses\009_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\sunglasses\009_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\sunglasses\009_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\sunglasses\009_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\sunglasses\009_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\glasses\012_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\glasses\012_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\glasses\012_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\glasses\012_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\nightglasses\012_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\nightglasses\012_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\nightglasses\012_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\nightglasses\012_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\night_noglasses\012_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\night_noglasses\012_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\night_noglasses\012_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\night_noglasses\012_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\noglasses\012_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\noglasses\012_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\noglasses\012_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\noglasses\012_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\sunglasses\012_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\sunglasses\012_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\sunglasses\012_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\sunglasses\012_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\glasses\013_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\glasses\013_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\glasses\013_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\glasses\013_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\nightglasses\013_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\nightglasses\013_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\nightglasses\013_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\nightglasses\013_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\night_noglasses\013_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\night_noglasses\013_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\night_noglasses\013_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\night_noglasses\013_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\noglasses\013_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\noglasses\013_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\noglasses\013_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\noglasses\013_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\sunglasses\013_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\sunglasses\013_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\sunglasses\013_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\sunglasses\013_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\glasses\015_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\glasses\015_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\glasses\015_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\glasses\015_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\nightglasses\015_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\nightglasses\015_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\nightglasses\015_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\nightglasses\015_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\night_noglasses\015_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\night_noglasses\015_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\night_noglasses\015_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\night_noglasses\015_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\noglasses\015_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\noglasses\015_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\noglasses\015_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\noglasses\015_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\sunglasses\015_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\sunglasses\015_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\sunglasses\015_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\sunglasses\015_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\glasses\020_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\glasses\020_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\glasses\020_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\glasses\020_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\nightglasses\020_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\nightglasses\020_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\nightglasses\020_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\nightglasses\020_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\night_noglasses\020_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\night_noglasses\020_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\night_noglasses\020_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\night_noglasses\020_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\noglasses\020_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\noglasses\020_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\noglasses\020_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\noglasses\020_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\sunglasses\020_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\sunglasses\020_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\sunglasses\020_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\sunglasses\020_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\glasses\023_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\glasses\023_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\glasses\023_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\glasses\023_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\nightglasses\023_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\nightglasses\023_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\nightglasses\023_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\nightglasses\023_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\night_noglasses\023_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\night_noglasses\023_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\night_noglasses\023_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\night_noglasses\023_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\023_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\023_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\023_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\023_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\sunglasses\023_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\sunglasses\023_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\sunglasses\023_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\sunglasses\023_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\glasses\024_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\glasses\024_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\glasses\024_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\glasses\024_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\nightglasses\024_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\nightglasses\024_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\nightglasses\024_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\nightglasses\024_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\night_noglasses\024_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\night_noglasses\024_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\night_noglasses\024_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\night_noglasses\024_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\noglasses\024_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\noglasses\024_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\noglasses\024_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\noglasses\024_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\sunglasses\024_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\sunglasses\024_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\sunglasses\024_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\sunglasses\024_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\glasses\031_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\glasses\031_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\glasses\031_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\glasses\031_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\nightglasses\031_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\nightglasses\031_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\nightglasses\031_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\nightglasses\031_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\night_noglasses\031_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\night_noglasses\031_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\night_noglasses\031_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\night_noglasses\031_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\noglasses\031_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\noglasses\031_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\noglasses\031_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\noglasses\031_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\sunglasses\031_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\sunglasses\031_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\sunglasses\031_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\sunglasses\031_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\glasses\032_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\glasses\032_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\glasses\032_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\glasses\032_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\nightglasses\032_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\nightglasses\032_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\nightglasses\032_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\nightglasses\032_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\night_noglasses\032_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\night_noglasses\032_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\night_noglasses\032_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\night_noglasses\032_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\noglasses\032_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\noglasses\032_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\noglasses\032_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\noglasses\032_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\sunglasses\032_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\sunglasses\032_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\sunglasses\032_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\sunglasses\032_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\glasses\033_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\glasses\033_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\glasses\033_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\glasses\033_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\nightglasses\033_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\nightglasses\033_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\nightglasses\033_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\nightglasses\033_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\night_noglasses\033_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\night_noglasses\033_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\night_noglasses\033_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\night_noglasses\033_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\noglasses\033_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\noglasses\033_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\noglasses\033_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\noglasses\033_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\sunglasses\033_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\sunglasses\033_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\sunglasses\033_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\sunglasses\033_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\glasses\034_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\glasses\034_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\glasses\034_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\glasses\034_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\nightglasses\034_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\nightglasses\034_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\nightglasses\034_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\nightglasses\034_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\night_noglasses\034_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\night_noglasses\034_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\night_noglasses\034_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\night_noglasses\034_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\noglasses\034_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\noglasses\034_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\noglasses\034_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\noglasses\034_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\sunglasses\034_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\sunglasses\034_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\sunglasses\034_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\sunglasses\034_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\glasses\035_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\glasses\035_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\glasses\035_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\glasses\035_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\nightglasses\035_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\nightglasses\035_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\nightglasses\035_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\nightglasses\035_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\night_noglasses\035_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\night_noglasses\035_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\night_noglasses\035_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\night_noglasses\035_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\noglasses\035_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\noglasses\035_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\noglasses\035_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\noglasses\035_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\sunglasses\035_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\sunglasses\035_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\sunglasses\035_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\sunglasses\035_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\glasses\036_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\glasses\036_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\glasses\036_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\glasses\036_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\nightglasses\036_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\nightglasses\036_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\nightglasses\036_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\nightglasses\036_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\night_noglasses\036_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\night_noglasses\036_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\night_noglasses\036_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\night_noglasses\036_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\noglasses\036_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\noglasses\036_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\noglasses\036_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\noglasses\036_yawning_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\sunglasses\036_nonsleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\sunglasses\036_sleepyCombination_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\sunglasses\036_slowBlinkWithNodding_head.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\sunglasses\036_yawning_head.txt
# (356,)

# %%
import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Training Image'

AllImageFolder = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for directory in d:
        if ("nonsleepyCombination" in directory or "sleepyCombination" in directory or "slowBlinkWithNodding"  in directory or "yawning" in directory)   :
            #print(directory)
            AllImageFolder.append(os.path.join(r, directory))
        
for d in AllImageFolder:
    print(d)
np.array(AllImageFolder).shape
# Out:
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\sunglasses\yawning
# (356,)

# %%
num_samples = 235578
batch_size = 200

# %%
import numpy as np
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import cv2
from math import ceil

from keras.callbacks import EarlyStopping




def LoadImageandLabel(batch_size,AllVideoImageFolder,AllLabelFile):
    #print(Originalpath)
    count=0
    
    while True:
        LabelFileindex = 0
        for Originalpath in AllVideoImageFolder:

            labelPath = AllLabelFile[LabelFileindex]
            LabelFileindex = LabelFileindex + 1

            Face_ImageDataList = []
            Eyes_ImageDataList = []
            Mouth_ImageDataList = []
            #=====load all label in a video
            LabelList = []
            TempLabelList = []
            inputfile = open(labelPath, 'r').read()
            TempLabelList = list(map(int, inputfile))

            #=========================

            TEMP_ImageDataList = []

            path = Originalpath+"\\face"


            #=====find all files in path=======    
            Facefiles = []
            Eyefiles = []
            Mouthfiles = []
            # r=root, d=directories, f = files
            for r, d, f in os.walk(path):
                for file in f:
                    if ".jpg" in file:
                        temp = os.path.join(r, file)
                        
                        Facefiles.append(temp)
                        '''
                        Eyefiles.append(temp.replace("face", "eyes"))
                        Mouthfiles.append(temp.replace("face", "mouth"))
                        '''

            Facefiles.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
            '''
            Eyefiles.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
            Mouthfiles.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
            '''
            for FileIndex in range(len(Facefiles)):
                #======================load label

                index = Facefiles[FileIndex].find('frame')
                framenumber =int(Facefiles[FileIndex][index+5:-4]) 

                #print(framenumber)

                #if(judgeflag == 0 and TempLabelList[framenumber-1] == 1):
                #    judgeflag = 1
                    #print(framenumber-1)

                #Labelarray = np.array(LabelList)
                #print(TempLabelList[framenumber-1])
                Labelarray = to_categorical(TempLabelList[framenumber-1], num_classes=3)
                LabelList.append(Labelarray)
                
                


                    #Labelarray = np.array(LabelList)
                    #Labelarray = to_categorical(Labelarray, num_classes=2)

                #================================
                ImgGray = cv2.imread(Facefiles[FileIndex],0)
                #ImgRGB = cv2.merge((ImgGray,ImgGray,ImgGray))# this line make gray image to RGB
                #TEMP_ImageDataList.append(ImgRGB)  
                
                ImgGray = ImgGray.reshape(ImgGray.shape[0],ImgGray.shape[1],1)
                #ImgGray = cv2.merge((ImgGray,ImgGray,ImgGray))
                
                #print(ImgGray.shape)
                Face_ImageDataList.append(ImgGray)
                #print(np.array(Face_ImageDataList).shape)
                '''
                ImgGray = cv2.imread(Mouthfiles[FileIndex],0)
                ImgGray = ImgGray.reshape(ImgGray.shape[0],ImgGray.shape[1],1)
                Mouth_ImageDataList.append(ImgGray)


                ImgGray = cv2.imread(Eyefiles[FileIndex],0)
                ImgGray = ImgGray.reshape(ImgGray.shape[0],ImgGray.shape[1],1)
                Eyes_ImageDataList.append(ImgGray)
                '''
                 #====================================
               
                count = count +1
                if count>=batch_size:
                        #yield(np.array(Face_ImageDataList),np.array(LabelList))
                        yield ([np.array(Face_ImageDataList)],np.array(LabelList))
                        count=0
                        Face_ImageDataList = []
                        Eyes_ImageDataList = []
                        Mouth_ImageDataList = []
                        LabelList = []
               
            '''
            print(np.array(Eyes_ImageDataList).shape)
            print(np.array(Face_ImageDataList).shape)
            print(np.array(Mouth_ImageDataList).shape)
            Face_ImageDataList = []
            Eyes_ImageDataList = []
            Mouth_ImageDataList = []
            LabelList = []
            '''
            #return Face_ImageDataList , Mouth_ImageDataList , Eyes_ImageDataList
            



#for epoch in range(50):
   # index = 0
#for Video in AllImageFolder:

    #if(index == 0 ):
    #    index = index + 1
    #    continue
    #print("---")
    #=========================load file

   # faceImage = []
   # mouthImage = []
   # eyesImage = []


    #print("label: "+labelfile)
    #==================================
    #LoadImageandLabel(50,AllImageFolder,AllLabelFile)
    #faceImage,mouthImage,eyesImage = LoadImageandLabel(50,,AllImageFolder,AllLabelFile)

    #print(eyesImage)

    #print(np.array(eyesImage).shape)
    #print(np.array(faceImage).shape)
    #print(np.array(mouthImage).shape)

    #print("---")
    #print("---")
    #print("---")
    #print(faceImage[1])
    
    
#earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='auto')

model.fit_generator(LoadImageandLabel(batch_size,AllImageFolder,AllLabelFile),
                steps_per_epoch=ceil(num_samples / batch_size),
                epochs=100,
                #callbacks=[earlyStopping],
                workers = 5
                )
    
#loss ,accuracy= model2.evaluate_generator(LoadImageandLabel(50,AllImageFolder,AllLabelFile), steps=5)
    
    #model_result = model2.fit([eyesImage,mouthImage,faceImage], Labelarray,batch_size=20,epochs=epoch+1, initial_epoch=epoch, shuffle=True,verbose = 1)
# Out:
# Using TensorFlow backend.
# Epoch 1/100
# 1178/1178 [==============================] - 455s 386ms/step - loss: 0.2929 - acc: 0.9271
# Epoch 2/100
# 1178/1178 [==============================] - 296s 251ms/step - loss: 0.1677 - acc: 0.9482
# Epoch 3/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.1421 - acc: 0.9539
# Epoch 4/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.1174 - acc: 0.9613
# Epoch 5/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.1062 - acc: 0.9642
# Epoch 6/100
# 1178/1178 [==============================] - 256s 217ms/step - loss: 0.1420 - acc: 0.9585
# Epoch 7/100
# 1178/1178 [==============================] - 256s 218ms/step - loss: 0.1022 - acc: 0.9642
# Epoch 8/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0913 - acc: 0.9682
# Epoch 9/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0902 - acc: 0.9681
# Epoch 10/100
# 1178/1178 [==============================] - 255s 216ms/step - loss: 0.0968 - acc: 0.9679
# Epoch 11/100
# 1178/1178 [==============================] - 256s 218ms/step - loss: 0.0836 - acc: 0.9712
# Epoch 12/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0803 - acc: 0.9722
# Epoch 13/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0722 - acc: 0.9748
# Epoch 14/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0666 - acc: 0.9769
# Epoch 15/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0679 - acc: 0.9765
# Epoch 16/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0624 - acc: 0.9776
# Epoch 17/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0630 - acc: 0.9776
# Epoch 18/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0621 - acc: 0.9780
# Epoch 19/100
# 1178/1178 [==============================] - 256s 217ms/step - loss: 0.0599 - acc: 0.9792
# Epoch 20/100
# 1178/1178 [==============================] - 256s 218ms/step - loss: 0.0578 - acc: 0.9798
# Epoch 21/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0555 - acc: 0.9804
# Epoch 22/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0536 - acc: 0.9812
# Epoch 23/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0518 - acc: 0.9816
# Epoch 24/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0527 - acc: 0.9815
# Epoch 25/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0469 - acc: 0.9832
# Epoch 26/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0463 - acc: 0.9832
# Epoch 27/100
# 1178/1178 [==============================] - 260s 220ms/step - loss: 0.0497 - acc: 0.9824
# Epoch 28/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0468 - acc: 0.9831
# Epoch 29/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0435 - acc: 0.9847
# Epoch 30/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0440 - acc: 0.9844
# Epoch 31/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0427 - acc: 0.9846
# Epoch 32/100
# 1178/1178 [==============================] - 260s 221ms/step - loss: 0.0417 - acc: 0.9850
# Epoch 33/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0398 - acc: 0.9855
# Epoch 34/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0369 - acc: 0.9865
# Epoch 35/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0390 - acc: 0.9858
# Epoch 36/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0384 - acc: 0.9862
# Epoch 37/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0369 - acc: 0.9867
# Epoch 38/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0358 - acc: 0.9871
# Epoch 39/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0351 - acc: 0.9874
# Epoch 40/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0341 - acc: 0.9876
# Epoch 41/100
# 1178/1178 [==============================] - 260s 221ms/step - loss: 0.0317 - acc: 0.9888
# Epoch 42/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0339 - acc: 0.9877
# Epoch 43/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0313 - acc: 0.9888
# Epoch 44/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0312 - acc: 0.9887
# Epoch 45/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0290 - acc: 0.9897
# Epoch 46/100
# 1178/1178 [==============================] - 260s 221ms/step - loss: 0.0294 - acc: 0.9895s - loss: 0.0293 - acc
# Epoch 47/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0278 - acc: 0.9902
# Epoch 48/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0265 - acc: 0.9902
# Epoch 49/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0290 - acc: 0.9896
# Epoch 50/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0265 - acc: 0.9904
# Epoch 51/100
# 1178/1178 [==============================] - 260s 220ms/step - loss: 0.0238 - acc: 0.9915
# Epoch 52/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0234 - acc: 0.9914
# Epoch 53/100
# 1178/1178 [==============================] - 260s 220ms/step - loss: 0.0247 - acc: 0.9911
# Epoch 54/100
# 1178/1178 [==============================] - 260s 221ms/step - loss: 0.0247 - acc: 0.9912
# Epoch 55/100
# 1178/1178 [==============================] - 260s 221ms/step - loss: 0.0217 - acc: 0.9921
# Epoch 56/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0215 - acc: 0.9924
# Epoch 57/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0213 - acc: 0.9920
# Epoch 58/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0213 - acc: 0.9923
# Epoch 59/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0195 - acc: 0.9930
# Epoch 60/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0203 - acc: 0.9925
# Epoch 61/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0199 - acc: 0.9930
# Epoch 62/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0171 - acc: 0.9940
# Epoch 63/100
# 1178/1178 [==============================] - 260s 221ms/step - loss: 0.0188 - acc: 0.9935
# Epoch 64/100
# 1178/1178 [==============================] - 260s 221ms/step - loss: 0.0172 - acc: 0.9939
# Epoch 65/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0167 - acc: 0.9939
# Epoch 66/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0181 - acc: 0.9936
# Epoch 67/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0166 - acc: 0.9942
# Epoch 68/100
# 1178/1178 [==============================] - 260s 220ms/step - loss: 0.0151 - acc: 0.9946
# Epoch 69/100
# 1178/1178 [==============================] - 260s 220ms/step - loss: 0.0150 - acc: 0.9947
# Epoch 70/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0183 - acc: 0.9935
# Epoch 71/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0132 - acc: 0.9955
# Epoch 72/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0134 - acc: 0.9951
# Epoch 73/100
# 1178/1178 [==============================] - 260s 221ms/step - loss: 0.0149 - acc: 0.9948
# Epoch 74/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0145 - acc: 0.9949
# Epoch 75/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0121 - acc: 0.9957
# Epoch 76/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0126 - acc: 0.9955
# Epoch 77/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0145 - acc: 0.9949
# Epoch 78/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0154 - acc: 0.9946
# Epoch 79/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0125 - acc: 0.9955
# Epoch 80/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0111 - acc: 0.9961
# Epoch 81/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0119 - acc: 0.9957
# Epoch 82/100
# 1178/1178 [==============================] - 260s 220ms/step - loss: 0.0114 - acc: 0.9959
# Epoch 83/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0136 - acc: 0.9953
# Epoch 84/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0120 - acc: 0.9957
# Epoch 85/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0111 - acc: 0.9960
# Epoch 86/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0106 - acc: 0.9963
# Epoch 87/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0116 - acc: 0.9964
# Epoch 88/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0099 - acc: 0.9967
# Epoch 89/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0091 - acc: 0.9969
# Epoch 90/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0092 - acc: 0.9968
# Epoch 91/100
# 1178/1178 [==============================] - 260s 220ms/step - loss: 0.0116 - acc: 0.9961
# Epoch 92/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0109 - acc: 0.9961
# Epoch 93/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0091 - acc: 0.9970
# Epoch 94/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0083 - acc: 0.9971
# Epoch 95/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0095 - acc: 0.9968
# Epoch 96/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0100 - acc: 0.9967
# Epoch 97/100
# 1178/1178 [==============================] - 257s 218ms/step - loss: 0.0099 - acc: 0.9967
# Epoch 98/100
# 1178/1178 [==============================] - 258s 219ms/step - loss: 0.0088 - acc: 0.9970
# Epoch 99/100
# 1178/1178 [==============================] - 260s 221ms/step - loss: 0.0083 - acc: 0.9972
# Epoch 100/100
# 1178/1178 [==============================] - 259s 220ms/step - loss: 0.0078 - acc: 0.9974

# %%
model_json = model.to_json()
open('ModelFace.json', 'w').write(model_json)
model.save_weights('ModelFace.h5')

# %% [markdown]
# 1.dataGenerator <br/>
# 2.Image 減小

# %%
earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='auto')

model2.fit_generator(LoadImageandLabel(batch_size,AllImageFolder,AllLabelFile),
                steps_per_epoch=ceil(num_samples / batch_size),
                epochs=100,
                callbacks=[earlyStopping],
                workers = 5
                )
    
loss ,accuracy= model2.evaluate_generator(LoadImageandLabel(50,AllImageFolder,AllLabelFile), steps=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-87a721996582> in <module>()
#       1 earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='auto')
#       2
# ----> 3 model2.fit_generator(LoadImageandLabel(batch_size,AllImageFolder,AllLabelFile),
#       4                 steps_per_epoch=ceil(num_samples / batch_size),
#       5                 epochs=10,
#
# NameError: name 'model2' is not defined

# %% [markdown]
# ### Eyes

# %%
# %run ./Model.ipynb
# Out:
# C:\Users\T-Rex\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
eyes_width = 45
eyes_height = 25
mouth_width = 35
mouth_height = 25
face_width = 50
face_height = 64
num_classes = 2
channel = 1

# %%
eyes1 = Input(shape=(eyes_height,eyes_width,1))

#x = incresA(eyes1,0.15,name='incresA_1')

conv11 = Conv2D(64, kernel_size=(3, 3), activation='relu',padding = 'same')(eyes1)
pool11 = MaxPooling2D(pool_size=(2, 2))(conv11)
conv12 = Conv2D(128, kernel_size=(3, 3), activation='relu',padding = 'same')(pool11)
pool12 = MaxPooling2D(pool_size=(2, 2))(conv12)
conv13 = Conv2D(256, kernel_size=(3, 3), activation='relu',padding = 'same')(pool12)
pool13 = MaxPooling2D(pool_size=(2, 2))(conv13)
conv14 = Conv2D(512, kernel_size=(3, 3), activation='relu',padding = 'same')(pool13)

#pool13 = MaxPooling2D(pool_size=(2, 2))(conv13)
#flat1 = Flatten()(pool12)
pool14 = GlobalAveragePooling2D(data_format='channels_last')(conv14)
flat1 = Flatten()(pool14)
output = Dense(num_classes, activation='softmax')(flat1)

'''
flat1 = Flatten()(x)

output = Dense(num_classes, activation='softmax')(flat1)
'''



EyeModel = Model(inputs=[eyes1], outputs=output, name='inception_resnet_v2')
EyeModel.summary()
EyeModel.compile(loss='binary_crossentropy', optimizer=Adam(lr = 0.0005), metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 25, 45, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 25, 45, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 22, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 12, 22, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 11, 128)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 6, 11, 256)        295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 5, 256)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 5, 512)         1180160
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 1026
# =================================================================
# Total params: 1,550,850
# Trainable params: 1,550,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
# load label

import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset'

AllLabelFile = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if "eye.txt" in file :
            AllLabelFile.append(os.path.join(r, file))
        
for f in AllLabelFile:
    print(f)
np.array(AllLabelFile).shape
# Out:
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\001_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\001_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\001_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\001_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\001_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\001_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\001_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\001_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\001_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\001_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\001_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\001_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\001_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\001_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\001_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\001_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\001_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\001_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\001_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\001_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\002_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\002_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\002_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\002_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\nightglasses\002_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\nightglasses\002_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\nightglasses\002_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\nightglasses\002_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\night_noglasses\002_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\night_noglasses\002_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\night_noglasses\002_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\night_noglasses\002_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\noglasses\002_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\noglasses\002_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\noglasses\002_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\noglasses\002_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\sunglasses\002_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\sunglasses\002_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\sunglasses\002_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\sunglasses\002_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\glasses\005_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\glasses\005_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\glasses\005_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\glasses\005_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\night_noglasses\005_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\night_noglasses\005_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\night_noglasses\005_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\night_noglasses\005_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\noglasses\005_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\noglasses\005_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\noglasses\005_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\noglasses\005_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\sunglasses\005_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\sunglasses\005_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\sunglasses\005_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\sunglasses\005_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\glasses\006_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\glasses\006_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\glasses\006_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\glasses\006_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\nightglasses\006_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\nightglasses\006_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\nightglasses\006_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\nightglasses\006_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\night_noglasses\006_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\night_noglasses\006_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\night_noglasses\006_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\night_noglasses\006_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\noglasses\006_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\noglasses\006_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\noglasses\006_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\noglasses\006_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\sunglasses\006_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\sunglasses\006_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\sunglasses\006_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\sunglasses\006_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\glasses\008_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\glasses\008_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\glasses\008_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\glasses\008_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\nightglasses\008_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\nightglasses\008_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\nightglasses\008_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\nightglasses\008_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\night_noglasses\008_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\night_noglasses\008_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\night_noglasses\008_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\night_noglasses\008_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\noglasses\008_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\noglasses\008_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\noglasses\008_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\noglasses\008_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\sunglasses\008_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\sunglasses\008_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\sunglasses\008_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\sunglasses\008_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\glasses\009_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\glasses\009_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\glasses\009_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\glasses\009_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\nightglasses\009_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\nightglasses\009_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\nightglasses\009_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\nightglasses\009_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\night_noglasses\009_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\night_noglasses\009_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\night_noglasses\009_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\night_noglasses\009_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\noglasses\009_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\noglasses\009_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\noglasses\009_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\noglasses\009_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\sunglasses\009_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\sunglasses\009_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\sunglasses\009_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\sunglasses\009_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\glasses\012_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\glasses\012_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\glasses\012_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\glasses\012_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\nightglasses\012_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\nightglasses\012_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\nightglasses\012_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\nightglasses\012_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\night_noglasses\012_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\night_noglasses\012_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\night_noglasses\012_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\night_noglasses\012_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\noglasses\012_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\noglasses\012_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\noglasses\012_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\noglasses\012_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\sunglasses\012_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\sunglasses\012_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\sunglasses\012_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\sunglasses\012_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\glasses\013_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\glasses\013_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\glasses\013_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\glasses\013_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\nightglasses\013_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\nightglasses\013_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\nightglasses\013_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\nightglasses\013_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\night_noglasses\013_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\night_noglasses\013_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\night_noglasses\013_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\night_noglasses\013_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\noglasses\013_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\noglasses\013_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\noglasses\013_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\noglasses\013_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\sunglasses\013_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\sunglasses\013_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\sunglasses\013_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\sunglasses\013_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\glasses\015_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\glasses\015_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\glasses\015_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\glasses\015_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\nightglasses\015_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\nightglasses\015_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\nightglasses\015_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\nightglasses\015_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\night_noglasses\015_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\night_noglasses\015_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\night_noglasses\015_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\night_noglasses\015_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\noglasses\015_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\noglasses\015_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\noglasses\015_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\noglasses\015_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\sunglasses\015_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\sunglasses\015_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\sunglasses\015_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\sunglasses\015_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\glasses\020_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\glasses\020_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\glasses\020_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\glasses\020_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\nightglasses\020_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\nightglasses\020_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\nightglasses\020_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\nightglasses\020_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\night_noglasses\020_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\night_noglasses\020_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\night_noglasses\020_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\night_noglasses\020_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\noglasses\020_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\noglasses\020_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\noglasses\020_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\noglasses\020_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\sunglasses\020_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\sunglasses\020_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\sunglasses\020_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\sunglasses\020_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\glasses\023_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\glasses\023_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\glasses\023_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\glasses\023_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\nightglasses\023_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\nightglasses\023_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\nightglasses\023_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\nightglasses\023_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\night_noglasses\023_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\night_noglasses\023_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\night_noglasses\023_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\night_noglasses\023_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\023_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\023_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\023_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\023_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\sunglasses\023_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\sunglasses\023_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\sunglasses\023_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\sunglasses\023_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\glasses\024_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\glasses\024_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\glasses\024_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\glasses\024_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\nightglasses\024_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\nightglasses\024_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\nightglasses\024_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\nightglasses\024_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\night_noglasses\024_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\night_noglasses\024_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\night_noglasses\024_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\night_noglasses\024_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\noglasses\024_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\noglasses\024_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\noglasses\024_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\noglasses\024_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\sunglasses\024_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\sunglasses\024_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\sunglasses\024_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\sunglasses\024_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\glasses\031_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\glasses\031_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\glasses\031_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\glasses\031_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\nightglasses\031_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\nightglasses\031_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\nightglasses\031_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\nightglasses\031_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\night_noglasses\031_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\night_noglasses\031_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\night_noglasses\031_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\night_noglasses\031_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\noglasses\031_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\noglasses\031_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\noglasses\031_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\noglasses\031_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\sunglasses\031_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\sunglasses\031_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\sunglasses\031_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\sunglasses\031_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\glasses\032_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\glasses\032_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\glasses\032_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\glasses\032_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\nightglasses\032_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\nightglasses\032_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\nightglasses\032_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\nightglasses\032_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\night_noglasses\032_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\night_noglasses\032_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\night_noglasses\032_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\night_noglasses\032_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\noglasses\032_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\noglasses\032_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\noglasses\032_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\noglasses\032_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\sunglasses\032_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\sunglasses\032_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\sunglasses\032_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\sunglasses\032_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\glasses\033_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\glasses\033_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\glasses\033_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\glasses\033_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\nightglasses\033_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\nightglasses\033_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\nightglasses\033_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\nightglasses\033_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\night_noglasses\033_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\night_noglasses\033_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\night_noglasses\033_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\night_noglasses\033_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\noglasses\033_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\noglasses\033_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\noglasses\033_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\noglasses\033_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\sunglasses\033_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\sunglasses\033_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\sunglasses\033_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\sunglasses\033_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\glasses\034_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\glasses\034_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\glasses\034_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\glasses\034_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\nightglasses\034_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\nightglasses\034_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\nightglasses\034_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\nightglasses\034_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\night_noglasses\034_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\night_noglasses\034_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\night_noglasses\034_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\night_noglasses\034_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\noglasses\034_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\noglasses\034_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\noglasses\034_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\noglasses\034_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\sunglasses\034_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\sunglasses\034_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\sunglasses\034_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\sunglasses\034_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\glasses\035_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\glasses\035_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\glasses\035_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\glasses\035_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\nightglasses\035_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\nightglasses\035_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\nightglasses\035_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\nightglasses\035_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\night_noglasses\035_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\night_noglasses\035_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\night_noglasses\035_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\night_noglasses\035_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\noglasses\035_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\noglasses\035_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\noglasses\035_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\noglasses\035_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\sunglasses\035_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\sunglasses\035_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\sunglasses\035_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\sunglasses\035_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\glasses\036_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\glasses\036_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\glasses\036_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\glasses\036_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\nightglasses\036_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\nightglasses\036_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\nightglasses\036_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\nightglasses\036_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\night_noglasses\036_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\night_noglasses\036_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\night_noglasses\036_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\night_noglasses\036_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\noglasses\036_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\noglasses\036_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\noglasses\036_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\noglasses\036_yawning_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\sunglasses\036_nonsleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\sunglasses\036_sleepyCombination_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\sunglasses\036_slowBlinkWithNodding_eye.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\sunglasses\036_yawning_eye.txt
# (356,)

# %%
import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Training Image'

AllImageFolder = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for directory in d:
        if ("nonsleepyCombination" in directory or "sleepyCombination" in directory or "slowBlinkWithNodding"  in directory or "yawning" in directory)   :
            #print(directory)
            AllImageFolder.append(os.path.join(r, directory))
        
for d in AllImageFolder:
    print(d)
np.array(AllImageFolder).shape
# Out:
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\sunglasses\yawning
# (356,)

# %%
num_samples = 235578
batch_size = 200

# %%
import numpy as np
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import cv2
from math import ceil

from keras.callbacks import EarlyStopping




def LoadImageandLabel(batch_size,AllVideoImageFolder,AllLabelFile):
    #print(Originalpath)
    count=0
    
    while True:
        LabelFileindex = 0
        for Originalpath in AllVideoImageFolder:

            labelPath = AllLabelFile[LabelFileindex]
            LabelFileindex = LabelFileindex + 1

            Face_ImageDataList = []
            Eyes_ImageDataList = []
            Mouth_ImageDataList = []
            #=====load all label in a video
            LabelList = []
            TempLabelList = []
            inputfile = open(labelPath, 'r').read()
            TempLabelList = list(map(int, inputfile))

            #=========================

            TEMP_ImageDataList = []

            path = Originalpath+"\\face"


            #=====find all files in path=======    
            Facefiles = []
            Eyefiles = []
            Mouthfiles = []
            # r=root, d=directories, f = files
            for r, d, f in os.walk(path):
                for file in f:
                    if ".jpg" in file:
                        temp = os.path.join(r, file)
                        Eyefiles.append(temp.replace("face", "eyes"))

            Eyefiles.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
            for FileIndex in range(len(Eyefiles)):
                #======================load label

                index = Eyefiles[FileIndex].find('frame')
                framenumber =int(Eyefiles[FileIndex][index+5:-4]) 

                Labelarray = to_categorical(TempLabelList[framenumber-1], num_classes=2)
                LabelList.append(Labelarray)

                #================================
                ImgGray = cv2.imread(Eyefiles[FileIndex],0)
                ImgGray = ImgGray.reshape(ImgGray.shape[0],ImgGray.shape[1],1)

                Eyes_ImageDataList.append(ImgGray)

                 #====================================
               
                count = count +1
                if count>=batch_size:
                        #yield(np.array(Face_ImageDataList),np.array(LabelList))
                        yield ([np.array(Eyes_ImageDataList)],np.array(LabelList))
                        count=0
                        Face_ImageDataList = []
                        Eyes_ImageDataList = []
                        Mouth_ImageDataList = []
                        LabelList = []


EyeModel.fit_generator(LoadImageandLabel(batch_size,AllImageFolder,AllLabelFile),
                steps_per_epoch=ceil(num_samples / batch_size),
                epochs=100,
                #callbacks=[earlyStopping],
                workers = 5
                )
# Out:
# Using TensorFlow backend.
# Epoch 1/100
# 1178/1178 [==============================] - 41s 35ms/step - loss: 7.7713 - acc: 0.5144
# Epoch 2/100
# 1178/1178 [==============================] - 32s 27ms/step - loss: 7.8164 - acc: 0.5124
# Epoch 3/100
# 1178/1178 [==============================] - 33s 28ms/step - loss: 7.7792 - acc: 0.5147 7s - loss: 7.5969 - acc: 0.5 - ETA:
# Epoch 4/100
#  178/1178 [===>..........................] - ETA: 27s - loss: 7.9257 - acc: 0.5056
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-fc17ea4fd61d> in <module>()
#      81                 epochs=100,
#      82                 #callbacks=[earlyStopping],
# ---> 83                 workers = 5
#      84                 )
#      85
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2175         use_multiprocessing=use_multiprocessing,
#    2176         shuffle=shuffle,
# -> 2177         initial_epoch=initial_epoch)
#    2178
#    2179   def evaluate_generator(self,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     145       batch_index = 0
#     146       while steps_done < steps_per_epoch:
# --> 147         generator_output = next(output_generator)
#     148
#     149         if not hasattr(generator_output, '__len__'):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\utils\data_utils.py in get(self)
#     823           raise StopIteration()
#     824         else:
# --> 825           time.sleep(self.wait_time)
#     826
#     827     # Make sure to rethrow the first exception in the queue, if any
#
# KeyboardInterrupt:

# %% [markdown]
# ### mouth

# %%
# %run ./Model.ipynb
# Out:
# C:\Users\T-Rex\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
eyes_width = 45
eyes_height = 25
mouth_width = 35
mouth_height = 25
face_width = 50
face_height = 64
num_classes = 3
channel = 1

# %%
mouth1 = Input(shape=(face_height,face_width,1))

x = incresA(mouth1,0.15,name='incresA_1')

'''conv11 = Conv2D(32, kernel_size=(3, 3), activation='relu')(mouth1)
pool11 = MaxPooling2D(pool_size=(2, 2))(conv11)
conv12 = Conv2D(64, kernel_size=(3, 3), activation='relu')(pool11)
pool12 = MaxPooling2D(pool_size=(2, 2))(conv12)
conv13 = Conv2D(128, kernel_size=(3, 3), activation='relu',padding = 'same')(pool12)
pool13 = MaxPooling2D(pool_size=(2, 2))(conv13)
#flat1 = Flatten()(pool12)
#pool14 = GlobalAveragePooling2D(data_format='channels_last')(conv14)
flat1 = Flatten()(pool13)
output = Dense(num_classes, activation='softmax')(flat1)

'''
flat1 = Flatten()(x)

output = Dense(num_classes, activation='softmax')(flat1)




MouthModel = Model(inputs=[mouth1], outputs=output, name='inception_resnet_v2')
MouthModel.summary()
MouthModel.compile(loss='binary_crossentropy', optimizer=Adam(lr = 0.001), metrics=['accuracy'])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 50, 1)    0
# __________________________________________________________________________________________________
# incresA_1b2_1conv2d (Conv2D)    (None, 64, 50, 32)   32          input_1[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2dbn (BatchNor (None, 64, 50, 32)   96          incresA_1b2_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2dact (Activat (None, 64, 50, 32)   0           incresA_1b2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2d (Conv2D)    (None, 64, 50, 32)   32          input_1[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2d (Conv2D)    (None, 64, 50, 48)   13824       incresA_1b2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2dbn (BatchNor (None, 64, 50, 32)   96          incresA_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2dbn (BatchNor (None, 64, 50, 48)   144         incresA_1b2_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2dact (Activat (None, 64, 50, 32)   0           incresA_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2dact (Activat (None, 64, 50, 48)   0           incresA_1b2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2d (Conv2D)      (None, 64, 50, 32)   32          input_1[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2d (Conv2D)    (None, 64, 50, 32)   9216        incresA_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2d (Conv2D)    (None, 64, 50, 64)   27648       incresA_1b2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2dbn (BatchNorma (None, 64, 50, 32)   96          incresA_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2dbn (BatchNor (None, 64, 50, 32)   96          incresA_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2dbn (BatchNor (None, 64, 50, 64)   192         incresA_1b2_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2dact (Activatio (None, 64, 50, 32)   0           incresA_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2dact (Activat (None, 64, 50, 32)   0           incresA_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2dact (Activat (None, 64, 50, 64)   0           incresA_1b2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1_concat (Concatenate)  (None, 64, 50, 128)  0           incresA_1b0conv2dact[0][0]
#                                                                  incresA_1b1_2conv2dact[0][0]
#                                                                  incresA_1b2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1filt_exp_1x1conv2d (Co (None, 64, 50, 384)  49152       incresA_1_concat[0][0]
# __________________________________________________________________________________________________
# incresA_1filt_exp_1x1conv2dbn ( (None, 64, 50, 384)  1152        incresA_1filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1act_scaling (Lambda)   (None, 64, 50, 384)  0           input_1[0][0]
#                                                                  incresA_1filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1228800)      0           incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            3686403     flatten[0][0]
# ==================================================================================================
# Total params: 3,788,211
# Trainable params: 3,786,963
# Non-trainable params: 1,248
# __________________________________________________________________________________________________

# %%
# load label

import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset'

AllLabelFile = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if "mouth.txt" in file :
            AllLabelFile.append(os.path.join(r, file))
        
for f in AllLabelFile:
    print(f)
np.array(AllLabelFile).shape
# Out:
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\001_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\001_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\001_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\001_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\001_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\001_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\001_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\001_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\001_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\001_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\001_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\001_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\001_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\001_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\001_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\001_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\001_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\001_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\001_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\001_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\002_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\002_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\002_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\002_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\nightglasses\002_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\nightglasses\002_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\nightglasses\002_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\nightglasses\002_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\night_noglasses\002_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\night_noglasses\002_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\night_noglasses\002_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\night_noglasses\002_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\noglasses\002_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\noglasses\002_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\noglasses\002_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\noglasses\002_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\sunglasses\002_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\sunglasses\002_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\sunglasses\002_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\sunglasses\002_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\glasses\005_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\glasses\005_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\glasses\005_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\glasses\005_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\night_noglasses\005_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\night_noglasses\005_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\night_noglasses\005_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\night_noglasses\005_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\noglasses\005_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\noglasses\005_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\noglasses\005_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\noglasses\005_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\sunglasses\005_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\sunglasses\005_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\sunglasses\005_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\sunglasses\005_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\glasses\006_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\glasses\006_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\glasses\006_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\glasses\006_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\nightglasses\006_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\nightglasses\006_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\nightglasses\006_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\nightglasses\006_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\night_noglasses\006_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\night_noglasses\006_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\night_noglasses\006_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\night_noglasses\006_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\noglasses\006_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\noglasses\006_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\noglasses\006_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\noglasses\006_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\sunglasses\006_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\sunglasses\006_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\sunglasses\006_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\sunglasses\006_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\glasses\008_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\glasses\008_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\glasses\008_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\glasses\008_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\nightglasses\008_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\nightglasses\008_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\nightglasses\008_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\nightglasses\008_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\night_noglasses\008_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\night_noglasses\008_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\night_noglasses\008_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\night_noglasses\008_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\noglasses\008_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\noglasses\008_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\noglasses\008_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\noglasses\008_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\sunglasses\008_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\sunglasses\008_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\sunglasses\008_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\sunglasses\008_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\glasses\009_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\glasses\009_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\glasses\009_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\glasses\009_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\nightglasses\009_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\nightglasses\009_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\nightglasses\009_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\nightglasses\009_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\night_noglasses\009_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\night_noglasses\009_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\night_noglasses\009_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\night_noglasses\009_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\noglasses\009_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\noglasses\009_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\noglasses\009_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\noglasses\009_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\sunglasses\009_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\sunglasses\009_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\sunglasses\009_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\sunglasses\009_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\glasses\012_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\glasses\012_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\glasses\012_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\glasses\012_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\nightglasses\012_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\nightglasses\012_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\nightglasses\012_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\nightglasses\012_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\night_noglasses\012_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\night_noglasses\012_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\night_noglasses\012_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\night_noglasses\012_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\noglasses\012_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\noglasses\012_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\noglasses\012_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\noglasses\012_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\sunglasses\012_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\sunglasses\012_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\sunglasses\012_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\sunglasses\012_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\glasses\013_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\glasses\013_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\glasses\013_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\glasses\013_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\nightglasses\013_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\nightglasses\013_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\nightglasses\013_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\nightglasses\013_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\night_noglasses\013_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\night_noglasses\013_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\night_noglasses\013_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\night_noglasses\013_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\noglasses\013_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\noglasses\013_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\noglasses\013_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\noglasses\013_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\sunglasses\013_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\sunglasses\013_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\sunglasses\013_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\sunglasses\013_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\glasses\015_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\glasses\015_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\glasses\015_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\glasses\015_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\nightglasses\015_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\nightglasses\015_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\nightglasses\015_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\nightglasses\015_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\night_noglasses\015_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\night_noglasses\015_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\night_noglasses\015_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\night_noglasses\015_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\noglasses\015_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\noglasses\015_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\noglasses\015_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\noglasses\015_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\sunglasses\015_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\sunglasses\015_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\sunglasses\015_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\sunglasses\015_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\glasses\020_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\glasses\020_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\glasses\020_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\glasses\020_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\nightglasses\020_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\nightglasses\020_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\nightglasses\020_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\nightglasses\020_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\night_noglasses\020_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\night_noglasses\020_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\night_noglasses\020_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\night_noglasses\020_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\noglasses\020_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\noglasses\020_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\noglasses\020_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\noglasses\020_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\sunglasses\020_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\sunglasses\020_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\sunglasses\020_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\sunglasses\020_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\glasses\023_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\glasses\023_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\glasses\023_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\glasses\023_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\nightglasses\023_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\nightglasses\023_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\nightglasses\023_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\nightglasses\023_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\night_noglasses\023_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\night_noglasses\023_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\night_noglasses\023_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\night_noglasses\023_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\023_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\023_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\023_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\023_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\sunglasses\023_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\sunglasses\023_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\sunglasses\023_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\sunglasses\023_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\glasses\024_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\glasses\024_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\glasses\024_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\glasses\024_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\nightglasses\024_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\nightglasses\024_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\nightglasses\024_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\nightglasses\024_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\night_noglasses\024_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\night_noglasses\024_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\night_noglasses\024_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\night_noglasses\024_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\noglasses\024_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\noglasses\024_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\noglasses\024_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\noglasses\024_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\sunglasses\024_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\sunglasses\024_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\sunglasses\024_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\sunglasses\024_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\glasses\031_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\glasses\031_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\glasses\031_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\glasses\031_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\nightglasses\031_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\nightglasses\031_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\nightglasses\031_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\nightglasses\031_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\night_noglasses\031_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\night_noglasses\031_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\night_noglasses\031_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\night_noglasses\031_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\noglasses\031_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\noglasses\031_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\noglasses\031_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\noglasses\031_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\sunglasses\031_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\sunglasses\031_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\sunglasses\031_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\sunglasses\031_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\glasses\032_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\glasses\032_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\glasses\032_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\glasses\032_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\nightglasses\032_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\nightglasses\032_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\nightglasses\032_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\nightglasses\032_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\night_noglasses\032_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\night_noglasses\032_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\night_noglasses\032_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\night_noglasses\032_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\noglasses\032_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\noglasses\032_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\noglasses\032_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\noglasses\032_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\sunglasses\032_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\sunglasses\032_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\sunglasses\032_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\sunglasses\032_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\glasses\033_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\glasses\033_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\glasses\033_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\glasses\033_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\nightglasses\033_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\nightglasses\033_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\nightglasses\033_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\nightglasses\033_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\night_noglasses\033_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\night_noglasses\033_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\night_noglasses\033_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\night_noglasses\033_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\noglasses\033_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\noglasses\033_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\noglasses\033_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\noglasses\033_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\sunglasses\033_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\sunglasses\033_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\sunglasses\033_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\sunglasses\033_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\glasses\034_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\glasses\034_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\glasses\034_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\glasses\034_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\nightglasses\034_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\nightglasses\034_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\nightglasses\034_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\nightglasses\034_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\night_noglasses\034_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\night_noglasses\034_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\night_noglasses\034_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\night_noglasses\034_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\noglasses\034_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\noglasses\034_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\noglasses\034_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\noglasses\034_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\sunglasses\034_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\sunglasses\034_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\sunglasses\034_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\sunglasses\034_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\glasses\035_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\glasses\035_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\glasses\035_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\glasses\035_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\nightglasses\035_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\nightglasses\035_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\nightglasses\035_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\nightglasses\035_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\night_noglasses\035_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\night_noglasses\035_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\night_noglasses\035_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\night_noglasses\035_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\noglasses\035_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\noglasses\035_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\noglasses\035_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\noglasses\035_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\sunglasses\035_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\sunglasses\035_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\sunglasses\035_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\sunglasses\035_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\glasses\036_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\glasses\036_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\glasses\036_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\glasses\036_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\nightglasses\036_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\nightglasses\036_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\nightglasses\036_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\nightglasses\036_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\night_noglasses\036_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\night_noglasses\036_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\night_noglasses\036_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\night_noglasses\036_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\noglasses\036_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\noglasses\036_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\noglasses\036_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\noglasses\036_yawning_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\sunglasses\036_nonsleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\sunglasses\036_sleepyCombination_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\sunglasses\036_slowBlinkWithNodding_mouth.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\sunglasses\036_yawning_mouth.txt
# (356,)

# %%
import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Training Image'

AllImageFolder = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for directory in d:
        if ("nonsleepyCombination" in directory or "sleepyCombination" in directory or "slowBlinkWithNodding"  in directory or "yawning" in directory)   :
            #print(directory)
            AllImageFolder.append(os.path.join(r, directory))
        
for d in AllImageFolder:
    print(d)
np.array(AllImageFolder).shape
# Out:
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\sunglasses\yawning
# (356,)

# %%
num_samples = 235578
batch_size = 200

# %%
import numpy as np
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import cv2
from math import ceil

from keras.callbacks import EarlyStopping




def LoadImageandLabel(batch_size,AllVideoImageFolder,AllLabelFile):
    #print(Originalpath)
    count=0
    
    while True:
        LabelFileindex = 0
        for Originalpath in AllVideoImageFolder:

            labelPath = AllLabelFile[LabelFileindex]
            LabelFileindex = LabelFileindex + 1

            Face_ImageDataList = []
            Eyes_ImageDataList = []
            Mouth_ImageDataList = []
            #=====load all label in a video
            LabelList = []
            TempLabelList = []
            inputfile = open(labelPath, 'r').read()
            TempLabelList = list(map(int, inputfile))

            #=========================

            TEMP_ImageDataList = []

            path = Originalpath+"\\face"


            #=====find all files in path=======    
            Facefiles = []
            Eyefiles = []
            Mouthfiles = []
            # r=root, d=directories, f = files
            for r, d, f in os.walk(path):
                for file in f:
                    if ".jpg" in file:
                        temp = os.path.join(r, file)
                        
                        Facefiles.append(temp)
                        

            Facefiles.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
            for FileIndex in range(len(Facefiles)):
                #======================load label

                index = Facefiles[FileIndex].find('frame')
                framenumber =int(Facefiles[FileIndex][index+5:-4]) 

                #print(TempLabelList[framenumber-1])
                Labelarray = to_categorical(TempLabelList[framenumber-1], num_classes=num_classes)
                LabelList.append(Labelarray)
                
                #================================
                ImgGray = cv2.imread(Facefiles[FileIndex],0)
                ImgGray = ImgGray.reshape(ImgGray.shape[0],ImgGray.shape[1],1)
                Face_ImageDataList.append(ImgGray)
                 #====================================
               
                count = count +1
                if count>=batch_size:
                        #yield(np.array(Face_ImageDataList),np.array(LabelList))
                        yield ([np.array(Face_ImageDataList)],np.array(LabelList))
                        count=0
                        Face_ImageDataList = []
                        Eyes_ImageDataList = []
                        Mouth_ImageDataList = []
                        LabelList = []


MouthModel.fit_generator(LoadImageandLabel(batch_size,AllImageFolder,AllLabelFile),
                steps_per_epoch=ceil(num_samples / batch_size),
                epochs=100,
                #callbacks=[earlyStopping],
                workers = 5
                )
# Out:
# Using TensorFlow backend.
# Epoch 1/100
#   53/1178 [>.............................] - ETA: 6:42 - loss: 1.8300 - acc: 0.8850
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e19e6c486fcd> in <module>()
#      82                 epochs=100,
#      83                 #callbacks=[earlyStopping],
# ---> 84                 workers = 5
#      85                 )
#      86
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2175         use_multiprocessing=use_multiprocessing,
#    2176         shuffle=shuffle,
# -> 2177         initial_epoch=initial_epoch)
#    2178
#    2179   def evaluate_generator(self,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     174
#     175         outs = model.train_on_batch(
# --> 176             x, y, sample_weight=sample_weight, class_weight=class_weight)
#     177
#     178         if not isinstance(outs, list):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1938
#    1939       self._make_train_function()
# -> 1940       outputs = self.train_function(ins)
#    1941
#    1942     if len(outputs) == 1:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    2984
#    2985     fetched = self._callable_fn(*array_vals,
# -> 2986                                 run_metadata=self.run_metadata)
#    2987     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    2988     return fetched[:len(self.outputs)]
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
