# %%
import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset'

files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if ".avi" in file:
            files.append(os.path.join(r, file))
        
for f in files:
    print(f)
np.array(files).shape

# %%
Statelist=['nonsleepyCombination','sleepyCombination','slowBlinkWithNodding','yawning']
for i in range(4):
    print(files[i][55:58])
    print(files[i][67:-4])
    print(files[i][54:-4])
    print('----')
# Out:
# 001
# s\nonsleepyCombination
# \001\noglasses\nonsleepyCombination
# ----
# 001
# s\sleepyCombination
# \001\noglasses\sleepyCombination
# ----
# 001
# s\slowBlinkWithNodding
# \001\noglasses\slowBlinkWithNodding
# ----
# 001
# s\yawning
# \001\noglasses\yawning
# ----

# %% [markdown]
# ## MTCNN
#
# if face not detected in 60 frames, use the last detected

# %%
from mtcnn.mtcnn import MTCNN
# import the necessary packages
from imutils import face_utils
import dlib
import cv2
import numpy as np
import os
from operator import itemgetter
import time

eyes_width = 90
eyes_height = 50
mouth_width = 75
mouth_height = 50
face_width = 105
face_height = 125
num_classes = 2
channel = 1



def CreateFolder(name):
    try:
        # creating a folder named data 
        if not os.path.exists(name):
            os.makedirs(name)
        # if not created then raise error 
    except OSError: 
        print ('Error: Creating directory of data')            
#==============================================================

detector = MTCNN()

for filename in files:
    # img = cv2.imread("me.jpg")
    
    #filename = '.\\Dataset\\Training_Evaluation_Dataset\\Training Dataset\\001\\glasses\\yawning.avi'

    print(filename)
    cap = cv2.VideoCapture(filename)
    #================================================================ create new folder

    DefaultPath = '.\\Dataset\\Training_Evaluation_Dataset\\Training Image\\'+filename[54:-4]+"\\"
    CreateFolder(DefaultPath+"face")
    CreateFolder(DefaultPath+"eyes")
    CreateFolder(DefaultPath+"mouth")
    #================================================================
    Face_ImageDataList = []

    currentframe = 0
    missing_frame = 0
    DropList = []

    eyes_w = eyes_width
    eyes_h = eyes_height
    face_w = face_width
    face_h = face_height
    mouth_w = mouth_width
    mouth_h = mouth_height
    length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print(length)
    x,y,w,h = 0,0,0,0
    
    while(cap.isOpened()):

        start_time = time.time()

        currentframe += 1
        # load the input image and convert it to grayscale
        ret, image = cap.read()
        if (not ret):
          break
        
        #if(currentframe<2200):
        #    continue
        

        height,width = image.shape[:2]
        #gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        #image = cv2.resize(image,(width//2,height//2),interpolation=cv2.INTER_CUBIC)
        #print(image.shape[:2])
        faces = detector.detect_faces(image)
        #print(np.array(faces).shape[0])
        
        if(np.array(faces).shape[0] > 0):
            face = faces[0]
            x,y,w,h = face['box']
            
            face_image = image[max(0,y):max(0,y+h),max(0,x):max(0,x+w)]
            #print(face_image.shape)
            #print(image[x:x+w,y:y+h])
            #cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)
            face_image = cv2.resize(face_image,(face_w,face_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "face\\frame" + str(currentframe) + '.jpg',face_image) 


            eyes_image = image[max(0,face['keypoints']['left_eye'][1]-int(h*0.2)):max(0,face['keypoints']['right_eye'][1]+int(h*0.2))
                                ,max(0,face['keypoints']['left_eye'][0]-int(w*0.2)):max(0,face['keypoints']['right_eye'][0]+int(w*0.2))]
            
            #cv2.rectangle(image, (face['keypoints']['left_eye'][0]-int(w*0.2), face['keypoints']['left_eye'][1]-int(h*0.2)),
            #              (face['keypoints']['right_eye'][0]+int(w*0.2), face['keypoints']['right_eye'][1]+int(h*0.2)),(0, 255, 0),2)
            eyes_image = cv2.resize(eyes_image,(eyes_w,eyes_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "eyes\\frame" + str(currentframe) + '.jpg',eyes_image) 


            mouth_image = image[max(0,face['keypoints']['mouth_left'][1]-int(h*0.2)):max(0,face['keypoints']['mouth_right'][1]+int(h*0.2))
                               ,max(0,face['keypoints']['mouth_left'][0]-int(w*0.2)):max(0,face['keypoints']['mouth_right'][0]+int(w*0.2))]
            #cv2.rectangle(image, (face['keypoints']['mouth_left'][0]-int(w*0.2), face['keypoints']['mouth_left'][1]-int(h*0.2)),
            #              (face['keypoints']['mouth_right'][0]+int(w*0.2), face['keypoints']['mouth_right'][1]+int(h*0.2)),(0, 255, 0),2)
            mouth_image = cv2.resize(mouth_image,(mouth_w,mouth_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "mouth\\frame" + str(currentframe) + '.jpg',mouth_image) 



            #cv2.rectangle(image, (face['keypoints']['left_eye'][0], face['keypoints']['left_eye'][1]), 2, (0, 255, 0), -1)


            #cv2.circle(image, (face['keypoints']['left_eye'][0], face['keypoints']['left_eye'][1]), 2, (0, 255, 0), -1)
            #cv2.circle(image, (face['keypoints']['right_eye'][0], face['keypoints']['right_eye'][1]), 2, (0, 255, 0), -1)
            #cv2.circle(image, (face['keypoints']['nose'][0], face['keypoints']['nose'][1]), 2, (0, 255, 0), -1)
            #cv2.circle(image, (face['keypoints']['mouth_left'][0], face['keypoints']['mouth_left'][1]), 2, (0, 255, 0), -1)
            #cv2.circle(image, (face['keypoints']['mouth_right'][0], face['keypoints']['mouth_right'][1]), 2, (0, 255, 0), -1)
            if(currentframe%100==0):        
                name = './data/frame' + str(currentframe) + '.jpg'
                print ('Creating...' + name) 
        elif (missing_frame<60):
            print ('missing using last frame') 
            missing_frame = missing_frame + 1        

            face_image = image[max(0,y):max(0,y+h),max(0,x):max(0,x+w)]

            #print(image[x:x+w,y:y+h])
            #cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)
            face_image = cv2.resize(face_image,(face_w,face_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "face\\frame" + str(currentframe) + '.jpg',face_image) 


            eyes_image = image[max(0,face['keypoints']['left_eye'][1]-int(h*0.2)):max(0,face['keypoints']['right_eye'][1]+int(h*0.2))
                                ,max(0,face['keypoints']['left_eye'][0]-int(w*0.2)):max(0,face['keypoints']['right_eye'][0]+int(w*0.2))]
            #cv2.rectangle(image, (face['keypoints']['left_eye'][0]-int(w*0.2), face['keypoints']['left_eye'][1]-int(h*0.2)),
            #              (face['keypoints']['right_eye'][0]+int(w*0.2), face['keypoints']['right_eye'][1]+int(h*0.2)),(0, 255, 0),2)
            eyes_image = cv2.resize(eyes_image,(eyes_w,eyes_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "eyes\\frame" + str(currentframe) + '.jpg',eyes_image) 


            mouth_image = image[max(0,face['keypoints']['mouth_left'][1]-int(h*0.2)):max(0,face['keypoints']['mouth_right'][1]+int(h*0.2))
                               ,max(0,face['keypoints']['mouth_left'][0]-int(w*0.2)):max(0,face['keypoints']['mouth_right'][0]+int(w*0.2))]
            #cv2.rectangle(image, (face['keypoints']['mouth_left'][0]-int(w*0.2), face['keypoints']['mouth_left'][1]-int(h*0.2)),
            #              (face['keypoints']['mouth_right'][0]+int(w*0.2), face['keypoints']['mouth_right'][1]+int(h*0.2)),(0, 255, 0),2)
            mouth_image = cv2.resize(mouth_image,(mouth_w,mouth_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "mouth\\frame" + str(currentframe) + '.jpg',mouth_image) 
            
            #if(currentframe%100==0):
            name = './data/frame' + str(currentframe) + '.jpg'
            print ('missing using last frame:  '+ 'Creating...' + name) 

        else:
            name = './data/frame' + str(currentframe) + '.jpg'
            f = open('droplist.txt','a')
            f.write(name)
            f.close()
            DropList.append(currentframe)
            print("drop")



        '''
        cv2.imshow('img',image)

        #print("FPS: ", 1.0 / (time.time() - start_time))

        k = cv2.waitKey(5) & 0xFF
        if k == 27:
            break
        '''
    
    print("total_frame:" +str(length)+" missing frame"+ str(np.array(DropList).shape[0])+" total frame2:"+ str(currentframe))
    print(DropList)
    cap.release()
    cv2.destroyAllWindows()
# Out:
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\nonsleepyCombination.avi
# 2732
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2216.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2217.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2218.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2219.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2220.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2221.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2222.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2223.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2224.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2225.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2226.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2227.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2228.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2229.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2230.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2231.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2232.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2233.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2234.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2235.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2236.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2237.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2238.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2239.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2240.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2241.jpg
# Creating..../data/frame2300.jpg
# Creating..../data/frame2400.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2459.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2461.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2462.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2464.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2465.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2466.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2467.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2468.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2469.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2470.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2471.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2472.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2473.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2474.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2475.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2476.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2477.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2478.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2479.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2480.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2481.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2482.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2483.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2484.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2485.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2486.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2487.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2488.jpg
# Creating..../data/frame2500.jpg
# Creating..../data/frame2600.jpg
# Creating..../data/frame2700.jpg
# total_frame:2732 missing frame0 total frame2:2733
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\sleepyCombination.avi
# 2711
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# Creating..../data/frame2300.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2500.jpg
# Creating..../data/frame2600.jpg
# Creating..../data/frame2700.jpg
# total_frame:2711 missing frame0 total frame2:2712
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\slowBlinkWithNodding.avi
# 1852
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# total_frame:1852 missing frame0 total frame2:1853
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\yawning.avi
# 1872
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# total_frame:1872 missing frame0 total frame2:1873
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\nonsleepyCombination.avi
# 2803
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1376.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# Creating..../data/frame2300.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2500.jpg
# Creating..../data/frame2600.jpg
# Creating..../data/frame2700.jpg
# Creating..../data/frame2800.jpg
# total_frame:2803 missing frame0 total frame2:2804
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\sleepyCombination.avi
# 2805
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame739.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame744.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame745.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# Creating..../data/frame2300.jpg
# Creating..../data/frame2400.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2460.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2461.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2462.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2463.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2466.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2469.jpg
# Creating..../data/frame2500.jpg
# Creating..../data/frame2600.jpg
# Creating..../data/frame2700.jpg
# Creating..../data/frame2800.jpg
# total_frame:2805 missing frame0 total frame2:2806
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\slowBlinkWithNodding.avi
# 2001
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# total_frame:2001 missing frame0 total frame2:2002
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\yawning.avi
# 1965
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# total_frame:1965 missing frame0 total frame2:1966
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\nonsleepyCombination.avi
# 2934
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame234.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame235.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame236.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame237.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame238.jpg
# Creating..../data/frame300.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame329.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame352.jpg
# Creating..../data/frame400.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame443.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame633.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame634.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame635.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame636.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame637.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame638.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame644.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame645.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame646.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame647.jpg
# Creating..../data/frame700.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame783.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame989.jpg
# Creating..../data/frame1000.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1045.jpg
# Creating..../data/frame1100.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1170.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1378.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1379.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2270.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2271.jpg
# Creating..../data/frame2300.jpg
# Creating..../data/frame2400.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2489.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2493.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2494.jpg
# Creating..../data/frame2500.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2510.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2511.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2512.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2532.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2533.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2542.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2557.jpg
# Creating..../data/frame2600.jpg
# Creating..../data/frame2700.jpg
# Creating..../data/frame2800.jpg
# Creating..../data/frame2900.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2933.jpg
# total_frame:2934 missing frame0 total frame2:2935
# []
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\sleepyCombination.avi
# 2879
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1205.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1225.jpg
# Creating..../data/frame1300.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1332.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-7b54f2d0e1ac> in <module>()
#      80         #image = cv2.resize(image,(width//2,height//2),interpolation=cv2.INTER_CUBIC)
#      81         #print(image.shape[:2])
# ---> 82         faces = detector.detect_faces(image)
#      83         #print(np.array(faces).shape[0])
#      84
#
# ~\Anaconda3\lib\site-packages\mtcnn\mtcnn.py in detect_faces(self, img)
#     416         # We pipe here each of the stages
#     417         for stage in stages:
# --> 418             result = stage(img, result[0], result[1])
#     419
#     420         [total_boxes, points] = result
#
# ~\Anaconda3\lib\site-packages\mtcnn\mtcnn.py in __stage1(self, image, scales, stage_status)
#     452
#     453         for scale in scales:
# --> 454             scaled_image = self.__scale_image(image, scale)
#     455
#     456             img_x = np.expand_dims(scaled_image, 0)
#
# ~\Anaconda3\lib\site-packages\mtcnn\mtcnn.py in __scale_image(image, scale)
#     240         height_scaled = int(np.ceil(height * scale))
#     241
# --> 242         im_data = cv2.resize(image, (width_scaled, height_scaled), interpolation=cv2.INTER_AREA)
#     243
#     244         # Normalize the image's pixels
#
# KeyboardInterrupt:

# %% [markdown]
# ### TODO
# 1. 所有file 存檔案
# 2. training 進CNN model
# 3. 存沒有東西的frame

# %% [markdown]
# ### define CNN [model](https://medium.com/@mannasiladittya/building-inception-resnet-v2-in-keras-from-scratch-a3546c4d93f0)

# %%
# %run ./Model.ipynb
# Out:
# C:\Users\T-Rex\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
eyes_width = 90
eyes_height = 50
mouth_width = 75
mouth_height = 50
face_width = 105
face_height = 125
num_classes = 2
channel = 1

# %%
img_input = Input(shape=(face_height,face_width,1))

x = conv2d(img_input,32,3,2,'valid',True,name='conv1')
x = conv2d(x,32,3,1,'valid',True,name='conv2')
x = conv2d(x,64,3,1,'valid',True,name='conv3')

x_11 = MaxPooling2D(3,strides=1,padding='valid',name='stem_br_11'+'_maxpool_1')(x)
x_12 = conv2d(x,96,3,1,'valid',True,name='stem_br_12')

x = Concatenate(axis=3, name = 'stem_concat_1')([x_11,x_12])

x_21 = conv2d(x,64,1,1,'same',True,name='stem_br_211')
x_21 = conv2d(x_21,64,[1,7],1,'same',True,name='stem_br_212')
x_21 = conv2d(x_21,64,[7,1],1,'same',True,name='stem_br_213')
x_21 = conv2d(x_21,96,3,1,'valid',True,name='stem_br_214')

x_22 = conv2d(x,64,1,1,'same',True,name='stem_br_221')
x_22 = conv2d(x_22,96,3,1,'valid',True,name='stem_br_222')

x = Concatenate(axis=3, name = 'stem_concat_2')([x_21,x_22])

x_31 = conv2d(x,192,3,1,'valid',True,name='stem_br_31')
x_32 = MaxPooling2D(3,strides=1,padding='valid',name='stem_br_32'+'_maxpool_2')(x)
x = Concatenate(axis=3, name = 'stem_concat_3')([x_31,x_32])

# %%
#Inception-ResNet-A modules
x = incresA(x,0.15,name='incresA_1')
x = incresA(x,0.15,name='incresA_2')
#x = incresA(x,0.15,name='incresA_3')
#x = incresA(x,0.15,name='incresA_4')

#35 × 35 to 17 × 17 reduction module.
x_red_11 = MaxPooling2D(3,strides=2,padding='valid',name='red_maxpool_1')(x)

x_red_12 = conv2d(x,384,3,2,'valid',True,name='x_red1_c1')

x_red_13 = conv2d(x,256,1,1,'same',True,name='x_red1_c2_1')
x_red_13 = conv2d(x_red_13,256,3,1,'same',True,name='x_red1_c2_2')
x_red_13 = conv2d(x_red_13,384,3,2,'valid',True,name='x_red1_c2_3')

x = Concatenate(axis=3, name='red_concat_1')([x_red_11,x_red_12,x_red_13])

#Inception-ResNet-B modules
x = incresB(x,0.1,name='incresB_1')
x = incresB(x,0.1,name='incresB_2')
x = incresB(x,0.1,name='incresB_3')
#x = incresB(x,0.1,name='incresB_4')
#x = incresB(x,0.1,name='incresB_5')
#x = incresB(x,0.1,name='incresB_6')
#x = incresB(x,0.1,name='incresB_7')

#17 × 17 to 8 × 8 reduction module.
x_red_21 = MaxPooling2D(3,strides=2,padding='valid',name='red_maxpool_2')(x)

x_red_22 = conv2d(x,256,1,1,'same',True,name='x_red2_c11')
x_red_22 = conv2d(x_red_22,384,3,2,'valid',True,name='x_red2_c12')

x_red_23 = conv2d(x,256,1,1,'same',True,name='x_red2_c21')
x_red_23 = conv2d(x_red_23,256,3,2,'valid',True,name='x_red2_c22')

x_red_24 = conv2d(x,256,1,1,'same',True,name='x_red2_c31')
x_red_24 = conv2d(x_red_24,256,3,1,'same',True,name='x_red2_c32')
x_red_24 = conv2d(x_red_24,256,3,2,'valid',True,name='x_red2_c33')

x = Concatenate(axis=3, name='red_concat_2')([x_red_21,x_red_22,x_red_23,x_red_24])

#Inception-ResNet-C modules
x = incresC(x,0.2,name='incresC_1')
x = incresC(x,0.2,name='incresC_2')
#x = incresC(x,0.2,name='incresC_3')

#TOP
x = GlobalAveragePooling2D(data_format='channels_last')(x)
x = Dropout(0.6)(x)
#x = Dense(num_classes, activation='softmax')(x)
flat3 = Flatten()(x)

# %%
# first input model: eyes
eyes1 = Input(shape=(eyes_height,eyes_width,1))
conv11 = Conv2D(32, kernel_size=(3, 3), activation='relu')(eyes1)
pool11 = MaxPooling2D(pool_size=(2, 2))(conv11)
conv12 = Conv2D(64, kernel_size=(3, 3), activation='relu')(pool11)
#pool12 = MaxPooling2D(pool_size=(2, 2))(conv12)
#flat1 = Flatten()(pool12)
pool12 = GlobalAveragePooling2D(data_format='channels_last')(conv12)
flat1 = Flatten()(pool12)


# second input model: mouth
mouth1 = Input(shape=(mouth_height,mouth_width,1))
conv21 = Conv2D(32, kernel_size=(3, 3), activation='relu')(mouth1)
pool21 = MaxPooling2D(pool_size=(2, 2))(conv21)
conv22 = Conv2D(16, kernel_size=(3, 3), activation='relu')(pool21)
#pool22 = MaxPooling2D(pool_size=(2, 2))(conv22)
#flat2 = Flatten()(pool22)
pool22 = GlobalAveragePooling2D(data_format='channels_last')(conv22)
flat2 = Flatten()(pool22)

merge = Concatenate(axis=1, name='concat_2')([flat1, flat2,flat3])
output = Dense(num_classes, activation='softmax')(merge)

# %%
model = Model(inputs=[eyes1, mouth1, img_input], outputs=output, name='inception_resnet_v2')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 125, 105, 1)  0
# __________________________________________________________________________________________________
# conv1conv2d (Conv2D)            (None, 62, 52, 32)   288         input_1[0][0]
# __________________________________________________________________________________________________
# conv1conv2dbn (BatchNormalizati (None, 62, 52, 32)   96          conv1conv2d[0][0]
# __________________________________________________________________________________________________
# conv1conv2dact (Activation)     (None, 62, 52, 32)   0           conv1conv2dbn[0][0]
# __________________________________________________________________________________________________
# conv2conv2d (Conv2D)            (None, 60, 50, 32)   9216        conv1conv2dact[0][0]
# __________________________________________________________________________________________________
# conv2conv2dbn (BatchNormalizati (None, 60, 50, 32)   96          conv2conv2d[0][0]
# __________________________________________________________________________________________________
# conv2conv2dact (Activation)     (None, 60, 50, 32)   0           conv2conv2dbn[0][0]
# __________________________________________________________________________________________________
# conv3conv2d (Conv2D)            (None, 58, 48, 64)   18432       conv2conv2dact[0][0]
# __________________________________________________________________________________________________
# conv3conv2dbn (BatchNormalizati (None, 58, 48, 64)   192         conv3conv2d[0][0]
# __________________________________________________________________________________________________
# conv3conv2dact (Activation)     (None, 58, 48, 64)   0           conv3conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_12conv2d (Conv2D)       (None, 56, 46, 96)   55296       conv3conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_12conv2dbn (BatchNormal (None, 56, 46, 96)   288         stem_br_12conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_11_maxpool_1 (MaxPoolin (None, 56, 46, 64)   0           conv3conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_12conv2dact (Activation (None, 56, 46, 96)   0           stem_br_12conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_concat_1 (Concatenate)     (None, 56, 46, 160)  0           stem_br_11_maxpool_1[0][0]
#                                                                  stem_br_12conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_211conv2d (Conv2D)      (None, 56, 46, 64)   10240       stem_concat_1[0][0]
# __________________________________________________________________________________________________
# stem_br_211conv2dbn (BatchNorma (None, 56, 46, 64)   192         stem_br_211conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_211conv2dact (Activatio (None, 56, 46, 64)   0           stem_br_211conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_212conv2d (Conv2D)      (None, 56, 46, 64)   28672       stem_br_211conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_212conv2dbn (BatchNorma (None, 56, 46, 64)   192         stem_br_212conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_212conv2dact (Activatio (None, 56, 46, 64)   0           stem_br_212conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_213conv2d (Conv2D)      (None, 56, 46, 64)   28672       stem_br_212conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_221conv2d (Conv2D)      (None, 56, 46, 64)   10240       stem_concat_1[0][0]
# __________________________________________________________________________________________________
# stem_br_213conv2dbn (BatchNorma (None, 56, 46, 64)   192         stem_br_213conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_221conv2dbn (BatchNorma (None, 56, 46, 64)   192         stem_br_221conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_213conv2dact (Activatio (None, 56, 46, 64)   0           stem_br_213conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_221conv2dact (Activatio (None, 56, 46, 64)   0           stem_br_221conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_214conv2d (Conv2D)      (None, 54, 44, 96)   55296       stem_br_213conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_222conv2d (Conv2D)      (None, 54, 44, 96)   55296       stem_br_221conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_214conv2dbn (BatchNorma (None, 54, 44, 96)   288         stem_br_214conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_222conv2dbn (BatchNorma (None, 54, 44, 96)   288         stem_br_222conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_214conv2dact (Activatio (None, 54, 44, 96)   0           stem_br_214conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_222conv2dact (Activatio (None, 54, 44, 96)   0           stem_br_222conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_concat_2 (Concatenate)     (None, 54, 44, 192)  0           stem_br_214conv2dact[0][0]
#                                                                  stem_br_222conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_31conv2d (Conv2D)       (None, 52, 42, 192)  331776      stem_concat_2[0][0]
# __________________________________________________________________________________________________
# stem_br_31conv2dbn (BatchNormal (None, 52, 42, 192)  576         stem_br_31conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_31conv2dact (Activation (None, 52, 42, 192)  0           stem_br_31conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_32_maxpool_2 (MaxPoolin (None, 52, 42, 192)  0           stem_concat_2[0][0]
# __________________________________________________________________________________________________
# stem_concat_3 (Concatenate)     (None, 52, 42, 384)  0           stem_br_31conv2dact[0][0]
#                                                                  stem_br_32_maxpool_2[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2d (Conv2D)    (None, 52, 42, 32)   12288       stem_concat_3[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2dbn (BatchNor (None, 52, 42, 32)   96          incresA_1b2_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2dact (Activat (None, 52, 42, 32)   0           incresA_1b2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2d (Conv2D)    (None, 52, 42, 32)   12288       stem_concat_3[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2d (Conv2D)    (None, 52, 42, 48)   13824       incresA_1b2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2dbn (BatchNor (None, 52, 42, 32)   96          incresA_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2dbn (BatchNor (None, 52, 42, 48)   144         incresA_1b2_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2dact (Activat (None, 52, 42, 32)   0           incresA_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2dact (Activat (None, 52, 42, 48)   0           incresA_1b2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2d (Conv2D)      (None, 52, 42, 32)   12288       stem_concat_3[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2d (Conv2D)    (None, 52, 42, 32)   9216        incresA_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2d (Conv2D)    (None, 52, 42, 64)   27648       incresA_1b2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2dbn (BatchNorma (None, 52, 42, 32)   96          incresA_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2dbn (BatchNor (None, 52, 42, 32)   96          incresA_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2dbn (BatchNor (None, 52, 42, 64)   192         incresA_1b2_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2dact (Activatio (None, 52, 42, 32)   0           incresA_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2dact (Activat (None, 52, 42, 32)   0           incresA_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2dact (Activat (None, 52, 42, 64)   0           incresA_1b2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1_concat (Concatenate)  (None, 52, 42, 128)  0           incresA_1b0conv2dact[0][0]
#                                                                  incresA_1b1_2conv2dact[0][0]
#                                                                  incresA_1b2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1filt_exp_1x1conv2d (Co (None, 52, 42, 384)  49152       incresA_1_concat[0][0]
# __________________________________________________________________________________________________
# incresA_1filt_exp_1x1conv2dbn ( (None, 52, 42, 384)  1152        incresA_1filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1act_scaling (Lambda)   (None, 52, 42, 384)  0           stem_concat_3[0][0]
#                                                                  incresA_1filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# incresA_2b2_1conv2d (Conv2D)    (None, 52, 42, 32)   12288       incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_1conv2dbn (BatchNor (None, 52, 42, 32)   96          incresA_2b2_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_1conv2dact (Activat (None, 52, 42, 32)   0           incresA_2b2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_1conv2d (Conv2D)    (None, 52, 42, 32)   12288       incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_2conv2d (Conv2D)    (None, 52, 42, 48)   13824       incresA_2b2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_1conv2dbn (BatchNor (None, 52, 42, 32)   96          incresA_2b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_2conv2dbn (BatchNor (None, 52, 42, 48)   144         incresA_2b2_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_1conv2dact (Activat (None, 52, 42, 32)   0           incresA_2b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_2conv2dact (Activat (None, 52, 42, 48)   0           incresA_2b2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b0conv2d (Conv2D)      (None, 52, 42, 32)   12288       incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_2conv2d (Conv2D)    (None, 52, 42, 32)   9216        incresA_2b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_3conv2d (Conv2D)    (None, 52, 42, 64)   27648       incresA_2b2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2b0conv2dbn (BatchNorma (None, 52, 42, 32)   96          incresA_2b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_2conv2dbn (BatchNor (None, 52, 42, 32)   96          incresA_2b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_3conv2dbn (BatchNor (None, 52, 42, 64)   192         incresA_2b2_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b0conv2dact (Activatio (None, 52, 42, 32)   0           incresA_2b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_2conv2dact (Activat (None, 52, 42, 32)   0           incresA_2b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_3conv2dact (Activat (None, 52, 42, 64)   0           incresA_2b2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2_concat (Concatenate)  (None, 52, 42, 128)  0           incresA_2b0conv2dact[0][0]
#                                                                  incresA_2b1_2conv2dact[0][0]
#                                                                  incresA_2b2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2filt_exp_1x1conv2d (Co (None, 52, 42, 384)  49152       incresA_2_concat[0][0]
# __________________________________________________________________________________________________
# incresA_2filt_exp_1x1conv2dbn ( (None, 52, 42, 384)  1152        incresA_2filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2act_scaling (Lambda)   (None, 52, 42, 384)  0           incresA_1act_scaling[0][0]
#                                                                  incresA_2filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# x_red1_c2_1conv2d (Conv2D)      (None, 52, 42, 256)  98304       incresA_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_1conv2dbn (BatchNorma (None, 52, 42, 256)  768         x_red1_c2_1conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_1conv2dact (Activatio (None, 52, 42, 256)  0           x_red1_c2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2d (Conv2D)      (None, 52, 42, 256)  589824      x_red1_c2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2dbn (BatchNorma (None, 52, 42, 256)  768         x_red1_c2_2conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2dact (Activatio (None, 52, 42, 256)  0           x_red1_c2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2d (Conv2D)        (None, 25, 20, 384)  1327104     incresA_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2d (Conv2D)      (None, 25, 20, 384)  884736      x_red1_c2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2dbn (BatchNormali (None, 25, 20, 384)  1152        x_red1_c1conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2dbn (BatchNorma (None, 25, 20, 384)  1152        x_red1_c2_3conv2d[0][0]
# __________________________________________________________________________________________________
# red_maxpool_1 (MaxPooling2D)    (None, 25, 20, 384)  0           incresA_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2dact (Activation) (None, 25, 20, 384)  0           x_red1_c1conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2dact (Activatio (None, 25, 20, 384)  0           x_red1_c2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# red_concat_1 (Concatenate)      (None, 25, 20, 1152) 0           red_maxpool_1[0][0]
#                                                                  x_red1_c1conv2dact[0][0]
#                                                                  x_red1_c2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2d (Conv2D)    (None, 25, 20, 128)  147456      red_concat_1[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2dbn (BatchNor (None, 25, 20, 128)  384         incresB_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2dact (Activat (None, 25, 20, 128)  0           incresB_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2d (Conv2D)    (None, 25, 20, 160)  143360      incresB_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2dbn (BatchNor (None, 25, 20, 160)  480         incresB_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2dact (Activat (None, 25, 20, 160)  0           incresB_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2d (Conv2D)      (None, 25, 20, 192)  221184      red_concat_1[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2d (Conv2D)    (None, 25, 20, 192)  215040      incresB_1b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2dbn (BatchNorma (None, 25, 20, 192)  576         incresB_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2dbn (BatchNor (None, 25, 20, 192)  576         incresB_1b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2dact (Activatio (None, 25, 20, 192)  0           incresB_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2dact (Activat (None, 25, 20, 192)  0           incresB_1b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1_mixed (Concatenate)   (None, 25, 20, 384)  0           incresB_1b0conv2dact[0][0]
#                                                                  incresB_1b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1filt_exp_1x1conv2d (Co (None, 25, 20, 1152) 442368      incresB_1_mixed[0][0]
# __________________________________________________________________________________________________
# incresB_1filt_exp_1x1conv2dbn ( (None, 25, 20, 1152) 3456        incresB_1filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1act_scaling (Lambda)   (None, 25, 20, 1152) 0           red_concat_1[0][0]
#                                                                  incresB_1filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# incresB_2b1_1conv2d (Conv2D)    (None, 25, 20, 128)  147456      incresB_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_1conv2dbn (BatchNor (None, 25, 20, 128)  384         incresB_2b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_1conv2dact (Activat (None, 25, 20, 128)  0           incresB_2b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_2conv2d (Conv2D)    (None, 25, 20, 160)  143360      incresB_2b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_2conv2dbn (BatchNor (None, 25, 20, 160)  480         incresB_2b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_2conv2dact (Activat (None, 25, 20, 160)  0           incresB_2b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2b0conv2d (Conv2D)      (None, 25, 20, 192)  221184      incresB_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_3conv2d (Conv2D)    (None, 25, 20, 192)  215040      incresB_2b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_2b0conv2dbn (BatchNorma (None, 25, 20, 192)  576         incresB_2b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_3conv2dbn (BatchNor (None, 25, 20, 192)  576         incresB_2b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b0conv2dact (Activatio (None, 25, 20, 192)  0           incresB_2b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_3conv2dact (Activat (None, 25, 20, 192)  0           incresB_2b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2_mixed (Concatenate)   (None, 25, 20, 384)  0           incresB_2b0conv2dact[0][0]
#                                                                  incresB_2b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_2filt_exp_1x1conv2d (Co (None, 25, 20, 1152) 442368      incresB_2_mixed[0][0]
# __________________________________________________________________________________________________
# incresB_2filt_exp_1x1conv2dbn ( (None, 25, 20, 1152) 3456        incresB_2filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2act_scaling (Lambda)   (None, 25, 20, 1152) 0           incresB_1act_scaling[0][0]
#                                                                  incresB_2filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# incresB_3b1_1conv2d (Conv2D)    (None, 25, 20, 128)  147456      incresB_2act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_3b1_1conv2dbn (BatchNor (None, 25, 20, 128)  384         incresB_3b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_3b1_1conv2dact (Activat (None, 25, 20, 128)  0           incresB_3b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_3b1_2conv2d (Conv2D)    (None, 25, 20, 160)  143360      incresB_3b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_3b1_2conv2dbn (BatchNor (None, 25, 20, 160)  480         incresB_3b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_3b1_2conv2dact (Activat (None, 25, 20, 160)  0           incresB_3b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_3b0conv2d (Conv2D)      (None, 25, 20, 192)  221184      incresB_2act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_3b1_3conv2d (Conv2D)    (None, 25, 20, 192)  215040      incresB_3b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_3b0conv2dbn (BatchNorma (None, 25, 20, 192)  576         incresB_3b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_3b1_3conv2dbn (BatchNor (None, 25, 20, 192)  576         incresB_3b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_3b0conv2dact (Activatio (None, 25, 20, 192)  0           incresB_3b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_3b1_3conv2dact (Activat (None, 25, 20, 192)  0           incresB_3b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_3_mixed (Concatenate)   (None, 25, 20, 384)  0           incresB_3b0conv2dact[0][0]
#                                                                  incresB_3b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_3filt_exp_1x1conv2d (Co (None, 25, 20, 1152) 442368      incresB_3_mixed[0][0]
# __________________________________________________________________________________________________
# incresB_3filt_exp_1x1conv2dbn ( (None, 25, 20, 1152) 3456        incresB_3filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_3act_scaling (Lambda)   (None, 25, 20, 1152) 0           incresB_2act_scaling[0][0]
#                                                                  incresB_3filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# x_red2_c31conv2d (Conv2D)       (None, 25, 20, 256)  294912      incresB_3act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c31conv2dbn (BatchNormal (None, 25, 20, 256)  768         x_red2_c31conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c31conv2dact (Activation (None, 25, 20, 256)  0           x_red2_c31conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c11conv2d (Conv2D)       (None, 25, 20, 256)  294912      incresB_3act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c21conv2d (Conv2D)       (None, 25, 20, 256)  294912      incresB_3act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c32conv2d (Conv2D)       (None, 25, 20, 256)  589824      x_red2_c31conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c11conv2dbn (BatchNormal (None, 25, 20, 256)  768         x_red2_c11conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c21conv2dbn (BatchNormal (None, 25, 20, 256)  768         x_red2_c21conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c32conv2dbn (BatchNormal (None, 25, 20, 256)  768         x_red2_c32conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c11conv2dact (Activation (None, 25, 20, 256)  0           x_red2_c11conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c21conv2dact (Activation (None, 25, 20, 256)  0           x_red2_c21conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c32conv2dact (Activation (None, 25, 20, 256)  0           x_red2_c32conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c12conv2d (Conv2D)       (None, 12, 9, 384)   884736      x_red2_c11conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c22conv2d (Conv2D)       (None, 12, 9, 256)   589824      x_red2_c21conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c33conv2d (Conv2D)       (None, 12, 9, 256)   589824      x_red2_c32conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c12conv2dbn (BatchNormal (None, 12, 9, 384)   1152        x_red2_c12conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c22conv2dbn (BatchNormal (None, 12, 9, 256)   768         x_red2_c22conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c33conv2dbn (BatchNormal (None, 12, 9, 256)   768         x_red2_c33conv2d[0][0]
# __________________________________________________________________________________________________
# red_maxpool_2 (MaxPooling2D)    (None, 12, 9, 1152)  0           incresB_3act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c12conv2dact (Activation (None, 12, 9, 384)   0           x_red2_c12conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c22conv2dact (Activation (None, 12, 9, 256)   0           x_red2_c22conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c33conv2dact (Activation (None, 12, 9, 256)   0           x_red2_c33conv2dbn[0][0]
# __________________________________________________________________________________________________
# red_concat_2 (Concatenate)      (None, 12, 9, 2048)  0           red_maxpool_2[0][0]
#                                                                  x_red2_c12conv2dact[0][0]
#                                                                  x_red2_c22conv2dact[0][0]
#                                                                  x_red2_c33conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_1conv2d (Conv2D)    (None, 12, 9, 192)   393216      red_concat_2[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_1conv2dbn (BatchNor (None, 12, 9, 192)   576         incresC_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_1conv2dact (Activat (None, 12, 9, 192)   0           incresC_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_2conv2d (Conv2D)    (None, 12, 9, 224)   129024      incresC_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_2conv2dbn (BatchNor (None, 12, 9, 224)   672         incresC_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_2conv2dact (Activat (None, 12, 9, 224)   0           incresC_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1b0conv2d (Conv2D)      (None, 12, 9, 192)   393216      red_concat_2[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_3conv2d (Conv2D)    (None, 12, 9, 256)   172032      incresC_1b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1b0conv2dbn (BatchNorma (None, 12, 9, 192)   576         incresC_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_3conv2dbn (BatchNor (None, 12, 9, 256)   768         incresC_1b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b0conv2dact (Activatio (None, 12, 9, 192)   0           incresC_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_3conv2dact (Activat (None, 12, 9, 256)   0           incresC_1b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1_mixed (Concatenate)   (None, 12, 9, 448)   0           incresC_1b0conv2dact[0][0]
#                                                                  incresC_1b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1fin1x1conv2d (Conv2D)  (None, 12, 9, 2048)  917504      incresC_1_mixed[0][0]
# __________________________________________________________________________________________________
# incresC_1fin1x1conv2dbn (BatchN (None, 12, 9, 2048)  6144        incresC_1fin1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1act_saling (Lambda)    (None, 12, 9, 2048)  0           red_concat_2[0][0]
#                                                                  incresC_1fin1x1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_1conv2d (Conv2D)    (None, 12, 9, 192)   393216      incresC_1act_saling[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_1conv2dbn (BatchNor (None, 12, 9, 192)   576         incresC_2b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_1conv2dact (Activat (None, 12, 9, 192)   0           incresC_2b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_2conv2d (Conv2D)    (None, 12, 9, 224)   129024      incresC_2b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_2conv2dbn (BatchNor (None, 12, 9, 224)   672         incresC_2b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_2conv2dact (Activat (None, 12, 9, 224)   0           incresC_2b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b0conv2d (Conv2D)      (None, 12, 9, 192)   393216      incresC_1act_saling[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_3conv2d (Conv2D)    (None, 12, 9, 256)   172032      incresC_2b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_2b0conv2dbn (BatchNorma (None, 12, 9, 192)   576         incresC_2b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_3conv2dbn (BatchNor (None, 12, 9, 256)   768         incresC_2b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b0conv2dact (Activatio (None, 12, 9, 192)   0           incresC_2b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_3conv2dact (Activat (None, 12, 9, 256)   0           incresC_2b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2_mixed (Concatenate)   (None, 12, 9, 448)   0           incresC_2b0conv2dact[0][0]
#                                                                  incresC_2b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 50, 90, 1)    0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            (None, 50, 75, 1)    0
# __________________________________________________________________________________________________
# incresC_2fin1x1conv2d (Conv2D)  (None, 12, 9, 2048)  917504      incresC_2_mixed[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 48, 88, 32)   320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 48, 73, 32)   320         input_3[0][0]
# __________________________________________________________________________________________________
# incresC_2fin1x1conv2dbn (BatchN (None, 12, 9, 2048)  6144        incresC_2fin1x1conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 24, 44, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 24, 36, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# incresC_2act_saling (Lambda)    (None, 12, 9, 2048)  0           incresC_1act_saling[0][0]
#                                                                  incresC_2fin1x1conv2dbn[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 22, 42, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 22, 34, 16)   4624        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           incresC_2act_saling[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 64)           0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 16)           0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 64)           0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 16)           0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           dropout[0][0]
# __________________________________________________________________________________________________
# concat_2 (Concatenate)          (None, 2128)         0           flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            4258        concat_2[0][0]
# ==================================================================================================
# Total params: 14,911,794
# Trainable params: 14,878,578
# Non-trainable params: 33,216
# __________________________________________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
'''
from keras.utils.vis_utils import model_to_dot
from tensorflow.keras.utils import plot_model
from IPython.display import SVG

SVG(model_to_dot(model).create(prog='dot', format='svg'))
plot_model(model, to_file='model_plot.png', 
                  show_shapes=True, show_layer_names=True)
'''
# Out:
# "\nfrom keras.utils.vis_utils import model_to_dot\nfrom tensorflow.keras.utils import plot_model\nfrom IPython.display import SVG\n\nSVG(model_to_dot(model).create(prog='dot', format='svg'))\nplot_model(model, to_file='model_plot.png', \n                  show_shapes=True, show_layer_names=True)\n"

# %%
eyes_width = 90
eyes_height = 50
mouth_width = 75
mouth_height = 50
face_width = 105
face_height = 125
num_classes = 2
channel = 1

# first input model: eyes
eyes1 = Input(shape=(eyes_height,eyes_width,1))
conv11 = Conv2D(32, kernel_size=(3, 3), activation='relu')(eyes1)
pool11 = MaxPooling2D(pool_size=(2, 2))(conv11)
conv12 = Conv2D(64, kernel_size=(3, 3), activation='relu')(pool11)
#pool12 = MaxPooling2D(pool_size=(2, 2))(conv12)
#flat1 = Flatten()(pool12)
pool12 = GlobalAveragePooling2D(data_format='channels_last')(conv12)
flat1 = Flatten()(pool12)


# second input model: mouth
mouth1 = Input(shape=(mouth_height,mouth_width,1))
conv21 = Conv2D(32, kernel_size=(3, 3), activation='relu')(mouth1)
pool21 = MaxPooling2D(pool_size=(2, 2))(conv21)
conv22 = Conv2D(16, kernel_size=(3, 3), activation='relu')(pool21)
#pool22 = MaxPooling2D(pool_size=(2, 2))(conv22)
#flat2 = Flatten()(pool22)
pool22 = GlobalAveragePooling2D(data_format='channels_last')(conv22)
flat2 = Flatten()(pool22)

# input model: face
face1 = Input(shape=(face_height,face_width,1))

x = incresA(face1,0.15,name='incresA_1')

#35 × 35 to 17 × 17 reduction module.
x_red_11 = MaxPooling2D(3,strides=2,padding='valid',name='red_maxpool_1')(x)

x_red_12 = conv2d(x,384,3,2,'valid',True,name='x_red1_c1')

x_red_13 = conv2d(x,256,1,1,'same',True,name='x_red1_c2_1')
x_red_13 = conv2d(x_red_13,256,3,1,'same',True,name='x_red1_c2_2')
x_red_13 = conv2d(x_red_13,384,3,2,'valid',True,name='x_red1_c2_3')

x = Concatenate(axis=3, name='red_concat_1')([x_red_11,x_red_12,x_red_13])

x = incresB(x,0.1,name='incresB_1')

x = GlobalAveragePooling2D(data_format='channels_last')(x)
x = Dropout(0.6)(x)
flat3 = Flatten()(x)

merge = Concatenate(axis=1, name='concat_2')([flat1, flat2,flat3])
output = Dense(num_classes, activation='softmax')(merge)

# %%
model2 = Model(inputs=[eyes1, mouth1, face1], outputs=output, name='inception_resnet_v2')
model2.summary()
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 125, 105, 1)  0
# __________________________________________________________________________________________________
# incresA_1b2_1conv2d (Conv2D)    (None, 125, 105, 32) 32          input_6[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2dbn (BatchNor (None, 125, 105, 32) 96          incresA_1b2_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2dact (Activat (None, 125, 105, 32) 0           incresA_1b2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2d (Conv2D)    (None, 125, 105, 32) 32          input_6[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2d (Conv2D)    (None, 125, 105, 48) 13824       incresA_1b2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2dbn (BatchNor (None, 125, 105, 32) 96          incresA_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2dbn (BatchNor (None, 125, 105, 48) 144         incresA_1b2_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2dact (Activat (None, 125, 105, 32) 0           incresA_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2dact (Activat (None, 125, 105, 48) 0           incresA_1b2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2d (Conv2D)      (None, 125, 105, 32) 32          input_6[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2d (Conv2D)    (None, 125, 105, 32) 9216        incresA_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2d (Conv2D)    (None, 125, 105, 64) 27648       incresA_1b2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2dbn (BatchNorma (None, 125, 105, 32) 96          incresA_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2dbn (BatchNor (None, 125, 105, 32) 96          incresA_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2dbn (BatchNor (None, 125, 105, 64) 192         incresA_1b2_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2dact (Activatio (None, 125, 105, 32) 0           incresA_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2dact (Activat (None, 125, 105, 32) 0           incresA_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2dact (Activat (None, 125, 105, 64) 0           incresA_1b2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1_concat (Concatenate)  (None, 125, 105, 128 0           incresA_1b0conv2dact[0][0]
#                                                                  incresA_1b1_2conv2dact[0][0]
#                                                                  incresA_1b2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1filt_exp_1x1conv2d (Co (None, 125, 105, 384 49152       incresA_1_concat[0][0]
# __________________________________________________________________________________________________
# incresA_1filt_exp_1x1conv2dbn ( (None, 125, 105, 384 1152        incresA_1filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1act_scaling (Lambda)   (None, 125, 105, 384 0           input_6[0][0]
#                                                                  incresA_1filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# x_red1_c2_1conv2d (Conv2D)      (None, 125, 105, 256 98304       incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_1conv2dbn (BatchNorma (None, 125, 105, 256 768         x_red1_c2_1conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_1conv2dact (Activatio (None, 125, 105, 256 0           x_red1_c2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2d (Conv2D)      (None, 125, 105, 256 589824      x_red1_c2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2dbn (BatchNorma (None, 125, 105, 256 768         x_red1_c2_2conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2dact (Activatio (None, 125, 105, 256 0           x_red1_c2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2d (Conv2D)        (None, 62, 52, 384)  1327104     incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2d (Conv2D)      (None, 62, 52, 384)  884736      x_red1_c2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2dbn (BatchNormali (None, 62, 52, 384)  1152        x_red1_c1conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2dbn (BatchNorma (None, 62, 52, 384)  1152        x_red1_c2_3conv2d[0][0]
# __________________________________________________________________________________________________
# red_maxpool_1 (MaxPooling2D)    (None, 62, 52, 384)  0           incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2dact (Activation) (None, 62, 52, 384)  0           x_red1_c1conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2dact (Activatio (None, 62, 52, 384)  0           x_red1_c2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# red_concat_1 (Concatenate)      (None, 62, 52, 1152) 0           red_maxpool_1[0][0]
#                                                                  x_red1_c1conv2dact[0][0]
#                                                                  x_red1_c2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2d (Conv2D)    (None, 62, 52, 128)  147456      red_concat_1[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2dbn (BatchNor (None, 62, 52, 128)  384         incresB_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2dact (Activat (None, 62, 52, 128)  0           incresB_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2d (Conv2D)    (None, 62, 52, 160)  143360      incresB_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2dbn (BatchNor (None, 62, 52, 160)  480         incresB_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2dact (Activat (None, 62, 52, 160)  0           incresB_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2d (Conv2D)      (None, 62, 52, 192)  221184      red_concat_1[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2d (Conv2D)    (None, 62, 52, 192)  215040      incresB_1b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2dbn (BatchNorma (None, 62, 52, 192)  576         incresB_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2dbn (BatchNor (None, 62, 52, 192)  576         incresB_1b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2dact (Activatio (None, 62, 52, 192)  0           incresB_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2dact (Activat (None, 62, 52, 192)  0           incresB_1b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1_mixed (Concatenate)   (None, 62, 52, 384)  0           incresB_1b0conv2dact[0][0]
#                                                                  incresB_1b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 50, 90, 1)    0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, 50, 75, 1)    0
# __________________________________________________________________________________________________
# incresB_1filt_exp_1x1conv2d (Co (None, 62, 52, 1152) 442368      incresB_1_mixed[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 48, 88, 32)   320         input_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 48, 73, 32)   320         input_5[0][0]
# __________________________________________________________________________________________________
# incresB_1filt_exp_1x1conv2dbn ( (None, 62, 52, 1152) 3456        incresB_1filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 24, 44, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 24, 36, 32)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# incresB_1act_scaling (Lambda)   (None, 62, 52, 1152) 0           red_concat_1[0][0]
#                                                                  incresB_1filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 22, 42, 64)   18496       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 22, 34, 16)   4624        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 1152)         0           incresB_1act_scaling[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 64)           0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 16)           0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1152)         0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 64)           0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 16)           0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 1152)         0           dropout_1[0][0]
# __________________________________________________________________________________________________
# concat_2 (Concatenate)          (None, 1232)         0           flatten_3[0][0]
#                                                                  flatten_4[0][0]
#                                                                  flatten_5[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            2466        concat_2[0][0]
# ==================================================================================================
# Total params: 4,206,722
# Trainable params: 4,199,266
# Non-trainable params: 7,456
# __________________________________________________________________________________________________

# %% [markdown]
# ### Load one file and label

# %%
# load label

import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset'

AllLabelFile = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if "drowsiness.txt" in file :
            AllLabelFile.append(os.path.join(r, file))
        
for f in AllLabelFile:
    print(f)
np.array(AllLabelFile).shape
# Out:
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\001_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\001_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\001_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\glasses\001_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\001_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\001_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\001_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\nightglasses\001_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\001_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\001_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\001_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\night_noglasses\001_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\001_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\001_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\001_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\noglasses\001_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\001_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\001_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\001_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\001\sunglasses\001_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\002_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\002_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\002_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\glasses\002_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\nightglasses\002_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\nightglasses\002_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\nightglasses\002_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\nightglasses\002_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\night_noglasses\002_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\night_noglasses\002_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\night_noglasses\002_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\night_noglasses\002_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\noglasses\002_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\noglasses\002_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\noglasses\002_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\noglasses\002_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\sunglasses\002_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\sunglasses\002_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\sunglasses\002_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\002\sunglasses\002_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\glasses\005_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\glasses\005_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\glasses\005_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\glasses\005_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\night_noglasses\005_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\night_noglasses\005_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\night_noglasses\005_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\night_noglasses\005_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\noglasses\005_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\noglasses\005_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\noglasses\005_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\noglasses\005_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\sunglasses\005_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\sunglasses\005_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\sunglasses\005_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\005\sunglasses\005_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\glasses\006_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\glasses\006_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\glasses\006_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\glasses\006_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\nightglasses\006_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\nightglasses\006_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\nightglasses\006_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\nightglasses\006_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\night_noglasses\006_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\night_noglasses\006_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\night_noglasses\006_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\night_noglasses\006_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\noglasses\006_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\noglasses\006_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\noglasses\006_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\noglasses\006_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\sunglasses\006_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\sunglasses\006_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\sunglasses\006_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\006\sunglasses\006_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\glasses\008_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\glasses\008_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\glasses\008_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\glasses\008_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\nightglasses\008_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\nightglasses\008_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\nightglasses\008_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\nightglasses\008_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\night_noglasses\008_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\night_noglasses\008_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\night_noglasses\008_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\night_noglasses\008_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\noglasses\008_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\noglasses\008_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\noglasses\008_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\noglasses\008_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\sunglasses\008_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\sunglasses\008_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\sunglasses\008_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\008\sunglasses\008_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\glasses\009_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\glasses\009_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\glasses\009_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\glasses\009_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\nightglasses\009_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\nightglasses\009_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\nightglasses\009_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\nightglasses\009_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\night_noglasses\009_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\night_noglasses\009_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\night_noglasses\009_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\night_noglasses\009_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\noglasses\009_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\noglasses\009_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\noglasses\009_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\noglasses\009_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\sunglasses\009_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\sunglasses\009_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\sunglasses\009_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\009\sunglasses\009_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\glasses\012_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\glasses\012_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\glasses\012_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\glasses\012_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\nightglasses\012_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\nightglasses\012_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\nightglasses\012_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\nightglasses\012_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\night_noglasses\012_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\night_noglasses\012_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\night_noglasses\012_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\night_noglasses\012_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\noglasses\012_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\noglasses\012_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\noglasses\012_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\noglasses\012_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\sunglasses\012_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\sunglasses\012_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\sunglasses\012_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\012\sunglasses\012_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\glasses\013_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\glasses\013_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\glasses\013_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\glasses\013_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\nightglasses\013_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\nightglasses\013_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\nightglasses\013_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\nightglasses\013_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\night_noglasses\013_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\night_noglasses\013_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\night_noglasses\013_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\night_noglasses\013_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\noglasses\013_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\noglasses\013_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\noglasses\013_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\noglasses\013_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\sunglasses\013_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\sunglasses\013_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\sunglasses\013_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\013\sunglasses\013_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\glasses\015_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\glasses\015_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\glasses\015_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\glasses\015_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\nightglasses\015_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\nightglasses\015_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\nightglasses\015_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\nightglasses\015_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\night_noglasses\015_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\night_noglasses\015_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\night_noglasses\015_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\night_noglasses\015_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\noglasses\015_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\noglasses\015_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\noglasses\015_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\noglasses\015_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\sunglasses\015_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\sunglasses\015_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\sunglasses\015_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\015\sunglasses\015_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\glasses\020_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\glasses\020_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\glasses\020_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\glasses\020_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\nightglasses\020_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\nightglasses\020_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\nightglasses\020_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\nightglasses\020_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\night_noglasses\020_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\night_noglasses\020_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\night_noglasses\020_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\night_noglasses\020_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\noglasses\020_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\noglasses\020_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\noglasses\020_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\noglasses\020_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\sunglasses\020_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\sunglasses\020_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\sunglasses\020_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\020\sunglasses\020_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\glasses\023_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\glasses\023_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\glasses\023_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\glasses\023_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\nightglasses\023_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\nightglasses\023_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\nightglasses\023_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\nightglasses\023_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\night_noglasses\023_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\night_noglasses\023_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\night_noglasses\023_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\night_noglasses\023_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\023_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\023_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\023_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\023_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\sunglasses\023_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\sunglasses\023_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\sunglasses\023_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\sunglasses\023_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\glasses\024_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\glasses\024_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\glasses\024_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\glasses\024_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\nightglasses\024_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\nightglasses\024_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\nightglasses\024_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\nightglasses\024_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\night_noglasses\024_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\night_noglasses\024_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\night_noglasses\024_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\night_noglasses\024_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\noglasses\024_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\noglasses\024_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\noglasses\024_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\noglasses\024_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\sunglasses\024_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\sunglasses\024_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\sunglasses\024_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\024\sunglasses\024_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\glasses\031_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\glasses\031_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\glasses\031_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\glasses\031_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\nightglasses\031_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\nightglasses\031_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\nightglasses\031_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\nightglasses\031_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\night_noglasses\031_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\night_noglasses\031_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\night_noglasses\031_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\night_noglasses\031_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\noglasses\031_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\noglasses\031_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\noglasses\031_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\noglasses\031_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\sunglasses\031_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\sunglasses\031_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\sunglasses\031_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\031\sunglasses\031_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\glasses\032_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\glasses\032_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\glasses\032_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\glasses\032_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\nightglasses\032_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\nightglasses\032_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\nightglasses\032_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\nightglasses\032_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\night_noglasses\032_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\night_noglasses\032_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\night_noglasses\032_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\night_noglasses\032_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\noglasses\032_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\noglasses\032_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\noglasses\032_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\noglasses\032_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\sunglasses\032_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\sunglasses\032_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\sunglasses\032_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\032\sunglasses\032_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\glasses\033_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\glasses\033_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\glasses\033_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\glasses\033_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\nightglasses\033_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\nightglasses\033_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\nightglasses\033_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\nightglasses\033_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\night_noglasses\033_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\night_noglasses\033_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\night_noglasses\033_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\night_noglasses\033_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\noglasses\033_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\noglasses\033_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\noglasses\033_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\noglasses\033_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\sunglasses\033_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\sunglasses\033_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\sunglasses\033_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\033\sunglasses\033_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\glasses\034_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\glasses\034_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\glasses\034_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\glasses\034_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\nightglasses\034_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\nightglasses\034_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\nightglasses\034_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\nightglasses\034_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\night_noglasses\034_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\night_noglasses\034_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\night_noglasses\034_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\night_noglasses\034_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\noglasses\034_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\noglasses\034_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\noglasses\034_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\noglasses\034_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\sunglasses\034_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\sunglasses\034_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\sunglasses\034_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\034\sunglasses\034_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\glasses\035_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\glasses\035_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\glasses\035_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\glasses\035_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\nightglasses\035_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\nightglasses\035_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\nightglasses\035_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\nightglasses\035_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\night_noglasses\035_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\night_noglasses\035_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\night_noglasses\035_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\night_noglasses\035_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\noglasses\035_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\noglasses\035_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\noglasses\035_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\noglasses\035_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\sunglasses\035_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\sunglasses\035_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\sunglasses\035_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\035\sunglasses\035_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\glasses\036_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\glasses\036_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\glasses\036_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\glasses\036_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\nightglasses\036_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\nightglasses\036_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\nightglasses\036_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\nightglasses\036_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\night_noglasses\036_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\night_noglasses\036_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\night_noglasses\036_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\night_noglasses\036_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\noglasses\036_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\noglasses\036_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\noglasses\036_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\noglasses\036_yawning_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\sunglasses\036_nonsleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\sunglasses\036_sleepyCombination_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\sunglasses\036_slowBlinkWithNodding_drowsiness.txt
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\036\sunglasses\036_yawning_drowsiness.txt
# (356,)

# %%
import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Training Image'

AllImageFolder = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for directory in d:
        if ("nonsleepyCombination" in directory or "sleepyCombination" in directory or "slowBlinkWithNodding"  in directory or "yawning" in directory)   :
            #print(directory)
            AllImageFolder.append(os.path.join(r, directory))
        
for d in AllImageFolder:
    print(d)
np.array(AllImageFolder).shape
# Out:
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\yawning
# (4,)

# %%
import numpy as np
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import cv2

def LoadImage(path):
    Face_ImageDataList = []
    files = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if ".jpg" in file:
                files.append(os.path.join(r, file))

    files.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
    for f in files:
        ImgGray = cv2.imread(f,0)
        #ImgRGB = cv2.merge((ImgGray,ImgGray,ImgGray))# this line make gray image to RGB
        #Face_ImageDataList.append(ImgRGB)  
        
        ImgGray = ImgGray.reshape(ImgGray.shape[0],ImgGray.shape[1],1)
        print(ImgGray.shape)
        Face_ImageDataList.append(ImgGray)
        #print(np.array(Face_ImageDataList).shape)
    return Face_ImageDataList




for epoch in range(50):
    index = 0
    for Video in AllImageFolder:
        
        #if(index == 0 ):
        #    index = index + 1
        #    continue
        print("---")
        #=========================load file
        
        faceImage = []
        mouthImage = []
        eyesImage = []

        labelfile = AllLabelFile[index]
        index = index + 1
        #print("label: "+labelfile)

        LabelList = []

        inputfile = open(labelfile, 'r').read()


        LabelList = list(map(int, inputfile))
        Labelarray = np.array(LabelList)

        Labelarray = to_categorical(Labelarray, num_classes=2)
        #print(Labelarray[1500])
        #==================================
        
        eyesfolder = Video+"\\eyes"
        eyesImage = LoadImage(eyesfolder)
        facefolder = Video+"\\face"
        faceImage = LoadImage(facefolder)
        mouthfolder = Video+"\\mouth"
        mouthImage = LoadImage(mouthfolder)
        
        print(eyesfolder)
        #print(eyesImage)
        print(np.array(eyesImage).shape)
        print(np.array(faceImage).shape)
        print(np.array(mouthImage).shape)
        #plt.imshow(faceImage[1] , cmap = 'gray')
        
        model_result = model2.fit([eyesImage,mouthImage,faceImage], Labelarray,batch_size=20,epochs=epoch+1, initial_epoch=epoch, shuffle=True,verbose = 1)
# Out:
# ---
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (50, 90, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (100, 180, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# (125, 105, 1)
# ...
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (50, 75, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# (100, 150, 1)
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\sleepyCombination\eyes
# (3472,)
# (3472,)
# (3472,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-85f629766b00> in <module>()
#      72         #plt.imshow(faceImage[1] , cmap = 'gray')
#      73
# ---> 74         model_result = model2.fit([eyesImage,mouthImage,faceImage], Labelarray,batch_size=20,epochs=epoch+1, initial_epoch=epoch, shuffle=True,verbose = 1)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1534         steps_name='steps_per_epoch',
#    1535         steps=steps_per_epoch,
# -> 1536         validation_split=validation_split)
#    1537
#    1538     # Prepare validation data.
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split)
#     990         x, y, sample_weight = next_element
#     991     x, y, sample_weights = self._standardize_weights(x, y, sample_weight,
# --> 992                                                      class_weight, batch_size)
#     993     return x, y, sample_weights
#     994
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _standardize_weights(self, x, y, sample_weight, class_weight, batch_size)
#    1115         feed_input_shapes,
#    1116         check_batch_axis=False,  # Don't enforce the batch size.
# -> 1117         exception_prefix='input')
#    1118
#    1119     if y is not None:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     321                            ': expected ' + names[i] + ' to have ' +
#     322                            str(len(shape)) + ' dimensions, but got array '
# --> 323                            'with shape ' + str(data_shape))
#     324         if not check_batch_axis:
#     325           data_shape = data_shape[1:]
#
# ValueError: Error when checking input: expected input_4 to have 4 dimensions, but got array with shape (3472, 1)
