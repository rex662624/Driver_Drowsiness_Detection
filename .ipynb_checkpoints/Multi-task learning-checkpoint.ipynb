# %%
# %run ./Model.ipynb
# Out:
# C:\Users\T-Rex\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
eyes_width = 60
eyes_height = 33
mouth_width = 50
mouth_height = 33
face_width = 66
face_height = 85
num_classes = 2
channel = 1

# %%
img_input = Input(shape=(face_height,face_width,1))
#img_input = Input(shape=(face_height,face_width,1))
#img_input = Input(shape=(face_height,face_width,1))

x = conv2d(img_input,32,3,2,'valid',True,name='conv1')
x = conv2d(x,32,3,1,'valid',True,name='conv2')
x = conv2d(x,64,3,1,'valid',True,name='conv3')

x_11 = MaxPooling2D(3,strides=1,padding='valid',name='stem_br_11'+'_maxpool_1')(x)
x_12 = conv2d(x,96,3,1,'valid',True,name='stem_br_12')

x = Concatenate(axis=3, name = 'stem_concat_1')([x_11,x_12])

x_21 = conv2d(x,64,1,1,'same',True,name='stem_br_211')
x_21 = conv2d(x_21,64,[1,7],1,'same',True,name='stem_br_212')
x_21 = conv2d(x_21,64,[7,1],1,'same',True,name='stem_br_213')
x_21 = conv2d(x_21,96,3,1,'valid',True,name='stem_br_214')

x_22 = conv2d(x,64,1,1,'same',True,name='stem_br_221')
x_22 = conv2d(x_22,96,3,1,'valid',True,name='stem_br_222')

x = Concatenate(axis=3, name = 'stem_concat_2')([x_21,x_22])

x_31 = conv2d(x,192,3,1,'valid',True,name='stem_br_31')
x_32 = MaxPooling2D(3,strides=1,padding='valid',name='stem_br_32'+'_maxpool_2')(x)
x = Concatenate(axis=3, name = 'stem_concat_3')([x_31,x_32])

# %%
#Inception-ResNet-A modules
x = incresA(x,0.15,name='incresA_1')
x = incresA(x,0.15 ,name='incresA_2')
#x = incresA(x,0.15,name='incresA_3')
#x = incresA(x,0.15,name='incresA_4')

#35 × 35 to 17 × 17 reduction module.
x_red_11 = MaxPooling2D(3,strides=2,padding='valid',name='red_maxpool_1')(x)

x_red_12 = conv2d(x,384,3,2,'valid',True,name='x_red1_c1')

x_red_13 = conv2d(x,256,1,1,'same',True,name='x_red1_c2_1')
x_red_13 = conv2d(x_red_13,256,3,1,'same',True,name='x_red1_c2_2')
x_red_13 = conv2d(x_red_13,384,3,2,'valid',True,name='x_red1_c2_3')

x = Concatenate(axis=3, name='red_concat_1')([x_red_11,x_red_12,x_red_13])

#Inception-ResNet-B modules
x = incresB(x,0.1,name='incresB_1')
x = incresB(x,0.1,name='incresB_2')
#x = incresB(x,0.1,name='incresB_3')
#x = incresB(x,0.1,name='incresB_4')
#x = incresB(x,0.1,name='incresB_5')
#x = incresB(x,0.1,name='incresB_6')
#x = incresB(x,0.1,name='incresB_7')

#17 × 17 to 8 × 8 reduction module.
x_red_21 = MaxPooling2D(3,strides=2,padding='valid',name='red_maxpool_2')(x)

x_red_22 = conv2d(x,256,1,1,'same',True,name='x_red2_c11')
x_red_22 = conv2d(x_red_22,384,3,2,'valid',True,name='x_red2_c12')

x_red_23 = conv2d(x,256,1,1,'same',True,name='x_red2_c21')
x_red_23 = conv2d(x_red_23,256,3,2,'valid',True,name='x_red2_c22')

x_red_24 = conv2d(x,256,1,1,'same',True,name='x_red2_c31')
x_red_24 = conv2d(x_red_24,256,3,1,'same',True,name='x_red2_c32')
x_red_24 = conv2d(x_red_24,256,3,2,'valid',True,name='x_red2_c33')

x = Concatenate(axis=3, name='red_concat_2')([x_red_21,x_red_22,x_red_23,x_red_24])

#Inception-ResNet-C modules
x = incresC(x,0.2,name='incresC_1')
#x = incresC(x,0.2,name='incresC_3')
InceptionOut = incresC(x,0.2,name='incresC_2')

# %%
#TOP
x = GlobalAveragePooling2D(data_format='channels_last')(InceptionOut)
#x = MaxPooling2D(pool_size=(3,2), padding='valid', data_format='channels_last')(InceptionOut)
#x = Dense(num_classes, activation='softmax')(x)
x = Flatten()(x)

# %%
#x = Dense(2048, activation='relu')(x)



#classification_1 = Dense(2048, activation='relu')(x)
classification_1 = BatchNormalization(scale=False)(x)
classification_1 = Dense(512, activation='relu')(classification_1)
classification_1 = BatchNormalization(scale=False)(classification_1)
classification_1 = Dense(64, activation='relu')(classification_1)

classification_1d = Dropout(0.5)(classification_1)
HeadOutput = Dense(3, activation='softmax', name = 'Head')(classification_1d)

#classification_2 = Dense(2048, activation='relu')(x)
classification_2 = BatchNormalization(scale=False)(x)
classification_2 = Dense(512, activation='relu')(classification_2)
classification_2 = BatchNormalization(scale=False)(classification_2)
classification_2 = Dense(64, activation='relu')(classification_2)
classification_2d = Dropout(0.5)(classification_2)
MouthOutput = Dense(3, activation='softmax', name = 'Mouth')(classification_2d)

#Mouth help eyes

#classification_3 = Dense(2048, activation='relu')(x)

classification_3 = BatchNormalization(scale=False)(x)
classification_3 = Dense(512, activation='relu')(classification_3)
classification_3 = BatchNormalization(scale=False)(classification_3)
classification_3 = Dense(64, activation='relu')(classification_3)

#classification_3out = Concatenate()([classification_1,classification_2,classification_3])

classification_3d = Dropout(0.5)(classification_3)
EyesOutput = Dense(2, activation='softmax', name = 'Eyes')(classification_3d)

#classification_4 = Dense(2048, activation='relu')(x)
classification_4 = BatchNormalization(scale=False)(x)
classification_4 = Dense(512, activation='relu')(classification_4)
classification_4 = BatchNormalization(scale=False)(classification_4)
classification_4 = Dense(64, activation='relu')(classification_4)

classification_4out = Concatenate()([classification_1,classification_2,classification_4])
classification_4d = Dropout(0.5)(classification_4out)
TotalOutput = Dense(2, activation='softmax', name = 'Total')(classification_4d)

model = Model(inputs=[img_input], outputs=[
                                            HeadOutput
                                           , MouthOutput
                                           , EyesOutput
                                           ,TotalOutput
                                        ], name='inception_resnet_v2')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 85, 66, 1)    0
# __________________________________________________________________________________________________
# conv1conv2d (Conv2D)            (None, 42, 32, 32)   288         input_1[0][0]
# __________________________________________________________________________________________________
# conv1conv2dbn (BatchNormalizati (None, 42, 32, 32)   96          conv1conv2d[0][0]
# __________________________________________________________________________________________________
# conv1conv2dact (Activation)     (None, 42, 32, 32)   0           conv1conv2dbn[0][0]
# __________________________________________________________________________________________________
# conv2conv2d (Conv2D)            (None, 40, 30, 32)   9216        conv1conv2dact[0][0]
# __________________________________________________________________________________________________
# conv2conv2dbn (BatchNormalizati (None, 40, 30, 32)   96          conv2conv2d[0][0]
# __________________________________________________________________________________________________
# conv2conv2dact (Activation)     (None, 40, 30, 32)   0           conv2conv2dbn[0][0]
# __________________________________________________________________________________________________
# conv3conv2d (Conv2D)            (None, 38, 28, 64)   18432       conv2conv2dact[0][0]
# __________________________________________________________________________________________________
# conv3conv2dbn (BatchNormalizati (None, 38, 28, 64)   192         conv3conv2d[0][0]
# __________________________________________________________________________________________________
# conv3conv2dact (Activation)     (None, 38, 28, 64)   0           conv3conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_12conv2d (Conv2D)       (None, 36, 26, 96)   55296       conv3conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_12conv2dbn (BatchNormal (None, 36, 26, 96)   288         stem_br_12conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_11_maxpool_1 (MaxPoolin (None, 36, 26, 64)   0           conv3conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_12conv2dact (Activation (None, 36, 26, 96)   0           stem_br_12conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_concat_1 (Concatenate)     (None, 36, 26, 160)  0           stem_br_11_maxpool_1[0][0]
#                                                                  stem_br_12conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_211conv2d (Conv2D)      (None, 36, 26, 64)   10240       stem_concat_1[0][0]
# __________________________________________________________________________________________________
# stem_br_211conv2dbn (BatchNorma (None, 36, 26, 64)   192         stem_br_211conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_211conv2dact (Activatio (None, 36, 26, 64)   0           stem_br_211conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_212conv2d (Conv2D)      (None, 36, 26, 64)   28672       stem_br_211conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_212conv2dbn (BatchNorma (None, 36, 26, 64)   192         stem_br_212conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_212conv2dact (Activatio (None, 36, 26, 64)   0           stem_br_212conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_213conv2d (Conv2D)      (None, 36, 26, 64)   28672       stem_br_212conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_221conv2d (Conv2D)      (None, 36, 26, 64)   10240       stem_concat_1[0][0]
# __________________________________________________________________________________________________
# stem_br_213conv2dbn (BatchNorma (None, 36, 26, 64)   192         stem_br_213conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_221conv2dbn (BatchNorma (None, 36, 26, 64)   192         stem_br_221conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_213conv2dact (Activatio (None, 36, 26, 64)   0           stem_br_213conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_221conv2dact (Activatio (None, 36, 26, 64)   0           stem_br_221conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_214conv2d (Conv2D)      (None, 34, 24, 96)   55296       stem_br_213conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_222conv2d (Conv2D)      (None, 34, 24, 96)   55296       stem_br_221conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_214conv2dbn (BatchNorma (None, 34, 24, 96)   288         stem_br_214conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_222conv2dbn (BatchNorma (None, 34, 24, 96)   288         stem_br_222conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_214conv2dact (Activatio (None, 34, 24, 96)   0           stem_br_214conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_222conv2dact (Activatio (None, 34, 24, 96)   0           stem_br_222conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_concat_2 (Concatenate)     (None, 34, 24, 192)  0           stem_br_214conv2dact[0][0]
#                                                                  stem_br_222conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_31conv2d (Conv2D)       (None, 32, 22, 192)  331776      stem_concat_2[0][0]
# __________________________________________________________________________________________________
# stem_br_31conv2dbn (BatchNormal (None, 32, 22, 192)  576         stem_br_31conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_31conv2dact (Activation (None, 32, 22, 192)  0           stem_br_31conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_32_maxpool_2 (MaxPoolin (None, 32, 22, 192)  0           stem_concat_2[0][0]
# __________________________________________________________________________________________________
# stem_concat_3 (Concatenate)     (None, 32, 22, 384)  0           stem_br_31conv2dact[0][0]
#                                                                  stem_br_32_maxpool_2[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2d (Conv2D)    (None, 32, 22, 32)   12288       stem_concat_3[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_1b2_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2dact (Activat (None, 32, 22, 32)   0           incresA_1b2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2d (Conv2D)    (None, 32, 22, 32)   12288       stem_concat_3[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2d (Conv2D)    (None, 32, 22, 48)   13824       incresA_1b2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2dbn (BatchNor (None, 32, 22, 48)   144         incresA_1b2_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2dact (Activat (None, 32, 22, 32)   0           incresA_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2dact (Activat (None, 32, 22, 48)   0           incresA_1b2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2d (Conv2D)      (None, 32, 22, 32)   12288       stem_concat_3[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2d (Conv2D)    (None, 32, 22, 32)   9216        incresA_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2d (Conv2D)    (None, 32, 22, 64)   27648       incresA_1b2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2dbn (BatchNorma (None, 32, 22, 32)   96          incresA_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2dbn (BatchNor (None, 32, 22, 64)   192         incresA_1b2_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2dact (Activatio (None, 32, 22, 32)   0           incresA_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2dact (Activat (None, 32, 22, 32)   0           incresA_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2dact (Activat (None, 32, 22, 64)   0           incresA_1b2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1_concat (Concatenate)  (None, 32, 22, 128)  0           incresA_1b0conv2dact[0][0]
#                                                                  incresA_1b1_2conv2dact[0][0]
#                                                                  incresA_1b2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1filt_exp_1x1conv2d (Co (None, 32, 22, 384)  49152       incresA_1_concat[0][0]
# __________________________________________________________________________________________________
# incresA_1filt_exp_1x1conv2dbn ( (None, 32, 22, 384)  1152        incresA_1filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1act_scaling (Lambda)   (None, 32, 22, 384)  0           stem_concat_3[0][0]
#                                                                  incresA_1filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# incresA_2b2_1conv2d (Conv2D)    (None, 32, 22, 32)   12288       incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_1conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_2b2_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_1conv2dact (Activat (None, 32, 22, 32)   0           incresA_2b2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_1conv2d (Conv2D)    (None, 32, 22, 32)   12288       incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_2conv2d (Conv2D)    (None, 32, 22, 48)   13824       incresA_2b2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_1conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_2b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_2conv2dbn (BatchNor (None, 32, 22, 48)   144         incresA_2b2_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_1conv2dact (Activat (None, 32, 22, 32)   0           incresA_2b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_2conv2dact (Activat (None, 32, 22, 48)   0           incresA_2b2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b0conv2d (Conv2D)      (None, 32, 22, 32)   12288       incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_2conv2d (Conv2D)    (None, 32, 22, 32)   9216        incresA_2b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_3conv2d (Conv2D)    (None, 32, 22, 64)   27648       incresA_2b2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2b0conv2dbn (BatchNorma (None, 32, 22, 32)   96          incresA_2b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_2conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_2b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_3conv2dbn (BatchNor (None, 32, 22, 64)   192         incresA_2b2_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b0conv2dact (Activatio (None, 32, 22, 32)   0           incresA_2b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_2conv2dact (Activat (None, 32, 22, 32)   0           incresA_2b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_3conv2dact (Activat (None, 32, 22, 64)   0           incresA_2b2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2_concat (Concatenate)  (None, 32, 22, 128)  0           incresA_2b0conv2dact[0][0]
#                                                                  incresA_2b1_2conv2dact[0][0]
#                                                                  incresA_2b2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2filt_exp_1x1conv2d (Co (None, 32, 22, 384)  49152       incresA_2_concat[0][0]
# __________________________________________________________________________________________________
# incresA_2filt_exp_1x1conv2dbn ( (None, 32, 22, 384)  1152        incresA_2filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2act_scaling (Lambda)   (None, 32, 22, 384)  0           incresA_1act_scaling[0][0]
#                                                                  incresA_2filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# x_red1_c2_1conv2d (Conv2D)      (None, 32, 22, 256)  98304       incresA_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_1conv2dbn (BatchNorma (None, 32, 22, 256)  768         x_red1_c2_1conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_1conv2dact (Activatio (None, 32, 22, 256)  0           x_red1_c2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2d (Conv2D)      (None, 32, 22, 256)  589824      x_red1_c2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2dbn (BatchNorma (None, 32, 22, 256)  768         x_red1_c2_2conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2dact (Activatio (None, 32, 22, 256)  0           x_red1_c2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2d (Conv2D)        (None, 15, 10, 384)  1327104     incresA_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2d (Conv2D)      (None, 15, 10, 384)  884736      x_red1_c2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2dbn (BatchNormali (None, 15, 10, 384)  1152        x_red1_c1conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2dbn (BatchNorma (None, 15, 10, 384)  1152        x_red1_c2_3conv2d[0][0]
# __________________________________________________________________________________________________
# red_maxpool_1 (MaxPooling2D)    (None, 15, 10, 384)  0           incresA_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2dact (Activation) (None, 15, 10, 384)  0           x_red1_c1conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2dact (Activatio (None, 15, 10, 384)  0           x_red1_c2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# red_concat_1 (Concatenate)      (None, 15, 10, 1152) 0           red_maxpool_1[0][0]
#                                                                  x_red1_c1conv2dact[0][0]
#                                                                  x_red1_c2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2d (Conv2D)    (None, 15, 10, 128)  147456      red_concat_1[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2dbn (BatchNor (None, 15, 10, 128)  384         incresB_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2dact (Activat (None, 15, 10, 128)  0           incresB_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2d (Conv2D)    (None, 15, 10, 160)  143360      incresB_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2dbn (BatchNor (None, 15, 10, 160)  480         incresB_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2dact (Activat (None, 15, 10, 160)  0           incresB_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2d (Conv2D)      (None, 15, 10, 192)  221184      red_concat_1[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2d (Conv2D)    (None, 15, 10, 192)  215040      incresB_1b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2dbn (BatchNorma (None, 15, 10, 192)  576         incresB_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2dbn (BatchNor (None, 15, 10, 192)  576         incresB_1b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2dact (Activatio (None, 15, 10, 192)  0           incresB_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2dact (Activat (None, 15, 10, 192)  0           incresB_1b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1_mixed (Concatenate)   (None, 15, 10, 384)  0           incresB_1b0conv2dact[0][0]
#                                                                  incresB_1b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1filt_exp_1x1conv2d (Co (None, 15, 10, 1152) 442368      incresB_1_mixed[0][0]
# __________________________________________________________________________________________________
# incresB_1filt_exp_1x1conv2dbn ( (None, 15, 10, 1152) 3456        incresB_1filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1act_scaling (Lambda)   (None, 15, 10, 1152) 0           red_concat_1[0][0]
#                                                                  incresB_1filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# incresB_2b1_1conv2d (Conv2D)    (None, 15, 10, 128)  147456      incresB_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_1conv2dbn (BatchNor (None, 15, 10, 128)  384         incresB_2b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_1conv2dact (Activat (None, 15, 10, 128)  0           incresB_2b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_2conv2d (Conv2D)    (None, 15, 10, 160)  143360      incresB_2b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_2conv2dbn (BatchNor (None, 15, 10, 160)  480         incresB_2b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_2conv2dact (Activat (None, 15, 10, 160)  0           incresB_2b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2b0conv2d (Conv2D)      (None, 15, 10, 192)  221184      incresB_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_3conv2d (Conv2D)    (None, 15, 10, 192)  215040      incresB_2b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_2b0conv2dbn (BatchNorma (None, 15, 10, 192)  576         incresB_2b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_3conv2dbn (BatchNor (None, 15, 10, 192)  576         incresB_2b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b0conv2dact (Activatio (None, 15, 10, 192)  0           incresB_2b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_3conv2dact (Activat (None, 15, 10, 192)  0           incresB_2b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2_mixed (Concatenate)   (None, 15, 10, 384)  0           incresB_2b0conv2dact[0][0]
#                                                                  incresB_2b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_2filt_exp_1x1conv2d (Co (None, 15, 10, 1152) 442368      incresB_2_mixed[0][0]
# __________________________________________________________________________________________________
# incresB_2filt_exp_1x1conv2dbn ( (None, 15, 10, 1152) 3456        incresB_2filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2act_scaling (Lambda)   (None, 15, 10, 1152) 0           incresB_1act_scaling[0][0]
#                                                                  incresB_2filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# x_red2_c31conv2d (Conv2D)       (None, 15, 10, 256)  294912      incresB_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c31conv2dbn (BatchNormal (None, 15, 10, 256)  768         x_red2_c31conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c31conv2dact (Activation (None, 15, 10, 256)  0           x_red2_c31conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c11conv2d (Conv2D)       (None, 15, 10, 256)  294912      incresB_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c21conv2d (Conv2D)       (None, 15, 10, 256)  294912      incresB_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c32conv2d (Conv2D)       (None, 15, 10, 256)  589824      x_red2_c31conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c11conv2dbn (BatchNormal (None, 15, 10, 256)  768         x_red2_c11conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c21conv2dbn (BatchNormal (None, 15, 10, 256)  768         x_red2_c21conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c32conv2dbn (BatchNormal (None, 15, 10, 256)  768         x_red2_c32conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c11conv2dact (Activation (None, 15, 10, 256)  0           x_red2_c11conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c21conv2dact (Activation (None, 15, 10, 256)  0           x_red2_c21conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c32conv2dact (Activation (None, 15, 10, 256)  0           x_red2_c32conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c12conv2d (Conv2D)       (None, 7, 4, 384)    884736      x_red2_c11conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c22conv2d (Conv2D)       (None, 7, 4, 256)    589824      x_red2_c21conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c33conv2d (Conv2D)       (None, 7, 4, 256)    589824      x_red2_c32conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c12conv2dbn (BatchNormal (None, 7, 4, 384)    1152        x_red2_c12conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c22conv2dbn (BatchNormal (None, 7, 4, 256)    768         x_red2_c22conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c33conv2dbn (BatchNormal (None, 7, 4, 256)    768         x_red2_c33conv2d[0][0]
# __________________________________________________________________________________________________
# red_maxpool_2 (MaxPooling2D)    (None, 7, 4, 1152)   0           incresB_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c12conv2dact (Activation (None, 7, 4, 384)    0           x_red2_c12conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c22conv2dact (Activation (None, 7, 4, 256)    0           x_red2_c22conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c33conv2dact (Activation (None, 7, 4, 256)    0           x_red2_c33conv2dbn[0][0]
# __________________________________________________________________________________________________
# red_concat_2 (Concatenate)      (None, 7, 4, 2048)   0           red_maxpool_2[0][0]
#                                                                  x_red2_c12conv2dact[0][0]
#                                                                  x_red2_c22conv2dact[0][0]
#                                                                  x_red2_c33conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_1conv2d (Conv2D)    (None, 7, 4, 192)    393216      red_concat_2[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_1conv2dbn (BatchNor (None, 7, 4, 192)    576         incresC_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_1conv2dact (Activat (None, 7, 4, 192)    0           incresC_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_2conv2d (Conv2D)    (None, 7, 4, 224)    129024      incresC_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_2conv2dbn (BatchNor (None, 7, 4, 224)    672         incresC_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_2conv2dact (Activat (None, 7, 4, 224)    0           incresC_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1b0conv2d (Conv2D)      (None, 7, 4, 192)    393216      red_concat_2[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_3conv2d (Conv2D)    (None, 7, 4, 256)    172032      incresC_1b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1b0conv2dbn (BatchNorma (None, 7, 4, 192)    576         incresC_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_3conv2dbn (BatchNor (None, 7, 4, 256)    768         incresC_1b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b0conv2dact (Activatio (None, 7, 4, 192)    0           incresC_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_3conv2dact (Activat (None, 7, 4, 256)    0           incresC_1b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1_mixed (Concatenate)   (None, 7, 4, 448)    0           incresC_1b0conv2dact[0][0]
#                                                                  incresC_1b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1fin1x1conv2d (Conv2D)  (None, 7, 4, 2048)   917504      incresC_1_mixed[0][0]
# __________________________________________________________________________________________________
# incresC_1fin1x1conv2dbn (BatchN (None, 7, 4, 2048)   6144        incresC_1fin1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1act_saling (Lambda)    (None, 7, 4, 2048)   0           red_concat_2[0][0]
#                                                                  incresC_1fin1x1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_1conv2d (Conv2D)    (None, 7, 4, 192)    393216      incresC_1act_saling[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_1conv2dbn (BatchNor (None, 7, 4, 192)    576         incresC_2b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_1conv2dact (Activat (None, 7, 4, 192)    0           incresC_2b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_2conv2d (Conv2D)    (None, 7, 4, 224)    129024      incresC_2b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_2conv2dbn (BatchNor (None, 7, 4, 224)    672         incresC_2b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_2conv2dact (Activat (None, 7, 4, 224)    0           incresC_2b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b0conv2d (Conv2D)      (None, 7, 4, 192)    393216      incresC_1act_saling[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_3conv2d (Conv2D)    (None, 7, 4, 256)    172032      incresC_2b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_2b0conv2dbn (BatchNorma (None, 7, 4, 192)    576         incresC_2b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_3conv2dbn (BatchNor (None, 7, 4, 256)    768         incresC_2b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b0conv2dact (Activatio (None, 7, 4, 192)    0           incresC_2b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_3conv2dact (Activat (None, 7, 4, 256)    0           incresC_2b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2_mixed (Concatenate)   (None, 7, 4, 448)    0           incresC_2b0conv2dact[0][0]
#                                                                  incresC_2b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_2fin1x1conv2d (Conv2D)  (None, 7, 4, 2048)   917504      incresC_2_mixed[0][0]
# __________________________________________________________________________________________________
# incresC_2fin1x1conv2dbn (BatchN (None, 7, 4, 2048)   6144        incresC_2fin1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2act_saling (Lambda)    (None, 7, 4, 2048)   0           incresC_1act_saling[0][0]
#                                                                  incresC_2fin1x1conv2dbn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           incresC_2act_saling[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 2048)         6144        flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 2048)         6144        flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 2048)         6144        flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1049088     batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          1049088     batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 2048)         6144        flatten[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 512)          1049088     batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512)          1536        dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 512)          1536        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          1049088     batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 512)          1536        dense_6[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           32832       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           32832       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 512)          1536        dense_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           32832       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           32832       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 192)          0           dense_1[0][0]
#                                                                  dense_3[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 192)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# Head (Dense)                    (None, 3)            195         dropout[0][0]
# __________________________________________________________________________________________________
# Mouth (Dense)                   (None, 3)            195         dropout_1[0][0]
# __________________________________________________________________________________________________
# Eyes (Dense)                    (None, 2)            130         dropout_2[0][0]
# __________________________________________________________________________________________________
# Total (Dense)                   (None, 2)            386         dropout_3[0][0]
# ==================================================================================================
# Total params: 18,068,202
# Trainable params: 18,018,154
# Non-trainable params: 50,048
# __________________________________________________________________________________________________

# %%
model.compile(loss = {
                    'Head': 'categorical_crossentropy',
                    'Mouth': 'categorical_crossentropy',
                    'Eyes': 'categorical_crossentropy',
                    'Total': 'categorical_crossentropy'
                    },
                    loss_weights = {
                            'Head': 1.5,
                            'Mouth': 1.5,
                            'Eyes': 1.0,
                            'Total': 1.5,
                            }
                  , optimizer = Adam(lr = 0.0001, decay=1e-6), metrics=['accuracy'])

# %% [markdown]
# ### Load Label

# %%
# load label

import os
import numpy as np

def FindFile(path,keyword):

    #path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
    #path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset'

    File = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if keyword in file :
                File.append(os.path.join(r, file))

    #for f in File:
    #    print(f)
    print(np.array(File).shape)
    
    return File

# %%
Head_AllLabelFile = FindFile('.\Dataset\Training_Evaluation_Dataset\Training Dataset','head.txt')
Eye_AllLabelFile = FindFile('.\Dataset\Training_Evaluation_Dataset\Training Dataset','eye.txt')
Mouth_AllLabelFile = FindFile('.\Dataset\Training_Evaluation_Dataset\Training Dataset','mouth.txt')
Total_AllLabelFile = FindFile('.\Dataset\Training_Evaluation_Dataset\Training Dataset','drowsiness.txt')
# Out:
# (356,)
# (356,)
# (356,)
# (356,)

# %%
import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Training Image'

AllImageFolder = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for directory in d:
        if ("nonsleepyCombination" in directory or "sleepyCombination" in directory or "slowBlinkWithNodding"  in directory or "yawning" in directory)   :
            #print(directory)
            AllImageFolder.append(os.path.join(r, directory))
        
for d in AllImageFolder:
    print(d)
np.array(AllImageFolder).shape
# Out:
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\001\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\002\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\005\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\006\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\008\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\009\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\012\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\013\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\015\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\020\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\023\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\024\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\031\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\032\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\033\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\034\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\035\sunglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\glasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\glasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\glasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\glasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\nightglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\nightglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\nightglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\nightglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\night_noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\night_noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\night_noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\night_noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\noglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\noglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\noglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\noglasses\yawning
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\sunglasses\nonsleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\sunglasses\sleepyCombination
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\sunglasses\slowBlinkWithNodding
# .\Dataset\Training_Evaluation_Dataset\Training Image\036\sunglasses\yawning
# (356,)

# %%
num_samples = 234866
testing_sample = 167168
validation_sample = 83789

# %%
Head_Testing_AllLabelFile = FindFile('.\Dataset\Training_Evaluation_Dataset\Evaluation Dataset','head.txt')
Eye_Testing_AllLabelFile = FindFile('.\Dataset\Training_Evaluation_Dataset\Evaluation Dataset','eye.txt')
Mouth_Testing_AllLabelFile = FindFile('.\Dataset\Training_Evaluation_Dataset\Evaluation Dataset','mouth.txt')
Total_Testing_AllLabelFile = FindFile('.\Dataset\Training_Evaluation_Dataset\Evaluation Dataset','drowsiness.txt')
# Out:
# (20,)
# (20,)
# (20,)
# (20,)

# %%
import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Testing Image'

AllImageFolderTesting = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for directory in d:
        if ("mix" in directory):
            #print(directory)
            AllImageFolderTesting.append(os.path.join(r, directory))    
            
AllImageFolderTesting = AllImageFolderTesting
for d in AllImageFolderTesting:
    print(d)
    
#llImageFolder = AllImageFolder[2:]
np.array(AllImageFolderTesting).shape
# Out:
# .\Dataset\Training_Evaluation_Dataset\Testing Image\004\004_glasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\004\004_nightglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\004\004_nightnoglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\004\004_noglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\004\004_sunglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\022\022_glasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\022\022_nightglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\022\022_nightnoglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\022\022_noglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\022\022_sunglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\026\026_glasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\026\026_nightglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\026\026_nightnoglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\026\026_noglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\026\026_sunglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\030\030_glasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\030\030_nightglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\030\030_nightnoglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\030\030_noglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\030\030_sunglasses_mix
# (20,)

# %%
'''
Head_Testing_AllLabelFile = Head_Testing_AllLabelFile[6:15]
print(len(Head_Testing_AllLabelFile))
Eye_Testing_AllLabelFile = Eye_Testing_AllLabelFile[6:15]
print(len(Eye_Testing_AllLabelFile))
Mouth_Testing_AllLabelFile = Mouth_Testing_AllLabelFile[6:15]
print(len(Mouth_Testing_AllLabelFile))
Total_Testing_AllLabelFile = Total_Testing_AllLabelFile[6:15]
print(len(Total_Testing_AllLabelFile))
AllImageFolderTesting = AllImageFolderTesting[6:15]
'''
# Out:
# '\nHead_Testing_AllLabelFile = Head_Testing_AllLabelFile[6:15]\nprint(len(Head_Testing_AllLabelFile))\nEye_Testing_AllLabelFile = Eye_Testing_AllLabelFile[6:15]\nprint(len(Eye_Testing_AllLabelFile))\nMouth_Testing_AllLabelFile = Mouth_Testing_AllLabelFile[6:15]\nprint(len(Mouth_Testing_AllLabelFile))\nTotal_Testing_AllLabelFile = Total_Testing_AllLabelFile[6:15]\nprint(len(Total_Testing_AllLabelFile))\nAllImageFolderTesting = AllImageFolderTesting[6:15]\n'

# %%
AllImageFolderTesting
# Out:
# ['.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\004\\004_glasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\004\\004_nightglasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\004\\004_nightnoglasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\004\\004_noglasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\004\\004_sunglasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\022\\022_glasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\022\\022_nightglasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\022\\022_nightnoglasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\022\\022_noglasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\022\\022_sunglasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\026\\026_glasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\026\\026_nightglasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\026\\026_nightnoglasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\026\\026_noglasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\026\\026_sunglasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\030\\030_glasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\030\\030_nightglasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\030\\030_nightnoglasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\030\\030_noglasses_mix',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\030\\030_sunglasses_mix']

# %%
import numpy as np
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import cv2
from math import ceil

from keras.callbacks import EarlyStopping

import random



def LoadImageandLabel(Flag,batch_size,AllVideoImageFolder,Head_AllLabelFile,Mouth_AllLabelFile,Eye_AllLabelFile,Total_AllLabelFile):
    #print(Originalpath)
    count=0
    
    while True:
        LabelFileindex = 0
        

        Face_ImageDataList = []
        
        TotalLabelList = []
        HeadLabelList = []
        EyeLabelList = []
        MouthLabelList = []
        
        for Originalpath in AllVideoImageFolder:
            
            #=====load all label in a video
            HeadlabelPath = Head_AllLabelFile[LabelFileindex]
            MouthlabelPath = Mouth_AllLabelFile[LabelFileindex]
            EyelabelPath = Eye_AllLabelFile[LabelFileindex]
            TotallabelPath = Total_AllLabelFile[LabelFileindex]
            
            LabelFileindex = LabelFileindex + 1
            
                
            inputfile = open(HeadlabelPath, 'r').read()
            HeadTempLabelList = list(map(int, inputfile))
            inputfile = open(MouthlabelPath, 'r').read()
            MouthTempLabelList = list(map(int, inputfile))
            inputfile = open(EyelabelPath, 'r').read()
            EyeTempLabelList = list(map(int, inputfile))
            inputfile = open(TotallabelPath, 'r').read()
            TotalTempLabelList = list(map(int, inputfile))

            #=====find all files in path=======
            path = Originalpath+"\\face"
            Facefiles = []
            # r=root, d=directories, f = files
            for r, d, f in os.walk(path):
                for file in f:
                    if ".jpg" and 'frame_Middle' in file and not "ALL" in file:
                        temp = os.path.join(r, file)
                        Facefiles.append(temp)
            
            Facefiles.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
            Facefiles=Facefiles[:-2]
            
            #print(Originalpath)
            #print(len(TempLabelList))
            
            for FileIndex in range(len(Facefiles)):
                #======================load label
                
                index = Facefiles[FileIndex].find('frame_Middle')
                
                framenumber =int(Facefiles[FileIndex][index+12:-4]) 
                                
                HeadLabelarray = to_categorical(HeadTempLabelList[framenumber-1], num_classes=3)
                HeadLabelList.append(HeadLabelarray)
                
                MouthLabelarray = to_categorical(MouthTempLabelList[framenumber-1], num_classes=3)
                MouthLabelList.append(MouthLabelarray)
                
                EyeLabelarray = to_categorical(EyeTempLabelList[framenumber-1], num_classes=2)
                EyeLabelList.append(EyeLabelarray)

                TotalLabelarray = to_categorical(TotalTempLabelList[framenumber-1], num_classes=2)
                TotalLabelList.append(TotalLabelarray)

                #================================
                ImgGray = cv2.imread(Facefiles[FileIndex],0)
                
                #data augmentation
                if((random.uniform(0, 1)>0.5) and Flag == 0):
                    ImgGray = cv2.flip(ImgGray,1)
                    
                ImgGray = ImgGray.reshape(ImgGray.shape[0],ImgGray.shape[1],1)
                

                    
                Face_ImageDataList.append(ImgGray)
               
                count = count +1
                
                if count>=batch_size:
                    
                        yield ([np.array(Face_ImageDataList)],
                                                               [np.array(HeadLabelList),
                                                               np.array(MouthLabelList),
                                                               np.array(EyeLabelList), 
                                                               np.array(TotalLabelList)
                                                               ]
                                                               )
                        count=0
                        Face_ImageDataList = []
                        HeadLabelList = []
                        EyeLabelList = []
                        MouthLabelList = []
                        TotalLabelList = []
                
        #return Face_ImageDataList,HeadLabelList,MouthLabelList,EyeLabelList
# Out:
# C:\Users\T-Rex\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
'''
List1,List2,List3,List4 = LoadImageandLabelTesting(200,AllImageFolderTesting,Head_Testing_AllLabelFile,Mouth_Testing_AllLabelFile,Eye_Testing_AllLabelFile,Total_Testing_AllLabelFile)
print(len(List4))
print(len(List3))
print(len(List2))
print(len(List1))
'''
# Out:
# '\nList1,List2,List3,List4 = LoadImageandLabelTesting(200,AllImageFolderTesting,Head_Testing_AllLabelFile,Mouth_Testing_AllLabelFile,Eye_Testing_AllLabelFile,Total_Testing_AllLabelFile)\nprint(len(List4))\nprint(len(List3))\nprint(len(List2))\nprint(len(List1))\n'

# %%
import tensorflow as tf
# %run ./Model.ipynb 
model = tf.keras.models.model_from_json(open('.\\Temp\\backup\\MultiTask_Model_11.json').read())
model.load_weights('.\\Temp\\backup\\MultiTask_Model_11.h5')

# %%
layer_dict = dict([(layer.name, layer) for layer in model.layers])
layer_dict
# Out:
# {'input_1': <tensorflow.python.keras.engine.input_layer.InputLayer at 0x20edf4da940>,
#  'conv1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf4dac50>,
#  'conv1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf4dadd8>,
#  'conv1conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf4dae80>,
#  'conv2conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf4ea1d0>,
#  'conv2conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf4ea240>,
#  'conv2conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf4ea278>,
#  'conv3conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf4ea438>,
#  'conv3conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf4ea908>,
#  'conv3conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf4ea940>,
#  'stem_br_12conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf4ea978>,
#  'stem_br_12conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf4eaac8>,
#  'stem_br_11_maxpool_1': <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x20edf4eab00>,
#  'stem_br_12conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf4eac88>,
#  'stem_concat_1': <tensorflow.python.keras.layers.merge.Concatenate at 0x20edf4eacc0>,
#  'stem_br_211conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf4eacf8>,
#  'stem_br_211conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf4eae48>,
#  'stem_br_211conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf4eae80>,
#  'stem_br_212conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf4eaf98>,
#  'stem_br_212conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf501128>,
#  'stem_br_212conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf501160>,
#  'stem_br_213conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf501278>,
#  'stem_br_221conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf5013c8>,
#  'stem_br_213conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf501518>,
#  'stem_br_221conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf501550>,
#  'stem_br_213conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf501668>,
#  'stem_br_221conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf501780>,
#  'stem_br_214conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf5017b8>,
#  'stem_br_222conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf501908>,
#  'stem_br_214conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf501a58>,
#  'stem_br_222conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf501a90>,
#  'stem_br_214conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf501ba8>,
#  'stem_br_222conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf501cc0>,
#  'stem_concat_2': <tensorflow.python.keras.layers.merge.Concatenate at 0x20edf501cf8>,
#  'stem_br_31conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf501d30>,
#  'stem_br_31conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf501e80>,
#  'stem_br_31conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf501eb8>,
#  'stem_br_32_maxpool_2': <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x20edf501fd0>,
#  'stem_concat_3': <tensorflow.python.keras.layers.merge.Concatenate at 0x20edf5070b8>,
#  'incresA_1b2_1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf5070f0>,
#  'incresA_1b2_1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf507240>,
#  'incresA_1b2_1conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf507278>,
#  'incresA_1b1_1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf507390>,
#  'incresA_1b2_2conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf5074e0>,
#  'incresA_1b1_1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf507630>,
#  'incresA_1b2_2conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf507668>,
#  'incresA_1b1_1conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf507780>,
#  'incresA_1b2_2conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf507898>,
#  'incresA_1b0conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf5078d0>,
#  'incresA_1b1_2conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf507a20>,
#  'incresA_1b2_3conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf3b7208>,
#  'incresA_1b0conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf3b1f28>,
#  'incresA_1b1_2conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf3b1f98>,
#  'incresA_1b2_3conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf3b1da0>,
#  'incresA_1b0conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf507b70>,
#  'incresA_1b1_2conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf507c88>,
#  'incresA_1b2_3conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf507cc0>,
#  'incresA_1_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x20edf507cf8>,
#  'incresA_1filt_exp_1x1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf507d30>,
#  'incresA_1filt_exp_1x1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf507e80>,
#  'incresA_1act_scaling': <tensorflow.python.keras.layers.core.Lambda at 0x20ee084d438>,
#  'incresA_2b2_1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf507eb8>,
#  'incresA_2b2_1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf50c0b8>,
#  'incresA_2b2_1conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf50c160>,
#  'incresA_2b1_1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf50c2e8>,
#  'incresA_2b2_2conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf50c438>,
#  'incresA_2b1_1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf50c588>,
#  'incresA_2b2_2conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf50c5c0>,
#  'incresA_2b1_1conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf50c6d8>,
#  'incresA_2b2_2conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf50c7f0>,
#  'incresA_2b0conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf50c828>,
#  'incresA_2b1_2conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf50c978>,
#  'incresA_2b2_3conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf50cac8>,
#  'incresA_2b0conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf50cc18>,
#  'incresA_2b1_2conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf50cc50>,
#  'incresA_2b2_3conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf50cd68>,
#  'incresA_2b0conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf50ce80>,
#  'incresA_2b1_2conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf50cf98>,
#  'incresA_2b2_3conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf50cfd0>,
#  'incresA_2_concat': <tensorflow.python.keras.layers.merge.Concatenate at 0x20edf513048>,
#  'incresA_2filt_exp_1x1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf513080>,
#  'incresA_2filt_exp_1x1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf5131d0>,
#  'incresA_2act_scaling': <tensorflow.python.keras.layers.core.Lambda at 0x20edf513208>,
#  'x_red1_c2_1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf513358>,
#  'x_red1_c2_1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf5134a8>,
#  'x_red1_c2_1conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf5134e0>,
#  'x_red1_c2_2conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf5135f8>,
#  'x_red1_c2_2conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf513748>,
#  'x_red1_c2_2conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf513780>,
#  'x_red1_c1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf513898>,
#  'x_red1_c2_3conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf5139e8>,
#  'x_red1_c1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf513b38>,
#  'x_red1_c2_3conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf513b70>,
#  'red_maxpool_1': <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x20edf513c88>,
#  'x_red1_c1conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf513e10>,
#  'x_red1_c2_3conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf513e48>,
#  'red_concat_1': <tensorflow.python.keras.layers.merge.Concatenate at 0x20edf513e80>,
#  'incresB_1b1_1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf513eb8>,
#  'incresB_1b1_1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf51a048>,
#  'incresB_1b1_1conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf51a080>,
#  'incresB_1b1_2conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf51a198>,
#  'incresB_1b1_2conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf51a2e8>,
#  'incresB_1b1_2conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf51a320>,
#  'incresB_1b0conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf51a438>,
#  'incresB_1b1_3conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf51a588>,
#  'incresB_1b0conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf51a6d8>,
#  'incresB_1b1_3conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf51a710>,
#  'incresB_1b0conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf51a828>,
#  'incresB_1b1_3conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf51a940>,
#  'incresB_1_mixed': <tensorflow.python.keras.layers.merge.Concatenate at 0x20edf51a978>,
#  'incresB_1filt_exp_1x1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf51a9b0>,
#  'incresB_1filt_exp_1x1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf51ab00>,
#  'incresB_1act_scaling': <tensorflow.python.keras.layers.core.Lambda at 0x20edf51ab38>,
#  'incresB_2b1_1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf51ac88>,
#  'incresB_2b1_1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf51add8>,
#  'incresB_2b1_1conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf51ae10>,
#  'incresB_2b1_2conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf51af28>,
#  'incresB_2b1_2conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf5230b8>,
#  'incresB_2b1_2conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf5230f0>,
#  'incresB_2b0conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf523208>,
#  'incresB_2b1_3conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf5233c8>,
#  'incresB_2b0conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf523550>,
#  'incresB_2b1_3conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf523588>,
#  'incresB_2b0conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf5236a0>,
#  'incresB_2b1_3conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf5237b8>,
#  'incresB_2_mixed': <tensorflow.python.keras.layers.merge.Concatenate at 0x20edf5237f0>,
#  'incresB_2filt_exp_1x1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf523828>,
#  'incresB_2filt_exp_1x1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf523a58>,
#  'incresB_2act_scaling': <tensorflow.python.keras.layers.core.Lambda at 0x20edf523a90>,
#  'x_red2_c31conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf523be0>,
#  'x_red2_c31conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf523d68>,
#  'x_red2_c31conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf523da0>,
#  'x_red2_c11conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf523eb8>,
#  'x_red2_c21conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf5280b8>,
#  'x_red2_c32conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf528240>,
#  'x_red2_c11conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf5283c8>,
#  'x_red2_c21conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf528400>,
#  'x_red2_c32conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf528518>,
#  'x_red2_c11conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf528630>,
#  'x_red2_c21conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf528748>,
#  'x_red2_c32conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf528780>,
#  'x_red2_c12conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf5287b8>,
#  'x_red2_c22conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf5289e8>,
#  'x_red2_c33conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf528b70>,
#  'x_red2_c12conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf528cf8>,
#  'x_red2_c22conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf528d30>,
#  'x_red2_c33conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf528e48>,
#  'red_maxpool_2': <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x20edf528f60>,
#  'x_red2_c12conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf52d128>,
#  'x_red2_c22conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf52d198>,
#  'x_red2_c33conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf52d1d0>,
#  'red_concat_2': <tensorflow.python.keras.layers.merge.Concatenate at 0x20edf52d208>,
#  'incresC_1b1_1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf52d240>,
#  'incresC_1b1_1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf52d4a8>,
#  'incresC_1b1_1conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf52d4e0>,
#  'incresC_1b1_2conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf52d5f8>,
#  'incresC_1b1_2conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf52d7b8>,
#  'incresC_1b1_2conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf52d7f0>,
#  'incresC_1b0conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf52d908>,
#  'incresC_1b1_3conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf52dac8>,
#  'incresC_1b0conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf52dc50>,
#  'incresC_1b1_3conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf52dc88>,
#  'incresC_1b0conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf52dda0>,
#  'incresC_1b1_3conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf52deb8>,
#  'incresC_1_mixed': <tensorflow.python.keras.layers.merge.Concatenate at 0x20edf52def0>,
#  'incresC_1fin1x1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf52df28>,
#  'incresC_1fin1x1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf535198>,
#  'incresC_1act_saling': <tensorflow.python.keras.layers.core.Lambda at 0x20edf5351d0>,
#  'incresC_2b1_1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf535320>,
#  'incresC_2b1_1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf5354a8>,
#  'incresC_2b1_1conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf5354e0>,
#  'incresC_2b1_2conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf5355f8>,
#  'incresC_2b1_2conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf5357b8>,
#  'incresC_2b1_2conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf5357f0>,
#  'incresC_2b0conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf535908>,
#  'incresC_2b1_3conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf535ac8>,
#  'incresC_2b0conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf535c50>,
#  'incresC_2b1_3conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf535c88>,
#  'incresC_2b0conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf535da0>,
#  'incresC_2b1_3conv2dact': <tensorflow.python.keras.layers.core.Activation at 0x20edf535eb8>,
#  'incresC_2_mixed': <tensorflow.python.keras.layers.merge.Concatenate at 0x20edf535ef0>,
#  'incresC_2fin1x1conv2d': <tensorflow.python.keras.layers.convolutional.Conv2D at 0x20edf535f28>,
#  'incresC_2fin1x1conv2dbn': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf53c198>,
#  'incresC_2act_saling': <tensorflow.python.keras.layers.core.Lambda at 0x20edf53c1d0>,
#  'global_average_pooling2d': <tensorflow.python.keras.layers.pooling.GlobalAveragePooling2D at 0x20edf53c320>,
#  'flatten': <tensorflow.python.keras.layers.core.Flatten at 0x20edf53c390>,
#  'batch_normalization': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf53c400>,
#  'batch_normalization_2': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf53c438>,
#  'batch_normalization_6': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf53c588>,
#  'dense': <tensorflow.python.keras.layers.core.Dense at 0x20edf53c6a0>,
#  'dense_2': <tensorflow.python.keras.layers.core.Dense at 0x20edf53c940>,
#  'batch_normalization_4': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf53ca90>,
#  'dense_6': <tensorflow.python.keras.layers.core.Dense at 0x20edf53cac8>,
#  'batch_normalization_1': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf53ccf8>,
#  'batch_normalization_3': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf53cd30>,
#  'dense_4': <tensorflow.python.keras.layers.core.Dense at 0x20edf53ce48>,
#  'batch_normalization_7': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf5420b8>,
#  'dense_1': <tensorflow.python.keras.layers.core.Dense at 0x20edf5420f0>,
#  'dense_3': <tensorflow.python.keras.layers.core.Dense at 0x20edf542320>,
#  'batch_normalization_5': <tensorflow.python.keras.layers.normalization.BatchNormalization at 0x20edf542470>,
#  'dense_7': <tensorflow.python.keras.layers.core.Dense at 0x20edf5424a8>,
#  'dense_5': <tensorflow.python.keras.layers.core.Dense at 0x20edf5426d8>,
#  'concatenate': <tensorflow.python.keras.layers.merge.Concatenate at 0x20edf542828>,
#  'dropout': <tensorflow.python.keras.layers.core.Dropout at 0x20edf542860>,
#  'dropout_1': <tensorflow.python.keras.layers.core.Dropout at 0x20edf542898>,
#  'dropout_2': <tensorflow.python.keras.layers.core.Dropout at 0x20edf5428d0>,
#  'dropout_3': <tensorflow.python.keras.layers.core.Dropout at 0x20edf542908>,
#  'Head': <tensorflow.python.keras.layers.core.Dense at 0x20edf542940>,
#  'Mouth': <tensorflow.python.keras.layers.core.Dense at 0x20edf542ac8>,
#  'Eyes': <tensorflow.python.keras.layers.core.Dense at 0x20edf542c18>,
#  'Total': <tensorflow.python.keras.layers.core.Dense at 0x20edf542d68>}

# %%
'''
for layer in model.layers[:]:
    layer.trainable = False
    print(layer)
    
layer_dict['Total'].trainable = True
layer_dict['dropout_3'].trainable = True
layer_dict['concatenate'].trainable = True
layer_dict['dense_7'].trainable = True
layer_dict['batch_normalization_7'].trainable = True
layer_dict['dense_6'].trainable = True
layer_dict['batch_normalization_6'].trainable = True

layer_dict['Eyes'].trainable = True
layer_dict['dropout_2'].trainable = True
layer_dict['dense_5'].trainable = True
layer_dict['batch_normalization_5'].trainable = True
layer_dict['dense_4'].trainable = True
layer_dict['batch_normalization_4'].trainable = True
'''
# Out:
# "\nfor layer in model.layers[:]:\n    layer.trainable = False\n    print(layer)\n    \nlayer_dict['Total'].trainable = True\nlayer_dict['dropout_3'].trainable = True\nlayer_dict['concatenate'].trainable = True\nlayer_dict['dense_7'].trainable = True\nlayer_dict['batch_normalization_7'].trainable = True\nlayer_dict['dense_6'].trainable = True\nlayer_dict['batch_normalization_6'].trainable = True\n\nlayer_dict['Eyes'].trainable = True\nlayer_dict['dropout_2'].trainable = True\nlayer_dict['dense_5'].trainable = True\nlayer_dict['batch_normalization_5'].trainable = True\nlayer_dict['dense_4'].trainable = True\nlayer_dict['batch_normalization_4'].trainable = True\n"

# %%
model.compile(loss = {
                    'Head': 'categorical_crossentropy',
                    'Mouth': 'categorical_crossentropy',
                    'Eyes': 'categorical_crossentropy',
                    'Total': 'categorical_crossentropy'
                    },
                    loss_weights = {
                            'Head': 1.5,
                            'Mouth': 1.5,
                            'Eyes': 0.0,
                            'Total': 1.5,
                            }
                  , optimizer = Adam(lr = 0.000005, decay=1e-6), metrics=['accuracy'])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 85, 66, 1)    0
# __________________________________________________________________________________________________
# conv1conv2d (Conv2D)            (None, 42, 32, 32)   288         input_1[0][0]
# __________________________________________________________________________________________________
# conv1conv2dbn (BatchNormalizati (None, 42, 32, 32)   96          conv1conv2d[0][0]
# __________________________________________________________________________________________________
# conv1conv2dact (Activation)     (None, 42, 32, 32)   0           conv1conv2dbn[0][0]
# __________________________________________________________________________________________________
# conv2conv2d (Conv2D)            (None, 40, 30, 32)   9216        conv1conv2dact[0][0]
# __________________________________________________________________________________________________
# conv2conv2dbn (BatchNormalizati (None, 40, 30, 32)   96          conv2conv2d[0][0]
# __________________________________________________________________________________________________
# conv2conv2dact (Activation)     (None, 40, 30, 32)   0           conv2conv2dbn[0][0]
# __________________________________________________________________________________________________
# conv3conv2d (Conv2D)            (None, 38, 28, 64)   18432       conv2conv2dact[0][0]
# __________________________________________________________________________________________________
# conv3conv2dbn (BatchNormalizati (None, 38, 28, 64)   192         conv3conv2d[0][0]
# __________________________________________________________________________________________________
# conv3conv2dact (Activation)     (None, 38, 28, 64)   0           conv3conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_12conv2d (Conv2D)       (None, 36, 26, 96)   55296       conv3conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_12conv2dbn (BatchNormal (None, 36, 26, 96)   288         stem_br_12conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_11_maxpool_1 (MaxPoolin (None, 36, 26, 64)   0           conv3conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_12conv2dact (Activation (None, 36, 26, 96)   0           stem_br_12conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_concat_1 (Concatenate)     (None, 36, 26, 160)  0           stem_br_11_maxpool_1[0][0]
#                                                                  stem_br_12conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_211conv2d (Conv2D)      (None, 36, 26, 64)   10240       stem_concat_1[0][0]
# __________________________________________________________________________________________________
# stem_br_211conv2dbn (BatchNorma (None, 36, 26, 64)   192         stem_br_211conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_211conv2dact (Activatio (None, 36, 26, 64)   0           stem_br_211conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_212conv2d (Conv2D)      (None, 36, 26, 64)   28672       stem_br_211conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_212conv2dbn (BatchNorma (None, 36, 26, 64)   192         stem_br_212conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_212conv2dact (Activatio (None, 36, 26, 64)   0           stem_br_212conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_213conv2d (Conv2D)      (None, 36, 26, 64)   28672       stem_br_212conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_221conv2d (Conv2D)      (None, 36, 26, 64)   10240       stem_concat_1[0][0]
# __________________________________________________________________________________________________
# stem_br_213conv2dbn (BatchNorma (None, 36, 26, 64)   192         stem_br_213conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_221conv2dbn (BatchNorma (None, 36, 26, 64)   192         stem_br_221conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_213conv2dact (Activatio (None, 36, 26, 64)   0           stem_br_213conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_221conv2dact (Activatio (None, 36, 26, 64)   0           stem_br_221conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_214conv2d (Conv2D)      (None, 34, 24, 96)   55296       stem_br_213conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_222conv2d (Conv2D)      (None, 34, 24, 96)   55296       stem_br_221conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_214conv2dbn (BatchNorma (None, 34, 24, 96)   288         stem_br_214conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_222conv2dbn (BatchNorma (None, 34, 24, 96)   288         stem_br_222conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_214conv2dact (Activatio (None, 34, 24, 96)   0           stem_br_214conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_222conv2dact (Activatio (None, 34, 24, 96)   0           stem_br_222conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_concat_2 (Concatenate)     (None, 34, 24, 192)  0           stem_br_214conv2dact[0][0]
#                                                                  stem_br_222conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_31conv2d (Conv2D)       (None, 32, 22, 192)  331776      stem_concat_2[0][0]
# __________________________________________________________________________________________________
# stem_br_31conv2dbn (BatchNormal (None, 32, 22, 192)  576         stem_br_31conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_31conv2dact (Activation (None, 32, 22, 192)  0           stem_br_31conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_32_maxpool_2 (MaxPoolin (None, 32, 22, 192)  0           stem_concat_2[0][0]
# __________________________________________________________________________________________________
# stem_concat_3 (Concatenate)     (None, 32, 22, 384)  0           stem_br_31conv2dact[0][0]
#                                                                  stem_br_32_maxpool_2[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2d (Conv2D)    (None, 32, 22, 32)   12288       stem_concat_3[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_1b2_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2dact (Activat (None, 32, 22, 32)   0           incresA_1b2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2d (Conv2D)    (None, 32, 22, 32)   12288       stem_concat_3[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2d (Conv2D)    (None, 32, 22, 48)   13824       incresA_1b2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2dbn (BatchNor (None, 32, 22, 48)   144         incresA_1b2_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2dact (Activat (None, 32, 22, 32)   0           incresA_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2dact (Activat (None, 32, 22, 48)   0           incresA_1b2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2d (Conv2D)      (None, 32, 22, 32)   12288       stem_concat_3[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2d (Conv2D)    (None, 32, 22, 32)   9216        incresA_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2d (Conv2D)    (None, 32, 22, 64)   27648       incresA_1b2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2dbn (BatchNorma (None, 32, 22, 32)   96          incresA_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2dbn (BatchNor (None, 32, 22, 64)   192         incresA_1b2_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2dact (Activatio (None, 32, 22, 32)   0           incresA_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2dact (Activat (None, 32, 22, 32)   0           incresA_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2dact (Activat (None, 32, 22, 64)   0           incresA_1b2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1_concat (Concatenate)  (None, 32, 22, 128)  0           incresA_1b0conv2dact[0][0]
#                                                                  incresA_1b1_2conv2dact[0][0]
#                                                                  incresA_1b2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1filt_exp_1x1conv2d (Co (None, 32, 22, 384)  49152       incresA_1_concat[0][0]
# __________________________________________________________________________________________________
# incresA_1filt_exp_1x1conv2dbn ( (None, 32, 22, 384)  1152        incresA_1filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1act_scaling (Lambda)   (None, 32, 22, 384)  0           stem_concat_3[0][0]
#                                                                  incresA_1filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# incresA_2b2_1conv2d (Conv2D)    (None, 32, 22, 32)   12288       incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_1conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_2b2_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_1conv2dact (Activat (None, 32, 22, 32)   0           incresA_2b2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_1conv2d (Conv2D)    (None, 32, 22, 32)   12288       incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_2conv2d (Conv2D)    (None, 32, 22, 48)   13824       incresA_2b2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_1conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_2b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_2conv2dbn (BatchNor (None, 32, 22, 48)   144         incresA_2b2_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_1conv2dact (Activat (None, 32, 22, 32)   0           incresA_2b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_2conv2dact (Activat (None, 32, 22, 48)   0           incresA_2b2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b0conv2d (Conv2D)      (None, 32, 22, 32)   12288       incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_2conv2d (Conv2D)    (None, 32, 22, 32)   9216        incresA_2b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_3conv2d (Conv2D)    (None, 32, 22, 64)   27648       incresA_2b2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2b0conv2dbn (BatchNorma (None, 32, 22, 32)   96          incresA_2b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_2conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_2b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_3conv2dbn (BatchNor (None, 32, 22, 64)   192         incresA_2b2_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b0conv2dact (Activatio (None, 32, 22, 32)   0           incresA_2b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_2conv2dact (Activat (None, 32, 22, 32)   0           incresA_2b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_3conv2dact (Activat (None, 32, 22, 64)   0           incresA_2b2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2_concat (Concatenate)  (None, 32, 22, 128)  0           incresA_2b0conv2dact[0][0]
#                                                                  incresA_2b1_2conv2dact[0][0]
#                                                                  incresA_2b2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2filt_exp_1x1conv2d (Co (None, 32, 22, 384)  49152       incresA_2_concat[0][0]
# __________________________________________________________________________________________________
# incresA_2filt_exp_1x1conv2dbn ( (None, 32, 22, 384)  1152        incresA_2filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2act_scaling (Lambda)   (None, 32, 22, 384)  0           incresA_1act_scaling[0][0]
#                                                                  incresA_2filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# x_red1_c2_1conv2d (Conv2D)      (None, 32, 22, 256)  98304       incresA_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_1conv2dbn (BatchNorma (None, 32, 22, 256)  768         x_red1_c2_1conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_1conv2dact (Activatio (None, 32, 22, 256)  0           x_red1_c2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2d (Conv2D)      (None, 32, 22, 256)  589824      x_red1_c2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2dbn (BatchNorma (None, 32, 22, 256)  768         x_red1_c2_2conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2dact (Activatio (None, 32, 22, 256)  0           x_red1_c2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2d (Conv2D)        (None, 15, 10, 384)  1327104     incresA_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2d (Conv2D)      (None, 15, 10, 384)  884736      x_red1_c2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2dbn (BatchNormali (None, 15, 10, 384)  1152        x_red1_c1conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2dbn (BatchNorma (None, 15, 10, 384)  1152        x_red1_c2_3conv2d[0][0]
# __________________________________________________________________________________________________
# red_maxpool_1 (MaxPooling2D)    (None, 15, 10, 384)  0           incresA_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2dact (Activation) (None, 15, 10, 384)  0           x_red1_c1conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2dact (Activatio (None, 15, 10, 384)  0           x_red1_c2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# red_concat_1 (Concatenate)      (None, 15, 10, 1152) 0           red_maxpool_1[0][0]
#                                                                  x_red1_c1conv2dact[0][0]
#                                                                  x_red1_c2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2d (Conv2D)    (None, 15, 10, 128)  147456      red_concat_1[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2dbn (BatchNor (None, 15, 10, 128)  384         incresB_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2dact (Activat (None, 15, 10, 128)  0           incresB_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2d (Conv2D)    (None, 15, 10, 160)  143360      incresB_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2dbn (BatchNor (None, 15, 10, 160)  480         incresB_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2dact (Activat (None, 15, 10, 160)  0           incresB_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2d (Conv2D)      (None, 15, 10, 192)  221184      red_concat_1[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2d (Conv2D)    (None, 15, 10, 192)  215040      incresB_1b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2dbn (BatchNorma (None, 15, 10, 192)  576         incresB_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2dbn (BatchNor (None, 15, 10, 192)  576         incresB_1b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2dact (Activatio (None, 15, 10, 192)  0           incresB_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2dact (Activat (None, 15, 10, 192)  0           incresB_1b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1_mixed (Concatenate)   (None, 15, 10, 384)  0           incresB_1b0conv2dact[0][0]
#                                                                  incresB_1b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1filt_exp_1x1conv2d (Co (None, 15, 10, 1152) 442368      incresB_1_mixed[0][0]
# __________________________________________________________________________________________________
# incresB_1filt_exp_1x1conv2dbn ( (None, 15, 10, 1152) 3456        incresB_1filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1act_scaling (Lambda)   (None, 15, 10, 1152) 0           red_concat_1[0][0]
#                                                                  incresB_1filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# incresB_2b1_1conv2d (Conv2D)    (None, 15, 10, 128)  147456      incresB_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_1conv2dbn (BatchNor (None, 15, 10, 128)  384         incresB_2b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_1conv2dact (Activat (None, 15, 10, 128)  0           incresB_2b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_2conv2d (Conv2D)    (None, 15, 10, 160)  143360      incresB_2b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_2conv2dbn (BatchNor (None, 15, 10, 160)  480         incresB_2b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_2conv2dact (Activat (None, 15, 10, 160)  0           incresB_2b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2b0conv2d (Conv2D)      (None, 15, 10, 192)  221184      incresB_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_3conv2d (Conv2D)    (None, 15, 10, 192)  215040      incresB_2b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_2b0conv2dbn (BatchNorma (None, 15, 10, 192)  576         incresB_2b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_3conv2dbn (BatchNor (None, 15, 10, 192)  576         incresB_2b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b0conv2dact (Activatio (None, 15, 10, 192)  0           incresB_2b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_3conv2dact (Activat (None, 15, 10, 192)  0           incresB_2b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2_mixed (Concatenate)   (None, 15, 10, 384)  0           incresB_2b0conv2dact[0][0]
#                                                                  incresB_2b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_2filt_exp_1x1conv2d (Co (None, 15, 10, 1152) 442368      incresB_2_mixed[0][0]
# __________________________________________________________________________________________________
# incresB_2filt_exp_1x1conv2dbn ( (None, 15, 10, 1152) 3456        incresB_2filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2act_scaling (Lambda)   (None, 15, 10, 1152) 0           incresB_1act_scaling[0][0]
#                                                                  incresB_2filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# x_red2_c31conv2d (Conv2D)       (None, 15, 10, 256)  294912      incresB_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c31conv2dbn (BatchNormal (None, 15, 10, 256)  768         x_red2_c31conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c31conv2dact (Activation (None, 15, 10, 256)  0           x_red2_c31conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c11conv2d (Conv2D)       (None, 15, 10, 256)  294912      incresB_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c21conv2d (Conv2D)       (None, 15, 10, 256)  294912      incresB_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c32conv2d (Conv2D)       (None, 15, 10, 256)  589824      x_red2_c31conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c11conv2dbn (BatchNormal (None, 15, 10, 256)  768         x_red2_c11conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c21conv2dbn (BatchNormal (None, 15, 10, 256)  768         x_red2_c21conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c32conv2dbn (BatchNormal (None, 15, 10, 256)  768         x_red2_c32conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c11conv2dact (Activation (None, 15, 10, 256)  0           x_red2_c11conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c21conv2dact (Activation (None, 15, 10, 256)  0           x_red2_c21conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c32conv2dact (Activation (None, 15, 10, 256)  0           x_red2_c32conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c12conv2d (Conv2D)       (None, 7, 4, 384)    884736      x_red2_c11conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c22conv2d (Conv2D)       (None, 7, 4, 256)    589824      x_red2_c21conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c33conv2d (Conv2D)       (None, 7, 4, 256)    589824      x_red2_c32conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c12conv2dbn (BatchNormal (None, 7, 4, 384)    1152        x_red2_c12conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c22conv2dbn (BatchNormal (None, 7, 4, 256)    768         x_red2_c22conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c33conv2dbn (BatchNormal (None, 7, 4, 256)    768         x_red2_c33conv2d[0][0]
# __________________________________________________________________________________________________
# red_maxpool_2 (MaxPooling2D)    (None, 7, 4, 1152)   0           incresB_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c12conv2dact (Activation (None, 7, 4, 384)    0           x_red2_c12conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c22conv2dact (Activation (None, 7, 4, 256)    0           x_red2_c22conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c33conv2dact (Activation (None, 7, 4, 256)    0           x_red2_c33conv2dbn[0][0]
# __________________________________________________________________________________________________
# red_concat_2 (Concatenate)      (None, 7, 4, 2048)   0           red_maxpool_2[0][0]
#                                                                  x_red2_c12conv2dact[0][0]
#                                                                  x_red2_c22conv2dact[0][0]
#                                                                  x_red2_c33conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_1conv2d (Conv2D)    (None, 7, 4, 192)    393216      red_concat_2[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_1conv2dbn (BatchNor (None, 7, 4, 192)    576         incresC_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_1conv2dact (Activat (None, 7, 4, 192)    0           incresC_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_2conv2d (Conv2D)    (None, 7, 4, 224)    129024      incresC_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_2conv2dbn (BatchNor (None, 7, 4, 224)    672         incresC_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_2conv2dact (Activat (None, 7, 4, 224)    0           incresC_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1b0conv2d (Conv2D)      (None, 7, 4, 192)    393216      red_concat_2[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_3conv2d (Conv2D)    (None, 7, 4, 256)    172032      incresC_1b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1b0conv2dbn (BatchNorma (None, 7, 4, 192)    576         incresC_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_3conv2dbn (BatchNor (None, 7, 4, 256)    768         incresC_1b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b0conv2dact (Activatio (None, 7, 4, 192)    0           incresC_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_3conv2dact (Activat (None, 7, 4, 256)    0           incresC_1b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1_mixed (Concatenate)   (None, 7, 4, 448)    0           incresC_1b0conv2dact[0][0]
#                                                                  incresC_1b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1fin1x1conv2d (Conv2D)  (None, 7, 4, 2048)   917504      incresC_1_mixed[0][0]
# __________________________________________________________________________________________________
# incresC_1fin1x1conv2dbn (BatchN (None, 7, 4, 2048)   6144        incresC_1fin1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1act_saling (Lambda)    (None, 7, 4, 2048)   0           red_concat_2[0][0]
#                                                                  incresC_1fin1x1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_1conv2d (Conv2D)    (None, 7, 4, 192)    393216      incresC_1act_saling[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_1conv2dbn (BatchNor (None, 7, 4, 192)    576         incresC_2b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_1conv2dact (Activat (None, 7, 4, 192)    0           incresC_2b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_2conv2d (Conv2D)    (None, 7, 4, 224)    129024      incresC_2b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_2conv2dbn (BatchNor (None, 7, 4, 224)    672         incresC_2b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_2conv2dact (Activat (None, 7, 4, 224)    0           incresC_2b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b0conv2d (Conv2D)      (None, 7, 4, 192)    393216      incresC_1act_saling[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_3conv2d (Conv2D)    (None, 7, 4, 256)    172032      incresC_2b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_2b0conv2dbn (BatchNorma (None, 7, 4, 192)    576         incresC_2b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_3conv2dbn (BatchNor (None, 7, 4, 256)    768         incresC_2b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b0conv2dact (Activatio (None, 7, 4, 192)    0           incresC_2b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_3conv2dact (Activat (None, 7, 4, 256)    0           incresC_2b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2_mixed (Concatenate)   (None, 7, 4, 448)    0           incresC_2b0conv2dact[0][0]
#                                                                  incresC_2b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_2fin1x1conv2d (Conv2D)  (None, 7, 4, 2048)   917504      incresC_2_mixed[0][0]
# __________________________________________________________________________________________________
# incresC_2fin1x1conv2dbn (BatchN (None, 7, 4, 2048)   6144        incresC_2fin1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2act_saling (Lambda)    (None, 7, 4, 2048)   0           incresC_1act_saling[0][0]
#                                                                  incresC_2fin1x1conv2dbn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           incresC_2act_saling[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 2048)         6144        flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 2048)         6144        flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 2048)         6144        flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1049088     batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          1049088     batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 2048)         6144        flatten[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 512)          1049088     batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512)          1536        dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 512)          1536        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          1049088     batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 512)          1536        dense_6[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           32832       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           32832       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 512)          1536        dense_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           32832       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           32832       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 192)          0           dense_1[0][0]
#                                                                  dense_3[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 192)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# Head (Dense)                    (None, 3)            195         dropout[0][0]
# __________________________________________________________________________________________________
# Mouth (Dense)                   (None, 3)            195         dropout_1[0][0]
# __________________________________________________________________________________________________
# Eyes (Dense)                    (None, 2)            130         dropout_2[0][0]
# __________________________________________________________________________________________________
# Total (Dense)                   (None, 2)            386         dropout_3[0][0]
# ==================================================================================================
# Total params: 18,068,202
# Trainable params: 18,018,154
# Non-trainable params: 50,048
# __________________________________________________________________________________________________

# %%
'''
from keras.utils.vis_utils import model_to_dot
from tensorflow.keras.utils import plot_model
from IPython.display import SVG

SVG(model_to_dot(model).create(prog='dot', format='svg'))
plot_model(model, to_file='model_plot.png', 
                  show_shapes=True, show_layer_names=True)
                  '''
# Out:
# "\nfrom keras.utils.vis_utils import model_to_dot\nfrom tensorflow.keras.utils import plot_model\nfrom IPython.display import SVG\n\nSVG(model_to_dot(model).create(prog='dot', format='svg'))\nplot_model(model, to_file='model_plot.png', \n                  show_shapes=True, show_layer_names=True)\n                  "

# %%
best = 0
second = 0

batch_size = 120

for i in range(200):
    model.fit_generator(LoadImageandLabel(0,batch_size,AllImageFolder,Head_AllLabelFile,Mouth_AllLabelFile
                                          ,Eye_AllLabelFile,Total_AllLabelFile),
                    steps_per_epoch=ceil(num_samples / batch_size),
                    epochs=1,
                    #callbacks=[earlyStopping],
                    workers = 5,
                    shuffle=True
                    )
    result= model.evaluate_generator(LoadImageandLabel(1,150,AllImageFolderTesting,Head_Testing_AllLabelFile,Mouth_Testing_AllLabelFile
                                          ,Eye_Testing_AllLabelFile,Total_Testing_AllLabelFile), steps=ceil(validation_sample / 500),workers=5,verbose = 1)
    
    
    print(result)
    if(result[8]>best):
        print("save model")
        best = result[8]
        model_json = model.to_json()
        open('MultiTask_Model_0821Best.json', 'w').write(model_json)
        model.save_weights('MultiTask_Model_0821Best.h5')
    elif(result[8]>second):
        print("save model2")
        second = result[8]
        model_json = model.to_json()
        open('MultiTask_Model_0821Second.json', 'w').write(model_json)
        model.save_weights('MultiTask_Model_0821Second.h5')
# Out:
# Epoch 1/1
# 1958/1958 [==============================] - 516s 264ms/step - loss: 0.2241 - Head_loss: 0.0517 - Mouth_loss: 0.0623 - Eyes_loss: 0.1182 - Total_loss: 0.0354 - Head_acc: 0.9814 - Mouth_acc: 0.9779 - Eyes_acc: 0.9566 - Total_acc: 0.9874
# 168/168 [==============================] - 15s 89ms/step
# [2.924879912109602, 0.31822161543739486, 0.4940704665752405, 1.1720944581195778, 1.1376278507966726, 0.896587301799584, 0.8406746028035524, 0.5331349206001809, 0.5333333332701364]
# save model
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.1954 - Head_loss: 0.0479 - Mouth_loss: 0.0558 - Eyes_loss: 0.1154 - Total_loss: 0.0266 - Head_acc: 0.9828 - Mouth_acc: 0.9804 - Eyes_acc: 0.9571 - Total_acc: 0.9909
# 168/168 [==============================] - 13s 78ms/step
# [3.140131139152107, 0.35791201995046285, 0.5215368641999832, 1.2093332096438167, 1.213971869765027, 0.8823809517946627, 0.8186507937054903, 0.519007935909377, 0.5495634908854429]
# save model
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.1823 - Head_loss: 0.0456 - Mouth_loss: 0.0522 - Eyes_loss: 0.1139 - Total_loss: 0.0237 - Head_acc: 0.9831 - Mouth_acc: 0.9818 - Eyes_acc: 0.9583 - Total_acc: 0.9921
# 168/168 [==============================] - 13s 78ms/step
# [3.1735864680792605, 0.36341833972860643, 0.508530605662253, 1.1902821259282064, 1.2437753683244366, 0.8765873027898904, 0.822103174602879, 0.5356349220687878, 0.5117063510420156]
# save model2
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.1709 - Head_loss: 0.0427 - Mouth_loss: 0.0496 - Eyes_loss: 0.1162 - Total_loss: 0.0215 - Head_acc: 0.9843 - Mouth_acc: 0.9827 - Eyes_acc: 0.9577 - Total_acc: 0.9927
# 168/168 [==============================] - 13s 78ms/step
# [3.0377588719129562, 0.3353343269546138, 0.5268102420768195, 1.1820328962390445, 1.1630280148903174, 0.8953968263452962, 0.8127380974280337, 0.536984126188881, 0.5395238095384446]
# save model2
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.1636 - Head_loss: 0.0414 - Mouth_loss: 0.0475 - Eyes_loss: 0.1148 - Total_loss: 0.0202 - Head_acc: 0.9849 - Mouth_acc: 0.9833 - Eyes_acc: 0.9582 - Total_acc: 0.9933
# 168/168 [==============================] - 13s 78ms/step
# [3.013124412014371, 0.3701579478578704, 0.5289192855482161, 1.1807595380676157, 1.1096723718746078, 0.879999999356057, 0.8083333347236649, 0.5363095229757684, 0.5392460335611499]
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.1549 - Head_loss: 0.0395 - Mouth_loss: 0.0449 - Eyes_loss: 0.1145 - Total_loss: 0.0189 - Head_acc: 0.9858 - Mouth_acc: 0.9849 - Eyes_acc: 0.9587 - Total_acc: 0.9937
# 168/168 [==============================] - 13s 78ms/step
# [3.1713405652415183, 0.35537921492676444, 0.5566375203099077, 1.198280580785303, 1.2022103211687256, 0.8809920633433476, 0.7798809516243637, 0.5282142868686822, 0.5099603180285721]
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.1471 - Head_loss: 0.0376 - Mouth_loss: 0.0427 - Eyes_loss: 0.1137 - Total_loss: 0.0177 - Head_acc: 0.9864 - Mouth_acc: 0.9852 - Eyes_acc: 0.9584 - Total_acc: 0.9942
# 168/168 [==============================] - 13s 78ms/step
# [3.2563568353652954, 0.3831147322839328, 0.5519569464860459, 1.2070210666695078, 1.2358328865707986, 0.869682540285534, 0.7828571428323076, 0.5302777788324636, 0.5141666668156782]
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.1404 - Head_loss: 0.0360 - Mouth_loss: 0.0406 - Eyes_loss: 0.1142 - Total_loss: 0.0169 - Head_acc: 0.9870 - Mouth_acc: 0.9863 - Eyes_acc: 0.9586 - Total_acc: 0.9944
# 168/168 [==============================] - 13s 78ms/step
# [3.3327723448829993, 0.35888438133443706, 0.5998531063499589, 1.1942930973073955, 1.2631107401823447, 0.8892063490735987, 0.7563888896478429, 0.5303968264543939, 0.5107539689523124]
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.1365 - Head_loss: 0.0355 - Mouth_loss: 0.0392 - Eyes_loss: 0.1142 - Total_loss: 0.0163 - Head_acc: 0.9872 - Mouth_acc: 0.9868 - Eyes_acc: 0.9586 - Total_acc: 0.9945
# 168/168 [==============================] - 13s 78ms/step
# [3.348757392948582, 0.37311453648820175, 0.5777982581423116, 1.2014549484066221, 1.281592149398334, 0.8701984131531346, 0.7482539693869296, 0.5417460329065632, 0.5303571440689709]
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.1291 - Head_loss: 0.0333 - Mouth_loss: 0.0372 - Eyes_loss: 0.1145 - Total_loss: 0.0155 - Head_acc: 0.9880 - Mouth_acc: 0.9873 - Eyes_acc: 0.9582 - Total_acc: 0.9951
# 168/168 [==============================] - 13s 78ms/step
# [3.453443121165037, 0.4076706320408246, 0.5878101944039199, 1.2321110721635964, 1.306814603424365, 0.8581746045522214, 0.7544841271425996, 0.5351984126582032, 0.5228571425624458]
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.1261 - Head_loss: 0.0328 - Mouth_loss: 0.0364 - Eyes_loss: 0.1134 - Total_loss: 0.0149 - Head_acc: 0.9881 - Mouth_acc: 0.9877 - Eyes_acc: 0.9587 - Total_acc: 0.9951
# 168/168 [==============================] - 13s 78ms/step
# [3.3343422771209763, 0.4214798361465182, 0.5403611951237725, 1.2061273560393602, 1.2610538215542744, 0.8609126992911721, 0.7748809521574349, 0.5324206366314597, 0.5192063501592548]
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.1193 - Head_loss: 0.0313 - Mouth_loss: 0.0339 - Eyes_loss: 0.1148 - Total_loss: 0.0143 - Head_acc: 0.9887 - Mouth_acc: 0.9886 - Eyes_acc: 0.9587 - Total_acc: 0.9953
# 168/168 [==============================] - 13s 78ms/step
# [3.5441504691150927, 0.43218933079495647, 0.5849546760251715, 1.2253304994720522, 1.3456229612458541, 0.8595634939126848, 0.749603174671176, 0.534801588593317, 0.5262301583896347]
# Epoch 1/1
# 1958/1958 [==============================] - 501s 256ms/step - loss: 0.1138 - Head_loss: 0.0298 - Mouth_loss: 0.0326 - Eyes_loss: 0.1143 - Total_loss: 0.0135 - Head_acc: 0.9894 - Mouth_acc: 0.9890 - Eyes_acc: 0.9581 - Total_acc: 0.9956
# 168/168 [==============================] - 13s 78ms/step
# [3.388507763012534, 0.40321965335134635, 0.5863615702085857, 1.1782167354110806, 1.2694239465054125, 0.8672619040368036, 0.7565476187016993, 0.5383730157045648, 0.5349999997997656]
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.1096 - Head_loss: 0.0284 - Mouth_loss: 0.0317 - Eyes_loss: 0.1141 - Total_loss: 0.0129 - Head_acc: 0.9898 - Mouth_acc: 0.9895 - Eyes_acc: 0.9585 - Total_acc: 0.9958
# 168/168 [==============================] - 13s 78ms/step
# [3.532997480105786, 0.39395203225010145, 0.542918457348692, 1.2404309856466993, 1.4184611512630778, 0.8712698420332301, 0.7846428571446311, 0.5332936521043026, 0.5225793668900484]
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.1040 - Head_loss: 0.0272 - Mouth_loss: 0.0300 - Eyes_loss: 0.1149 - Total_loss: 0.0122 - Head_acc: 0.9902 - Mouth_acc: 0.9903 - Eyes_acc: 0.9586 - Total_acc: 0.9961
# 168/168 [==============================] - 13s 78ms/step
# [3.4744038069177243, 0.39570542570693956, 0.591435632168116, 1.21416224283582, 1.329128135505709, 0.8718253975024536, 0.7572222218316581, 0.5281349204735653, 0.5282539681232136]
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.0999 - Head_loss: 0.0261 - Mouth_loss: 0.0288 - Eyes_loss: 0.1140 - Total_loss: 0.0118 - Head_acc: 0.9907 - Mouth_acc: 0.9907 - Eyes_acc: 0.9584 - Total_acc: 0.9962
# 168/168 [==============================] - 13s 78ms/step
# [3.360881532320664, 0.3865392237495488, 0.5659093554735418, 1.1936820696795447, 1.2881391088483811, 0.8774206364926483, 0.7768253961666709, 0.5338095252213645, 0.5361507932733124]
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.0958 - Head_loss: 0.0250 - Mouth_loss: 0.0276 - Eyes_loss: 0.1156 - Total_loss: 0.0113 - Head_acc: 0.9910 - Mouth_acc: 0.9910 - Eyes_acc: 0.9580 - Total_acc: 0.9964
# 168/168 [==============================] - 13s 78ms/step
# [3.5118942977417085, 0.4165150896956179, 0.5833829057344355, 1.207472113209189, 1.341364869307394, 0.8693650786299258, 0.7834126995432944, 0.527301588572473, 0.5390476188677851]
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.0906 - Head_loss: 0.0237 - Mouth_loss: 0.0262 - Eyes_loss: 0.1152 - Total_loss: 0.0105 - Head_acc: 0.9916 - Mouth_acc: 0.9915 - Eyes_acc: 0.9586 - Total_acc: 0.9967
# 168/168 [==============================] - 13s 78ms/step
# [3.6399354731575366, 0.3955066960172341, 0.6559087306704896, 1.2110668302228165, 1.37520822658137, 0.8803174599694709, 0.7523809531703591, 0.5244047631221336, 0.5341666665072331]
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.0877 - Head_loss: 0.0233 - Mouth_loss: 0.0246 - Eyes_loss: 0.1152 - Total_loss: 0.0105 - Head_acc: 0.9919 - Mouth_acc: 0.9923 - Eyes_acc: 0.9579 - Total_acc: 0.9966
# 168/168 [==============================] - 13s 78ms/step
# [3.862276762191738, 0.4220030167953362, 0.6868901393008638, 1.1874809941689906, 1.4659580083902082, 0.8735317456580344, 0.7328174605998876, 0.523769841595952, 0.5329761921949241]
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.0836 - Head_loss: 0.0217 - Mouth_loss: 0.0242 - Eyes_loss: 0.1141 - Total_loss: 0.0099 - Head_acc: 0.9925 - Mouth_acc: 0.9923 - Eyes_acc: 0.9589 - Total_acc: 0.9968
# 168/168 [==============================] - 13s 78ms/step
# [3.7495700101855967, 0.3980620074784506, 0.6696132264765045, 1.1800103615886266, 1.4320381086075766, 0.8786111110599623, 0.7503571446120206, 0.5346031755020487, 0.5505555571899527]
# save model
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.0809 - Head_loss: 0.0215 - Mouth_loss: 0.0228 - Eyes_loss: 0.1154 - Total_loss: 0.0096 - Head_acc: 0.9925 - Mouth_acc: 0.9929 - Eyes_acc: 0.9580 - Total_acc: 0.9968
# 168/168 [==============================] - 13s 78ms/step
# [3.8747049916890406, 0.4544556865324361, 0.7092222575636351, 1.1871892102644779, 1.4194587272414494, 0.848095239411729, 0.7073809523523474, 0.5445634934918157, 0.54853174707941]
# save model2
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.0765 - Head_loss: 0.0199 - Mouth_loss: 0.0222 - Eyes_loss: 0.1149 - Total_loss: 0.0089 - Head_acc: 0.9931 - Mouth_acc: 0.9930 - Eyes_acc: 0.9585 - Total_acc: 0.9972
# 168/168 [==============================] - 13s 78ms/step
# [3.80864409845145, 0.42083444043387463, 0.6422551152946285, 1.20118425072897, 1.4760065126964557, 0.8682142867529321, 0.7521031756353166, 0.533055558107749, 0.5397619052701408]
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.0732 - Head_loss: 0.0191 - Mouth_loss: 0.0210 - Eyes_loss: 0.1153 - Total_loss: 0.0088 - Head_acc: 0.9935 - Mouth_acc: 0.9935 - Eyes_acc: 0.9582 - Total_acc: 0.9973
# 168/168 [==============================] - 13s 78ms/step
# [3.762726771955689, 0.386789047150578, 0.7466694174323775, 1.1948620060575195, 1.3750260523742153, 0.8862698412101183, 0.684285714601477, 0.5306746044495542, 0.5578174608859366]
# save model
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.0712 - Head_loss: 0.0185 - Mouth_loss: 0.0201 - Eyes_loss: 0.1135 - Total_loss: 0.0088 - Head_acc: 0.9935 - Mouth_acc: 0.9938 - Eyes_acc: 0.9585 - Total_acc: 0.9972
# 168/168 [==============================] - 13s 78ms/step
# [3.786153144868357, 0.41717192550956606, 0.6729462093879767, 1.1981238192668007, 1.4339839654996813, 0.8688492059286329, 0.736626985582656, 0.53083333356439, 0.5523015871765979]
# save model2
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.0676 - Head_loss: 0.0171 - Mouth_loss: 0.0194 - Eyes_loss: 0.1146 - Total_loss: 0.0086 - Head_acc: 0.9942 - Mouth_acc: 0.9939 - Eyes_acc: 0.9582 - Total_acc: 0.9972
# 168/168 [==============================] - 13s 78ms/step
# [3.7792436380959336, 0.4237910276545397, 0.6814276165412924, 1.2025033221774113, 1.4142771289528657, 0.873055555924241, 0.7519841275698993, 0.5284920649248219, 0.5459920633085338]
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.0647 - Head_loss: 0.0169 - Mouth_loss: 0.0184 - Eyes_loss: 0.1154 - Total_loss: 0.0079 - Head_acc: 0.9943 - Mouth_acc: 0.9945 - Eyes_acc: 0.9578 - Total_acc: 0.9976
# 168/168 [==============================] - 13s 78ms/step
# [4.161598015931391, 0.43506148117754695, 0.7620706679385334, 1.2143710627458946, 1.577266549166303, 0.8674603172666615, 0.6936904776708356, 0.5284523810149127, 0.5387698412717631]
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.0623 - Head_loss: 0.0164 - Mouth_loss: 0.0174 - Eyes_loss: 0.1153 - Total_loss: 0.0077 - Head_acc: 0.9943 - Mouth_acc: 0.9947 - Eyes_acc: 0.9585 - Total_acc: 0.9976
# 168/168 [==============================] - 13s 78ms/step
# [3.942433718946718, 0.40595287645989525, 0.7080549302421181, 1.1923188113169523, 1.5142813443741208, 0.8734920629067346, 0.7355952392321169, 0.5431746042145061, 0.5511507949226403]
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.0600 - Head_loss: 0.0158 - Mouth_loss: 0.0169 - Eyes_loss: 0.1158 - Total_loss: 0.0074 - Head_acc: 0.9946 - Mouth_acc: 0.9949 - Eyes_acc: 0.9582 - Total_acc: 0.9977
# 168/168 [==============================] - 50s 295ms/step
# [3.830836487845296, 0.40537878182212145, 0.7327735974794061, 1.2199232109345584, 1.4157386163188632, 0.8742460317776671, 0.7123412699438632, 0.5184523815100658, 0.5530158743273378]
# save model2
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.0560 - Head_loss: 0.0147 - Mouth_loss: 0.0157 - Eyes_loss: 0.1166 - Total_loss: 0.0069 - Head_acc: 0.9952 - Mouth_acc: 0.9954 - Eyes_acc: 0.9578 - Total_acc: 0.9979
# 168/168 [==============================] - 13s 78ms/step
# [3.8040192156054435, 0.38750963797784327, 0.7077626278620962, 1.2110888407526847, 1.4407405601703518, 0.8879761911618212, 0.7578174605122989, 0.5155952381347084, 0.5370634912867986]
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.0539 - Head_loss: 0.0144 - Mouth_loss: 0.0150 - Eyes_loss: 0.1159 - Total_loss: 0.0065 - Head_acc: 0.9953 - Mouth_acc: 0.9957 - Eyes_acc: 0.9583 - Total_acc: 0.9981
# 168/168 [==============================] - 13s 78ms/step
# [3.741356886036339, 0.4062547975398993, 0.6627104230896357, 1.187504445920543, 1.4252727090081732, 0.878253967623182, 0.7750000010100415, 0.527777777829518, 0.5502380958835905]
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.0521 - Head_loss: 0.0136 - Mouth_loss: 0.0145 - Eyes_loss: 0.1159 - Total_loss: 0.0066 - Head_acc: 0.9957 - Mouth_acc: 0.9957 - Eyes_acc: 0.9580 - Total_acc: 0.9980
# 168/168 [==============================] - 13s 78ms/step
# [3.7700524030785476, 0.4192011533062894, 0.7377290986078097, 1.2144523534945966, 1.3564380300120407, 0.8677777779909471, 0.7196825396358257, 0.5311111104175714, 0.5703571414508458]
# save model
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.0492 - Head_loss: 0.0128 - Mouth_loss: 0.0136 - Eyes_loss: 0.1163 - Total_loss: 0.0063 - Head_acc: 0.9961 - Mouth_acc: 0.9960 - Eyes_acc: 0.9575 - Total_acc: 0.9980
# 168/168 [==============================] - 13s 78ms/step
# [3.979353128333709, 0.4514517990956652, 0.7253389875948013, 1.2153562423883981, 1.476111303399583, 0.8612698407156304, 0.7344444456865036, 0.5264682527576086, 0.5772619060174163]
# save model
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.0483 - Head_loss: 0.0124 - Mouth_loss: 0.0136 - Eyes_loss: 0.1166 - Total_loss: 0.0061 - Head_acc: 0.9960 - Mouth_acc: 0.9959 - Eyes_acc: 0.9582 - Total_acc: 0.9982
# 168/168 [==============================] - 13s 78ms/step
# [4.2889282691647255, 0.45461952885252244, 0.8872924855695492, 1.2286806345066343, 1.5173735001174333, 0.8730555553144465, 0.6859126988122062, 0.5151587297496873, 0.5570238096628427]
# save model2
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.0450 - Head_loss: 0.0117 - Mouth_loss: 0.0127 - Eyes_loss: 0.1169 - Total_loss: 0.0057 - Head_acc: 0.9964 - Mouth_acc: 0.9965 - Eyes_acc: 0.9575 - Total_acc: 0.9982
# 168/168 [==============================] - 13s 78ms/step
# [4.199604497778983, 0.39310552797678194, 0.7895577597433209, 1.235277820833116, 1.6170730512142957, 0.8881746029836082, 0.7315079362042958, 0.5199603161807838, 0.5544444441218817]
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.0434 - Head_loss: 0.0112 - Mouth_loss: 0.0123 - Eyes_loss: 0.1164 - Total_loss: 0.0054 - Head_acc: 0.9964 - Mouth_acc: 0.9964 - Eyes_acc: 0.9574 - Total_acc: 0.9984
# 168/168 [==============================] - 13s 78ms/step
# [3.869841662945137, 0.38355287600676624, 0.6971218158794678, 1.189679617195257, 1.4992197498975743, 0.9001587292268163, 0.7489682548635063, 0.5283730138436935, 0.5503968264951947]
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.0426 - Head_loss: 0.0108 - Mouth_loss: 0.0121 - Eyes_loss: 0.1161 - Total_loss: 0.0055 - Head_acc: 0.9966 - Mouth_acc: 0.9965 - Eyes_acc: 0.9578 - Total_acc: 0.9984
# 168/168 [==============================] - 13s 78ms/step
# [4.597179535088972, 0.4599808882227598, 0.8786477781365236, 1.23287663134397, 1.726157686361278, 0.8719841275763299, 0.6809523816087416, 0.5110317465095293, 0.5340079372926128]
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.0405 - Head_loss: 0.0109 - Mouth_loss: 0.0110 - Eyes_loss: 0.1163 - Total_loss: 0.0051 - Head_acc: 0.9967 - Mouth_acc: 0.9968 - Eyes_acc: 0.9583 - Total_acc: 0.9984
# 168/168 [==============================] - 13s 78ms/step
# [4.2277469682462865, 0.40911295363660766, 0.7889380119032559, 1.2181190603434862, 1.620446998219926, 0.8885317446575278, 0.7301984127677444, 0.5152380938442158, 0.5406746023301301]
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.0388 - Head_loss: 0.0100 - Mouth_loss: 0.0106 - Eyes_loss: 0.1168 - Total_loss: 0.0052 - Head_acc: 0.9970 - Mouth_acc: 0.9970 - Eyes_acc: 0.9575 - Total_acc: 0.9985
# 168/168 [==============================] - 13s 78ms/step
# [4.238962101572681, 0.42808722914738767, 0.8227966764562997, 1.1952481086898064, 1.575090809389838, 0.8868650798020619, 0.7303968246837723, 0.5332539684715725, 0.5652380958587552]
# save model2
# Epoch 1/1
# 1958/1958 [==============================] - 505s 258ms/step - loss: 0.0369 - Head_loss: 0.0097 - Mouth_loss: 0.0101 - Eyes_loss: 0.1158 - Total_loss: 0.0048 - Head_acc: 0.9971 - Mouth_acc: 0.9972 - Eyes_acc: 0.9579 - Total_acc: 0.9986
# 168/168 [==============================] - 13s 78ms/step
# [4.442052479589447, 0.4236482891761301, 0.8720294138174425, 1.227975903519629, 1.665690612354887, 0.875158730694758, 0.7089285713653746, 0.5195634924817741, 0.5428174605615259]
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.0358 - Head_loss: 0.0093 - Mouth_loss: 0.0100 - Eyes_loss: 0.1168 - Total_loss: 0.0046 - Head_acc: 0.9972 - Mouth_acc: 0.9970 - Eyes_acc: 0.9574 - Total_acc: 0.9987
# 168/168 [==============================] - 13s 78ms/step
# [4.429063810479073, 0.42877577436435377, 0.8991273773095584, 1.2205294461760094, 1.6248060694418935, 0.878373015771753, 0.6901984124422251, 0.5213888877271009, 0.5440873024386487]
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.0338 - Head_loss: 0.0086 - Mouth_loss: 0.0093 - Eyes_loss: 0.1179 - Total_loss: 0.0046 - Head_acc: 0.9974 - Mouth_acc: 0.9974 - Eyes_acc: 0.9576 - Total_acc: 0.9986
# 168/168 [==============================] - 13s 78ms/step
# [4.570238038431853, 0.40409077265154625, 0.9124396537102114, 1.221833533291439, 1.7302949214132415, 0.9094444442363012, 0.6959920639915037, 0.5172619048805375, 0.5380555561111707]
# Epoch 1/1
# 1958/1958 [==============================] - 506s 258ms/step - loss: 0.0338 - Head_loss: 0.0085 - Mouth_loss: 0.0097 - Eyes_loss: 0.1169 - Total_loss: 0.0044 - Head_acc: 0.9975 - Mouth_acc: 0.9972 - Eyes_acc: 0.9577 - Total_acc: 0.9987
# 168/168 [==============================] - 13s 78ms/step
# [4.719536157812746, 0.4057026130687927, 0.8729405497926275, 1.2560735560421432, 1.8677142830591558, 0.8991666656608382, 0.725158729329927, 0.5082142842778316, 0.5346825399679974]
# Epoch 1/1
#  851/1958 [============>.................] - ETA: 4:50 - loss: 0.0339 - Head_loss: 0.0086 - Mouth_loss: 0.0077 - Eyes_loss: 0.1445 - Total_loss: 0.0064 - Head_acc: 0.9975 - Mouth_acc: 0.9979 - Eyes_acc: 0.9480 - Total_acc: 0.9981
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-00c89605db24> in <module>()
#      11                     #callbacks=[earlyStopping],
#      12                     workers = 5,
# ---> 13                     shuffle=True
#      14                     )
#      15     result= model.evaluate_generator(LoadImageandLabel(1,150,AllImageFolderTesting,Head_Testing_AllLabelFile,Mouth_Testing_AllLabelFile
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2175         use_multiprocessing=use_multiprocessing,
#    2176         shuffle=shuffle,
# -> 2177         initial_epoch=initial_epoch)
#    2178
#    2179   def evaluate_generator(self,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     174
#     175         outs = model.train_on_batch(
# --> 176             x, y, sample_weight=sample_weight, class_weight=class_weight)
#     177
#     178         if not isinstance(outs, list):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1938
#    1939       self._make_train_function()
# -> 1940       outputs = self.train_function(ins)
#    1941
#    1942     if len(outputs) == 1:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    2984
#    2985     fetched = self._callable_fn(*array_vals,
# -> 2986                                 run_metadata=self.run_metadata)
#    2987     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    2988     return fetched[:len(self.outputs)]
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
