# %%
import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Evaluation Dataset'

files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if ".mp4" in file:
            files.append(os.path.join(r, file))
        
for f in files:
    print(f)
np.array(files).shape
# Out:
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\004\004_glasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\004\004_nightglasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\004\004_nightnoglasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\004\004_noglasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\004\004_sunglasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\022\022_glasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\022\022_nightglasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\022\022_nightnoglasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\022\022_noglasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\022\022_sunglasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\026\026_glasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\026\026_nightglasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\026\026_nightnoglasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\026\026_noglasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\026\026_sunglasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\030\030_glasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\030\030_nightglasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\030\030_nightnoglasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\030\030_noglasses_mix.mp4
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\030\030_sunglasses_mix.mp4
# (20,)

# %%
for i in range(4):
    print(files[i][57:60])
    print(files[i][61:-4])
    print(files[i][57:-4])
    print('----')
# Out:
# 004
# 004_glasses_mix
# 004\004_glasses_mix
# ----
# 004
# 004_nightglasses_mix
# 004\004_nightglasses_mix
# ----
# 004
# 004_nightnoglasses_mix
# 004\004_nightnoglasses_mix
# ----
# 004
# 004_noglasses_mix
# 004\004_noglasses_mix
# ----

# %%
from mtcnn.mtcnn import MTCNN
# import the necessary packages
from imutils import face_utils
import dlib
import cv2
import numpy as np
import os
from operator import itemgetter
import time


eyes_width = 60
eyes_height = 33
mouth_width = 50
mouth_height = 33
face_width = 66
face_height = 85
num_classes = 2
channel = 1

eyes_width2 = 45
eyes_height2 = 25
mouth_width2 = 35
mouth_height2 = 25
face_width2 = 50
face_height2 = 64


def CreateFolder(name):
    try:
        # creating a folder named data 
        if not os.path.exists(name):
            os.makedirs(name)
        # if not created then raise error 
    except OSError: 
        print ('Error: Creating directory of data')            
#==============================================================

detector = MTCNN()

for filename in files:
    
    #==========================
    f = open('Testingdroplist.txt','a')
    f.write(filename+"\n")
    f.close()
    #==========================
    # img = cv2.imread("me.jpg")
    
    #filename = '.\\Dataset\\Training_Evaluation_Dataset\\Training Dataset\\001\\glasses\\yawning.avi'

    print(filename)
    cap = cv2.VideoCapture(filename)
    #================================================================ create new folder

    DefaultPath = '.\\Dataset\\Training_Evaluation_Dataset\\Testing Image\\'+filename[57:-4]+"\\"
    CreateFolder(DefaultPath+"face")
    CreateFolder(DefaultPath+"eyes")
    CreateFolder(DefaultPath+"mouth")
    #================================================================
    Face_ImageDataList = []

    currentframe = 0
    missing_frame = 0
    DropList = []

    eyes_w = eyes_width
    eyes_h = eyes_height
    face_w = face_width
    face_h = face_height
    mouth_w = mouth_width
    mouth_h = mouth_height
    length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print(length)
    x,y,w,h = 0,0,0,0
    
    while(cap.isOpened()):
        
        currentframe += 1
        # load the input image and convert it to grayscale
        ret, image = cap.read()
        if (not ret):
          break
        
        start_time = time.time()
        

        
        #3 frame sample once
       # if(currentframe%3!=0):
         #   continue
        
        #if(currentframe<2200):
        #    continue
        

        height,width = image.shape[:2]
        #gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        #image = cv2.resize(image,(width//2,height//2),interpolation=cv2.INTER_CUBIC)
        #print(image.shape[:2])
        faces = detector.detect_faces(image)
        #print(np.array(faces).shape[0])
        
        if(np.array(faces).shape[0] > 0):
            face = faces[0]
            x,y,w,h = face['box']
            
            face_image = image[max(0,y):max(0,y+h),max(0,x):max(0,x+w)]
            #print(face_image.shape)
            #print(face_image.shape)
            #print(image[x:x+w,y:y+h])
            #cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)
            face_image1 = cv2.resize(face_image,(face_w,face_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "face\\frame_MiddleALL" + str(currentframe) + '.jpg',face_image1)
            
           # face_image2 = cv2.resize(face_image,(face_width2,face_height2),interpolation=cv2.INTER_AREA)
           # cv2.imwrite(DefaultPath + "face\\frame_Small" + str(currentframe) + '.jpg',face_image2) 


            eyes_image = image[max(0,face['keypoints']['left_eye'][1]-int(h*0.2)):max(0,face['keypoints']['right_eye'][1]+int(h*0.2))
                                ,max(0,face['keypoints']['left_eye'][0]-int(w*0.2)):max(0,face['keypoints']['right_eye'][0]+int(w*0.2))]
            
            #cv2.rectangle(image, (face['keypoints']['left_eye'][0]-int(w*0.2), face['keypoints']['left_eye'][1]-int(h*0.2)),
            #              (face['keypoints']['right_eye'][0]+int(w*0.2), face['keypoints']['right_eye'][1]+int(h*0.2)),(0, 255, 0),2)
            eyes_image1 = cv2.resize(eyes_image,(eyes_w,eyes_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "eyes\\frame_MiddleALL" + str(currentframe) + '.jpg',eyes_image1) 
            
           # eyes_image2 = cv2.resize(eyes_image,(eyes_width2,eyes_height2),interpolation=cv2.INTER_AREA)
           # cv2.imwrite(DefaultPath + "eyes\\frame_Small" + str(currentframe) + '.jpg',eyes_image2) 


            mouth_image = image[max(0,face['keypoints']['mouth_left'][1]-int(h*0.2)):max(0,face['keypoints']['mouth_right'][1]+int(h*0.2))
                               ,max(0,face['keypoints']['mouth_left'][0]-int(w*0.2)):max(0,face['keypoints']['mouth_right'][0]+int(w*0.2))]
            #cv2.rectangle(image, (face['keypoints']['mouth_left'][0]-int(w*0.2), face['keypoints']['mouth_left'][1]-int(h*0.2)),
            #              (face['keypoints']['mouth_right'][0]+int(w*0.2), face['keypoints']['mouth_right'][1]+int(h*0.2)),(0, 255, 0),2)
            mouth_image1 = cv2.resize(mouth_image,(mouth_w,mouth_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "mouth\\frame_MiddleALL" + str(currentframe) + '.jpg',mouth_image1) 
            
           # mouth_image2 = cv2.resize(mouth_image,(mouth_width2,mouth_height2),interpolation=cv2.INTER_AREA)
           # cv2.imwrite(DefaultPath + "mouth\\frame_Small" + str(currentframe) + '.jpg',mouth_image2) 



            #cv2.rectangle(image, (face['keypoints']['left_eye'][0], face['keypoints']['left_eye'][1]), 2, (0, 255, 0), -1)


            #cv2.circle(image, (face['keypoints']['left_eye'][0], face['keypoints']['left_eye'][1]), 2, (0, 255, 0), -1)
            #cv2.circle(image, (face['keypoints']['right_eye'][0], face['keypoints']['right_eye'][1]), 2, (0, 255, 0), -1)
            #cv2.circle(image, (face['keypoints']['nose'][0], face['keypoints']['nose'][1]), 2, (0, 255, 0), -1)
            #cv2.circle(image, (face['keypoints']['mouth_left'][0], face['keypoints']['mouth_left'][1]), 2, (0, 255, 0), -1)
            #cv2.circle(image, (face['keypoints']['mouth_right'][0], face['keypoints']['mouth_right'][1]), 2, (0, 255, 0), -1)
            if(currentframe%100==0):        
                name = './data/frame' + str(currentframe) + '.jpg'
                print ('Creating...' + name) 
        elif (missing_frame<60 and (not((x == 0) or (y == 0) or (w == 0) or (h == 0) ))):
            print ('missing using last frame') 
            missing_frame = missing_frame + 1        

            face_image = image[max(0,y):max(0,y+h),max(0,x):max(0,x+w)]
            
            face_image1 = cv2.resize(face_image,(face_w,face_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "face\\frame_MiddleALL" + str(currentframe) + '.jpg',face_image1)
            
           # face_image2 = cv2.resize(face_image,(face_width2,face_height2),interpolation=cv2.INTER_AREA)
          #  cv2.imwrite(DefaultPath + "face\\frame_Small" + str(currentframe) + '.jpg',face_image2) 


            eyes_image = image[max(0,face['keypoints']['left_eye'][1]-int(h*0.2)):max(0,face['keypoints']['right_eye'][1]+int(h*0.2))
                                ,max(0,face['keypoints']['left_eye'][0]-int(w*0.2)):max(0,face['keypoints']['right_eye'][0]+int(w*0.2))]
            
            #cv2.rectangle(image, (face['keypoints']['left_eye'][0]-int(w*0.2), face['keypoints']['left_eye'][1]-int(h*0.2)),
            #              (face['keypoints']['right_eye'][0]+int(w*0.2), face['keypoints']['right_eye'][1]+int(h*0.2)),(0, 255, 0),2)
            eyes_image1 = cv2.resize(eyes_image,(eyes_w,eyes_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "eyes\\frame_MiddleALL" + str(currentframe) + '.jpg',eyes_image1) 
            
           # eyes_image2 = cv2.resize(eyes_image,(eyes_width2,eyes_height2),interpolation=cv2.INTER_AREA)
          #  cv2.imwrite(DefaultPath + "eyes\\frame_Small" + str(currentframe) + '.jpg',eyes_image2) 


            mouth_image = image[max(0,face['keypoints']['mouth_left'][1]-int(h*0.2)):max(0,face['keypoints']['mouth_right'][1]+int(h*0.2))
                               ,max(0,face['keypoints']['mouth_left'][0]-int(w*0.2)):max(0,face['keypoints']['mouth_right'][0]+int(w*0.2))]
            #cv2.rectangle(image, (face['keypoints']['mouth_left'][0]-int(w*0.2), face['keypoints']['mouth_left'][1]-int(h*0.2)),
            #              (face['keypoints']['mouth_right'][0]+int(w*0.2), face['keypoints']['mouth_right'][1]+int(h*0.2)),(0, 255, 0),2)
            mouth_image1 = cv2.resize(mouth_image,(mouth_w,mouth_h),interpolation=cv2.INTER_AREA)
            cv2.imwrite(DefaultPath + "mouth\\frame_MiddleALL" + str(currentframe) + '.jpg',mouth_image1) 
            
           # mouth_image2 = cv2.resize(mouth_image,(mouth_width2,mouth_height2),interpolation=cv2.INTER_AREA)
           # cv2.imwrite(DefaultPath + "mouth\\frame_Small" + str(currentframe) + '.jpg',mouth_image2) 
            
            #if(currentframe%100==0):
            name = './data/frame' + str(currentframe) + '.jpg'
            print ('missing using last frame:  '+ 'Creating...' + name) 

        else:
            name = './data/frame' + str(currentframe) + '.jpg'
            f = open('droplist.txt','a')
            f.write(name+"\n")
            f.close()
            DropList.append(currentframe)
            print("drop")



        '''
        cv2.imshow('img',image)

        #print("FPS: ", 1.0 / (time.time() - start_time))

        k = cv2.waitKey(5) & 0xFF
        if k == 27:
            break
        '''
    
    print("total_frame:" +str(length)+" missing frame"+ str(np.array(DropList).shape[0])+" total frame2:"+ str(currentframe))
    print(DropList)
    cap.release()
    cv2.destroyAllWindows()
# Out:
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\004\004_glasses_mix.mp4
# 3047
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# Creating..../data/frame2300.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2500.jpg
# Creating..../data/frame2600.jpg
# Creating..../data/frame2700.jpg
# Creating..../data/frame2800.jpg
# Creating..../data/frame2900.jpg
# Creating..../data/frame3000.jpg
# total_frame:3047 missing frame0 total frame2:3048
# []
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\004\004_nightglasses_mix.mp4
# 5398
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# Creating..../data/frame2300.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2500.jpg
# Creating..../data/frame2600.jpg
# Creating..../data/frame2700.jpg
# Creating..../data/frame2800.jpg
# Creating..../data/frame2900.jpg
# Creating..../data/frame3000.jpg
# Creating..../data/frame3100.jpg
# Creating..../data/frame3200.jpg
# Creating..../data/frame3300.jpg
# Creating..../data/frame3400.jpg
# Creating..../data/frame3500.jpg
# Creating..../data/frame3600.jpg
# Creating..../data/frame3700.jpg
# Creating..../data/frame3800.jpg
# Creating..../data/frame3900.jpg
# Creating..../data/frame4000.jpg
# Creating..../data/frame4100.jpg
# Creating..../data/frame4200.jpg
# Creating..../data/frame4300.jpg
# Creating..../data/frame4400.jpg
# Creating..../data/frame4500.jpg
# Creating..../data/frame4600.jpg
# Creating..../data/frame4700.jpg
# Creating..../data/frame4800.jpg
# Creating..../data/frame4900.jpg
# Creating..../data/frame5000.jpg
# Creating..../data/frame5100.jpg
# Creating..../data/frame5200.jpg
# Creating..../data/frame5300.jpg
# total_frame:5398 missing frame0 total frame2:5399
# []
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\004\004_nightnoglasses_mix.mp4
# 11728
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame905.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame906.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# Creating..../data/frame2300.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2500.jpg
# Creating..../data/frame2600.jpg
# Creating..../data/frame2700.jpg
# Creating..../data/frame2800.jpg
# Creating..../data/frame2900.jpg
# Creating..../data/frame3000.jpg
# Creating..../data/frame3100.jpg
# Creating..../data/frame3200.jpg
# Creating..../data/frame3300.jpg
# Creating..../data/frame3400.jpg
# Creating..../data/frame3500.jpg
# Creating..../data/frame3600.jpg
# Creating..../data/frame3700.jpg
# Creating..../data/frame3800.jpg
# Creating..../data/frame3900.jpg
# Creating..../data/frame4000.jpg
# Creating..../data/frame4100.jpg
# Creating..../data/frame4200.jpg
# Creating..../data/frame4300.jpg
# Creating..../data/frame4400.jpg
# Creating..../data/frame4500.jpg
# Creating..../data/frame4600.jpg
# Creating..../data/frame4700.jpg
# Creating..../data/frame4800.jpg
# Creating..../data/frame4900.jpg
# Creating..../data/frame5000.jpg
# Creating..../data/frame5100.jpg
# Creating..../data/frame5200.jpg
# Creating..../data/frame5300.jpg
# Creating..../data/frame5400.jpg
# Creating..../data/frame5500.jpg
# Creating..../data/frame5600.jpg
# Creating..../data/frame5700.jpg
# Creating..../data/frame5800.jpg
# Creating..../data/frame5900.jpg
# Creating..../data/frame6000.jpg
# Creating..../data/frame6100.jpg
# Creating..../data/frame6200.jpg
# Creating..../data/frame6300.jpg
# Creating..../data/frame6400.jpg
# Creating..../data/frame6500.jpg
# Creating..../data/frame6600.jpg
# Creating..../data/frame6700.jpg
# Creating..../data/frame6800.jpg
# Creating..../data/frame6900.jpg
# Creating..../data/frame7000.jpg
# Creating..../data/frame7100.jpg
# Creating..../data/frame7200.jpg
# Creating..../data/frame7300.jpg
# Creating..../data/frame7400.jpg
# Creating..../data/frame7500.jpg
# Creating..../data/frame7600.jpg
# Creating..../data/frame7700.jpg
# Creating..../data/frame7800.jpg
# Creating..../data/frame7900.jpg
# Creating..../data/frame8000.jpg
# Creating..../data/frame8100.jpg
# Creating..../data/frame8200.jpg
# Creating..../data/frame8300.jpg
# Creating..../data/frame8400.jpg
# Creating..../data/frame8500.jpg
# Creating..../data/frame8600.jpg
# Creating..../data/frame8700.jpg
# Creating..../data/frame8800.jpg
# Creating..../data/frame8900.jpg
# Creating..../data/frame9000.jpg
# Creating..../data/frame9100.jpg
# Creating..../data/frame9200.jpg
# Creating..../data/frame9300.jpg
# Creating..../data/frame9400.jpg
# Creating..../data/frame9500.jpg
# Creating..../data/frame9600.jpg
# Creating..../data/frame9700.jpg
# Creating..../data/frame9800.jpg
# Creating..../data/frame9900.jpg
# Creating..../data/frame10000.jpg
# Creating..../data/frame10100.jpg
# Creating..../data/frame10200.jpg
# Creating..../data/frame10300.jpg
# Creating..../data/frame10400.jpg
# Creating..../data/frame10500.jpg
# Creating..../data/frame10600.jpg
# Creating..../data/frame10700.jpg
# Creating..../data/frame10800.jpg
# Creating..../data/frame10900.jpg
# Creating..../data/frame11000.jpg
# Creating..../data/frame11100.jpg
# Creating..../data/frame11200.jpg
# Creating..../data/frame11300.jpg
# Creating..../data/frame11400.jpg
# Creating..../data/frame11500.jpg
# Creating..../data/frame11600.jpg
# Creating..../data/frame11700.jpg
# total_frame:11728 missing frame0 total frame2:11729
# []
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\004\004_noglasses_mix.mp4
# 10205
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# Creating..../data/frame2300.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2500.jpg
# Creating..../data/frame2600.jpg
# Creating..../data/frame2700.jpg
# Creating..../data/frame2800.jpg
# Creating..../data/frame2900.jpg
# Creating..../data/frame3000.jpg
# Creating..../data/frame3100.jpg
# Creating..../data/frame3200.jpg
# Creating..../data/frame3300.jpg
# Creating..../data/frame3400.jpg
# Creating..../data/frame3500.jpg
# Creating..../data/frame3600.jpg
# Creating..../data/frame3700.jpg
# Creating..../data/frame3800.jpg
# Creating..../data/frame3900.jpg
# Creating..../data/frame4000.jpg
# Creating..../data/frame4100.jpg
# Creating..../data/frame4200.jpg
# Creating..../data/frame4300.jpg
# Creating..../data/frame4400.jpg
# Creating..../data/frame4500.jpg
# Creating..../data/frame4600.jpg
# Creating..../data/frame4700.jpg
# Creating..../data/frame4800.jpg
# Creating..../data/frame4900.jpg
# Creating..../data/frame5000.jpg
# Creating..../data/frame5100.jpg
# Creating..../data/frame5200.jpg
# Creating..../data/frame5300.jpg
# Creating..../data/frame5400.jpg
# Creating..../data/frame5500.jpg
# Creating..../data/frame5600.jpg
# Creating..../data/frame5700.jpg
# Creating..../data/frame5800.jpg
# Creating..../data/frame5900.jpg
# Creating..../data/frame6000.jpg
# Creating..../data/frame6100.jpg
# Creating..../data/frame6200.jpg
# Creating..../data/frame6300.jpg
# Creating..../data/frame6400.jpg
# Creating..../data/frame6500.jpg
# Creating..../data/frame6600.jpg
# Creating..../data/frame6700.jpg
# Creating..../data/frame6800.jpg
# Creating..../data/frame6900.jpg
# Creating..../data/frame7000.jpg
# Creating..../data/frame7100.jpg
# Creating..../data/frame7200.jpg
# Creating..../data/frame7300.jpg
# Creating..../data/frame7400.jpg
# Creating..../data/frame7500.jpg
# Creating..../data/frame7600.jpg
# Creating..../data/frame7700.jpg
# Creating..../data/frame7800.jpg
# Creating..../data/frame7900.jpg
# Creating..../data/frame8000.jpg
# Creating..../data/frame8100.jpg
# Creating..../data/frame8200.jpg
# Creating..../data/frame8300.jpg
# Creating..../data/frame8400.jpg
# Creating..../data/frame8500.jpg
# Creating..../data/frame8600.jpg
# Creating..../data/frame8700.jpg
# Creating..../data/frame8800.jpg
# Creating..../data/frame8900.jpg
# Creating..../data/frame9000.jpg
# Creating..../data/frame9100.jpg
# Creating..../data/frame9200.jpg
# Creating..../data/frame9300.jpg
# Creating..../data/frame9400.jpg
# Creating..../data/frame9500.jpg
# Creating..../data/frame9600.jpg
# Creating..../data/frame9700.jpg
# Creating..../data/frame9800.jpg
# Creating..../data/frame9900.jpg
# Creating..../data/frame10000.jpg
# Creating..../data/frame10100.jpg
# Creating..../data/frame10200.jpg
# total_frame:10205 missing frame0 total frame2:10206
# []
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\004\004_sunglasses_mix.mp4
# 3506
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# Creating..../data/frame2300.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2500.jpg
# Creating..../data/frame2600.jpg
# Creating..../data/frame2700.jpg
# Creating..../data/frame2800.jpg
# Creating..../data/frame2900.jpg
# Creating..../data/frame3000.jpg
# Creating..../data/frame3100.jpg
# Creating..../data/frame3200.jpg
# Creating..../data/frame3300.jpg
# Creating..../data/frame3400.jpg
# Creating..../data/frame3500.jpg
# total_frame:3506 missing frame0 total frame2:3507
# []
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\022\022_glasses_mix.mp4
# 2552
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# Creating..../data/frame2300.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2500.jpg
# total_frame:2552 missing frame0 total frame2:2553
# []
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\022\022_nightglasses_mix.mp4
# 8202
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# Creating..../data/frame2300.jpg
# Creating..../data/frame2400.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2451.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2452.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2457.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2458.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2459.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2460.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2461.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2462.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2471.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2472.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2473.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2474.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2475.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2476.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2477.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2478.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2485.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2488.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2489.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2490.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2491.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2492.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2493.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2494.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2495.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2496.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2497.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2498.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2499.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2500.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2501.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2502.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2503.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2504.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2505.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2506.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2507.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2508.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2509.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2510.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2511.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2512.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2513.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2514.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2515.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2516.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2517.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2518.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2519.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2520.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2521.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2522.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2523.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2524.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2525.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2526.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2527.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2528.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2529.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2530.jpg
# drop
# drop
# drop
# drop
# Creating..../data/frame2600.jpg
# Creating..../data/frame2700.jpg
# Creating..../data/frame2800.jpg
# Creating..../data/frame2900.jpg
# Creating..../data/frame3000.jpg
# Creating..../data/frame3100.jpg
# Creating..../data/frame3200.jpg
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# Creating..../data/frame3500.jpg
# Creating..../data/frame3600.jpg
# Creating..../data/frame3700.jpg
# Creating..../data/frame3800.jpg
# Creating..../data/frame3900.jpg
# Creating..../data/frame4000.jpg
# Creating..../data/frame4100.jpg
# Creating..../data/frame4200.jpg
# drop
# drop
# Creating..../data/frame4300.jpg
# Creating..../data/frame4400.jpg
# Creating..../data/frame4500.jpg
# Creating..../data/frame4600.jpg
# Creating..../data/frame4700.jpg
# Creating..../data/frame4800.jpg
# Creating..../data/frame4900.jpg
# Creating..../data/frame5000.jpg
# Creating..../data/frame5100.jpg
# Creating..../data/frame5200.jpg
# Creating..../data/frame5300.jpg
# Creating..../data/frame5400.jpg
# Creating..../data/frame5500.jpg
# Creating..../data/frame5600.jpg
# Creating..../data/frame5700.jpg
# Creating..../data/frame5800.jpg
# Creating..../data/frame5900.jpg
# Creating..../data/frame6000.jpg
# Creating..../data/frame6100.jpg
# Creating..../data/frame6200.jpg
# Creating..../data/frame6300.jpg
# Creating..../data/frame6400.jpg
# Creating..../data/frame6500.jpg
# Creating..../data/frame6600.jpg
# Creating..../data/frame6700.jpg
# Creating..../data/frame6800.jpg
# Creating..../data/frame6900.jpg
# Creating..../data/frame7000.jpg
# Creating..../data/frame7100.jpg
# Creating..../data/frame7200.jpg
# Creating..../data/frame7300.jpg
# Creating..../data/frame7400.jpg
# Creating..../data/frame7500.jpg
# Creating..../data/frame7600.jpg
# Creating..../data/frame7700.jpg
# Creating..../data/frame7800.jpg
# Creating..../data/frame7900.jpg
# Creating..../data/frame8000.jpg
# Creating..../data/frame8100.jpg
# Creating..../data/frame8200.jpg
# total_frame:8202 missing frame193 total frame2:8203
# [2531, 2532, 2533, 2534, 3239, 3240, 3241, 3242, 3243, 3244, 3245, 3246, 3247, 3248, 3249, 3250, 3251, 3252, 3253, 3254, 3255, 3256, 3257, 3258, 3259, 3260, 3261, 3262, 3263, 3264, 3265, 3266, 3267, 3268, 3269, 3270, 3271, 3272, 3273, 3274, 3275, 3276, 3277, 3278, 3279, 3280, 3281, 3282, 3283, 3284, 3285, 3286, 3287, 3288, 3289, 3290, 3291, 3292, 3293, 3294, 3295, 3296, 3297, 3298, 3299, 3300, 3301, 3302, 3303, 3304, 3305, 3306, 3307, 3308, 3309, 3310, 3311, 3312, 3313, 3314, 3315, 3316, 3317, 3318, 3319, 3320, 3321, 3322, 3323, 3324, 3325, 3326, 3327, 3328, 3329, 3330, 3331, 3332, 3333, 3334, 3335, 3336, 3337, 3338, 3339, 3340, 3341, 3342, 3343, 3344, 3345, 3346, 3347, 3348, 3349, 3350, 3351, 3352, 3353, 3354, 3355, 3356, 3357, 3358, 3359, 3360, 3361, 3362, 3363, 3364, 3365, 3366, 3367, 3368, 3369, 3370, 3371, 3372, 3373, 3374, 3375, 3376, 3377, 3378, 3379, 3380, 3381, 3382, 3383, 3384, 3385, 3386, 3387, 3388, 3389, 3390, 3391, 3392, 3393, 3394, 3395, 3396, 3397, 3398, 3399, 3400, 3401, 3402, 3403, 3404, 3405, 3406, 3407, 3408, 3409, 3410, 3411, 3412, 3413, 3414, 3415, 3416, 3417, 3418, 3419, 3420, 3421, 3422, 3423, 3424, 3425, 4228, 4229]
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\022\022_nightnoglasses_mix.mp4
# 8617
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1607.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1608.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1609.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1610.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2282.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2283.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2292.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2293.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2294.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2295.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2296.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2297.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2300.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2301.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2302.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2303.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2304.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2305.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2306.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2307.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2308.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2309.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2310.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2311.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2312.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2313.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2314.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2315.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2316.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2317.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2318.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2319.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2320.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2321.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2322.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2323.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2324.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2325.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2326.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2327.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2328.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2329.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2330.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2331.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2500.jpg
# Creating..../data/frame2600.jpg
# Creating..../data/frame2700.jpg
# Creating..../data/frame2800.jpg
# Creating..../data/frame2900.jpg
# Creating..../data/frame3000.jpg
# Creating..../data/frame3100.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3197.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3198.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3199.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3200.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3201.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3202.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3203.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3204.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3205.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3206.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3207.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3208.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3209.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3210.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3211.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3212.jpg
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# Creating..../data/frame3300.jpg
# Creating..../data/frame3400.jpg
# Creating..../data/frame3500.jpg
# Creating..../data/frame3600.jpg
# Creating..../data/frame3700.jpg
# Creating..../data/frame3800.jpg
# Creating..../data/frame3900.jpg
# Creating..../data/frame4000.jpg
# Creating..../data/frame4100.jpg
# Creating..../data/frame4200.jpg
# Creating..../data/frame4300.jpg
# Creating..../data/frame4400.jpg
# Creating..../data/frame4500.jpg
# Creating..../data/frame4600.jpg
# Creating..../data/frame4700.jpg
# Creating..../data/frame4800.jpg
# Creating..../data/frame4900.jpg
# Creating..../data/frame5000.jpg
# Creating..../data/frame5100.jpg
# Creating..../data/frame5200.jpg
# Creating..../data/frame5300.jpg
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# Creating..../data/frame5400.jpg
# Creating..../data/frame5500.jpg
# Creating..../data/frame5600.jpg
# Creating..../data/frame5700.jpg
# Creating..../data/frame5800.jpg
# Creating..../data/frame5900.jpg
# Creating..../data/frame6000.jpg
# Creating..../data/frame6100.jpg
# Creating..../data/frame6200.jpg
# Creating..../data/frame6300.jpg
# Creating..../data/frame6400.jpg
# Creating..../data/frame6500.jpg
# Creating..../data/frame6600.jpg
# Creating..../data/frame6700.jpg
# drop
# drop
# Creating..../data/frame6800.jpg
# Creating..../data/frame6900.jpg
# drop
# drop
# Creating..../data/frame7000.jpg
# Creating..../data/frame7100.jpg
# Creating..../data/frame7200.jpg
# Creating..../data/frame7300.jpg
# Creating..../data/frame7400.jpg
# Creating..../data/frame7500.jpg
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# Creating..../data/frame7700.jpg
# Creating..../data/frame7800.jpg
# Creating..../data/frame7900.jpg
# Creating..../data/frame8000.jpg
# Creating..../data/frame8100.jpg
# Creating..../data/frame8200.jpg
# Creating..../data/frame8300.jpg
# Creating..../data/frame8400.jpg
# Creating..../data/frame8500.jpg
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# Creating..../data/frame8600.jpg
# total_frame:8617 missing frame232 total frame2:8618
# [3213, 3214, 3215, 3216, 3217, 3218, 3219, 3220, 3221, 3222, 3223, 3224, 3225, 3226, 3227, 3228, 3229, 3230, 3231, 3232, 3233, 3234, 3235, 3236, 3237, 3238, 3239, 3240, 3241, 3242, 3243, 3244, 3245, 3246, 3247, 3248, 3249, 3250, 3251, 3252, 3253, 3254, 3255, 3256, 3257, 3258, 3259, 3260, 3261, 3262, 3263, 3264, 3265, 3266, 3267, 3268, 3269, 3270, 3271, 3272, 3273, 3274, 3275, 3276, 3277, 3278, 3279, 3280, 3281, 3282, 3283, 3284, 3285, 3286, 3287, 3288, 5372, 5373, 5374, 5375, 5376, 5378, 5379, 5380, 5381, 5384, 5385, 5386, 5387, 5388, 5389, 5390, 5391, 6777, 6778, 6918, 6919, 7564, 7565, 7566, 7567, 7600, 7601, 7602, 7603, 7604, 7605, 7606, 7607, 7608, 7609, 7610, 7611, 7614, 7615, 7616, 7617, 7618, 7619, 7620, 7621, 7622, 7623, 7624, 7625, 7626, 7627, 7628, 7629, 7630, 7631, 7632, 7633, 7634, 7635, 7636, 7637, 7638, 7639, 7640, 7641, 8508, 8509, 8510, 8511, 8512, 8513, 8514, 8515, 8516, 8517, 8518, 8519, 8520, 8521, 8522, 8523, 8524, 8525, 8526, 8527, 8528, 8529, 8530, 8531, 8532, 8533, 8534, 8535, 8536, 8537, 8538, 8539, 8540, 8541, 8542, 8543, 8544, 8545, 8546, 8547, 8548, 8549, 8550, 8551, 8552, 8553, 8554, 8555, 8556, 8557, 8558, 8559, 8560, 8561, 8562, 8563, 8564, 8565, 8566, 8567, 8568, 8569, 8570, 8571, 8572, 8573, 8574, 8575, 8576, 8577, 8578, 8579, 8580, 8581, 8582, 8583, 8584, 8585, 8586, 8587, 8588, 8589, 8590, 8591, 8592, 8593, 8594, 8595, 8596, 8597, 8598]
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\022\022_noglasses_mix.mp4
# 16849
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2038.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2039.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2040.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2041.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2042.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2043.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2044.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2045.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2046.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2047.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2048.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2049.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2062.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2063.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2065.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2067.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2068.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2069.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2070.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2071.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2072.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2073.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2074.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2077.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2078.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# Creating..../data/frame2300.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2500.jpg
# Creating..../data/frame2600.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2659.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2661.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2662.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2664.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2666.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2670.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2671.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2672.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2673.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2674.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2675.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2676.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2677.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2678.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2679.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2680.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2681.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2682.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2683.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2684.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2685.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2686.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2687.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2688.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2689.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2690.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2691.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2692.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2693.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2694.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2695.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2696.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2697.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2698.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2699.jpg
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# Creating..../data/frame2800.jpg
# Creating..../data/frame2900.jpg
# Creating..../data/frame3000.jpg
# Creating..../data/frame3100.jpg
# Creating..../data/frame3200.jpg
# Creating..../data/frame3300.jpg
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# Creating..../data/frame3600.jpg
# Creating..../data/frame3700.jpg
# Creating..../data/frame3800.jpg
# Creating..../data/frame3900.jpg
# Creating..../data/frame4000.jpg
# Creating..../data/frame4100.jpg
# Creating..../data/frame4200.jpg
# Creating..../data/frame4300.jpg
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# Creating..../data/frame4400.jpg
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# Creating..../data/frame4500.jpg
# Creating..../data/frame4600.jpg
# Creating..../data/frame4700.jpg
# Creating..../data/frame4800.jpg
# Creating..../data/frame4900.jpg
# Creating..../data/frame5000.jpg
# Creating..../data/frame5100.jpg
# Creating..../data/frame5200.jpg
# Creating..../data/frame5300.jpg
# Creating..../data/frame5400.jpg
# Creating..../data/frame5500.jpg
# Creating..../data/frame5600.jpg
# Creating..../data/frame5700.jpg
# Creating..../data/frame5800.jpg
# Creating..../data/frame5900.jpg
# Creating..../data/frame6000.jpg
# Creating..../data/frame6100.jpg
# Creating..../data/frame6200.jpg
# Creating..../data/frame6300.jpg
# Creating..../data/frame6400.jpg
# Creating..../data/frame6500.jpg
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# Creating..../data/frame6600.jpg
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# Creating..../data/frame6700.jpg
# Creating..../data/frame6800.jpg
# Creating..../data/frame6900.jpg
# Creating..../data/frame7000.jpg
# Creating..../data/frame7100.jpg
# Creating..../data/frame7200.jpg
# Creating..../data/frame7300.jpg
# Creating..../data/frame7400.jpg
# Creating..../data/frame7500.jpg
# Creating..../data/frame7600.jpg
# Creating..../data/frame7700.jpg
# Creating..../data/frame7800.jpg
# Creating..../data/frame7900.jpg
# Creating..../data/frame8000.jpg
# Creating..../data/frame8100.jpg
# Creating..../data/frame8200.jpg
# Creating..../data/frame8300.jpg
# Creating..../data/frame8400.jpg
# Creating..../data/frame8500.jpg
# Creating..../data/frame8600.jpg
# Creating..../data/frame8700.jpg
# Creating..../data/frame8800.jpg
# Creating..../data/frame8900.jpg
# Creating..../data/frame9000.jpg
# Creating..../data/frame9100.jpg
# Creating..../data/frame9200.jpg
# Creating..../data/frame9300.jpg
# Creating..../data/frame9400.jpg
# Creating..../data/frame9500.jpg
# Creating..../data/frame9600.jpg
# Creating..../data/frame9700.jpg
# Creating..../data/frame9800.jpg
# Creating..../data/frame9900.jpg
# Creating..../data/frame10000.jpg
# Creating..../data/frame10100.jpg
# Creating..../data/frame10200.jpg
# Creating..../data/frame10300.jpg
# Creating..../data/frame10400.jpg
# Creating..../data/frame10500.jpg
# Creating..../data/frame10600.jpg
# Creating..../data/frame10700.jpg
# Creating..../data/frame10800.jpg
# Creating..../data/frame10900.jpg
# Creating..../data/frame11000.jpg
# Creating..../data/frame11100.jpg
# Creating..../data/frame11200.jpg
# Creating..../data/frame11300.jpg
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# Creating..../data/frame11400.jpg
# Creating..../data/frame11500.jpg
# Creating..../data/frame11600.jpg
# Creating..../data/frame11700.jpg
# Creating..../data/frame11800.jpg
# Creating..../data/frame11900.jpg
# Creating..../data/frame12000.jpg
# Creating..../data/frame12100.jpg
# Creating..../data/frame12200.jpg
# Creating..../data/frame12300.jpg
# Creating..../data/frame12400.jpg
# Creating..../data/frame12500.jpg
# Creating..../data/frame12600.jpg
# Creating..../data/frame12700.jpg
# Creating..../data/frame12800.jpg
# Creating..../data/frame12900.jpg
# Creating..../data/frame13000.jpg
# Creating..../data/frame13100.jpg
# Creating..../data/frame13200.jpg
# Creating..../data/frame13300.jpg
# Creating..../data/frame13400.jpg
# Creating..../data/frame13500.jpg
# Creating..../data/frame13600.jpg
# Creating..../data/frame13700.jpg
# Creating..../data/frame13800.jpg
# Creating..../data/frame13900.jpg
# Creating..../data/frame14000.jpg
# Creating..../data/frame14100.jpg
# Creating..../data/frame14200.jpg
# Creating..../data/frame14300.jpg
# Creating..../data/frame14400.jpg
# Creating..../data/frame14500.jpg
# Creating..../data/frame14600.jpg
# Creating..../data/frame14700.jpg
# Creating..../data/frame14800.jpg
# Creating..../data/frame14900.jpg
# Creating..../data/frame15000.jpg
# Creating..../data/frame15100.jpg
# Creating..../data/frame15200.jpg
# Creating..../data/frame15300.jpg
# Creating..../data/frame15400.jpg
# Creating..../data/frame15500.jpg
# Creating..../data/frame15600.jpg
# Creating..../data/frame15700.jpg
# Creating..../data/frame15800.jpg
# Creating..../data/frame15900.jpg
# Creating..../data/frame16000.jpg
# Creating..../data/frame16100.jpg
# Creating..../data/frame16200.jpg
# Creating..../data/frame16300.jpg
# Creating..../data/frame16400.jpg
# Creating..../data/frame16500.jpg
# Creating..../data/frame16600.jpg
# Creating..../data/frame16700.jpg
# Creating..../data/frame16800.jpg
# total_frame:16849 missing frame286 total frame2:16850
# [2700, 2701, 2702, 2703, 2704, 2705, 2706, 2707, 2708, 2709, 2710, 2711, 2712, 2713, 2714, 2715, 2716, 2717, 2718, 2719, 2720, 2721, 2722, 2723, 2724, 2725, 2726, 2727, 2728, 2729, 2730, 2731, 2732, 2733, 2734, 2735, 2736, 2737, 2738, 2739, 2740, 2741, 2742, 2743, 2744, 2745, 2746, 2747, 2748, 2749, 2750, 2751, 2752, 2753, 2754, 2755, 2756, 2757, 2758, 2759, 2760, 2761, 2762, 2763, 2764, 2765, 2766, 2767, 2768, 2769, 2770, 2771, 2772, 2773, 2774, 2775, 2776, 3392, 3393, 3394, 3396, 3397, 3398, 3399, 3400, 3421, 3422, 3429, 3430, 3431, 3448, 3452, 3453, 3454, 3455, 3456, 3457, 3458, 3459, 3460, 3461, 3462, 3463, 3464, 3465, 3466, 3467, 3468, 3469, 3470, 3471, 3472, 3473, 3474, 3475, 3476, 3477, 3478, 3479, 3480, 3481, 3482, 3483, 3484, 3485, 3486, 3487, 3488, 3489, 3490, 3491, 3492, 3493, 3494, 3495, 3496, 3497, 3498, 3499, 3500, 3501, 3502, 3503, 3504, 3505, 3506, 3507, 3508, 3509, 3510, 3511, 3512, 3513, 3514, 3515, 3516, 3517, 3518, 3519, 3520, 3521, 3522, 3523, 3524, 3525, 3526, 3527, 3531, 3533, 3536, 4330, 4331, 4332, 4333, 4334, 4335, 4336, 4337, 4338, 4339, 4340, 4341, 4342, 4343, 4344, 4345, 4346, 4347, 4348, 4349, 4350, 4351, 4352, 4353, 4354, 4355, 4356, 4357, 4358, 4359, 4360, 4361, 4362, 4363, 4364, 4365, 4366, 4367, 4368, 4371, 4372, 4403, 4406, 4407, 4408, 4409, 4410, 4411, 4412, 4413, 4414, 4415, 4416, 4417, 4418, 4419, 4420, 4421, 4422, 4423, 4432, 4434, 6583, 6584, 6585, 6586, 6587, 6588, 6589, 6590, 6591, 6592, 6593, 6606, 6607, 6608, 6609, 6610, 6611, 6612, 6613, 6614, 6615, 6616, 6617, 6618, 6619, 6620, 6621, 6622, 6623, 11301, 11302, 11303, 11304, 11305, 11306, 11307, 11308, 11309, 11310, 11311, 11312, 11324, 11325, 11326, 11327, 11329, 11330, 11331, 11332, 11334, 11336, 11337, 11339, 11340]
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\022\022_sunglasses_mix.mp4
# 2567
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2258.jpg
# Creating..../data/frame2300.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2500.jpg
# total_frame:2567 missing frame0 total frame2:2568
# []
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\026\026_glasses_mix.mp4
# 17460
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# missing using last frame
# ...
# missing using last frame
# missing using last frame:  Creating..../data/frame1082.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1083.jpg
# Creating..../data/frame1100.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1104.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1110.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1399.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1400.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1401.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1402.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1412.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1413.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1415.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1416.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1417.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1418.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1419.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1420.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1432.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1433.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1484.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1486.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1488.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1489.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1490.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1494.jpg
# Creating..../data/frame1500.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1762.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1776.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# Creating..../data/frame2300.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2500.jpg
# Creating..../data/frame2600.jpg
# Creating..../data/frame2700.jpg
# Creating..../data/frame2800.jpg
# Creating..../data/frame2900.jpg
# Creating..../data/frame3000.jpg
# Creating..../data/frame3100.jpg
# Creating..../data/frame3200.jpg
# Creating..../data/frame3300.jpg
# Creating..../data/frame3400.jpg
# Creating..../data/frame3500.jpg
# Creating..../data/frame3600.jpg
# Creating..../data/frame3700.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3767.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3768.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3769.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3772.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3774.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3775.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3776.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3777.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3778.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3779.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3780.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3781.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3782.jpg
# Creating..../data/frame3800.jpg
# Creating..../data/frame3900.jpg
# Creating..../data/frame4000.jpg
# Creating..../data/frame4100.jpg
# Creating..../data/frame4200.jpg
# Creating..../data/frame4300.jpg
# Creating..../data/frame4400.jpg
# Creating..../data/frame4500.jpg
# Creating..../data/frame4600.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame4678.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame4679.jpg
# Creating..../data/frame4700.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame4788.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame4789.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame4790.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame4791.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame4792.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame4793.jpg
# Creating..../data/frame4800.jpg
# Creating..../data/frame4900.jpg
# Creating..../data/frame5000.jpg
# Creating..../data/frame5100.jpg
# Creating..../data/frame5200.jpg
# total_frame:5251 missing frame0 total frame2:5252
# []
# .\Dataset\Training_Evaluation_Dataset\Evaluation Dataset\030\030_sunglasses_mix.mp4
# 9010
# Creating..../data/frame100.jpg
# Creating..../data/frame200.jpg
# Creating..../data/frame300.jpg
# Creating..../data/frame400.jpg
# Creating..../data/frame500.jpg
# Creating..../data/frame600.jpg
# Creating..../data/frame700.jpg
# Creating..../data/frame800.jpg
# Creating..../data/frame900.jpg
# Creating..../data/frame1000.jpg
# Creating..../data/frame1100.jpg
# Creating..../data/frame1200.jpg
# Creating..../data/frame1300.jpg
# Creating..../data/frame1400.jpg
# Creating..../data/frame1500.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1544.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1545.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1546.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1547.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1548.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1549.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1550.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1551.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1552.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1553.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1554.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1555.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame1556.jpg
# Creating..../data/frame1600.jpg
# Creating..../data/frame1700.jpg
# Creating..../data/frame1800.jpg
# Creating..../data/frame1900.jpg
# Creating..../data/frame2000.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2029.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2030.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2032.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2033.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2034.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2035.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2036.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2037.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2038.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2039.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2040.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame2041.jpg
# Creating..../data/frame2100.jpg
# Creating..../data/frame2200.jpg
# Creating..../data/frame2300.jpg
# Creating..../data/frame2400.jpg
# Creating..../data/frame2500.jpg
# Creating..../data/frame2600.jpg
# Creating..../data/frame2700.jpg
# Creating..../data/frame2800.jpg
# Creating..../data/frame2900.jpg
# Creating..../data/frame3000.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3073.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3074.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3075.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3076.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3077.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3078.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3079.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3080.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3081.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3082.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3083.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3084.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3085.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3086.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3087.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3088.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3089.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3090.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3091.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3092.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3093.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3094.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3097.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3098.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3099.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3100.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3101.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3102.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3103.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3104.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3105.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3106.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3107.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3108.jpg
# missing using last frame
# missing using last frame:  Creating..../data/frame3109.jpg
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# Creating..../data/frame3300.jpg
# Creating..../data/frame3400.jpg
# Creating..../data/frame3500.jpg
# Creating..../data/frame3600.jpg
# Creating..../data/frame3700.jpg
# Creating..../data/frame3800.jpg
# drop
# Creating..../data/frame3900.jpg
# Creating..../data/frame4000.jpg
# Creating..../data/frame4100.jpg
# Creating..../data/frame4200.jpg
# Creating..../data/frame4300.jpg
# Creating..../data/frame4400.jpg
# Creating..../data/frame4500.jpg
# Creating..../data/frame4600.jpg
# Creating..../data/frame4700.jpg
# Creating..../data/frame4800.jpg
# Creating..../data/frame4900.jpg
# Creating..../data/frame5000.jpg
# Creating..../data/frame5100.jpg
# Creating..../data/frame5200.jpg
# Creating..../data/frame5300.jpg
# Creating..../data/frame5400.jpg
# Creating..../data/frame5500.jpg
# Creating..../data/frame5600.jpg
# Creating..../data/frame5700.jpg
# Creating..../data/frame5800.jpg
# Creating..../data/frame5900.jpg
# Creating..../data/frame6000.jpg
# Creating..../data/frame6100.jpg
# Creating..../data/frame6200.jpg
# Creating..../data/frame6300.jpg
# Creating..../data/frame6400.jpg
# Creating..../data/frame6500.jpg
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# Creating..../data/frame6700.jpg
# Creating..../data/frame6800.jpg
# Creating..../data/frame6900.jpg
# Creating..../data/frame7000.jpg
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# Creating..../data/frame7100.jpg
# Creating..../data/frame7200.jpg
# Creating..../data/frame7300.jpg
# Creating..../data/frame7400.jpg
# Creating..../data/frame7500.jpg
# Creating..../data/frame7600.jpg
# Creating..../data/frame7700.jpg
# Creating..../data/frame7800.jpg
# Creating..../data/frame7900.jpg
# Creating..../data/frame8000.jpg
# Creating..../data/frame8100.jpg
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# drop
# Creating..../data/frame8300.jpg
# Creating..../data/frame8400.jpg
# Creating..../data/frame8500.jpg
# Creating..../data/frame8600.jpg
# Creating..../data/frame8700.jpg
# Creating..../data/frame8800.jpg
# Creating..../data/frame8900.jpg
# Creating..../data/frame9000.jpg
# total_frame:9010 missing frame249 total frame2:9011
# [3110, 3111, 3112, 3113, 3114, 3115, 3116, 3117, 3118, 3119, 3120, 3121, 3122, 3123, 3124, 3125, 3126, 3127, 3128, 3129, 3130, 3131, 3132, 3133, 3134, 3135, 3136, 3137, 3138, 3139, 3140, 3141, 3142, 3143, 3144, 3145, 3146, 3147, 3148, 3149, 3150, 3151, 3152, 3154, 3155, 3156, 3161, 3171, 3172, 3173, 3174, 3175, 3176, 3177, 3178, 3180, 3181, 3182, 3183, 3184, 3185, 3186, 3187, 3188, 3189, 3190, 3191, 3192, 3193, 3195, 3196, 3197, 3198, 3199, 3200, 3201, 3202, 3203, 3204, 3205, 3206, 3207, 3208, 3209, 3210, 3211, 3212, 3213, 3214, 3215, 3216, 3217, 3218, 3219, 3220, 3221, 3823, 6592, 6593, 6594, 6595, 6596, 6597, 6600, 6601, 6602, 6603, 6604, 7077, 7079, 7080, 7081, 7082, 7083, 7084, 7085, 7086, 7088, 8121, 8122, 8123, 8124, 8125, 8126, 8127, 8128, 8129, 8130, 8131, 8132, 8133, 8134, 8135, 8136, 8137, 8138, 8139, 8140, 8141, 8142, 8143, 8144, 8145, 8146, 8147, 8148, 8149, 8150, 8151, 8152, 8153, 8154, 8155, 8156, 8157, 8158, 8159, 8160, 8161, 8162, 8163, 8164, 8165, 8166, 8167, 8168, 8169, 8170, 8171, 8172, 8173, 8174, 8175, 8176, 8177, 8178, 8179, 8180, 8181, 8182, 8183, 8184, 8185, 8186, 8187, 8188, 8189, 8190, 8191, 8192, 8193, 8194, 8195, 8196, 8197, 8198, 8199, 8200, 8201, 8203, 8206, 8207, 8220, 8222, 8223, 8224, 8225, 8226, 8227, 8228, 8229, 8230, 8231, 8232, 8234, 8235, 8236, 8237, 8238, 8239, 8240, 8241, 8242, 8243, 8244, 8245, 8246, 8247, 8248, 8249, 8250, 8251, 8252, 8253, 8255, 8256, 8257, 8258, 8259, 8260, 8261, 8262, 8263, 8264, 8265, 8266, 8267, 8268, 8269]

# %% [markdown]
# ### Evaluation

# %%
import tensorflow as tf

model = tf.keras.models.model_from_json(open('./MultiTask_Model_0820Best.json').read())
model.load_weights('./MultiTask_Model_0820Best.h5')

# %%
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()

# %%
'''
import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Testing Image'

AllImageFolder = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        
        #print(directory)
        path = str(os.path.join(r, file))
        
        if('eyes' in path):
            AllImageFolder.append(os.path.join(r, file))
        
#for f in AllImageFolder:
#    print(f)
np.array(AllImageFolder).shape
'''

# %%
import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Testing Image'

AllImageFolder = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for directory in d:
        if ("mix" in directory):
            #print(directory)
            AllImageFolder.append(os.path.join(r, directory))
        
for d in AllImageFolder:
    print(d)
    
#llImageFolder = AllImageFolder[2:]
np.array(AllImageFolder).shape

# %%
# load label

import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Evaluation Dataset'

AllLabelFile = []

# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if "head.txt" in file :
            AllLabelFile.append(os.path.join(r, file))
        
for f in AllLabelFile:
    print(f)
    
#AllLabelFile = AllLabelFile [2:]
np.array(AllLabelFile).shape

# %%
num_samples = 167208
batch_size = 250

# %%
import numpy as np
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import cv2
from math import ceil

from keras.callbacks import EarlyStopping




def LoadImageandLabel(batch_size,AllVideoImageFolder,AllLabelFile):
    #print(Originalpath)
    count=0
    
    while True:
        LabelFileindex = 0
        for Originalpath in AllVideoImageFolder:
            labelPath = AllLabelFile[LabelFileindex]
            LabelFileindex = LabelFileindex + 1

            Face_ImageDataList = []
            Eyes_ImageDataList = []
            Mouth_ImageDataList = []
            #=====load all label in a video
            LabelList = []
            TempLabelList = []
            inputfile = open(labelPath, 'r').read()
            TempLabelList = list(map(int, inputfile))

            #=========================

            TEMP_ImageDataList = []

            path = Originalpath+"\\face"
            

            #=====find all files in path=======    
            Facefiles = []
            Eyefiles = []
            Mouthfiles = []
            # r=root, d=directories, f = files
            for r, d, f in os.walk(path):
                for file in f:
                    if ".jpg" in file:
                        temp = os.path.join(r, file)
                        Facefiles.append(temp)
                        
                        #Eyefiles.append(temp.replace("face", "eyes"))
                        #Mouthfiles.append(temp.replace("face", "mouth"))


            Facefiles.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
            #Eyefiles.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
            #Mouthfiles.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
            
            #Mouthfiles=Mouthfiles[:-2]
            #Eyefiles=Eyefiles[:-2]
            Facefiles=Facefiles[:-2]
            #print(len(Mouthfiles))
            #print(len(TempLabelList))
            
            for FileIndex in range(len(Facefiles)):
                #======================load label

                index = Facefiles[FileIndex].find('frame')
                framenumber =int(Facefiles[FileIndex][index+5:-4]) 
                
                #print(framenumber)

                #if(judgeflag == 0 and TempLabelList[framenumber-1] == 1):
                #    judgeflag = 1
                    #print(framenumber-1)

                #Labelarray = np.array(LabelList)
                #print(len(TempLabelList))
                #print(framenumber-1)
                Labelarray = to_categorical(TempLabelList[framenumber-1], num_classes=3)
                LabelList.append(Labelarray)
                #print(LabelList)

                    #Labelarray = np.array(LabelList)
                    #Labelarray = to_categorical(Labelarray, num_classes=2)

                #================================
                ImgGray = cv2.imread(Facefiles[FileIndex],0)
                #ImgRGB = cv2.merge((ImgGray,ImgGray,ImgGray))# this line make gray image to RGB
                #TEMP_ImageDataList.append(ImgRGB)  
                ImgGray = ImgGray.reshape(ImgGray.shape[0],ImgGray.shape[1],1)
                #print(ImgGray.shape)
                Face_ImageDataList.append(ImgGray)
                #print(np.array(Face_ImageDataList).shape)
                '''
                ImgGray = cv2.imread(Mouthfiles[FileIndex],0)
                ImgGray = ImgGray.reshape(ImgGray.shape[0],ImgGray.shape[1],1)
                Mouth_ImageDataList.append(ImgGray)


                ImgGray = cv2.imread(Eyefiles[FileIndex],0)
                ImgGray = ImgGray.reshape(ImgGray.shape[0],ImgGray.shape[1],1)
                Eyes_ImageDataList.append(ImgGray)
                '''
                 #====================================
               
                count = count +1
                if count>=batch_size:

                        yield ([np.array(Face_ImageDataList)],np.array(LabelList))
                        count=0
                        Face_ImageDataList = []
                        Eyes_ImageDataList = []
                        Mouth_ImageDataList = []
                        LabelList = []

                        
#                   
result= model.evaluate_generator(LoadImageandLabel(batch_size,AllImageFolder,AllLabelFile), steps=ceil(num_samples / batch_size),workers=5,verbose = 1)

# %%
result

# %% [markdown]
# ### Evaluation mouth

# %%
import tensorflow as tf

model = tf.keras.models.model_from_json(open('./MouthModelNEW.json').read())
model.load_weights('./MouthModelNEW.h5')

# %%
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()

# %%
import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Testing Image'

AllImageFolder = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for directory in d:
        if ("mix" in directory):
            #print(directory)
            AllImageFolder.append(os.path.join(r, directory))
        
for d in AllImageFolder:
    print(d)
    
#llImageFolder = AllImageFolder[2:]
np.array(AllImageFolder).shape

# %%
# load label

import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Evaluation Dataset'

AllLabelFile = []

# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if "mouth.txt" in file :
            AllLabelFile.append(os.path.join(r, file))
        
for f in AllLabelFile:
    print(f)
    
#AllLabelFile = AllLabelFile [2:]
np.array(AllLabelFile).shape

# %%
num_samples = 167208
batch_size = 250

eyes_width = 45
eyes_height = 25
mouth_width = 35
mouth_height = 25
face_width = 50
face_height = 64
num_classes = 3
channel = 1

# %%
import numpy as np
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import cv2
from math import ceil

from keras.callbacks import EarlyStopping




def LoadImageandLabel(batch_size,AllVideoImageFolder,AllLabelFile):
    #print(Originalpath)
    count=0
    
    while True:
        LabelFileindex = 0
        for Originalpath in AllVideoImageFolder:
            labelPath = AllLabelFile[LabelFileindex]
            LabelFileindex = LabelFileindex + 1

            Face_ImageDataList = []
            Eyes_ImageDataList = []
            Mouth_ImageDataList = []
            #=====load all label in a video
            LabelList = []
            TempLabelList = []
            inputfile = open(labelPath, 'r').read()
            TempLabelList = list(map(int, inputfile))

            #=========================

            TEMP_ImageDataList = []

            path = Originalpath+"\\face"
            

            #=====find all files in path=======    
            Facefiles = []
            Eyefiles = []
            Mouthfiles = []
            # r=root, d=directories, f = files
            for r, d, f in os.walk(path):
                for file in f:
                    if ".jpg" in file:
                        temp = os.path.join(r, file)
                        Facefiles.append(temp)
                        
                        #Eyefiles.append(temp.replace("face", "eyes"))
                        #Mouthfiles.append(temp.replace("face", "mouth"))

            
            Facefiles.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
            #Eyefiles.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
            #Mouthfiles.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
            
            #Mouthfiles=Mouthfiles[:-2]
            #Eyefiles=Eyefiles[:-2]
            Facefiles=Facefiles[:-2]
            '''
            print(len(Facefiles))
            print(len(TempLabelList))
            '''
            for FileIndex in range(len(Facefiles)):
                #======================load label

                index = Facefiles[FileIndex].find('frame')
                framenumber =int(Facefiles[FileIndex][index+5:-4]) 
                
                #print(framenumber)

                #if(judgeflag == 0 and TempLabelList[framenumber-1] == 1):
                #    judgeflag = 1
                    #print(framenumber-1)

                #Labelarray = np.array(LabelList)
                #print(len(TempLabelList))
                #print(framenumber-1)
                Labelarray = to_categorical(TempLabelList[framenumber-1], num_classes=3)
                LabelList.append(Labelarray)
                #print(LabelList)

                    #Labelarray = np.array(LabelList)
                    #Labelarray = to_categorical(Labelarray, num_classes=2)

                #================================
                ImgGray = cv2.imread(Facefiles[FileIndex],0)
                #ImgRGB = cv2.merge((ImgGray,ImgGray,ImgGray))# this line make gray image to RGB
                #TEMP_ImageDataList.append(ImgRGB)  
                ImgGray = ImgGray.reshape(ImgGray.shape[0],ImgGray.shape[1],1)
                #print(ImgGray.shape)
                Face_ImageDataList.append(ImgGray)
                #print(np.array(Face_ImageDataList).shape)
                '''
                ImgGray = cv2.imread(Mouthfiles[FileIndex],0)
                ImgGray = ImgGray.reshape(ImgGray.shape[0],ImgGray.shape[1],1)
                Mouth_ImageDataList.append(ImgGray)


                ImgGray = cv2.imread(Eyefiles[FileIndex],0)
                ImgGray = ImgGray.reshape(ImgGray.shape[0],ImgGray.shape[1],1)
                Eyes_ImageDataList.append(ImgGray)
                '''
                 #====================================
               
                count = count +1
                if count>=batch_size:

                        yield ([np.array(Face_ImageDataList)],np.array(LabelList))
                        count=0
                        Face_ImageDataList = []
                        Eyes_ImageDataList = []
                        Mouth_ImageDataList = []
                        LabelList = []
                        
#                   
result= model.evaluate_generator(LoadImageandLabel(batch_size,AllImageFolder,AllLabelFile), steps=ceil(num_samples / batch_size),workers=5,verbose = 1)

# %%
result

# %% [markdown]
# ### Evaluation eyes

# %%
import tensorflow as tf

model = tf.keras.models.model_from_json(open('./EyeModelNEW.json').read())
model.load_weights('./EyeModelNEW.h5')

# %%
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()

# %%
import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Testing Image'

AllImageFolder = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for directory in d:
        if ("mix" in directory):
            #print(directory)
            AllImageFolder.append(os.path.join(r, directory))
        
for d in AllImageFolder:
    print(d)
    
#llImageFolder = AllImageFolder[2:]
np.array(AllImageFolder).shape

# %%
# load label

import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Evaluation Dataset'

AllLabelFile = []

# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if "eye.txt" in file :
            AllLabelFile.append(os.path.join(r, file))
        
for f in AllLabelFile:
    print(f)
    
#AllLabelFile = AllLabelFile [2:]
np.array(AllLabelFile).shape

# %%
num_samples = 167208
batch_size = 250

eyes_width = 45
eyes_height = 25
mouth_width = 35
mouth_height = 25
face_width = 50
face_height = 64
num_classes = 2
channel = 1

# %%
import numpy as np
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import cv2
from math import ceil

from keras.callbacks import EarlyStopping



def LoadImageandLabel(batch_size,AllVideoImageFolder,AllLabelFile):
    #print(Originalpath)
    count=0
    
    while True:
        LabelFileindex = 0
        for Originalpath in AllVideoImageFolder:

            labelPath = AllLabelFile[LabelFileindex]
            LabelFileindex = LabelFileindex + 1

            Face_ImageDataList = []
            Eyes_ImageDataList = []
            Mouth_ImageDataList = []
            #=====load all label in a video
            LabelList = []
            TempLabelList = []
            inputfile = open(labelPath, 'r').read()
            TempLabelList = list(map(int, inputfile))

            #=========================

            TEMP_ImageDataList = []

            path = Originalpath+"\\face"


            #=====find all files in path=======    
            Facefiles = []
            Eyefiles = []
            Mouthfiles = []
            # r=root, d=directories, f = files
            for r, d, f in os.walk(path):
                for file in f:
                    if ".jpg" in file:
                        temp = os.path.join(r, file)
                        
                        Facefiles.append(temp)
                        

            Facefiles.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
            #Mouthfiles=Mouthfiles[:-2]
            #Eyefiles=Eyefiles[:-2]
            Facefiles=Facefiles[:-2]
            for FileIndex in range(len(Facefiles)):
                #======================load label

                index = Facefiles[FileIndex].find('frame')
                framenumber =int(Facefiles[FileIndex][index+5:-4]) 

                #print(TempLabelList[framenumber-1])
                Labelarray = to_categorical(TempLabelList[framenumber-1], num_classes=num_classes)
                LabelList.append(Labelarray)
                
                #================================
                ImgGray = cv2.imread(Facefiles[FileIndex],0)
                ImgGray = ImgGray.reshape(ImgGray.shape[0],ImgGray.shape[1],1)
                Face_ImageDataList.append(ImgGray)
                 #====================================
               
                count = count +1
                if count>=batch_size:
                        #yield(np.array(Face_ImageDataList),np.array(LabelList))
                        yield ([np.array(Face_ImageDataList)],np.array(LabelList))
                        count=0
                        Face_ImageDataList = []
                        Eyes_ImageDataList = []
                        Mouth_ImageDataList = []
                        LabelList = []


result= model.evaluate_generator(LoadImageandLabel(batch_size,AllImageFolder,AllLabelFile), steps=ceil(num_samples / batch_size),workers=5,verbose = 1)

# %%
result

# %%
import numpy as np
print(np.load(".\\Dataset\\Training_Evaluation_Dataset\\Training Image\\001\\night_noglasses\\sleepyCombination\\face\\frame3_Prob.npy"))
print(np.load(".\\Dataset\\Training_Evaluation_Dataset\\Training Image\\001\\night_noglasses\\sleepyCombination\\eyes\\frame3_Prob.npy"))
print(np.load(".\\Dataset\\Training_Evaluation_Dataset\\Training Image\\001\\night_noglasses\\sleepyCombination\\mouth\\frame3_Prob.npy"))

# %% [markdown]
# ### Evaluation for multi label

# %%
import tensorflow as tf

model = tf.keras.models.model_from_json(open('./MultiTask_Model_0821Second.json').read())
model.load_weights('./MultiTask_Model_0821Second.h5')
#model = tf.keras.models.model_from_json(open('.\\Temp\\backup\\MultiTask_Model_0821_9.json').read())
#model.load_weights('.\\Temp\\backup\\MultiTask_Model_0821_9.h5')

# %%
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 85, 66, 1)    0
# __________________________________________________________________________________________________
# conv1conv2d (Conv2D)            (None, 42, 32, 32)   288         input_1[0][0]
# __________________________________________________________________________________________________
# conv1conv2dbn (BatchNormalizati (None, 42, 32, 32)   96          conv1conv2d[0][0]
# __________________________________________________________________________________________________
# conv1conv2dact (Activation)     (None, 42, 32, 32)   0           conv1conv2dbn[0][0]
# __________________________________________________________________________________________________
# conv2conv2d (Conv2D)            (None, 40, 30, 32)   9216        conv1conv2dact[0][0]
# __________________________________________________________________________________________________
# conv2conv2dbn (BatchNormalizati (None, 40, 30, 32)   96          conv2conv2d[0][0]
# __________________________________________________________________________________________________
# conv2conv2dact (Activation)     (None, 40, 30, 32)   0           conv2conv2dbn[0][0]
# __________________________________________________________________________________________________
# conv3conv2d (Conv2D)            (None, 38, 28, 64)   18432       conv2conv2dact[0][0]
# __________________________________________________________________________________________________
# conv3conv2dbn (BatchNormalizati (None, 38, 28, 64)   192         conv3conv2d[0][0]
# __________________________________________________________________________________________________
# conv3conv2dact (Activation)     (None, 38, 28, 64)   0           conv3conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_12conv2d (Conv2D)       (None, 36, 26, 96)   55296       conv3conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_12conv2dbn (BatchNormal (None, 36, 26, 96)   288         stem_br_12conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_11_maxpool_1 (MaxPoolin (None, 36, 26, 64)   0           conv3conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_12conv2dact (Activation (None, 36, 26, 96)   0           stem_br_12conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_concat_1 (Concatenate)     (None, 36, 26, 160)  0           stem_br_11_maxpool_1[0][0]
#                                                                  stem_br_12conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_211conv2d (Conv2D)      (None, 36, 26, 64)   10240       stem_concat_1[0][0]
# __________________________________________________________________________________________________
# stem_br_211conv2dbn (BatchNorma (None, 36, 26, 64)   192         stem_br_211conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_211conv2dact (Activatio (None, 36, 26, 64)   0           stem_br_211conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_212conv2d (Conv2D)      (None, 36, 26, 64)   28672       stem_br_211conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_212conv2dbn (BatchNorma (None, 36, 26, 64)   192         stem_br_212conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_212conv2dact (Activatio (None, 36, 26, 64)   0           stem_br_212conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_213conv2d (Conv2D)      (None, 36, 26, 64)   28672       stem_br_212conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_221conv2d (Conv2D)      (None, 36, 26, 64)   10240       stem_concat_1[0][0]
# __________________________________________________________________________________________________
# stem_br_213conv2dbn (BatchNorma (None, 36, 26, 64)   192         stem_br_213conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_221conv2dbn (BatchNorma (None, 36, 26, 64)   192         stem_br_221conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_213conv2dact (Activatio (None, 36, 26, 64)   0           stem_br_213conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_221conv2dact (Activatio (None, 36, 26, 64)   0           stem_br_221conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_214conv2d (Conv2D)      (None, 34, 24, 96)   55296       stem_br_213conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_222conv2d (Conv2D)      (None, 34, 24, 96)   55296       stem_br_221conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_214conv2dbn (BatchNorma (None, 34, 24, 96)   288         stem_br_214conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_222conv2dbn (BatchNorma (None, 34, 24, 96)   288         stem_br_222conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_214conv2dact (Activatio (None, 34, 24, 96)   0           stem_br_214conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_222conv2dact (Activatio (None, 34, 24, 96)   0           stem_br_222conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_concat_2 (Concatenate)     (None, 34, 24, 192)  0           stem_br_214conv2dact[0][0]
#                                                                  stem_br_222conv2dact[0][0]
# __________________________________________________________________________________________________
# stem_br_31conv2d (Conv2D)       (None, 32, 22, 192)  331776      stem_concat_2[0][0]
# __________________________________________________________________________________________________
# stem_br_31conv2dbn (BatchNormal (None, 32, 22, 192)  576         stem_br_31conv2d[0][0]
# __________________________________________________________________________________________________
# stem_br_31conv2dact (Activation (None, 32, 22, 192)  0           stem_br_31conv2dbn[0][0]
# __________________________________________________________________________________________________
# stem_br_32_maxpool_2 (MaxPoolin (None, 32, 22, 192)  0           stem_concat_2[0][0]
# __________________________________________________________________________________________________
# stem_concat_3 (Concatenate)     (None, 32, 22, 384)  0           stem_br_31conv2dact[0][0]
#                                                                  stem_br_32_maxpool_2[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2d (Conv2D)    (None, 32, 22, 32)   12288       stem_concat_3[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_1b2_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_1conv2dact (Activat (None, 32, 22, 32)   0           incresA_1b2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2d (Conv2D)    (None, 32, 22, 32)   12288       stem_concat_3[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2d (Conv2D)    (None, 32, 22, 48)   13824       incresA_1b2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2dbn (BatchNor (None, 32, 22, 48)   144         incresA_1b2_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_1conv2dact (Activat (None, 32, 22, 32)   0           incresA_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_2conv2dact (Activat (None, 32, 22, 48)   0           incresA_1b2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2d (Conv2D)      (None, 32, 22, 32)   12288       stem_concat_3[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2d (Conv2D)    (None, 32, 22, 32)   9216        incresA_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2d (Conv2D)    (None, 32, 22, 64)   27648       incresA_1b2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2dbn (BatchNorma (None, 32, 22, 32)   96          incresA_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2dbn (BatchNor (None, 32, 22, 64)   192         incresA_1b2_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1b0conv2dact (Activatio (None, 32, 22, 32)   0           incresA_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b1_2conv2dact (Activat (None, 32, 22, 32)   0           incresA_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1b2_3conv2dact (Activat (None, 32, 22, 64)   0           incresA_1b2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_1_concat (Concatenate)  (None, 32, 22, 128)  0           incresA_1b0conv2dact[0][0]
#                                                                  incresA_1b1_2conv2dact[0][0]
#                                                                  incresA_1b2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_1filt_exp_1x1conv2d (Co (None, 32, 22, 384)  49152       incresA_1_concat[0][0]
# __________________________________________________________________________________________________
# incresA_1filt_exp_1x1conv2dbn ( (None, 32, 22, 384)  1152        incresA_1filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_1act_scaling (Lambda)   (None, 32, 22, 384)  0           stem_concat_3[0][0]
#                                                                  incresA_1filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# incresA_2b2_1conv2d (Conv2D)    (None, 32, 22, 32)   12288       incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_1conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_2b2_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_1conv2dact (Activat (None, 32, 22, 32)   0           incresA_2b2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_1conv2d (Conv2D)    (None, 32, 22, 32)   12288       incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_2conv2d (Conv2D)    (None, 32, 22, 48)   13824       incresA_2b2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_1conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_2b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_2conv2dbn (BatchNor (None, 32, 22, 48)   144         incresA_2b2_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_1conv2dact (Activat (None, 32, 22, 32)   0           incresA_2b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_2conv2dact (Activat (None, 32, 22, 48)   0           incresA_2b2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b0conv2d (Conv2D)      (None, 32, 22, 32)   12288       incresA_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_2conv2d (Conv2D)    (None, 32, 22, 32)   9216        incresA_2b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_3conv2d (Conv2D)    (None, 32, 22, 64)   27648       incresA_2b2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2b0conv2dbn (BatchNorma (None, 32, 22, 32)   96          incresA_2b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_2conv2dbn (BatchNor (None, 32, 22, 32)   96          incresA_2b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_3conv2dbn (BatchNor (None, 32, 22, 64)   192         incresA_2b2_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2b0conv2dact (Activatio (None, 32, 22, 32)   0           incresA_2b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b1_2conv2dact (Activat (None, 32, 22, 32)   0           incresA_2b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2b2_3conv2dact (Activat (None, 32, 22, 64)   0           incresA_2b2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresA_2_concat (Concatenate)  (None, 32, 22, 128)  0           incresA_2b0conv2dact[0][0]
#                                                                  incresA_2b1_2conv2dact[0][0]
#                                                                  incresA_2b2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresA_2filt_exp_1x1conv2d (Co (None, 32, 22, 384)  49152       incresA_2_concat[0][0]
# __________________________________________________________________________________________________
# incresA_2filt_exp_1x1conv2dbn ( (None, 32, 22, 384)  1152        incresA_2filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresA_2act_scaling (Lambda)   (None, 32, 22, 384)  0           incresA_1act_scaling[0][0]
#                                                                  incresA_2filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# x_red1_c2_1conv2d (Conv2D)      (None, 32, 22, 256)  98304       incresA_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_1conv2dbn (BatchNorma (None, 32, 22, 256)  768         x_red1_c2_1conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_1conv2dact (Activatio (None, 32, 22, 256)  0           x_red1_c2_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2d (Conv2D)      (None, 32, 22, 256)  589824      x_red1_c2_1conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2dbn (BatchNorma (None, 32, 22, 256)  768         x_red1_c2_2conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_2conv2dact (Activatio (None, 32, 22, 256)  0           x_red1_c2_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2d (Conv2D)        (None, 15, 10, 384)  1327104     incresA_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2d (Conv2D)      (None, 15, 10, 384)  884736      x_red1_c2_2conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2dbn (BatchNormali (None, 15, 10, 384)  1152        x_red1_c1conv2d[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2dbn (BatchNorma (None, 15, 10, 384)  1152        x_red1_c2_3conv2d[0][0]
# __________________________________________________________________________________________________
# red_maxpool_1 (MaxPooling2D)    (None, 15, 10, 384)  0           incresA_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red1_c1conv2dact (Activation) (None, 15, 10, 384)  0           x_red1_c1conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red1_c2_3conv2dact (Activatio (None, 15, 10, 384)  0           x_red1_c2_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# red_concat_1 (Concatenate)      (None, 15, 10, 1152) 0           red_maxpool_1[0][0]
#                                                                  x_red1_c1conv2dact[0][0]
#                                                                  x_red1_c2_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2d (Conv2D)    (None, 15, 10, 128)  147456      red_concat_1[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2dbn (BatchNor (None, 15, 10, 128)  384         incresB_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_1conv2dact (Activat (None, 15, 10, 128)  0           incresB_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2d (Conv2D)    (None, 15, 10, 160)  143360      incresB_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2dbn (BatchNor (None, 15, 10, 160)  480         incresB_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_2conv2dact (Activat (None, 15, 10, 160)  0           incresB_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2d (Conv2D)      (None, 15, 10, 192)  221184      red_concat_1[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2d (Conv2D)    (None, 15, 10, 192)  215040      incresB_1b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2dbn (BatchNorma (None, 15, 10, 192)  576         incresB_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2dbn (BatchNor (None, 15, 10, 192)  576         incresB_1b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1b0conv2dact (Activatio (None, 15, 10, 192)  0           incresB_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1b1_3conv2dact (Activat (None, 15, 10, 192)  0           incresB_1b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_1_mixed (Concatenate)   (None, 15, 10, 384)  0           incresB_1b0conv2dact[0][0]
#                                                                  incresB_1b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_1filt_exp_1x1conv2d (Co (None, 15, 10, 1152) 442368      incresB_1_mixed[0][0]
# __________________________________________________________________________________________________
# incresB_1filt_exp_1x1conv2dbn ( (None, 15, 10, 1152) 3456        incresB_1filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_1act_scaling (Lambda)   (None, 15, 10, 1152) 0           red_concat_1[0][0]
#                                                                  incresB_1filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# incresB_2b1_1conv2d (Conv2D)    (None, 15, 10, 128)  147456      incresB_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_1conv2dbn (BatchNor (None, 15, 10, 128)  384         incresB_2b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_1conv2dact (Activat (None, 15, 10, 128)  0           incresB_2b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_2conv2d (Conv2D)    (None, 15, 10, 160)  143360      incresB_2b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_2conv2dbn (BatchNor (None, 15, 10, 160)  480         incresB_2b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_2conv2dact (Activat (None, 15, 10, 160)  0           incresB_2b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2b0conv2d (Conv2D)      (None, 15, 10, 192)  221184      incresB_1act_scaling[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_3conv2d (Conv2D)    (None, 15, 10, 192)  215040      incresB_2b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_2b0conv2dbn (BatchNorma (None, 15, 10, 192)  576         incresB_2b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_3conv2dbn (BatchNor (None, 15, 10, 192)  576         incresB_2b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2b0conv2dact (Activatio (None, 15, 10, 192)  0           incresB_2b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2b1_3conv2dact (Activat (None, 15, 10, 192)  0           incresB_2b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresB_2_mixed (Concatenate)   (None, 15, 10, 384)  0           incresB_2b0conv2dact[0][0]
#                                                                  incresB_2b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresB_2filt_exp_1x1conv2d (Co (None, 15, 10, 1152) 442368      incresB_2_mixed[0][0]
# __________________________________________________________________________________________________
# incresB_2filt_exp_1x1conv2dbn ( (None, 15, 10, 1152) 3456        incresB_2filt_exp_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresB_2act_scaling (Lambda)   (None, 15, 10, 1152) 0           incresB_1act_scaling[0][0]
#                                                                  incresB_2filt_exp_1x1conv2dbn[0][
# __________________________________________________________________________________________________
# x_red2_c31conv2d (Conv2D)       (None, 15, 10, 256)  294912      incresB_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c31conv2dbn (BatchNormal (None, 15, 10, 256)  768         x_red2_c31conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c31conv2dact (Activation (None, 15, 10, 256)  0           x_red2_c31conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c11conv2d (Conv2D)       (None, 15, 10, 256)  294912      incresB_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c21conv2d (Conv2D)       (None, 15, 10, 256)  294912      incresB_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c32conv2d (Conv2D)       (None, 15, 10, 256)  589824      x_red2_c31conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c11conv2dbn (BatchNormal (None, 15, 10, 256)  768         x_red2_c11conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c21conv2dbn (BatchNormal (None, 15, 10, 256)  768         x_red2_c21conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c32conv2dbn (BatchNormal (None, 15, 10, 256)  768         x_red2_c32conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c11conv2dact (Activation (None, 15, 10, 256)  0           x_red2_c11conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c21conv2dact (Activation (None, 15, 10, 256)  0           x_red2_c21conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c32conv2dact (Activation (None, 15, 10, 256)  0           x_red2_c32conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c12conv2d (Conv2D)       (None, 7, 4, 384)    884736      x_red2_c11conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c22conv2d (Conv2D)       (None, 7, 4, 256)    589824      x_red2_c21conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c33conv2d (Conv2D)       (None, 7, 4, 256)    589824      x_red2_c32conv2dact[0][0]
# __________________________________________________________________________________________________
# x_red2_c12conv2dbn (BatchNormal (None, 7, 4, 384)    1152        x_red2_c12conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c22conv2dbn (BatchNormal (None, 7, 4, 256)    768         x_red2_c22conv2d[0][0]
# __________________________________________________________________________________________________
# x_red2_c33conv2dbn (BatchNormal (None, 7, 4, 256)    768         x_red2_c33conv2d[0][0]
# __________________________________________________________________________________________________
# red_maxpool_2 (MaxPooling2D)    (None, 7, 4, 1152)   0           incresB_2act_scaling[0][0]
# __________________________________________________________________________________________________
# x_red2_c12conv2dact (Activation (None, 7, 4, 384)    0           x_red2_c12conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c22conv2dact (Activation (None, 7, 4, 256)    0           x_red2_c22conv2dbn[0][0]
# __________________________________________________________________________________________________
# x_red2_c33conv2dact (Activation (None, 7, 4, 256)    0           x_red2_c33conv2dbn[0][0]
# __________________________________________________________________________________________________
# red_concat_2 (Concatenate)      (None, 7, 4, 2048)   0           red_maxpool_2[0][0]
#                                                                  x_red2_c12conv2dact[0][0]
#                                                                  x_red2_c22conv2dact[0][0]
#                                                                  x_red2_c33conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_1conv2d (Conv2D)    (None, 7, 4, 192)    393216      red_concat_2[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_1conv2dbn (BatchNor (None, 7, 4, 192)    576         incresC_1b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_1conv2dact (Activat (None, 7, 4, 192)    0           incresC_1b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_2conv2d (Conv2D)    (None, 7, 4, 224)    129024      incresC_1b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_2conv2dbn (BatchNor (None, 7, 4, 224)    672         incresC_1b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_2conv2dact (Activat (None, 7, 4, 224)    0           incresC_1b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1b0conv2d (Conv2D)      (None, 7, 4, 192)    393216      red_concat_2[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_3conv2d (Conv2D)    (None, 7, 4, 256)    172032      incresC_1b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1b0conv2dbn (BatchNorma (None, 7, 4, 192)    576         incresC_1b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_3conv2dbn (BatchNor (None, 7, 4, 256)    768         incresC_1b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1b0conv2dact (Activatio (None, 7, 4, 192)    0           incresC_1b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1b1_3conv2dact (Activat (None, 7, 4, 256)    0           incresC_1b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_1_mixed (Concatenate)   (None, 7, 4, 448)    0           incresC_1b0conv2dact[0][0]
#                                                                  incresC_1b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_1fin1x1conv2d (Conv2D)  (None, 7, 4, 2048)   917504      incresC_1_mixed[0][0]
# __________________________________________________________________________________________________
# incresC_1fin1x1conv2dbn (BatchN (None, 7, 4, 2048)   6144        incresC_1fin1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_1act_saling (Lambda)    (None, 7, 4, 2048)   0           red_concat_2[0][0]
#                                                                  incresC_1fin1x1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_1conv2d (Conv2D)    (None, 7, 4, 192)    393216      incresC_1act_saling[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_1conv2dbn (BatchNor (None, 7, 4, 192)    576         incresC_2b1_1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_1conv2dact (Activat (None, 7, 4, 192)    0           incresC_2b1_1conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_2conv2d (Conv2D)    (None, 7, 4, 224)    129024      incresC_2b1_1conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_2conv2dbn (BatchNor (None, 7, 4, 224)    672         incresC_2b1_2conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_2conv2dact (Activat (None, 7, 4, 224)    0           incresC_2b1_2conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b0conv2d (Conv2D)      (None, 7, 4, 192)    393216      incresC_1act_saling[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_3conv2d (Conv2D)    (None, 7, 4, 256)    172032      incresC_2b1_2conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_2b0conv2dbn (BatchNorma (None, 7, 4, 192)    576         incresC_2b0conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_3conv2dbn (BatchNor (None, 7, 4, 256)    768         incresC_2b1_3conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2b0conv2dact (Activatio (None, 7, 4, 192)    0           incresC_2b0conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2b1_3conv2dact (Activat (None, 7, 4, 256)    0           incresC_2b1_3conv2dbn[0][0]
# __________________________________________________________________________________________________
# incresC_2_mixed (Concatenate)   (None, 7, 4, 448)    0           incresC_2b0conv2dact[0][0]
#                                                                  incresC_2b1_3conv2dact[0][0]
# __________________________________________________________________________________________________
# incresC_2fin1x1conv2d (Conv2D)  (None, 7, 4, 2048)   917504      incresC_2_mixed[0][0]
# __________________________________________________________________________________________________
# incresC_2fin1x1conv2dbn (BatchN (None, 7, 4, 2048)   6144        incresC_2fin1x1conv2d[0][0]
# __________________________________________________________________________________________________
# incresC_2act_saling (Lambda)    (None, 7, 4, 2048)   0           incresC_1act_saling[0][0]
#                                                                  incresC_2fin1x1conv2dbn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           incresC_2act_saling[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 2048)         6144        flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 2048)         6144        flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 2048)         6144        flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1049088     batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          1049088     batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 2048)         6144        flatten[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 512)          1049088     batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512)          1536        dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 512)          1536        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          1049088     batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 512)          1536        dense_6[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           32832       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           32832       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 512)          1536        dense_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           32832       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           32832       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 192)          0           dense_1[0][0]
#                                                                  dense_3[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 192)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# Head (Dense)                    (None, 3)            195         dropout[0][0]
# __________________________________________________________________________________________________
# Mouth (Dense)                   (None, 3)            195         dropout_1[0][0]
# __________________________________________________________________________________________________
# Eyes (Dense)                    (None, 2)            130         dropout_2[0][0]
# __________________________________________________________________________________________________
# Total (Dense)                   (None, 2)            386         dropout_3[0][0]
# ==================================================================================================
# Total params: 18,068,202
# Trainable params: 18,018,154
# Non-trainable params: 50,048
# __________________________________________________________________________________________________

# %%
# load label

import os
import numpy as np

def FindFile(path,keyword):

    #path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
    #path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset'

    File = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if (keyword in file) and ("_night_noglasses_mixing_" in file ):
                File.append(os.path.join(r, file))

    #for f in File:
    #    print(f)
    print(np.array(File).shape)
    
    return File

# %%
Head_Testing_AllLabelFile = FindFile('.\Dataset\Training_Evaluation_Dataset\Evaluation Dataset','head.txt')
Eye_Testing_AllLabelFile = FindFile('.\Dataset\Training_Evaluation_Dataset\Evaluation Dataset','eye.txt')
Mouth_Testing_AllLabelFile = FindFile('.\Dataset\Training_Evaluation_Dataset\Evaluation Dataset','mouth.txt')
Total_Testing_AllLabelFile = FindFile('.\Dataset\Training_Evaluation_Dataset\Evaluation Dataset','drowsiness.txt')
Total_Testing_AllLabelFile
# Out:
# (4,)
# (4,)
# (4,)
# (4,)
# ['.\\Dataset\\Training_Evaluation_Dataset\\Evaluation Dataset\\004\\004_night_noglasses_mixing_drowsiness.txt',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Evaluation Dataset\\022\\022_night_noglasses_mixing_drowsiness.txt',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Evaluation Dataset\\026\\026_night_noglasses_mixing_drowsiness.txt',
#  '.\\Dataset\\Training_Evaluation_Dataset\\Evaluation Dataset\\030\\030_night_noglasses_mixing_drowsiness.txt']

# %%
import os
import numpy as np

#path = '.\Dataset\Training_Evaluation_Dataset\Training Dataset\\'
path = '.\Dataset\Training_Evaluation_Dataset\Testing Image'

AllImageFolderTesting = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for directory in d:
        if ("mix" in directory) and ("nightnoglasses" in directory ):
            #print(directory)
            AllImageFolderTesting.append(os.path.join(r, directory))
        
for d in AllImageFolderTesting:
    print(d)
np.array(AllImageFolderTesting).shape
# Out:
# .\Dataset\Training_Evaluation_Dataset\Testing Image\004\004_nightnoglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\022\022_nightnoglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\026\026_nightnoglasses_mix
# .\Dataset\Training_Evaluation_Dataset\Testing Image\030\030_nightnoglasses_mix
# (4,)

# %%
testing_sample = 167168
testing_sample = 9569

# %%
import numpy as np
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import cv2
from math import ceil

from keras.callbacks import EarlyStopping

import random



def LoadImageandLabel(Flag,batch_size,AllVideoImageFolder,Head_AllLabelFile,Mouth_AllLabelFile,Eye_AllLabelFile,Total_AllLabelFile):
    #print(Originalpath)
    count=0
    
    while True:
        LabelFileindex = 0
        

        Face_ImageDataList = []
        
        TotalLabelList = []
        HeadLabelList = []
        EyeLabelList = []
        MouthLabelList = []
        totalcount = 0
        for Originalpath in AllVideoImageFolder:
            #print(Originalpath)
            #=====load all label in a video
            HeadlabelPath = Head_AllLabelFile[LabelFileindex]
            MouthlabelPath = Mouth_AllLabelFile[LabelFileindex]
            EyelabelPath = Eye_AllLabelFile[LabelFileindex]
            TotallabelPath = Total_AllLabelFile[LabelFileindex]
            
            LabelFileindex = LabelFileindex + 1
            
                
            inputfile = open(HeadlabelPath, 'r').read()
            HeadTempLabelList = list(map(int, inputfile))
            inputfile = open(MouthlabelPath, 'r').read()
            MouthTempLabelList = list(map(int, inputfile))
            inputfile = open(EyelabelPath, 'r').read()
            EyeTempLabelList = list(map(int, inputfile))
            inputfile = open(TotallabelPath, 'r').read()
            TotalTempLabelList = list(map(int, inputfile))

            #=====find all files in path=======
            path = Originalpath+"\\face"
            Facefiles = []
            # r=root, d=directories, f = files
            for r, d, f in os.walk(path):
                for file in f:
                    if ".jpg" and 'frame_Middle'in file and (not "ALL" in file):
                        temp = os.path.join(r, file)
                        Facefiles.append(temp)
            
            Facefiles.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
            Facefiles=Facefiles[:-2]
            
            #print(Originalpath)
            #print(len(TempLabelList))
            
            for FileIndex in range(len(Facefiles)):
                #======================load label
                
                index = Facefiles[FileIndex].find('frame_Middle')
                
                framenumber =int(Facefiles[FileIndex][index+12:-4]) 
                                
                HeadLabelarray = to_categorical(HeadTempLabelList[framenumber-1], num_classes=3)
                HeadLabelList.append(HeadLabelarray)
                
                MouthLabelarray = to_categorical(MouthTempLabelList[framenumber-1], num_classes=3)
                MouthLabelList.append(MouthLabelarray)
                
                EyeLabelarray = to_categorical(EyeTempLabelList[framenumber-1], num_classes=2)
                EyeLabelList.append(EyeLabelarray)

                TotalLabelarray = to_categorical(TotalTempLabelList[framenumber-1], num_classes=2)
                TotalLabelList.append(TotalLabelarray)

                #================================
                ImgGray = cv2.imread(Facefiles[FileIndex],0)
                
                #data augmentation
                if((random.uniform(0, 1)>0.5) and Flag == 0):
                    ImgGray = cv2.flip(ImgGray,1)
                    
                ImgGray = ImgGray.reshape(ImgGray.shape[0],ImgGray.shape[1],1)
                

                    
                Face_ImageDataList.append(ImgGray)
               
                count = count +1
                totalcount = totalcount+1
                if count>=batch_size:
                    
                        yield ([np.array(Face_ImageDataList)],
                                                               [np.array(HeadLabelList),
                                                               np.array(MouthLabelList),
                                                               np.array(EyeLabelList), 
                                                               np.array(TotalLabelList)
                                                               ]
                                                               )
                        count=0
                        Face_ImageDataList = []
                        HeadLabelList = []
                        EyeLabelList = []
                        MouthLabelList = []
                        TotalLabelList = []
                        
        print(totalcount)
        #return Face_ImageDataList,HeadLabelList,MouthLabelList,EyeLabelList

# %%
testing_sample = 56123
import tensorflow as tf

#model = tf.keras.models.model_from_json(open('./MultiTask_Model_0821Second.json').read())
#model.load_weights('./MultiTask_Model_0821Second.h5')
model = tf.keras.models.model_from_json(open('.\\Temp\\backup\\MultiTask_Model_11.json').read())
model.load_weights('.\\Temp\\backup\\MultiTask_Model_11.h5')
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

result= model.evaluate_generator(LoadImageandLabel(1,500,AllImageFolderTesting,Head_Testing_AllLabelFile,Mouth_Testing_AllLabelFile
                                          ,Eye_Testing_AllLabelFile,Total_Testing_AllLabelFile), steps=ceil(testing_sample / 500),workers=5,verbose = 1)
# Out:
#   9/113 [=>............................] - ETA: 2:599569
#  28/113 [======>.......................] - ETA: 1:019569
#  47/113 [===========>..................] - ETA: 34s9569
#  66/113 [================>.............] - ETA: 20s9569
#  85/113 [=====================>........] - ETA: 11s9569
# 104/113 [==========================>...] - ETA: 3s9569
# 113/113 [==============================] - 41s 359ms/step

# %%
result
# Out:
# [3.2630833833069106,
#  0.2510061141556532,
#  0.3238416961399372,
#  1.2988374265930882,
#  1.3893981422067365,
#  0.9105562250199142,
#  0.8745274987360897,
#  0.46656449920082504,
#  0.4709997270217157]

# %% [markdown]
# ## Application

# %%
import tensorflow as tf

from tensorflow.keras import Model
#MultiTask_Model_0821_9
model = tf.keras.models.model_from_json(open('.\\Temp\\backup\\MultiTask_Model_11.json').read())
model.load_weights('.\\Temp\\backup\\MultiTask_Model_11.h5')
# Out:
# C:\Users\T-Rex\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def drawtext(image,Head,Mouth,Eyes,Total):
    
    if(Head == 0):
        cv2.putText(image,"Head: Stillness", (400 ,300),font,0.5,color)
    elif(Head == 1):
        cv2.putText(image,"Head: Nodding", (400 ,300),font,0.5,color)
    else:
        cv2.putText(image,"Head: Looking aside", (400 ,300),font,0.5,color)
    
    if(Mouth == 0):
        cv2.putText(image,"Mouth: Stillness", (400 ,320),font,0.5,color)
    elif(Mouth == 1):
        cv2.putText(image,"Mouth: Yawning", (400 ,320),font,0.5,color)
    else:
        cv2.putText(image,"Mouth: Talking & Laughing", (400 ,320),font,0.5,color)
        
    if(Eyes == 0):
        cv2.putText(image,"Eyes: Stillness", (400 ,340),font,0.5,color)
    else:
        cv2.putText(image,"Eyes: Sleepy-eyes", (400 ,340),font,0.5,color)
    #cv2.putText(image,"Eyes:"+str(Eyes), (500 ,340),font,0.5,color)
    
    if(Total == 0):
        cv2.putText(image,"Total: Stillness", (400 ,360),font,0.5,color)
    else:
        cv2.putText(image,"Total: Drowsy", (400 ,360),font,0.5,color)
    return image

# %%
from mtcnn.mtcnn import MTCNN
# import the necessary packages
from imutils import face_utils
import dlib
import cv2
import numpy as np
import os
from operator import itemgetter
import time


eyes_width = 60
eyes_height = 33
mouth_width = 50
mouth_height = 33
face_width = 66
face_height = 85
num_classes = 2
channel = 1

font = cv2.FONT_HERSHEY_COMPLEX
color = (0, 255, 255)

detector = MTCNN()

    
    
#filename = '.\\Dataset\\Training_Evaluation_Dataset\\Evaluation Dataset\\022\\022_noglasses_mix.mp4'
filename = '.\\Dataset\\Training_Evaluation_Dataset\\Training Dataset\\023\\noglasses\\nonsleepyCombination.avi'
#filename = '.\\Dataset\\Training_Evaluation_Dataset\\Training Dataset\\005\\noglasses\\nonsleepyCombination.avi'
print(filename)
cap = cv2.VideoCapture(filename)
Face_ImageDataList = []

missing_frame = 0
DropList = []

eyes_w = eyes_width
eyes_h = eyes_height
face_w = face_width
face_h = face_height
mouth_w = mouth_width
mouth_h = mouth_height
length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(length)
x,y,w,h = 0,0,0,0
frame = -1
Head, Mouth, Eyes, Total = 0, 0, 0, 0

cv2.namedWindow('frame', cv2.WINDOW_AUTOSIZE)
def ChangeFrame(value):
    cap.set(1,cv2.getTrackbarPos('Frame','frame'));

frame_lenth = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
cv2.createTrackbar('Frame','frame',0,frame_lenth,ChangeFrame)

while(cap.isOpened()):

    # load the input image and convert it to grayscale
    ret, image = cap.read()
    frame = frame + 1
    if (not ret):
      break

    start_time = time.time()

    
    height,width = image.shape[:2]
    faces = detector.detect_faces(image)

    if(np.array(faces).shape[0] > 0):
        face = faces[0]
        x,y,w,h = face['box']

        face_image = image[max(0,y):max(0,y+h),max(0,x):max(0,x+w)]
        cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)
        face_image1 = cv2.resize(face_image,(face_w,face_h),interpolation=cv2.INTER_AREA)
        
        face_image1 = cv2.cvtColor(face_image1, cv2.COLOR_BGR2GRAY)
        #print(face_image1.shape)
        Model_input = face_image1.reshape(1,face_image1.shape[0],face_image1.shape[1],1)
        Prob = model.predict(Model_input)
        
        Head = Prob[0].argmax(axis=-1)
        Mouth = Prob[1].argmax(axis=-1)
        Eyes = Prob[2].argmax(axis=-1)
        #print(np.amax(Prob[3]))
        
        if(np.amax(Prob[3])>0.6):
            Total = Prob[3].argmax(axis=-1)
        
        #print(Head, end = ', ')
        #print(Mouth, end = ', ')
        #print(Eyes, end = ', ')
        #print(Total)
        image = drawtext(image,Head,Mouth,Eyes,Total)
        
        
        
    elif (missing_frame<60 and (not((x == 0) or (y == 0) or (w == 0) or (h == 0) ))):
        print ('missing using last frame') 
        missing_frame = missing_frame + 1        

        face_image = image[max(0,y):max(0,y+h),max(0,x):max(0,x+w)]
        cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)
        face_image1 = cv2.resize(face_image,(face_w,face_h),interpolation=cv2.INTER_AREA)
        
        face_image1 = cv2.cvtColor(face_image1, cv2.COLOR_BGR2GRAY)
        #print(face_image1.shape)
        Model_input = face_image1.reshape(1,face_image1.shape[0],face_image1.shape[1],1)
        Prob = model.predict(Model_input)
        
        Head = Prob[0].argmax(axis=-1)
        Mouth = Prob[1].argmax(axis=-1)
        Eyes = Prob[2].argmax(axis=-1)
        #print(np.amax(Prob[3]))
        
        if(np.amax(Prob[3])>0.6):
            Total = Prob[3].argmax(axis=-1)
        
        #print(Head, end = ', ')
        #print(Mouth, end = ', ')
        #print(Eyes, end = ', ')
        #print(Total)
        image = drawtext(image,Head,Mouth,Eyes,Total)
        

    #else:
        


    
    cv2.imshow('frame',image)

    print("FPS: ", 1.0 / (time.time() - start_time))

    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break
    

cap.release()
cv2.destroyAllWindows()
# Out:
# .\Dataset\Training_Evaluation_Dataset\Training Dataset\023\noglasses\nonsleepyCombination.avi
# 2847
# FPS:  0.4146553123539939
# FPS:  23.30868149333689
# FPS:  32.00683739812582
# FPS:  20.023411467035853
# FPS:  23.318270770325565
# FPS:  33.771107425240345
# FPS:  27.446220692453164
# FPS:  24.42909145975666
# FPS:  26.37462585205121
# FPS:  26.711739194120533
# FPS:  27.099188504677727
# FPS:  26.386074396542504
# FPS:  25.7096867127209
# FPS:  27.099188504677727
# FPS:  26.37943634865628
# FPS:  27.099538682207605
# FPS:  24.24971814781196
# FPS:  26.386240390543414
# FPS:  32.00659315502308
# FPS:  32.00708164495624
# FPS:  32.00683739812582
# FPS:  22.46619602129688
# FPS:  25.70952912186929
# FPS:  26.148538368983125
# FPS:  32.00708164495624
# FPS:  32.00732589551441
# FPS:  26.386240390543414
# FPS:  32.00683739812582
# FPS:  32.00708164495624
# FPS:  32.00732589551441
# FPS:  26.386406386632864
# FPS:  26.386904387432843
# FPS:  27.099188504677727
# FPS:  26.386074396542504
# FPS:  29.473009626870915
# FPS:  32.00683739812582
# FPS:  26.090470266235382
# FPS:  38.53677450178704
# FPS:  32.00634891564794
# FPS:  32.00732589551441
# FPS:  32.00732589551441
# FPS:  25.06651048545662
# FPS:  32.00732589551441
# FPS:  32.00732589551441
# FPS:  32.00708164495624
# FPS:  32.00732589551441
# FPS:  25.431738255196333
# FPS:  29.76879400408812
# FPS:  32.00659315502308
# FPS:  32.00683739812582
# FPS:  32.00781440781441
# FPS:  25.70952912186929
# FPS:  32.00708164495624
# FPS:  32.00683739812582
# FPS:  32.00757014980044
# FPS:  32.00757014980044
# FPS:  25.489541172895777
# FPS:  31.439202458586312
# FPS:  32.00708164495624
# FPS:  32.00683739812582
# FPS:  32.00708164495624
# FPS:  25.066660291885302
# FPS:  30.062816267435025
# FPS:  32.00708164495624
# FPS:  32.00805866955639
# FPS:  32.00683739812582
# FPS:  24.812494084240416
# FPS:  31.64437738126674
# FPS:  32.00781440781441
# FPS:  32.00683739812582
# FPS:  32.00708164495624
# FPS:  24.88049448919788
# FPS:  31.645093630698195
# FPS:  32.00732589551441
# FPS:  32.00708164495624
# FPS:  32.00805866955639
# FPS:  24.83835512601857
# FPS:  32.67762594075759
# FPS:  21.338217263676277
# FPS:  32.00634891564794
# FPS:  32.00830293502648
# FPS:  24.831884813034314
# FPS:  33.778994757145504
# FPS:  32.00781440781441
# FPS:  32.00708164495624
# FPS:  32.00757014980044
# FPS:  24.712789149314762
# FPS:  32.00708164495624
# FPS:  32.00708164495624
# FPS:  32.00659315502308
